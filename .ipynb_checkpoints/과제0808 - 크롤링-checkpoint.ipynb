# %% [markdown]
# ## 검색

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from bs4 import BeautifulSoup 
import urllib
import urllib.request as rq
import pandas as pd


global news_df

def News():
    global keyword, num, news_df, url,page_num
    
    keyword = input('검색 키워드를 입력해주세요')
    keyword = urllib.parse.quote(keyword) #퍼센트인코딩 #URL에 문자를 표현하는 인코딩방법(URL에 한글이 섞이면 오류 발생)
    num = int(input('필요한 뉴스기사의 숫자를 입력해주세요'))
    
    news_df = pd.DataFrame(columns=['title','url']) 
    
    page_num=1
    i=0 #크롤링한 기사의 수
    while num > i:
        url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query='+keyword+'&start='+str(page_num)
        html = rq.urlopen(url)
        bs = BeautifulSoup(html,'html.parser')
        texts = bs.find_all(class_='news_tit')

        for text in texts:
            news_df.loc[i,'title'] = text.get_text()
            news_df.loc[i,'url'] = text['href']
            i +=1
            if i == num:
                break
        page_num +=10
    return news_df

News()

# AI
# 1000
# Out:
# 검색 키워드를 입력해주세요AI
# 필요한 뉴스기사의 숫자를 입력해주세요4000
#                                                  title  \
# 0                         KT·서울성모병원, 당뇨 관리 돕는 AI 기술 개발
# 1                         삼성전자, AI인재 키워 반도체·디스플레이 연구한다
# 2                                        삼성전자 ‘AI 챌린지’
# 3                        농정원, 스마트농업 AI 경진대회 개최…총상금 1억원
# 4                        코트라, 'AI 활용'…중견기업 ESG 모니터링 지원
# ...                                                ...
# 3995              미래에셋증권-네이버클라우드, AI·클라우드 기반 서비스 강화 맞손
# 3996    AI로 복잡한 배차관리도 손쉽게…'과로버스'·'졸음운전' 등 노동환경 개선 기...
# 3997  AI 딥테크 스타트업 '코코넛사일로', 사회·환경적 성과 공식 인증 '비콥(B C...
# 3998               SK텔레콤-한국컴퓨터정보학회, AI·메타버스 대학생 인재 키운다
# 3999                    포스텍, 육군과 군사과학기술 발전 협약…AI 드론봇 등
#
#                                                     url
# 0     https://biz.chosun.com/it-science/ict/2022/08/...
# 1           https://zdnet.co.kr/view/?no=20220807083406
# 2     https://www.chosun.com/economy/tech_it/2022/08...
# 3     https://www.yna.co.kr/view/AKR2022080806520000...
# 4     http://www.edaily.co.kr/news/newspath.asp?news...
# ...                                                 ...
# 3995  http://www.s-journal.co.kr/news/articleView.ht...
# 3996  http://www.aitimes.com/news/articleView.html?i...
# 3997  http://www.aitimes.kr/news/articleView.html?id...
# 3998  http://www.fntimes.com/html/view.php?ud=202207...
# 3999  http://www.newsis.com/view/?id=NISX20220714_00...
#
# [4000 rows x 2 columns]

# %% [markdown]
# - 중복값 제거

# %%
news_df1 = news_df.copy()

# %%
news_df[news_df['title'].duplicated() == True] #688중복
# Out:
#                                      title  \
# 10      AI와 대화·이동통신 모니터링…‘고독사 예방’ 팔걷은 지자체들
# 12      KT-NIPA, ICT 벤처에 DX 컨설팅·AI인재 양성 지원
# 18        영진전문대 AI융합기계계열, 로봇관련 학술대회 논문상 수상
# 36                  시 쓰는 AI, 인간에게 던지는 화두는?
# 86                    AI 돌봄 인형…독거 노인 든든한 벗
# ...                                    ...
# 3930           전남교육청, AI활용 수학학습플랫폼 시범학교 운영
# 3931  KT, 다국어 AI 음성합성 서비스 'AI 보이스 스튜디오' 출시
# 3936          뷰노, AI 기반 심전도 분석 기술 국제학술지 게재
# 3962                인텔, 오픈소스 AI 레퍼런스 키트 공개
# 3993                인텔, 오픈소스 AI 레퍼런스 키트 공개
#
#                                                     url
# 10    http://www.munhwa.com/news/view.html?no=202208...
# 12                 http://www.etnews.com/20220808000071
# 18    http://www.newsis.com/view/?id=NISX20220808_00...
# 36    https://www.ytn.co.kr/_ln/0106_202208070606416803
# 86    https://news.kbs.co.kr/news/view.do?ncd=552652...
# ...                                                 ...
# 3930  http://www.m-i.kr/news/articleView.html?idxno=...
# 3931  https://www.ebn.co.kr/news/view/1538917/?sc=Naver
# 3936  http://www.newstomato.com/ReadNews.aspx?no=113...
# 3962  https://www.dailysecu.com/news/articleView.htm...
# 3993  http://www.it-b.co.kr/news/articleView.html?id...
#
# [688 rows x 2 columns]

# %%
news_df=news_df1.drop_duplicates(subset=['title'])
news_df.describe()
# Out:
#                                title  \
# count                           3312
# unique                          3312
# top     KT·서울성모병원, 당뇨 관리 돕는 AI 기술 개발
# freq                               1
#
#                                                       url
# count                                                3312
# unique                                               3312
# top     https://biz.chosun.com/it-science/ict/2022/08/...
# freq                                                    1

# %%
news_df[news_df['title'].duplicated() == True] #688중복
# Out:
# Empty DataFrame
# Columns: [title, url]
# Index: []

# %%
import re
target = news_df['title'].values #Series.values = array
title_list = target.tolist() # array > list
title_list
# Out:
# ['KT·서울성모병원, 당뇨 관리 돕는 AI 기술 개발',
#  '삼성전자, AI인재 키워 반도체·디스플레이 연구한다',
#  '삼성전자 ‘AI 챌린지’',
#  '농정원, 스마트농업 AI 경진대회 개최…총상금 1억원',
#  "코트라, 'AI 활용'…중견기업 ESG 모니터링 지원",
#  'KT-NIPA, ICT 벤처에 DX 컨설팅·AI인재 양성 지원',
#  '영진전문대 AI융합기계계열, 로봇관련 학술대회 논문상 수상',
#  '“일주일내 범죄 발생 예측 정확도 90%” AI 도입 득될까?',
#  'KT, 공감하는 AI로 ‘사람다운’ 로봇 세상 만든다',
#  'AI와 대화·이동통신 모니터링…‘고독사 예방’ 팔걷은 지자체들',
#  '영남중·대구고 SW동아리, MS 주최 AI 경진대회 수상',
#  '현대차 `R&D 경력` 세자릿수 채용… AI 인터뷰 도입',
#  '서울시-KAIST, 기업 내부서 고급 AI개발자 인력 양성하도록 지원',
#  "지금 들어가고 9월까지는 팔아라…AI가 예언하는 '나스닥100'",
#  '남성희 전문대교협회장 "전문대 AI·반도체 전공에 4년제 허용해야"',
#  "[AI-META 시대 '미래전략']<26>교육 대전환",
#  '시 쓰는 AI, 인간에게 던지는 화두는?',
#  '조선대, 프라이버시 보장 AI 기술 공동 개발…동형암호 실용화 기반 마련',
#  '도로교통공단, 빅데이터ㆍAI 기반 위험도로예측 시범서비스 구축',
#  '조선대, 화정중서 ‘AI‧SW 여름방학 아카데미’ 진행',
#  "AI와 영어 말하기 대결…윤선생 '말하톤 대회' 개최",
#  "카카오가 찜한 'AI 아이돌', 뉴스 생방송에서 일냈다…'가상인간' 열풍",
#  '‘땅개’서 ‘AI 무장 호랑이’로… 전투력 초격차로 적 초토화 [S스토리]',
#  '과기정통부, AI 초일류 전략 내놓는다···AI 활용 제고에 방점',
#  'KT, EBS와 AI 인재 육성 맞손',
#  '풍선 속 다이아몬드 찾기…중국 쇼핑몰 아수라장｜AI가 Pick한 세상',
#  "광주시의회, AI 전문가 초청 '인공지능 R&D 발전방향' 공부",
#  "똑똑한 'AI 은행원' 나온다...금융위, 가명정보 AI 데이터로 허용",
#  '동강대\xa0AI\xa0기반 맞춤형 토익 프로그램 실시',
#  'AI가 이젠 시도 쓰고 작곡도 한다…저작권은 어떻게 될까',
#  '김포공항 AI, 반입금지 물품 1초만에 잡는다',
#  '서울시-KAIST, 고급 AI개발자 양성 프로그램 지원',
#  '"AI로 병원 혁신시킨다는 믿음" 네이버 광폭행보',
#  "에이프리카, AI 통합 플랫폼 '치타' 조달청 디지털서비스몰 등록",
#  '세일즈포스·마이크로소프트…전세계 AI기업 한방에 투자',
#  '현대차 연구개발본부, AI활용 대규모 경력직원 채용',
#  "포스코그룹, AI 기술 자문위원회 신설…'미래 전략' 수립 시동",
#  '포스코그룹, \'AI 기술 자문위원회\' 신설…"신사업·인재 발굴"',
#  "괴산군도 합류 … AI 영재고 유치전 `후끈'",
#  "KB증권, 인공지능 기술 적용한 'AI상담 콜봇'",
#  '서천교육청, 미래 시대를 위한 AI 교육 교원 연수 운영',
#  'aT, 농산물 가격 예측 AI 경진대회 개최',
#  '시(詩) 감정선까지 짚어낸 AI...‘무한도전’',
#  '의료기 유통 에이치엔드림, AI영상분석 우경정보기술과 협약',
#  '호남대, 광주발달장애인훈련센터 AI교육과정 자문',
#  '덴마크에 AI정당 등장···2023년 의석 확보 목표',
#  '[Pangyo Tech] 리빌더AI, 가상공간 구축 위해 메가플랜과 맞손... 다량의 실사...',
#  "'모네인 듯, 모네 아닌' AI 그림…예술적 가치 있을까? [아트마켓 사용설명서...",
#  '진천교육청-진천군-카이스트, K-스마트교육 2.0 로봇 AI 영재캠프 개최',
#  '울산대 맞춤형 AI 인력양성과정 수료식 개최',
#  '기보, 신입직원 75명 뽑는다…AI역량검사·블라인드 채용',
#  '[AI·VR·AR, 미래를 연다](9)써니팩토리',
#  "[김주하 AI 앵커와 쉬운 우리말로] '스키드 마크'를 우리말로 하면?",
#  '라이언로켓 X 티그컴퍼니, AI 접목한 새로운 K컬처 선봬',
#  '[포착] 한밤중 극단적 선택 직전, AI가 극적 구조했다',
#  '지질자원연, 제2회 지질자원데이터 활용 AI 경진대회',
#  '키움증권, AI가 고객 투자성향 분석해 자동으로 자산 배분',
#  '[이환주의 아트살롱]AI와 예술 1화: AI가 노벨문학상을 받는다면?',
#  '[삼성화재배 AI와 함께하는 바둑 해설] 수에는 가격이 없다',
#  'DL이앤씨, AI·360도 카메라 기반 현장관리 솔루션 도입',
#  '고위험 수입식품, AI가 차단한다',
#  "GS네오텍, AI 기반 보안 서비스 '사이트 디펜더' 출시",
#  '"딥페이크, 사회·국가적 혼란 초래 우려…AI로 AI 악용 막아야"',
#  '[게시판] KB증권, AI 상담 콜봇 서비스 오픈',
#  'AI 스타트업 ‘마크비전’ 260억 시리즈A 유치 성공 [주간 VC 동향]',
#  '제이엘케이 AI 치매 분석 솔루션, 태국 허가 획득',
#  '포스코 AI기술 자문위원회…산학전문가 20여명 첫 회의',
#  '[데일리 IT 단신] KT-NIPA, ICT 벤처 DX컨설팅·AI인재양성 지원 外',
#  "[특징주]드림어스컴퍼니, 아마존 2조에 아이로봇 인수..AI 로봇청소기 '에이클...",
#  '한양대 ERICA, CEO를 위한 AI 교육과정 신설',
#  'KAIST "반도체·AI 생태계 선도…논문 수 세계 상위권"',
#  'KT-세존, AI·DX기술 기반 방역 산업 분야 협력',
#  'KT-강동경희대병원, AI로봇 활용 병원업무 디지털전환 협약',
#  'KT, EBS와 AI 인재 육성…SW·AI 학습환경 제공',
#  '[특징주]링크제니시스, 정부 AI 산업 원천기술 확보 추진..국내최초 AI 시스템...',
#  "'인공지능(AI) 활용 간담회' 개최",
#  '이영복 제네시스랩 대표 "사람이 갖는 편견…공정한 AI면접에는 없습니다" [시...',
#  'AI 돌봄 인형…독거 노인 든든한 벗',
#  '강기정 광주시장 "여당이 AI반도체 단지 등 현안 힘써달라"',
#  'KB증권, AI 상담 콜봇 서비스 오픈外키움증권 [쿡경제]',
#  '시 쓰고 그림 그리고… 예술영역 넘보는 AI',
#  '가상의 쌍둥이로 내 병 미리 찾아낸다... KT, AI 헬스케어 시스템 개발 착수',
#  '금융에 스며드는 AI…활성화 정책도',
#  "[IR52 장영실상] 삼성전자, '로봇청소기 비스포크 제트봇 AI'",
#  '화성시 새솔동 등 AI 자원회수기기 9곳 시범 운영',
#  "삼성전자·SK하이닉스, AI 반도체로 '초격차 경영 속도'",
#  '빅데이터ㆍAI 활용 고위험 수입식품 선별한다',
#  "'인공지능(AI) 활용 간담회'에서 발언하는 김소영 금융위 부위원장",
#  "아이스크림에듀, '서리풀 샘 AI 스마트 스쿨링' 우수 학습 멘티에 장학금 수여",
#  '괴산군도 AI영재고 유치전 가세…군의회, 건의문 채택',
#  "에듀윌, 공무원 합격진단 'AI-Pass'…예측 서비스 운영",
#  '위메프, 애플 출신 AI전문가 기술책임자로 영입',
#  "롯데정보통신, '보안 AI 모델'로 지능형 위협 차단",
#  '딥브레인AI, 하나은행 앱에 AI은행원 공급',
#  '금융위, 금융분야 AI기술 활성화 나선다',
#  'KOTRA, 중견기업 ESG 위기감지…AI로 관련뉴스 분석 후 제공키로',
#  '빅데이터·AI 기반 위험도로예측 시범서비스 구축',
#  '포스코그룹, AI 기술 자문위원회 신설…신기술·전략방향 조언',
#  '삼성전자, “국내 대학·대학원생 중 AI 최고수는?”',
#  'KT, EBS와 AI 교육 협력…"디지털 100만 인재 양성 기여"',
#  '삼성전자, AI 인력・기술 난제 공모전으로 해결',
#  '영진전문대 AI융합기계계열 학생들, ICROS 2022 학술대회 우수논문상 수상',
#  '현대차, 전동화 등 연구개발 경력 인재 대규모 채용…AI 활용 인터뷰 도입',
#  '괴산군의회, AI 영재고 유치 건의문 채택',
#  "KB증권, 인공지능 기술 적용 'AI 상담 콜봇' 서비스 시행",
#  "삼성전자, 대학·대학원생 대상 '2022 삼성 AI 챌린지' 개최",
#  '위험상황, 폰으로…도로교통공단, ‘AI 기술 활용’ 교통사고 예방 나서',
#  "삼성전자, 제2회 '삼성 AI 챌린지' 개최",
#  '현대자동차, AI로 대규모 R&D 경력 인재 확보 나선다',
#  'KB證, ‘AI 상담 콜봇’ 서비스 오픈',
#  '인공지능 우수 인력 발굴…삼성전자 ‘AI 챌린지’',
#  '호남대,\xa0광주발달장애인훈련센터\xa0AI교육과정 자문',
#  '포스코그룹, AI 기술 자문위원회 신설한다',
#  '포스코그룹, AI 기술 자문위 신설…미래 전략 수립',
#  "KB증권, 'AI 상담 콜봇' 서비스 오픈",
#  "금융 분야 AI기술 키운다…'데이터 라이브러리' 구축(종합)",
#  'KT, EBS와 손잡고 ‘AI 꿈나무’ 육성',
#  "삼성전자, 대학원생 대상 'AI 챌린지'... 신소재 연구·컴퓨터 비전 공모",
#  '포스코그룹, AI 기술 자문위원회 신설',
#  '호남대, 광주발달장애인훈련센터 AI교육 자문',
#  '"초등생도 \'코딩\' 즐기도록"…KT, EBS와 \'SW·AI\' 인재 키운다',
#  "삼성전자, '2022 삼성 AI 챌린지' 개최",
#  '포스코그룹, AI 기술 자문위원회 신설…기술 공유·토론 진행',
#  '현대차, R&D 인력 채용…AI가 면접 본다',
#  '경북교육청, 누구나 가능한 SW-AI교육 기반 마련 확대',
#  "현대차, R&D 경력 인재 세자릿수 채용…'AI 인터뷰 도입'",
#  '맞춤형 AI 인력 양성과정 77명 수료',
#  '"AI반도체 수요 폭발"…삼성전자, 우수인력 발굴',
#  '"100만 디지털 인재 양성"...KT, EBS와 AI·SW 교육 협력',
#  '서울시-KAIST, 기업 AI 인력양성 프로그램 지원',
#  'KT·NIPA, AI·DX 분야 인재양성 MOU 체결',
#  "KB증권 'AI 상담 콜봇' 서비스 시행…24시간 어디서나 상담 가능",
#  "삼성전자, '2022 삼성 AI 챌린지'...인공지능 기반 '신소재 연구'와 '컴퓨터 ...",
#  'KT, EBS와 ‘소프트웨어·AI 미래인재’ 키운다',
#  '금융 AI 개발용 공동 데이터 라이브러리 출범',
#  '인공지능 솔루션 전문기업 리빌더AI, 메가플랜과 가상공간 활용 최적 솔루션 ...',
#  'KB증권, ‘AI 상담 콜봇’ 서비스 오픈',
#  '"인공지능으로 반·디 연구" 삼성전자, \'2022 삼성 AI 챌린지\' 개최',
#  "포스코그룹 'AI 기술 자문위원회' 신설",
#  "금융권 AI 도입 확대되나…금융위 '데이터 라이브러리' 추진",
#  '영진전문대 AI융합기계계열, 제어로봇시스템 재학생 전문대 유일 우수 논문상...',
#  'KT-NIPA, 컨설팅 및 AI·DX 인재양성 업무 협약',
#  'KT, EBS와 AI·SW 인재 양성 위한 교육 콘텐츠 제작',
#  '경북교육청, SW-AI교육 환경개선 사업 확대 실시',
#  "삼성전자, '2022 삼성 AI 챌린지' 개최....AI 우수 인력 발굴과 반도체, 디스...",
#  "거대 금융 정보 저장소 구축...'금융AI 고도화' 첫걸음",
#  '영진전문대, AI융합기계계열 학술대회서 전문대생 유일 우수논문상 수상',
#  'KT, EBS와 AI 인재 육성 협력',
#  'KB증권, AI 상담 콜봇 서비스 개시',
#  '포스코그룹, AI기술 자문위 신설…AI사업분야·인재 발굴 나선다',
#  "경북교육청, 누구나 가능한 'SW-AI교육' 기반 마련",
#  'KT, EBS와 함께 AI 인재 육성한다',
#  "KB증권, AI 음성 상담 서비스 '콜봇' 오픈",
#  '경북교육청, SW-AI교육 환경개선 사업 확대 추진',
#  "농정원, 총 상금 1억 원 규모 '스마트농업 AI 경진대회’",
#  '"신사업·인재 발굴"…포스코그룹, \'AI 기술 자문위원회\' 운영',
#  "동강대, 'AI 산타' 플랫폼 활용 토익 교육 실시",
#  "가명정보 재사용 허용 '금융 AI 데이터 라이브러리' 구축",
#  '포스코그룹, AI기술 자문위원회 신설',
#  'KT, AI로봇 기반 병원업무 DX 추진',
#  "KT, EBS와 함께 'SW·AI 인재' 키운다",
#  "KT-EBS, SW·AI 인재 육성 '한뜻'",
#  '김소영 "금융권도 AI 활성화 필요…빅데이터 확보·제도정비 나설 것"',
#  "KAIST가 'AI 반도체' 주도한다",
#  '설계대로 잘 짓고 있나…AI가 콕 찾아낸다',
#  '포스코그룹, AI기술 자문위 신설…전문가 20명으로 구성',
#  '포스코그룹, AI기술 자문위원회 신설…전문가 20여명 참여',
#  '금융위 "AI로 불필요한 규제 없애고 소비자 편익 높인다"',
#  "화성시, 'AI자원회수기기 설치' 시범운영",
#  "조선대, 화정중서 'AI‧SW 여름방학 아카데미' 진행",
#  "KT, EBS와 함께 'AI 인재' 육성한다",
#  "윤선생, AI 영어 말하기 이벤트 '말하톤 대회' 개최",
#  '포스코그룹, AI와 더 가깝게…AI기술 자문委 신설',
#  '금융AI 활성화 위해 금융·비금융 대규모 컨소시엄 꾸린다',
#  '도로교통공단, AI 기반 교통사고분석시스템 사업 착수',
#  "서울시, KAIST AI 대학원과 협력…'최고급 AI 개발자 양성 교육' 프로그램 지...",
#  "한밤 충무대교 난간 넘어간 40대 'AI 시스템'이 구조했다",
#  "금융권 AI기술 키운다...'데이터 라이브러리' 추진",
#  'KB증권, "AI가 고객에 전화 걸어 상담진행한다"',
#  "'AI 영재고 괴산군 유치 건의문' 채택",
#  "삼성전자 '2022 삼성 AI 챌린지' 개최",
#  "삼성전자, '2022 삼성 AI 챌린지' 개최...대학·대학원생 대상",
#  'KB증권, 인공지능 기술 적용 ‘AI 상담 콜봇’ 서비스 시행',
#  '[게시판] 에프앤가이드·리퍼블릭케이·연세대, AI 업무협약',
#  '[주간VC동향] 인공지능(AI) 스타트업 마크비전 260억원 규모 시리즈A 투자 유...',
#  '‘AI 돌봄 인형’ 독거 노인 든든한 벗',
#  '삼진제약, 사이클리카와 AI 신약개발 공동연구 계약 체결',
#  '韓国の大学・大学院生を対象に「2022サムスンAIチャレンジ」開催',
#  'KT, EBS와 AI 인재 육성 위해 MOU 체결\xa0\xa0',
#  "KB증권, 'AI 상담 콜봇' 서비스 선봬",
#  '"美, AI칩 설계·제조 핵심 소프트웨어 中수출금지 추진"',
#  "AI가 시를 쓴다고?...카카오브레인이 개발한 '시인 AI' 첫 작품 나온다",
#  '‘금융 데이터 도서관’ 만든다… 금융위, ‘금융 AI 혁신’ 박차',
#  '화성시, AI\xa0자원회수기기로 재활용률 높인다',
#  '삼진제약, 신약개발 속도…AI 개발 플랫폼과 협업',
#  'KT, NIPA와 ICT 벤처 육성 및 AI·디지털전환 인재 양성 공동 추진',
#  '"치매예방"…SK케미칼, 36개 기관에 AI기반 인지개선 프로그램 보급',
#  '금융권, 빅테크 진출 위해 AI 활용 활성화 나선다',
#  'KT, EBS와 공교육 내\xa0SW·AI\xa0학습환경 개선 나서',
#  "SK㈜ C&C 'AI 뇌출혈 영상의료 솔루션', 울릉도 환자 돕는다",
#  "리퍼블릭케이·에프앤가이드·연세대, 'AI로 금융시장 연구' 협약",
#  '리빌더AI, 가상공간 구축위해 메가플랜과 MOU 체결',
#  "SK케미칼 '치매예방 AI서비스' 노인센터에 지원",
#  '`금융 AI 데이터 라이브러리` 구축된다…"가명정보 재사용 허용"',
#  'KT, EBS와 SW·AI 학습환경 제공 위한 MOU 체결',
#  'KB증권, AI 상담 콜봇 서비스 오픈',
#  '인공지능으로 미래가치 높인다…포스코그룹, AI 기술 자문위원회 신설',
#  "KB증권, 시간·장소\xa0제약없이 'AI 상담' 받는다",
#  "DL이앤씨, AI·360도 카메라 기반 현장관리 솔루션 '디비전' 도입",
#  "SK C&C, 울릉군보건의료원에 'AI 뇌출혈 영상 의료 솔루션' 공급",
#  'KT, EBS와 AI 인재 키운다…100만 디지털 인재 양성 기여',
#  "자율주행 시스템용 AI 스타트업 '퍼셉티브 오토마타' 좌초",
#  "시드투자…의료 AI 로봇 '코넥티브'·푸드헬스 '마음영양'",
#  '경북교육청, 누구나 가능한 SW-AI교육 기반 마련',
#  '괴산군의회 "AI 영재고 유치 생존 문제"…건의문 채택',
#  "포스코그룹, AI 기술 자문위원회 신설… '학계위원회' 킥오프 미팅",
#  'AI 신약개발, ‘빨리빨리’ 안되는 이유 있다…“정확도⋅상업성에 초점 맞춰...',
#  "KB증권, 고객 편의 증대 위한 'AI 상담 콜봇' 서비스 오픈",
#  'KT, S/W·AI 인재 육성 위해 EBS와 맞손',
#  '포스코, AI기술 자문위원회 신설… 트렌드 공유·미래사업 조언',
#  'KAIST, AI 반도체 생태계 선도...관련 세계 학회 종횡무진',
#  'SK㈜ C&C, 울릉군보건의료원에 AI 뇌출혈 판독 솔루션 공급',
#  '"충무대교 배회하면 수상해"…통영시 AI로 자살시도자 구조',
#  'AI가 설명도 한다고?',
#  '울산대, 맞춤형 AI 인력양성과정 수료식',
#  '[AI 주간 브리핑] 신기방기 AI모델들, 인기몰이 중 \xa0 \xa0\xa0',
#  "AI·우주 분야 등 전문가 한 곳에?···대전시, '월드포럼' 개최",
#  '충북 4개 시·군 AI영재고 유치전 후끈…의회도 가세',
#  '포스코그룹, AI기술 자문위원회 신설로 "체계 구축"',
#  '김소영 부위원장 "빅데이터·AI 활용 지원…금융규제 혁신"',
#  '금융위 부위원장 “금융권 빅데이터·AI 활용 위해 규제 혁신”',
#  '포스코그룹, 전문가 20여명 참여한 AI 기술 자문위원회 신설',
#  '파수, 비식별 솔루션에 AI 기술 탑재…“분류 정확도 강화”',
#  'SK케미칼, 치매 해결 위한 AI기반 인지개선 프로그램 보급 시작',
#  '현대차 연구개발본부, 대규모 경력R&D 인재 모집!... AI 활용 화상 인터뷰 적...',
#  '괴산군의회 "괴산에 \'AI 영재고\' 유치해야" 결의문 채택',
#  '포스코그룹, AI 기술 자문위원회 신설...AI분야 학계, 산업계 전문가 20명으로...',
#  '스타트업 손잡은 교육업계…AI 기술 도입 에듀테크 강화',
#  '[농정춘추] 단순농작업 혁신 위한 AI 로봇 개발과 보급 필요성',
#  '이글루, KISA 사이버보안 AI 데이터셋 구축 사업 수주',
#  "삼성전자, AI 인재 발굴·연구 위한 경연장 '삼성 AI 챌린지' 개최",
#  "'가명정보 재사용' AI 데이터 라이브러리 구축",
#  '금융당국, AI데이터 라이브러리 구축 추진',
#  "카카오 AI, '시'도 쓴다",
#  "AI 적극 활용하는 포스코그룹... 스마트 제철소 이어 'AI 기술 자문위' 신설해...",
#  "DL이앤씨, 국내 최초 AI·360도 카메라 기반 현장관리 솔루션 '디비전' 도입",
#  '금융위 "빅데이터·AI 활용 지원…금융규제 혁신"',
#  '전북교육청, AI기반 학생맞춤형 수업 전체 학교로 확산',
#  '떨어지는 글쓰기 능력…AI가 작문 훈련 돕는다',
#  "세종충남대병원, 대화형 메신저 'AI 챗봇' 서비스 오픈",
#  '[Tech in Trend] 개인정보 침해 우려 줄이는 AI 알고리즘, 연합학습',
#  "인기 애니 '귀멸의 칼날' 속 캐릭터들을 'AI'로 현실세계에 소환하자 보인 실...",
#  'KB證, AI 상담 콜봇 서비스 오픈',
#  '삼성전자, \'2022 삼성 AI 챌린지\' 개최..."AI 우수 인력 발굴, 반도체, 디스플...',
#  '한줄? 두줄? 애매한 임테기…AI는 안다 99.9% 확률로',
#  '삼진제약, 캐나다 사이클리카와 AI 신약개발 공동연구 계약',
#  '포스코그룹, AI 분야 전문가 20명으로 ‘AI 기술 자문위원회’ 신설',
#  "딥브레인AI, 하나은행 하나원큐에 'AI뱅커' 공급",
#  'DL이앤씨, AI 360도 카메라 기반 ‘디비전’ 도입',
#  '건강하고 안전한 생활 공간을 위해 … KT, ㈜세존과 AI/DX기술 기반 방역 산업...',
#  '3D 모델링 AI 솔루션 전문기업 리빌더AI, 메가플랜과 MOU 체결',
#  '\xa0‘AI 뇌출혈 영상 의료 솔루션’으로 울릉도 응급환자 돕는다',
#  'KT, EBS와 함께 AI 인재육성 나선다',
#  'DL이앤씨, 국내 첫 AI·360도 카메라 기반 현장관리 솔루션 도입',
#  '"AI반도체 집적단지 조성 등 힘 모으자"',
#  "금융위, 가명정보 재사용하는 'AI 데이터 라이브러리' 구축",
#  '인포텍코퍼레이션, 세액공제 AI솔루션 출시',
#  '"언제든 신속 상담 가능"...KB증권, ‘AI 상담 콜봇’ 서비스 오픈',
#  '포스코, AI 기술 자문위 신설 … 학계·산업계 두 분야로 운영',
#  "SK케미칼, AI 인지개선 '사운드마인드' 노인보호센터 보급",
#  '포스코그룹, AI 기술 자문위원회 첫 회의',
#  '식약처, AI로 위험 수입식품 잡는다',
#  '에프앤가이드·리퍼블릭케이·연세대, AI 금융투자 연구 나선다',
#  "더핑크퐁컴퍼니-AI 네트워크, '핑크퐁 아기상어' NFT 전시",
#  "에듀윌, 인공지능 합격비서 'AI-Pass' 추진…AI 합격진단 예측 서비스 선오픈",
#  "KB증권, 'AI 상담 콜봇' 서비스 개시",
#  '이제 AI컴퓨터비전과 360도 카메라로 건설현장 관리한다',
#  '‘의사만큼 똑똑한’ 뇌출혈 전문 AI 의사, 이번엔 울릉도로 향한다',
#  'GS네오텍, AI 기반 보안솔루션 서비스 ‘사이트디펜더’ 출시',
#  "'치매' ESG 나선 SK케미칼… AI 인지개선 프로그램 보급",
#  "[단독] n번방 사건 뒤 'AI 탐지' 도입했지만…이름값 '글쎄'",
#  "시(詩) 쓰는 카카오 AI '시아', 첫번째 시집 '시를 쓰는 이유' 출간",
#  '괴산군의회 "AI 영재고 유치는 지역 생존 문제"…건의문 채택',
#  '[포토] KT, EBS와 SW·AI 학습환경 제공 MOU',
#  '한밤중 대교 위 왔다갔다…극단적 선택 직전 AI가 구조했다',
#  '방문요양 스타트업 케어링, 네이버와 손잡고 AI 돌봄 서비스 박차',
#  "KB증권, 'AI 상담 콜봇' 서비스 오픈…연내 적용범위 확대 [증권오늘]",
#  '포스코그룹, AI 기술 자문위 신설',
#  '조선대, ‘AI·SW 여름방학 아카데미’ 성료',
#  '중기부, 194억 투입 AI로봇 등 154개 기업 지원',
#  'DGIST 창업기업 ㈜유니바, AI학습용 데이터 구축 지원사업 선정',
#  '포스코그룹, AI 기술자문위원회 신설',
#  '삼진제약, 캐나다 AI 기업과 신약개발 공동연구',
#  "금융위, AI 활용 활성화한다…'금융 AI 데이터 라이브러리' 구축",
#  "롯데정보통신, '시큐파이 SOC'에 보안 AI 모델 적용",
#  '화성시, AI자원회수기 새솔동 9군데 설치 운영',
#  "KT, EBS와 '맞손'…소프트웨어(SW)·인공지능(AI)\xa0학습환경 제공",
#  '금융위 "금융권 공유 AI 데이터 라이브러리 구축 지원"',
#  '에듀윌, 공무원 수험생 대상 AI 합격진단 서비스 오픈',
#  'KT·EBS, 디지털 인재 양성 \'맞손\'···"AI 학습환경 제공"',
#  "SK(주) C&C, 울릉군보건의료원에 'AI 뇌출혈 영상 의료 솔루션' 공급",
#  '[동아광장/이성주]책임감 있는 AI',
#  '\'금융 AI 데이터 라이브러리\' 구축···"가명정보 재사용 허용"',
#  '경북교육청, SW-AI교육 환경개선 사업 확대',
#  '포스코그룹, AI 기술 자문위 신설···각계 전문가 20명 구성',
#  'KT 대구경북본부, 라마다 문경새재에 AI호텔 서비스 제공',
#  '화성시 , 재활용 AI자원회수기 설치',
#  'KB증권, ‘AI 상담 콜봇’ 서비스 오픈... “신속한 상담 가능”',
#  'SK케미칼, 36개 기관에 AI 기반 인지개선프로그램 보급',
#  'KT, EBS와 소프트웨어·AI 인재 육성한다',
#  '금융위,\xa0금융분야 AI 활성화 나선다…"가명정보 재사용 허용"',
#  "에듀윌, 인공지능 합격비서 'AI-Pass'로 에듀테크 입지 강화",
#  'AI로 위조상품 꽉 잡는 마크비전, 260억원 투자 유치',
#  'SK㈜ C&C, 3시간 골든타임 잡는 ‘AI 뇌출혈 솔루션’ 울릉도에 공급',
#  '딥노이드, AI 기반 흉부 엑스레이 진단 논문 국제학술지 게재',
#  'SK㈜ C&C의 CT분석 AI가 울릉도 응급진료 돕는다',
#  'AI가 쓴 시집 나온다',
#  "리빌더AI-메가플랜, 가상공간 구축위해 모델링 전문 기업 '맞손'",
#  'AI가 내 대출 심사, 어떻게 믿지?',
#  '금융위 "금융권 빅데이터 AI 활성화 위해 규제 혁신"',
#  "이글루코퍼레이션, KISA '보안 AI 데이터셋' 구축 사업 수주",
#  'AI영재고 유치전 괴산군도 가세…군의회 건의문 채택',
#  "멋쟁이사자처럼, 데이터 분석가 양성 'AI 스쿨' 29일까지 모집",
#  'AI인재가 없는 이유 "코딩 몇 줄로 답 내는 게 아니라 기본원리 아는 인재 필...',
#  "DL이앤씨, AI·360도 카메라 기반 현장관리기법 '디비전' 도입",
#  "KB증권, 'AI 상담 콜봇' 서비스 시행",
#  'AI 은행원이 대출 심사까지…"금융빅데이터·AI활용 막는 규제 혁신"',
#  'GS네오텍, AI 기반의 보안솔루션 서비스 ‘사이트디펜더’ 출시',
#  'KAIST “반도체·AI 생태계 선도…논문 수 세계 상위권”',
#  '금융 AI 활성화 추진…데이터 라이브러리 만든다',
#  "'농산물 가격 예측 AI 경진대회’ 개최",
#  'SK케미칼 "고령층에 AI 치매예방 프로그램 보급합니다"',
#  '포스코그룹, AI 기술 자문위원회 신설..."진화하는 AI신기술·전략 방향 조언...',
#  'KT, AI 식이·인슐린 솔루션 디지털 트윈으로 당뇨 관리',
#  "2022년\xa0말,\xa0AI\xa0보안성\xa0검증체계\xa0위해\xa0'AI\xa0보안\xa0가이드라인'\xa0마련",
#  '10년째 2400억 비트코인 찾는 영국男…"AI·로봇 사용해 수색"',
#  "SK C&C, 골든타임 잡는 'AI 기반 뇌출혈 솔루션' 울릉도 공급",
#  'KT-강동경희대병원, AI 로봇 의료서비스 개발 협약 맺어',
#  '1만3000여편 읽으며 작법 익혀…시 쓰는 카카오 AI',
#  'AI 학습속도 4.5배↑…스마트폰 과부하 막는다',
#  '의료 AI 로봇기업 ‘코넥티브’, 시드 투자 유치',
#  'KB국민銀, AI기술 적용 기업여신 자동심사 시스템 구축',
#  '한밤중 대교 위 서성여…극단적 선택 직전 AI가 구조',
#  "'큰 글씨에 AI 자막'… 저축은행, 금융 취약층 맞춤 디지털 서비스",
#  "aT, '농산물 가격 예측모형 개발' AI 경진대회 연다",
#  '포스코그룹, AI 기술 자문위원회 신설…AI분야 학계 등 20명 구성',
#  '금융위, 금융분야 AI 활성화 나선다…"규제 적극 해소"',
#  "카카오브레인, '시 쓰는 AI' 내놨다…시집도 출간",
#  '시, 그림, 작곡까지 ‘뚝딱’…“AI, 넌 못하는 게 뭐니?”',
#  'SK C&C, 울릉군보건의료원에 AI 뇌출혈 판독 솔루션 공급',
#  "KB증권 'AI 상담 콜봇' 서비스…담보부족 등 자동 안내",
#  '포스코, AI기술 자문위원회 신설...첫 회의 개최',
#  '루이비통도 고객…AI로 위조상품 막는 마크비전, 260억 투자 유치',
#  '"AI가 유전도 뚫는다…전환기 에너지기업은 변신중" [실리콘밸리 인사이드]',
#  '딥노이드, AI 솔루션 활용한 폐질환 탐지 유용성 입증',
#  "[#IT라운지] 통신 4사 '업무협약'·SK C&C 'AI의료솔루션' 제공",
#  '스마트폰 위 ‘AI 연합학습 속도’ 4.5배 늘리는 기법 개발',
#  '루닛, 임상시험서 AI 치료 효과 확인에 주가 급등',
#  '포스코그룹, AI사업분야ㆍ인재 발굴 나선다',
#  "팜캐드, '바이오플러스·인터펙스'서 AI 약물개발 성과 등 발표",
#  "SK C&C 'AI 뇌출혈 영상 진단'…울릉도 응급환자 돕는다",
#  "한국농수산식품유통공사, '농산물 가격 예측 AI 경진대회' 개최",
#  '롯데정보통신, 보안 AI로 지능형 위협 차단',
#  '기보, 신입 공채…표절 여부 AI로 거른다',
#  "투디지트, AI 기반 뉴스 추천·분석 정보 제공 서비스 '뉴스샐러드' 개발",
#  '정부, 가명정보 재사용 허용 ‘금융 AI 데이터 라이브러리’ 구축한다',
#  '통영시, AI 딥러닝 기술로 ‘극단적 선택’ 막았다',
#  'AI가 개발하는 신약, 어디까지 왔나…"수요 맞춰 다양한 방식 분화"',
#  'KT, EBS와 함께 AI 인재 육성..."소프트웨어·인공지능 학습환경 제공을 위한...',
#  '오산시, AI로 CCTV 관제…범죄 예방 효과 기대',
#  '포스코그룹, AI 기술 자문위원회 신설…AI분야 산·학 전문가 20명 구성',
#  '삼진제약, 캐나다 사이클리카와 AI 신약개발 공동연구 계약 체결',
#  '금융권 "금융 AI 활성화, 소비자 편익 제고 기대"',
#  '허송연 아나, 은행원 됐다?…"AI휴먼 모델 계약후 AI뱅커로 활약"',
#  '화성시, AI 자원회수기기 9개소 시범운영',
#  '세종충남대병원, AI 챗봇 서비스 오픈',
#  '금융권 AI 빅데이터 적극 활용 돕는다',
#  "식약처, AI 활용한 '위험예측 기반 검사·관리 시스템' 구축 추진",
#  'SK㈜ C&C, ‘AI 뇌출혈 영상 의료 솔루션’으로 울릉도 응급환자 돕는다',
#  'KB증권, ‘AI 상담 콜봇’ 서비스 개시···담보부족·해외주식 배당옵션 등...',
#  '금융위, 디지털 금융혁신…빅데이터-AI 활용 활성화한다',
#  '‘AI 반도체’ 기술패권 전쟁시대…KAIST ‘초격차기술’ 확보 나선다',
#  '반도체·AI·빅데이터 등 석박사 증원 쉬워져···개정안 국무회의 통과',
#  "메타AI, 최신 AI 챗봇 '블렌더봇3' 소개",
#  "에프앤가이드·리퍼블릭케이·연세대, 'AI 활용한 금융 시장 연구' MOU 체결",
#  '조선대 지역사회 중학생 AI·SW교실 임무 완수',
#  '김소영 부위원장 "금융규제 혁신해 빅데이터·AI 활성화해야"',
#  "포스코그룹, 'AI기술 자문위원회' 신설...인공지능 분야 학계, 산업계 전문가...",
#  "KB증권 'AI 상담 콜봇' 서비스 오픈",
#  '롯데정보통신, 보안 AI 모델로 지능형 위협 차단',
#  'KT, EBS와 함께 AI 인재 육성 협력',
#  "DL이앤씨, AI·360도 카메라 활용 현장관리 솔루션 '디비전' 도입",
#  '‘예술’ 영역 넘보는 인공지능…시 쓰고 그림 그리는 초거대AI',
#  "멋쟁이사자처럼, 데이터 분석가 양성 과정 'AI 스쿨' 모집",
#  "영진전문대 'AI융합기계계열 학술대회 논문상' 수상",
#  "딥브레인AI, 하나은행 모바일 앱에 'AI 휴먼' 공급",
#  '김소영, "디지털 금융규제 혁신…빅데이터·AI 활용 지원"',
#  'SK하이닉스, AI·빅데이터 연산에 최적화한 CXL 메모리 첫 샘플 개발',
#  "KB증권, 'AI 상담 콜봇' 서비스 시작...24시간 상담 가능",
#  "헷갈리는 '임테기' 결과 AI가 알려준다…NHN에듀, 서비스 출시",
#  "조선대 김영식 교수, 서울대 및 대구경북대 연구팀과 '프라이버시 보장 AI 기...",
#  'SK케미칼 등 3사, AI 치매예방 프로그램 보급···"사회적 가치 창출"',
#  '“300회 이상 실증, AI와 위성, 암호통신까지…UAM 경쟁사보다 우위”',
#  'SK케미칼, AI기반 인지개선 프로그램 노인보호센터 보급',
#  "AI 기반 무릎관절 수술 '코넥티브', 카카오벤처스 시드투자 유치",
#  'SK케미칼, AI 인지개선 프로그램 보급…치매 예방 앞장',
#  '스마트폰 위 AI 연합학습 속도 4.5배 높여 과부하 막는다',
#  '“AI가 이런 것까지?”‥KB증권, ‘AI 상담 콜봇’ 서비스 선봬',
#  '[인터뷰] 김제민 연출 "시 쓰는 AI 작가 \'시아\'는 질문 품은 공동 창작자"',
#  'SK㈜ C&C ‘AI 영상 의료 솔루션’ 울릉도에 공급',
#  "카카오브레인, 시쓰는 AI '시아' 시집 출간",
#  '이글루코퍼레이션, KISA 사이버보안 AI 데이터셋 사업 수주',
#  '“삼성·LG, 고객 목소리 들어야…” 글로벌 AI 고객경험 분석 CEO가 던진 말...',
#  '통영 충무대교 난간 넘던 40대 AI가 구해',
#  '제이엘케이, AI 기반 뇌 노화 분석 솔루션 태국 허가 획득',
#  '카카오 AI, 시인으로 데뷔한다…"시를 쓰는 이유" 8일 출간',
#  '삼진제약, 캐나다 `사이클리카`와 AI 신약개발 공동연구 계약 체결',
#  'SK㈜ C&C, AI 뇌출혈 검사 솔루션 울릉도 공급',
#  'AI로 공공SW사업 제안요청서 작성 불편 해결',
#  '경북교육청, 누구나 가능한 SW-AI 교육 기반 마련',
#  '의료 AI 로봇 기업 코넥티브, 카카오벤처스 시드 투자 유치',
#  'SK㈜ C&C, 울릉군보건의료원에 AI 뇌출혈 영상 의료 솔루션 공급',
#  '스마트뱅킹에 AI 휴먼이?',
#  '딥브레인AI, 하나은행 모바일 앱에 AI 뱅커 공급',
#  'KB증권 " \'AI상담 콜봇\' 서비스 시행...고객 편익 증대"',
#  '금융분야 AI 경쟁력 키운다…관련 제도·규제 혁신',
#  '조달청 AI기반 SW사업 발주지원시스템 도입…제안요청서 자동생성',
#  "AI 물류 스타트업 '바이너리브릿지' 44억 규모 프리A 투자 유치",
#  '"해외 우수 인재 모신다" 현대차, AI·자율주행 박사 국내 초청 채용',
#  '롯데정보통신, 보안 AI로 고도화된 사이버위협 대응',
#  "DL이앤씨, AI‧360도 카메라 기반 현장관리 솔루션 '디비전' 도입",
#  '화성시 AI 자원회수기기로 재활용률 높인다',
#  "KT 인공지능 교육서비스 '코디니', EBS 교육플랫폼 '이솦'에 탑재...AI·SW\xa0...",
#  '금융위, 금융분야 AI 데이터 라이브러리 구축',
#  '위험한 수입식품, AI로 판별한다',
#  'SK케미칼·SK바이오사이언스·SK플라즈마, AI로 치매 해결 시도',
#  '에듀윌, 인공지능 합격비서 ‘AI 패스’ 만든다',
#  '"시를 쓴다는 건, 세상에서 가장 짧은 말을 하는 것"..AI가 쓴 서시',
#  'SK케미칼, 치매 예방 활동 펼친다…노인센터에 AI 기반 인지개선프로그램 보급',
#  '‘쿨투라cultura 8월호’ K-콘텐츠의 AI 활용 전망을 탐색하다',
#  '조달청, AI기반 공공SW사업 발주지원시스템 개통',
#  "딥브레인AI, 하나은행 모바일 앱에 'AI 뱅커' 공급",
#  'SK㈜ C&C, AI 뇌출혈 영상기술로 울릉도 환자 돕는다',
#  "DL이앤씨, 국내 최초 AI·360도 카메라 현장관리 솔루션 '디비전' 도입",
#  '화성시, AI 자원회수기기로 재활용률 높인다',
#  '국민은행, AI 기술 적용 기업여신 자동심사 시스템 구축',
#  '삼진제약, 캐나다 사이클리카와 AI 신약개발 공동연구',
#  '카카오브레인, 초거대 AI 언어 모델 ‘KoGPT’ 활용 시집 출간',
#  "하나은행, 모바일 앱 내 'AI뱅커' 도입",
#  '딥노이드, "AI솔루션 폐질환 위치 탐지 입증… 국제학술지 게재"',
#  '메디웨일 "망막 검사로 심혈관질환 예측하는 AI 의료기기 허가"',
#  '트윔, 에너지 산업 분야 50억원 규모 AI 검사 프로젝트 수주',
#  "SK㈜ C&C, 울릉도보건의료원에 'AI 뇌출혈 영상 의료 솔루션' 공급",
#  '삼진제약, AI 신약개발 플랫폼사와 공동연구 계약',
#  '"국방과학기술의 첨단화"…정부, AI·로봇·UAM 활용 국방 R&D 강화',
#  '"美, 中에 AI 반도체 설계·제조 핵심 소프트웨어 수출 금지 추진"',
#  '포스코그룹, AI 기술 전문가 모아 자문위원회 신설',
#  "[초점] 메타 경영진, 새로 발표한 최첨단 AI 때문에 '난감'",
#  'AI 기반 인지개선 프로그램… 노인보호센터 통해 보급',
#  "스마트폰 위 AI '연합학습' 속도 4.5배 달성...KAIST, 새로운 가속 기법 개발",
#  '"AI신약개발, 속도보다 정확도…상업화 위한 맞춤형·차별화 필요"',
#  'DL이앤씨, AI기반 360도 카메라 건설현장 도입..공기 단축 효과',
#  '김소영 금융위 부위원장 "AI 기술 고도화 필수적"',
#  '금융위, 가명 금융정보 재사용 허용...금융 AI 데이터 라이브러리 구축',
#  '"AI로 골든타임 지킨다"…SK C&C, 울릉도에 \'AI 뇌출혈 판독 솔루션\' 공급',
#  "파수, 개인정보 비식별 솔루션 'ADID'에 AI 기술 탑재",
#  '삼진제약, 캐나다 AI 업체와 신약 개발 나선다',
#  'KT-강동경희대병원, AI 로봇 활용 병원 업무 디지털 전환 협력',
#  "의료 AI 로봇기업 '코넥티브', 시드 투자 유치",
#  "파수, 비식별 솔루션 '애널리틱디아이디'에 AI 기술 탑재",
#  '"여성 언더웨어도 이젠 AI시대"...AI맞춤형 속옷추천앱 ‘퍼펙트핏’ 눈길',
#  '"우린 늘 1등" 카이스트, 반도체·AI 연구 성과 발표',
#  '"발주도 입찰도 어려운 공공SW사업, AI기술이 도와드려요"',
#  'SK케미칼, AI 인지개선프로그램 보급 통해 치매 예방 나선다',
#  '스마트폰 AI 연합학습 속도, 4.5배 빨라진다',
#  '카카오 AI, 그림 이어 시도 쓴다',
#  "[굿모닝충북] 한 끼 밥도 못 챙기면서 'AI영재고' 타령 빈축",
#  '“충무대교 위 수상한 움직임 포착” 통영시 AI, 투신 시도자 구했다',
#  "'6천억 시장' 음식물처리기…똑똑해야 팔린다 'AI 무장'",
#  'KAIST, AI 반도체 생태계 이끈다',
#  'KT, 채용연계형 AI 석사과정 신입생 모집',
#  '장성군,인공지능(AI)말동무 인형 지원사업 추진',
#  'SK㈜ C&C, AI 뇌출혈 영상 의료 솔루션 공급 확대',
#  'DL이앤씨, AI·360도 카메라 활용해 현장관리 효율 극대화',
#  '2400억 비트코인 찾으려 9년째 쓰레기장 맴도는 남성…"AI·로봇으로 수색"',
#  "\xad AI 모델 '연합학습' 속도 빨라진다",
#  '괴산군의회 "AI영재고, 괴산 유치해야"',
#  'DGIST 학부생 창업기업, AI 학습용 데이터 구축 지원사업 선정',
#  '美 애플 AI개발 이진호 박사 위메프, 최고기술책임자 영입',
#  'SK C&C, AI로 울릉도 응급환자 돕는다',
#  '"반도체·AI 생태계 선도"',
#  '포항공대, AI 경영자 양성을 위한 최고경영자과정 신설',
#  '삼진제약-사이클리카 ‘AI 신약개발 공동연구’ 계약',
#  '충남도, AI학습용 ‘종패 생산 데이터’ 구축',
#  '기보, 2022년도 신입직원 75명 채용... AI 빅데이터 기반 검사 실시',
#  "이글루코퍼레이션, 'KISA 사이버보안 AI 데이터셋' 사업 수주",
#  'KB국민은행, AI활용 다각화 나선다',
#  "DL이앤씨, AI·360도카메라 기반 현장관리기법 '디비전' 도입",
#  '금융위, AI 활용 디지털 금융혁신 돕는다..‘AI 데이터 라이브러리’ 구축',
#  '괴산도 AI영재고 ‘유치전’ 가세…군의회, 건의문 채택',
#  '카이스트 “반도체·AI 생태계 선도…논문 수 세계 상위권”',
#  '통영 충무대교 난간 넘은 40대 `AI`가 구조',
#  'AI기반 학생맞춤형 수업 전체 학교로 확대 모색',
#  '괴산군의회, AI 영재고 유치 건의문',
#  'KT AI 호텔, 라마다 문경새재 호텔에 들어선다',
#  "에듀윌, 인공지능 비서 'AI-Pass' 공개",
#  "[재택플러스] '무인'점포 범죄‥'AI'기술 도입",
#  '英, 운전중 핸드폰 사용 단속하는 AI 감시 차량 운영',
#  'SK㈜ C&C, 울릉군보건의료원에 AI 뇌출혈 검사 솔루션 공급',
#  '포스코그룹, AI 전문가 목소리 듣는다',
#  'DL이앤씨, AI·360도 카메라 기반 현장관리 솔루션 ‘디비전’ 도입',
#  'CJ올리브네트웍스, AI 인재 양성 박차',
#  '코트라, 중견기업 ESG 이슈 모니터링 서비스…“AI로 분석해요”',
#  '경상국립대 AI융합인재교육연구단, 지자체 네트워킹 및 협력강화 워크숍',
#  '팜캐드, AI 신약개발 플랫폼 성과 공개',
#  '형형색색 두둥실…미국서 열기구 축제｜AI가 Pick한 세상',
#  '금융 AI 데이터 라이브러리 구축…금융위 "금융규제 혁신"',
#  '보은군의회, AI영재고 유치 촉구',
#  'AI·360도 카메라 기반 현장관리 솔루션...DL이앤씨, 이스라엘社 손잡고 전격...',
#  '블로그 | 클라우드 기반 AI/ML이 온프레미스로 돌아오는 이유',
#  '"나랑 게임 한판 할래?"...친구 아닌 AI가 하는 말이었다',
#  '경북교육청, SW-AI교육 환경개선 사업 시행',
#  '금융위, “금융권 AI 활성화 적극 지원”',
#  '파수, 비식별 솔루션 ‘애널리틱디아이디’에 AI 기술 탑재',
#  '개인정보 유출 없다···스마트폰 AI기술 4.5배 ↑\xa0',
#  '포스코, AI 기술 자문위원회 신설…신기술·미래 전략 조언',
#  "괴산군의회 'AI 영재고 괴산군 유치 건의문' 채택",
#  '삼성, AI·ML에 최적화된 차세대 메모리 솔루션 대거 공개',
#  "인공지능 합격비서가 공무원 수험생에게 합격 진단해주는 에듀윌 'AI-Pass'",
#  "KAIST, 반도체와 AI 핵심 기술력으로 '인공지능 반도체 '생태계 선도한다",
#  '고려대 법학전문대학원, 데이터·AI 전문 과정 개설',
#  '누구나 고흐처럼 그릴 수 있다… AI만 있다면',
#  'SK C&C, 울릉군보건의료원에 AI기반 영상 의료 솔루션 ‘메디컬 인사이트 플러...',
#  'LG전자·美 사운드하운드, 차량용 AI 음성인식 공동 개발',
#  'DL이앤씨, 국내 최초 AI·360도 카메라 기반 현장관리 솔루션 ‘디비전’ 도입',
#  'AI 활용해 고위험 수입식품 스마트하게 찾는다',
#  '"AI 코딩 교육 인프라 확대"...KT-EBS, SW·AI 인재 양성 위한 업무협약',
#  '화성시, AI자원회수기기 설치 시범운영',
#  '미디어그룹사람과숲, ‘AI 데이터셋’ 부문 3년 연속 ‘ICT대상’ 수상',
#  'DL이앤씨, AI 기반 현장관리 솔루션 ‘디비전’ 도입',
#  '"AI로 임신테스트기 결과 확인하세요"…NHN에듀 \'AI핑봇 임신테스트\' 출시',
#  '강기정 광주시장 “여당이 AI반도체 단지 등 현안 힘써달라”',
#  'AI속기사, 이젠 경찰조사때 대신 받아쓴다',
#  '의료인공지능 솔루션 기업 뷰노, 데이터 기반 의료AI 사업 박차',
#  'KAIST, 스마트폰 위 AI 연합학습 속도 4.5배 획기적 향상 기법 ‘개발’',
#  '[NOW] 詩 쓰는 AI 작가, 대학로 무대 진출',
#  '에듀윌, 인공지능 합격비서 ‘AI-Pass’ 서비스 오픈',
#  "카카오브레인 AI모델 시아, 첫 시집 '시를 쓰는 이유' 출간",
#  "이스트소프트-YBM, 외국어 교육 특화 'AI 휴먼' 만든다",
#  'KB국민은행, AI 기업여신 자동심사 시스템 구축',
#  '금융위, AI 활성화 위해 망분리 규제 개선ㆍ데이터 라이브러리 구축 나선다',
#  '금융당국, 금융권 AI 도입 박차…“금융규제 혁신 필수”',
#  '"AI, 7살 수준 자의식" 주장했다 해고…현실은?',
#  'HPE, AI 추론 전용 서버 출시',
#  "하나은행, 모바일 앱 하나원큐에 'AI 뱅커' 도입",
#  'KTOA, KIF 신규 자펀드 결성 추진...AI·6G 분야 투자',
#  "[AI-META 시대 '미래전략'] <25>공정거래",
#  "SK㈜ C&C, 'AI 뇌출혈 영상 의료 솔루션'으로 울릉도 응급환자 돕는다",
#  'KB국민은행, 기업여신 자동심사 AI 구축',
#  '"상상력을 펼쳐라"...경북교육청, SW-AI교육 기반 마련 나서',
#  '“모두가 쓸 수 있는 AI 기술을 만들고 싶다”',
#  'AI 인재 찾아 어디든 간다… 대학교·지하철역서 채용 캠페인',
#  '"중대재해처벌법 해법 찾기"...철강사, 안전 경영 위한 AI 기술 고도화',
#  '경상국립대학교 AI융합인재교육연구단, 지자체 네트워킹 및 협력강화 워크숍 ...',
#  '한양대 ERICA, CEO AI 교육과정 신설',
#  '루닛, 임상시험서 AI 치료효과 확인에 주가 급등',
#  '[단독] 실체없는 AI 영재고, 충북도내 기초정부간 갈등만 증폭',
#  '[#증권톡톡] 한국투자증권, 해외주식형 ELS 2종 모집·KB증권, AI 상담 콜봇 ...',
#  'DL이앤씨, AI기반 컴퓨터‧360도 카메라로 건설현장 관리',
#  '금융 모바일 앱에도 AI 휴먼이··· 딥브레인AI, 하나은행에 ‘AI 뱅커’ 공...',
#  '제이엘케이 AI 치매 분석 솔루션 태국 허가',
#  "조달청, AI 기반 공공SW사업 발주지원시스템 'e-제안요청 도움' 구축",
#  "AI 인공관절 로봇 전문 코넥티브 '시드 투자' 완료",
#  'KT, 2023학년도 봄학기 채용연계형 AI 석사과정 신입생 모집',
#  "농정원, '2022 스마트농업 AI 경진대회' 개최",
#  '리퍼블릭케이·에프앤가이드·연세대학교 AI기술 활용 위해 MOU체결',
#  '성범죄 피해 조서 쓰는 AI, 2급지 경찰서까지 확대',
#  '전주비전대 평생교육원, AI융합교육·데이터라벨러 수강생 모집',
#  '"재활용률을 높이자"… 화성시, 새솔동에 AI 자원 회수기기 설치',
#  '보은군의회 "교육·정주여건 위해 AI영재고 유치해야"',
#  '금융위 “빅데이터·AI활용 규제 혁신” 금융사 가명정보 재사용도 허용한다',
#  'AI가 극단적 선택 40대 구해…학습 통해 행동 포착',
#  'ポスコグループ、「AI技術諮問委員会」新設…新事業·人材発掘',
#  'AI활용 스마트폰으로 술 등 진위 여부 가린다',
#  "[AI-META 시대 '미래전략'] <24>평생교육 '새판짜기'",
#  'AI 물류 스타트업 ‘바이너리브릿지’, 44억원 투자 유치',
#  '미래에셋증권, AI활용한 디지털PB센터 출범',
#  '충남도, AI 학습용 ‘종패 생산 데이터’ 구축',
#  'A4 1장을 순식간에 1줄 요약… 초거대 AI ‘엑사원’이 세상을 바꾼다',
#  "AI가 나 대신 '대출심사' 해준다는데,,,과연?",
#  '금융당국 "금융권, 빅데이터·AI 효과적 활용토록 규제 혁신할 것"',
#  'DL이앤씨, 360도 카메라로 건설 현장 찍고 AI로 분석',
#  '수리硏, 산업수학에 ‘AI’ 접목시킨다',
#  '화성시, AI 자원회수기기 9개소 설치',
#  '국민은행, 안심전환대출 AI 상담 서비스 지원…"수요 급증 대비"',
#  '"시 쓰는 카카오 AI"…카카오브레인 AI \'시아\' 시집 출간',
#  "KB국민은행, AI 적용 '기업여신 자동심사 시스템' 구축",
#  "'모빌리티,\xa0로봇,\xa0AI\xa0넘어서\xa0우주로'\xa0제2회\xa0MARS\xa0월드포럼\xa0개최",
#  '충남도, AI 학습용 종패 생산 데이터 구축',
#  'KT, 산학협력 고도화…AI인재 연간 30명 키운다',
#  '전남 장성군, 인공지능(AI) 말동무 인형 지원사업 추진',
#  '딥노이드, AI로 폐질환 위치까지 탐지한다',
#  "빅데이터· AI 활용한 '위험 수입식품' 관리 체계 구축 추진 - 식약처-",
#  '국민은행, AI기술 적용 기업대출 자동심사 시스템 구축',
#  'KT, 채용연계형 전일제 AI 석사과정 신입생 모집',
#  "조선대, 지역사회 연계 '중학생 AI·SW 교실’ 성황리 마무리",
#  '딥노이드, AI 기반 흉부 엑스레이 진단 논문 네이처 파트너저널 게재',
#  'AI·SW 온라인 코딩입문훈련 교육과정 운영',
#  'SK C&C, ‘AI 뇌출혈 영상 의료 솔루션’으로 울릉도 응급환자 돕는다',
#  '시 한편 쓰는 데 1초…초거대 AI가 쓴 시집 나온다',
#  'AI 챗봇 심심이, 연구자 위해 초거대 대화 데이터 공개',
#  'KAIST, AI 연합학습 속도 4.5배 획기적 향상…스마트폰 과부하 문제 해결 기대',
#  'TTA, AI 제품·서비스 신뢰성 확보 컨설팅 제공',
#  '美, ‘주요고객’ 中에 AI칩 설계·제조 핵심 소프트웨어 수출금지 추진',
#  '충남도, 스마트 어업 실현...AI 학습용 수산종자 생산 데이터 구축',
#  'aT, 농산물 가격 예측 AI 경진대회',
#  '인권위, 국가인권정책계획에 ‘AI 인권보호 강화’ 권고 담았다',
#  '[단독 인터뷰] \'AI 대부\' 제프리 힌턴 "Mr. Cho 같은 인재 유치하려면 기업도...',
#  'KB국민은행, AI 기술을 적용한 기업여신 자동심사 시스템 구축',
#  'DL이앤씨, 국내 최초 AI·360도 카메라 기반 현장관리 솔루션 도입',
#  '금융위 "금융분야 AI기술 고도화 필수"...\'금융 AI 데이터 라이브러리\'\xa0구축',
#  "투디지트, AI 뉴스 분석 주식정보 서비스 '뉴스샐러드'로 글로벌 기업 도약 꿈...",
#  '국표원, AI 응용 가전제품 안전관리 지침 개발 착수',
#  '‘이루다 사태 방지’…TTA, ‘AI 신뢰성 확보 컨설팅’ 제공',
#  '표준협회, AI·SW 온라인 코딩입문훈련 교육과정 운영',
#  '전북교육청, AI기반 교수·학습지원을 위한 미래교육 공감토크',
#  "이글루코퍼레이션, KISA '사이버보안 AI 데이터셋 구축 사업' 수주",
#  '울릉도 뇌출혈환자 "골든타임 지킨다"…SK㈜ C&C, \'AI 뇌출혈 판독 솔루션\' 군...',
#  "화성시, 새솔동에 'AI자원회수기기' 설치하고 시범운영",
#  'AI 시대 겨냥 CXL 기반 차세대 메모리 확장 플랫폼 개발',
#  '지질연, 제2회 지질자원데이터 활용 및 AI 경진대회 개최',
#  "인티그리트, 차세대 AI 소셜로봇 '디코닉' 출시",
#  "'충북 AI 영재고' 유치, 괴산도 참여…도내 7곳 뜨거운 경쟁",
#  "충남도, AI 학습용 '종패 생산 데이터' 구축",
#  "SKT, 화신과 '인더스트리얼AI' 사업 확대 협력",
#  '이종호 과기부 장관 “반도체·5G 기술 우위…바이오·AI 부족”',
#  '"KAIST, 반도체·AI 분야 논문 수 세계 상위권"',
#  'SKT, AI 비서 \'에이닷\'…"TV와 게임도 품었다"',
#  "하나은행, 모바일앱에 'AI뱅커' 도입",
#  '카카오브레인, 초거대 AI 보폭 넓힌다…의료영상 분야 진출',
#  '에프앤가이드·리퍼블릭케이·연세대, ‘AI 자산 관리’ 연구 개발 위해 맞손',
#  "'멋쟁이사자처럼', 'AI 스쿨' 8월29일까지 모집",
#  "AI·머신러닝 응답속도 최대 20배 '업'...삼성, 차세대 메모리 솔루션 대거 공...",
#  '"AI, 7살 수준 자의식" 주장했다 해고…실제 어느 정도?',
#  '"AI 뱅커입니다" 은행 모바일 앱에 디지털 휴먼 최초 등장',
#  '식약처, AI 활용 고위험 수입식품 검사·관리 나선다',
#  'SK㈜C&C,울릉도에 ‘AI뇌출혈 영상 의료 솔루션’ 공급',
#  '딥노이드, AI로 폐질환 및 위치까지 탐지하는 논문 네이처 파트너저널에 게재',
#  '한밤중 충무대교 난간 넘어간 40대 AI가 구조',
#  'KB국민은행, ‘안심전환대출’ 상담에 AI 음성상담 지원',
#  "딥브레인AI, '월클' 손흥민 AI 휴먼으로 구현",
#  "DL이앤씨, 국내 최초 AI 현장관리 솔루션 '디비전' 도입",
#  "(현장+)AI 기반 신약 개발…데이터 활용 여부가 '관건'",
#  '인공지능(AI)이 쓴 시(詩), 사람들 마음 울릴까?',
#  '건양고 AI 및 디스플레이 응용 융합 메이커 교육 개최',
#  '이스트소프트, 외국어 교육 특화된 AI 휴먼 만든다…YBM과 맞손',
#  "의료 AI 로봇기업 '코넥티브', 카카오벤처스 시드 투자 유치",
#  '농산물 가격 예측 AI 경진대회 개최',
#  "AI 물류 스타트업 '바이너리브릿지', 44억원 투자 유치",
#  "AI ARS '상담콜', AI 보이스 적용 '고객 콜백 예약 기능' 오픈",
#  '진천중, 생거진천 인공지능(AI) 마을학교 운영',
#  'KT, 2023 봄학기 채용연계형 AI 석사 신입생 모집',
#  'KT, 강동경희대병원과 AI 로봇 서비스 개발',
#  "'2022 농산물 가격 예측 AI 경진대회' 개최",
#  "KAIST, 스마트폰 위 인공지능(AI) 연합학습 속도 '4.5배 향상'",
#  '대화를 통해 더 똑똑해지는 인공지능 챗봇...메타 AI, 거의 모든 주제에 말할...',
#  '그림 그리는 AI ‘DALL·E’, 저작권 문제 없을까?',
#  '[특징주] 루닛, AI 치료효과 확인에 5% 급등',
#  '카페24, AI로 만든 쇼핑몰 상세페이지 500만건 넘어',
#  "'해리포터' 책으로만 읽은 AI가 그린 캐릭터들 실제 외모 (사진 10장)",
#  "울산대 '맞춤형 AI 인력양성과정 수료식 및 시상식' 개최",
#  'KT, AI 로봇으로 병원 디지털 전환 나선다',
#  '이글루코퍼레이션, KISA 사이버보안 AI 데이터셋 구축 사업 수주',
#  '"우리 공장에도 AI 도입하자"…LGU+, 구독형 스마트팩토리 상품 출시',
#  'AI technology-financial services',
#  "[주간 IT] 사용자 스마트폰 데이터 기반 'AI 서비스' 날개 단다",
#  'SK C&C, 울릉군보건의료원에 AI 뇌출혈 영상 의료 솔루션 공급',
#  '출시 한 달 된 AI코딩비서 "개발자 수준 높인다"',
#  "DL이앤씨, AI·360도 카메라 현장 도입 '디지털 혁신' 박차",
#  'SK케미칼, 치매 예방 위해 AI 기반 인지개선프로그램 보급 나서',
#  'DL이앤씨, AI로 공정별 하자 바로바로 잡아낸다',
#  "진짜보다 나은 '가짜' 데이터로 AI에 연료 공급",
#  'SKT, 산업 AI로 뿌리기업 지원',
#  '미국, AI칩 설계·제조 핵심 소프트웨어 중국 수출금지 추진',
#  '보은군의회 "지역균형 발전 차원 보은에 AI영재고 건립해야"',
#  'KISTI, 쿠웨이트 고등학생 대상 DATA·AI 캠프 운영',
#  '순천시, AI 반려로봇 돌봄 서비스',
#  '모아데이타, AI 기반 B2C 자회사 세이지앤컴퍼니 신설',
#  "SK㈜ C&C, 'AI 뇌출혈 영상 의료 솔루션'으로 울릉도 응급환자 지원",
#  '하나은행, 은행권 최초 모바일 앱 하나원큐 내 ‘AI뱅커’ 도입',
#  "하나은행 앱에선 'AI 뱅커'가 금융시장 브리핑",
#  '강기정 광주시장 "AI반도체 단지 현안 힘 보태달라"',
#  '보은군의회, AI영재고 유치 촉구 결의안 채택',
#  '‘눈’으로 심혈관질환 예측하는 AI 의료기기 등장',
#  '삼진제약, AI 신약개발 나선다',
#  'AI 활용해 고위험 수입식품 선별',
#  '청년·신중년에 AI 원스톱 취업 지원',
#  '조달청, 공공 SW사업 발주에 AI 기술 도입…오늘부터 본격 서비스',
#  "파수, 데이터 비식별화 솔루션 '애널리틱디아이디'에 AI 기술 탑재",
#  "세종충남대병원, 대화형 메신저 'AI 챗봇'서비스 오픈",
#  '순천향대천안병원, AI·IoT 활용 정신질환자 응급상황 예측시스템 개발 추진',
#  '[단독] 조용병 회장 야심작 ‘신한 AI’ 상장 추진…지주 자회사 최초',
#  "삼진제약, 캐나다 '사이클리카'와 AI 신약개발 공동연구 나선다",
#  "셀바스AI, 'AI 음성인식 기반 성폭력 피해 조서 작성 시스템' 확대 적용",
#  '[D리포트] "AI, 사람 같은 자아 있다" 주장했다가 해고…현실은?',
#  '혁신성장 정책금융, AI 분야 공급액 5년새 45배 증가',
#  '건양고, AI 및 디스플레이 응용 융합 메이커 교육 개최',
#  '카카오엔터프라이즈, 세계 AI 얼굴인식 기술대회서 잇따라 1위',
#  '카뱅, 에프앤가이드와 금융콘텐츠 읽고 쓰는 AI 모델 만든다',
#  '전주비전대 평생교육원, AI융합교육 자격취득 과정생 등 모집',
#  "충남, AI 학습용 '종패 생산 데이터' 구축한다",
#  'KB국민은행, AI 기술 적용한 기업여신 자동심사 시스템 구축',
#  "와이즈에이아이, AI 개인비서 앱 'AI-ME' 상표 등록 완료",
#  "[AI-META 시대 '미래전략'] <23>게임스토리텔링",
#  '딥브레인AI, 하나은행 모바일 앱에 ‘AI 뱅커’ 공급',
#  "'임테기 흐릿한 줄로 수차례 반복'…이젠 AI가 판독해준다",
#  '[인터뷰] “KT는 음성 전문가…목소리로 자폐⋅폐렴 진단 AI 만들 것”',
#  '룰루랩, 하노이의대와 피부질환 AI 분석 솔루션 공동연구 협약',
#  'SKT, 화신과 AI 용접품질 관리기술 협업…"인더스트리얼AI 확대"',
#  'DL이앤씨, AI·360도 카메라로 현장 하자 줄인다',
#  '이글루코퍼레이션, KISA 사이버 보안 AI 데이터셋 구축 사업 수주',
#  '광양제철소, AI 기반 하역 크레인 안전거리 자동측정 시스템 구축',
#  '조선대, AI‧SW 여름방학 아카데미 진행',
#  '"헷갈리는 \'임테기\' 결과, AI가 판독"…NHN에듀, \'AI핑봇 임신테스트\' 출시',
#  '광양제철소, \'AI 기반\' 하역크레인 안전거리 자동측정 시스템 구축.."즉각 감...',
#  "하나은행, 은행권 최초 모바일 앱 하나원큐 내 'AI뱅커' 도입",
#  '금융위원회 "빅데이터·AI 활용 지원…규제 혁신"',
#  '인천재능대,\xa0AI\xa0ONE-STOP\xa0프로그램\xa0체험\xa0교육\xa0운영',
#  '고병원성 AI·ASF 미발생 EU지역 축산물 수입 가능…수입조건 변경',
#  "딥노이드 연구팀, 2년여간 'AI기반 흉부 X-ray진단' 논문 네이처 파트너저널(...",
#  "[fn마켓워치]카카오벤처스·슈미트, AI 인공관절 로봇 수술 '코넥티브'에 투자",
#  '에듀윌, AI로 합격 예측한다…"연내 AI-Pass 완성"',
#  'SK케미칼, AI 기반 인지개선 프로그램 보급…치매 해결 나서',
#  '더핑크퐁컴퍼니-AI 네트워크, ‘핑크퐁 아기상어’ NFT 전시 개최',
#  "광주인력개발원, AI활용 SW개발 경진대회 '성료'",
#  '미, AI칩 설계·제조 핵심 소프트웨어 중국수출 막는다',
#  '딥노이드 AI 의료 솔루션, 폐질환 및 위치까지 탐지하는 임상적 유용성 입증',
#  'KB국민은행, AI 기술 적용 기업여신 자동심사 시스템 구축',
#  'DL이앤씨 AI·360도 카메라 현장관리 솔루션 도입',
#  "aT, '농산물 가격 예측 AI 경진대회' 개최",
#  "금융권 'AI 혁신' 시동 걸었지만… 활성화까진 '산 넘어 산'",
#  "KT, EBS와 AI 인재 육성 '맞손'… 소프트웨어·인공지능 학습 제공 MOU 체결 ...",
#  '조달청, AI 기반 공공SW 사업 발주지원시스템 개통',
#  "AI ARS 상담콜, 인공지능 보이스 적용 '고객 콜백 예약 기능' 선봬",
#  '"사람의 뇌처럼 인지하는 AI 탐구 중"…제프리 힌턴 교수 \'뇌\' 향한 혁신은 평...',
#  '울릉군 의료 서비스 향상...SK C&C, AI 뇌출혈 판독 솔루션 공급',
#  'TTA, AI 제품·서비스 신뢰성 무료 컨설팅 기업 공모',
#  '금융 AI 도서관 출범...데이터 필요할 때 꺼내쓴다',
#  '미래에셋증권-네이버클라우드, AI·클라우드로 금융서비스',
#  "하나은행, 환율·금융시장 전망해주는 'AI뱅커' 도입",
#  '식약처, AI 활용해 고위험 수입식품 걸러낸다',
#  "삼진제약, 'AI 신약개발 공동연구' 계약 체결",
#  'KAIST, 국내 AI 반도체 선도...내년에 반도체시스템공학과 설립',
#  'KT·강동경희대병원, AI 로봇 활용해 병원 업무 디지털 전환 추진',
#  'AI 물류 스타트업 ‘바이너리브릿지’, 44억 원 규모 프리A 투자 유치',
#  '천안교육지원청, 2022 천안AI꿈키움터 여름방학캠프',
#  "디지털 금융혁신 목표...금융위, '빅데이터-AI 활용 활성화 방안' 제시",
#  "채용 정보서 AI 테크로...'HR 서비스 2.0' 변신 경쟁 후끈",
#  '`AI뱅커`가 시장동향 알려주는 하나은행앱',
#  "DL이앤씨, AI 현장관리 솔루션 '디비전' 도입",
#  "카카오브레인, 초거대 AI 언어 모델 활용 '시집' 출간",
#  '"AI가 보험 심사" 생보사들 디지털 혁신 바람',
#  '이든앤앨리스마케팅, AI 전문기업 데이콘과 데이터 기반 마케팅 플랫폼 개발 ...',
#  'KAIST, 스스로 학습·진화하는 흉부 엑스선 AI진단기술 개발',
#  '하나은행 "모바일 앱 하나원큐에 \'AI뱅커\' 도입"',
#  "DL이앤씨, 현장관리 솔루션 도입...'국내 최초' AI·360도 카메라 활용",
#  'KT-강동경희대학교병원, AI 로봇 활용 병원 업무 디지털 전환 협력',
#  '삼진제약, 加 사이클리카와 AI 신약개발 공동연구 계약 체결',
#  "AI, 작곡하고 그림 그리더니...이번엔 시집 냈다[Geeks' Briefing]",
#  '지자연, 지질자원데이터·AI 경진대회 개최',
#  '수리연, IAAE 국제인공지능&윤리협회, 산업수학 기반 AI 사업 협력',
#  '<오후여담>AI시대 新직업',
#  "의료 AI 로봇 '코넥티브', 시드 투자 유치...카카오·슈미트 참여",
#  "AI ARS '상담콜', 인공지능 적용 '고객 콜백 예약 기능' 오픈",
#  '삼진제약, 캐나다 바이오사와 AI 공동연구',
#  '김소영 금융위 부위원장 "금융분야 AI 활성화 정책 적극 지원"',
#  '"결혼도 스마트하게"…하동군, \'AI 맞썸다방\' 눈길',
#  'AI가 축구대회를 알아서 중계한다고? AI스포츠중계 시스템은 무엇?',
#  'AI와 병원정보시스템 결합…비플러스랩-이지케어텍 맞손',
#  '카카오브레인, 시 쓰는 AI 모델 `시아` 시집 출간',
#  '통영시, CCTV에 AI 딥러닝 기법 도입',
#  'SK㈜ C&C, \'AI 뇌출혈 판독 솔루션\' 울릉도에 공급…"골든타임 지킨다"',
#  "KB증권, 'AI 상담 콜봇' 서비스 실시",
#  "AI가 쓴 시로 만든 시극 '파포스'…8월 대학로예술극장",
#  "KB국민은행, '기업 성장성 분석' AI 심사시스템 구축",
#  '"AI로 자폐증 진단한다"… 정부 예산 100억 투입하는 이유',
#  '건설산업 혁신 IT 기술로 진화…AI·360도 카메라 기반 솔루션 도입',
#  '기후변화·AI 전문가 대거 참석…공동번영 위해 머리 맞댄다',
#  '하나은행, 은행권 최초 앱에 AI뱅커 도입...환율·펀드 서비스',
#  '암 찾아 치료하는 ‘방사선 미사일’ 등 핵의학 발전…"AI 접목 신약 개발 도...',
#  '“어르신, AI 스피커 이 바구니에 담아 보관하세요”',
#  '천안교육지원청, 2022 천안AI꿈키움터 여름방학캠프 운영',
#  '"덜어내고 덜어내 남는 말이 詩" AI시인의 등장',
#  'KT 대경본부, AI 호텔 서비스 도입…라마다 문경새재 호텔과 업무협약',
#  'DL이앤씨, AI·360도 카메라 현장관리 솔루션 도입',
#  "[중기소식]상담콜, AI 보이스 적용 '고객 콜백 예약' 등",
#  '진천중 AI 마을학교 운영',
#  '[사고]‘2022 AI코리아 대상’ 공모합니다',
#  'AI영재고 유치에 괴산도 가세',
#  "'내가 보고 싶은 선수만'…와이에스티, '추계 중등축구대회' AI 중계 적용",
#  "캠프서 배우는 'AI 교육', 초‧중‧고 200명 참여",
#  "AI 학습용 '종패 생산 데이터' 구축한다",
#  '롯데정보통신, 보안 AI 모델로 지능형 위협 차단한다',
#  '보은군 AI 영재고 유치전 가세…지자체 간 불꽃경쟁 예고',
#  '[특징주] 딥노이드, AI로 폐 질환 위치까지 감지 소식에 급등',
#  'DL이앤씨, 디지털 혁신의 힘..AI·360도 카메라 기반 현장관리 솔루션 도입',
#  'SK케미칼 등 SK 3사, 성남·청주 36개 기관에 AI 인지개선프로그램 보급',
#  '지식의 전당에 걸맞은 웅장한 선율…AI음악가 작품입니다',
#  "도시공유플랫폼, 창업박람회서 AI 무인 편의점 '아이스Go' 전시",
#  "KB국민은행, AI 기술 적용 '기업여신 자동심사 시스템' 구축",
#  '삼진제약-加 사이클리카, AI 신약개발 공동연구',
#  '김주하 AI 앵커와 함께하는 이 시각 주요뉴스 - 8월 5일 낮 12시',
#  'SK케미칼 등 3사, AI 기반 인지기능개선 프로그램으로 치매 예방 나서',
#  'LG전자, 사운드하운드와 차량용 AI 음성인식 솔루션 개발',
#  "전북교육청 'AI기반 맞춤형 수업 확산' 모색",
#  "전북교육청, 'AI기반 학생맞춤형 수업' 전체 학교로 확산한다",
#  '하나은행, 모바일 앱 하나원큐에 ‘AI 뱅커’ 도입… “금융정보 브리핑 서비...',
#  'KT AI로봇 활용해 병원 디지털전환 지원, 강동경희대병원과 업무협약 체결',
#  "모바일서 금융시장·환율 전망 브리핑…하나銀 'AI뱅커' 도입",
#  '인재 양성에 열 올리는 북한…"VR부터 AI 교수법까지 개발"',
#  "SKT, 용접 품질 관리도 AI로…'인더스트리얼 AI' 사업 확대",
#  "'사람인가, AI인가'…CNN, 韓 가상 인플루언서 열풍 조명",
#  '카카오브레인, 의료영상 분야로 초거대 AI 연구 확장',
#  "카카오브레인 AI 아티스트 칼로, '갤럭시 북 아트 프로젝트'에 활용",
#  '"AI기반 시장변화 감지"...KB국민카드 \'소셜미디어\' 분석 플랫폼 구축',
#  'KT-KAIST·포스텍·한양대, 채용연계형 AI 석사과정 모집',
#  '마이더스AI, 663억 규모 유상증자 결정',
#  "삼진제약, 캐나다 '사이클리카'와 AI 신약개발 협력",
#  '포스코그룹, AI 기술 자문위원회 신설…"미래 전략 수립에 큰 역할 기대"',
#  "[AI-META 시대 '미래전략']<21>지역 발전",
#  '미래에셋증권·네이버클라우드, AI·클라우드 기반 서비스 협력',
#  '[ET라씨로] 루닛, 비인두암 환자 대상 AI 치료효과 확인에 주가 강세',
#  'AI 번역 엑스엘에이트(XL8), WINGS(윙스) 선정..."구어체까지 완벽 소화"',
#  'AI 챗봇 심심이, 초거대 대화 데이터 연구자들에게 공개',
#  "NHN에듀, 'AI핑봇 임신테스트'서비스 출시",
#  "KB국민카드 임직원들, AI 활용해 '소셜 데이터' 분석한다",
#  '룰루랩, 하노이의대와 베트남 AI 의료 생태계 구축한다',
#  '미래에셋證·네이버클라우드, AI 기반 고객서비스 확대에 맞손',
#  'DL이앤씨, AI·360도 카메라로 시공 품질 체크한다',
#  '전주교대 SW·AI 교육 역량 강화 연수 실시',
#  '[제45기 SG배 한국일보 명인전] AI와의 시너지 효과',
#  'KT, 2023년 봄학기 채용연계형 AI 석사과정 신입생 모집',
#  "[AI-META 시대 '미래전략'] <22>인공지능 미래 발전과 대응",
#  '日 NYK 이데미츠, AI 연료저감 시스템으로 동남아 석탄발전시장 공략',
#  "영상 속 '깊이 정보'… AI 알고리즘으로 정확히 알아낸다",
#  "삼진제약x사이클리카 'AI 신약개발 공동연구' 계약",
#  '현대차, AI. AAM. 자율주행. 로보틱스 분야 우수인재 모신다. 북미. 유럽대학...',
#  'SK케미칼, AI 기반 인지 개선 프로그램 보급으로 치매 예방에 앞장',
#  'TTA,\xa0AI 제품‧서비스 신뢰성 확보 컨설팅 제공',
#  '“금융권 기술 수준 감안, AI 금융 정책방향 ‘활성화’에 초점 맞춰야”',
#  "'인공지능 AI 로봇이 관리하는 호텔은 어떨까?' .... KT AI 호텔, 라마다 문경...",
#  "장성, 고위험 독거노인 위한 '인공지능(AI) 말동무 인형' 지원",
#  "SK텔레콤, AI 서비스 '에이닷'에 TV·게임 추가",
#  "스스로 데이터 공부해 진단능력 끌어올리는 '흉부 엑스선 AI' 나왔다",
#  'KTOA, KIF 신규 자펀드 결성 추진..."AI·6G·메타버스 투자"',
#  '초거대 AI가 쓴 시집 나온다',
#  '하나은행, 모바일 앱 내 AI뱅커 도입…"은행권 최초"',
#  "대전AI교육지원체험센터, '인공지능 교육\xa0학생캠프' 운영",
#  '에이수스, 엔비디아 젯슨 플랫폼 기반 지능형 엣지 AI 시스템 발표',
#  '삼진제약, 사이클리카와 AI 신약개발 공동연구 협약',
#  '인간을 흔드는 AI, 바로 보기',
#  '가톨릭중앙의료원·카카오브레인, 의료영상 AI 개발 업무협약',
#  '폭포서 흙탕물이 콸콸…최악 홍수 미얀마｜AI가 Pick한 세상',
#  "하나은행, 'AI뱅커' 도입",
#  '삼진제약, 캐나다 사이클리카와 AI 신약개발 공동 연구',
#  '삼성전자 "AI 아티스트와 함께 갤럭시 북 꾸며봐요"',
#  '기업여신도 AI가 머신러닝 기반 심사',
#  '고병원성 AI·아프리카돼지열병 미발생 EU 지역 축산물 수입 가능',
#  '[ET뉴스픽!]日 세관, AI로 부정수출 감시',
#  '"비대면으로 가입하고 AI가 심사"…생명보험업계 디지털 혁신 바람',
#  "DL이앤씨,\xa0국내 최초 'AI·360도 카메라' 기반 현장관리 솔루션 선봬",
#  'AI 국제표준화 한국이 주도한다',
#  "오씸코리아, AI 스트레스 관리시스템 탑재 안마의자 '유러브3' 선보여",
#  'KT, EBS와 함께 AI 인재 육성',
#  "카카오브레인, 시 쓰는 AI 모델 '시아' 개발…시집도 출간",
#  "'금융 AI기술 지원' 금융위, '데이터댐 구축' 나선다",
#  '스마트폰 위 AI 연합학습 속도 4.5배 향상 기법 개발',
#  "더핑크퐁컴퍼니-AI 네트워크, '핑크퐁 아기상어' NFT 전시 개최",
#  '룰루랩, 하노이 의대와 피부데이터 기반 AI 의료 생태계 육성',
#  '서울대, 구글·메타·스탠퍼드 대학 등 해외 AI 연구자 초청',
#  '와이즈에이아이, AI 비서 앱 ‘에이미’ 상표 등록 완료',
#  '핑크다이어리, AI핑봇 임신테스트 서비스 출시',
#  "KT, 'AI 방역로봇' 광고 유튜브 조회수 1200만회 돌파",
#  'KT 대경본부 AI 기반 솔루션 호텔 라마다 문경새재에 적용',
#  '카카오브레인 AI 기반 모델 시아, 시집 출간한다',
#  "'AI 기계학습' 국제 표준화, ETRI 선봉 나선다",
#  '의료 AI 로봇기업 코넥티브, 시드 투자 유치',
#  'KT, 2023학년도 봄학기 채용연계형 AI석사과정 신입생 모집',
#  '매년 뇌경색 환자 2% ‘심근경색’…“AI로 심장병 찾아낸다”',
#  'KB국민은행, AI 기술로 기업여신 자동심사',
#  '삼진제약, 캐나다 ‘사이클리카’社와 AI 신약개발 공동연구 착수',
#  "인공지능 융합 강의 'AI+X'…국내 최고의 강좌를 개설하다",
#  '카카오브레인 "AI가 시를 쓰는 이유"',
#  '경북교육청, 누구나 가능한 SW-AI교육 기반 마련…학교 현장 70.2억 지원',
#  '광양제철소, "AI 기반 하역 크레인 안전거리 자동측정 시스템 구축"',
#  '"AI가 자동심사해 보험금 즉시 지급"…생보사, 디지털 혁신 \'박차\'',
#  "조선대 '중학생 AI·SW 교실' 성황",
#  "'루미가 돕는다' 순천시, AI 반려로봇 어르신 돌봄 시작",
#  "[팍스테크니카 인재에 달렸다] 영업맨도 AI 전문가 '환골탈태'…전공 상관없이...",
#  'KT-강동경희대학교병원, AI 로봇 활용-병원 업무 디지털 전환 협력',
#  '“하나 모바일 AI 뱅커가 금융 브리핑 해드려요”',
#  '손 잡은 이지케어텍·비플러스랩…"AI 의료솔루션 신규 서비스 모색"',
#  '에이수스(ASUS), 엔비디아 젯슨 플랫폼 기반 지능형 엣지 AI 시스템 발표',
#  '지질자원연, 지질자원데이터 활용·AI 경진대회 개최',
#  "[더뉴스] 시 쓰고, 연예계까지 접수...'AI' 얼마나 진화했나?",
#  "롯데정보통신, '보안 AI 모델' 지능형 위협 차단",
#  '표준협회, AI·SW 실무 기술인력 양성한다',
#  'NHN에듀 “한줄? 두줄? 헷갈리는 ‘임테기’ 결과 AI로 판단하세요”',
#  '김주하 AI가 전하는 8월 5일 뉴스7 예고',
#  '인천재능대, AI ONE-STOP 프로그램 체험 교육 운영',
#  "시(詩) 쓰는 AI '시아', 첫번째 시집 '시를 쓰는 이유' 출간",
#  'KT, 강동경희대병원과 AI로봇 활용 병원 업무 디지털 전환 MOU',
#  "하나은행, 모바일 앱에 'AI 뱅커' 도입",
#  "순천시, AI 반려로봇 '말동무 해드리는 인형' 보급 사업",
#  '생체 신호 분야 주목하는 의료 AI 기업들…그 배경은?',
#  '[특징주] 루닛, 비인두암 환자 병용요법서 AI 치료효과 확인에 강세',
#  "AI 네트워크-더핑크퐁컴퍼니, '언커먼 갤러리'서 핑크퐁 아기상어 NFT 첫 전시",
#  '보안기업 이글루코퍼레이션, AI 특허 획득…머신러닝 강화한다',
#  '카페24 "AI로 만든 쇼핑몰 상세페이지 500만건 넘어"',
#  "[SR전자] 삼성전자 '삼성 AI 챌린지' 개최…디스플레이 연구 난제 해결",
#  '초중등 교사 AI·SW 교육 역량 키운다',
#  'DL이앤씨, 업계 최초 AI·360도 카메라 활용 현장관리 솔루션 도입',
#  'SKT, 산업용 AI 사업 확대…“국내 제조업 경쟁력 강화”',
#  '통영시 ‘AI 자살예방시스템’으로 40대 구조',
#  "산업AI 원프레딕트, '세계 50대 첨단 제조 스타트업'에 이름 올렸다",
#  '교육시장에 AI 기술 도입 사례 확산',
#  '룰루랩-하노이의대, 피부데이터 기반 AI 의료생태계 키운다',
#  'CJ올리브네트웍스, AI·SW 재능기부 대학생 모집',
#  '경기도, 고병원성 AI 92% 줄어…"야생조수 차단 시범사업 덕"',
#  '재활용률↑...화성시, AI 자원회수기기 운영',
#  "AI 학습용 '종패 생산 데이터' 구축",
#  '[카드] 셀바스 AI, 성폭력 피해 조서 작성 시스템 확대 적용',
#  "이글루, '능동형 보안관제' AI 데이터셋 구축 사업 수주",
#  '尹 AI·디지털 의료 평가기간 단축...의료 빅데이터 법제화 주문',
#  '카카오뱅크 "금융 콘텐츠 읽고 쓰는 AI 모델 개발"',
#  "[기업] SKT, 자동차 부품업체와 '용접 AI' 기술 계약 체결",
#  "'논문 수 세계 최상위권' 반도체·AI서 위용 펼치는 KAIST",
#  'SKT AI 서비스 ‘에이닷’, TV·게임 신규 서비스 업데이트',
#  '하나은행, 모바일 앱 하나원큐 내 ‘AI 뱅커’ 도입',
#  '세종대 김수연 교수, AI 학습용 데이터 구축 지원사업 선정',
#  "하나은행,\xa0모바일 앱 하나원큐 내 'AI뱅커' 도입",
#  'DL이앤씨, 국내 첫 AI·360º 카메라 현장관리 도입... "디지털 기술 선도"',
#  'NHN에듀 ‘핑크다이어리’, 헷갈리는 임신 여부 ‘AI’로 판독',
#  '제이엘케이, AI 치매 분석 솔루션 ‘에이트로스캔’ 태국 허가 획득',
#  "AI로봇 활용 병원업무 디지털전환...KT·강동경희대병원, '맞손'",
#  "밸류링크유, AI기반 물류 서비스 '바이너리브릿지'와 이커머스 물류 혁신 및 ...",
#  'SKT, 車부품 제조사와 손잡고 산업용 AI 확대 나선다',
#  '울진 추계중등축구대회, AI 중계한다… 어떤 효과 있을까?',
#  'SKT, 용접 품질 관리도 AI로',
#  '하나은행, 하나원큐 ‘AI뱅커’ 선봬',
#  "하나은행, 딥러닝 기반 'AI뱅커' 하나원큐에 도입 [은행오늘]",
#  "'CXL 초격차' 속도내는 삼성·SK…AI 등 포트폴리오 확대(종합)",
#  '"새로운 세상을 여는 모두의 인공지능(AI)교육 학생캠프" 운영',
#  'KAIST, 민간과 손잡고 SAR 위성 정보 활용 AI연구 나서',
#  '전북교육청 미래교육 토크서 서거석 교육감, AI수업 시연',
#  '돌고래와 인간의 의사소통, AI로 시도한다',
#  'KT, 2023년 봄학기 채용연계형 AI 석사과정 모집',
#  'LGU+, 근로복지공단 민원업무 AI로 개선',
#  "[주간VC동향] 인공지능(AI) 의료 스타트업 '에어스메디컬' 253억원 규모 시리...",
#  '168m 상공에 대롱대롱…번지점프 사고｜AI가 Pick한 세상',
#  "딥노이드 'AI 기반 폐질환 탐지' 논문, 네이처 파트너 저널 게재",
#  '구글 딥마인드 AI, 거의 모든 단백질 구조를 예측한다',
#  '삼진제약-사이클리카, AI 신약개발 공동연구 계약 체결',
#  "DL이앤씨, 국내 최초 건설현장에서 AI 활용... 현장관리 솔루션 '디비전' 도입",
#  'AI 신약개발업계 정체기 돌입..."시장 확장보다 성과 주력할때"',
#  "하나은행, 은행권 최초 모바일 앱 내 'AI뱅커' 도입",
#  '신한AI, 신한금융 자회사 최초 IPO 도전?',
#  '서울인공지능고, 중3학생 대상 AI·빅데이터 캠프 개최…29일까지 신청',
#  'DL이앤씨, AI·360도 카메라로 시공하자 줄인다',
#  "하나은행, 모바일 앱 하나원큐에 'AI뱅커' 도입",
#  '카페24, AI 제작 쇼핑몰 상세페이지 제작 500만건 돌파',
#  "장성군, 독거노인 '인공지능(AI) 말동무 인형' 지원",
#  "SKT, '인더스트리얼 AI' 사업 확대",
#  "AI가 시도 쓰네…카카오브레인, 초거대 AI 'KoGPT' 활용 시집 출간",
#  '오픈소스 AI 쓸 수 없는 軍…독자 개발 모색 위한 세미나 개최',
#  '[사설]고도화 시급한 금융AI 컨소시엄',
#  '보은군 AI영재고 유치전 가세…추진위원회 구성',
#  '인트플로우, 축산동물 AI 학습 데이터 구축사업 수주',
#  '카카오브레인, 의료영상 분야로 초거대 AI 모델 연구 확장 나서',
#  '천안시 아우내도서관 초·중생 대상 AI/SW 교육 캠프 운영',
#  '김주하 AI 앵커와 함께하는 이 시각 주요뉴스 - 8월 4일 낮 12시',
#  'KB국민은행, 안심전환대출 상담에 AI 도입',
#  "오씸코리아, AI 스트레스 관리시스템 탑재한 안마의자 '유러브3' 출시",
#  "대전AI교육지원체험센터, 초‧중‧고 '인공지능(AI)교육 학생캠프' 운영",
#  'KT, 2023학년도 채용연계형 AI석사과정 신입생 모집',
#  '메디웨일, 망막 기반 심혈관질환 예측 AI 의료기기 품목 허가',
#  "AI ARS 상담콜, '고객 콜백 예약 기능' 선봬...인공지능 보이스 적용",
#  '강동경희대병원, KT와 의료기관 AI로봇서비스모델 공동개발',
#  "하나은행, 은행권 최초 'AI뱅커' 도입",
#  '삼진제약, 캐나다 기업과 AI 신약개발 공동연구 추진',
#  '괴산군의회, AI영재고 유치 건의문 채택',
#  '베토벤, 고흐 환생도 가능..‘스탠포드 AI 인덱스’ 미-중 투톱, 한국은?[여의...',
#  "카카오뱅크, 에프앤가이드와 금융 AI 고도화 '맞손'",
#  "리퍼블릭케이·에프앤가이드·연세대, 'AI 시장진단 연구' MOU 체결",
#  '한국AI속기사협회, AI데이터전문속기 프리랜서 오프라인 교육 실시',
#  'KB국민은행, ‘AI 기업여신 자동심사 시스템’ 구축',
#  "SK텔레콤, '인터스트리얼 AI' 사업 확대 나선다",
#  'SKT, ‘인더스트리얼 AI’ 사업 확대 나선다',
#  '軍도 수학에 러브콜 "독자 AI(인공지능) 알고리즘 만들겠다"',
#  "가톨릭대-마인드허브, '뇌신경 환자 언어재활 AI 연구' 협약",
#  ...]

# %% [markdown]
# ## 저장

# %% [markdown]
# - 임시저장

# %%
#list > df > csv
title_df = pd.DataFrame(title_list)
title_df.to_csv('AI_title.csv',header=None, index=None)

# %% [markdown]
# - 다시 불러오기

# %%
title_df = pd.read_csv('AI_title.csv', header=None)
title_df.rename(columns={0:'title'}, inplace=True)
title_list=title_df['title'].values.tolist()
title_list
# Out:
# ['KT·서울성모병원, 당뇨 관리 돕는 AI 기술 개발',
#  '삼성전자, AI인재 키워 반도체·디스플레이 연구한다',
#  '삼성전자 ‘AI 챌린지’',
#  '농정원, 스마트농업 AI 경진대회 개최…총상금 1억원',
#  "코트라, 'AI 활용'…중견기업 ESG 모니터링 지원",
#  'KT-NIPA, ICT 벤처에 DX 컨설팅·AI인재 양성 지원',
#  '영진전문대 AI융합기계계열, 로봇관련 학술대회 논문상 수상',
#  '“일주일내 범죄 발생 예측 정확도 90%” AI 도입 득될까?',
#  'KT, 공감하는 AI로 ‘사람다운’ 로봇 세상 만든다',
#  'AI와 대화·이동통신 모니터링…‘고독사 예방’ 팔걷은 지자체들',
#  '영남중·대구고 SW동아리, MS 주최 AI 경진대회 수상',
#  '현대차 `R&D 경력` 세자릿수 채용… AI 인터뷰 도입',
#  '서울시-KAIST, 기업 내부서 고급 AI개발자 인력 양성하도록 지원',
#  "지금 들어가고 9월까지는 팔아라…AI가 예언하는 '나스닥100'",
#  '남성희 전문대교협회장 "전문대 AI·반도체 전공에 4년제 허용해야"',
#  "[AI-META 시대 '미래전략']<26>교육 대전환",
#  '시 쓰는 AI, 인간에게 던지는 화두는?',
#  '조선대, 프라이버시 보장 AI 기술 공동 개발…동형암호 실용화 기반 마련',
#  '도로교통공단, 빅데이터ㆍAI 기반 위험도로예측 시범서비스 구축',
#  '조선대, 화정중서 ‘AI‧SW 여름방학 아카데미’ 진행',
#  "AI와 영어 말하기 대결…윤선생 '말하톤 대회' 개최",
#  "카카오가 찜한 'AI 아이돌', 뉴스 생방송에서 일냈다…'가상인간' 열풍",
#  '‘땅개’서 ‘AI 무장 호랑이’로… 전투력 초격차로 적 초토화 [S스토리]',
#  '과기정통부, AI 초일류 전략 내놓는다···AI 활용 제고에 방점',
#  'KT, EBS와 AI 인재 육성 맞손',
#  '풍선 속 다이아몬드 찾기…중국 쇼핑몰 아수라장｜AI가 Pick한 세상',
#  "광주시의회, AI 전문가 초청 '인공지능 R&D 발전방향' 공부",
#  "똑똑한 'AI 은행원' 나온다...금융위, 가명정보 AI 데이터로 허용",
#  '동강대\xa0AI\xa0기반 맞춤형 토익 프로그램 실시',
#  'AI가 이젠 시도 쓰고 작곡도 한다…저작권은 어떻게 될까',
#  '김포공항 AI, 반입금지 물품 1초만에 잡는다',
#  '서울시-KAIST, 고급 AI개발자 양성 프로그램 지원',
#  '"AI로 병원 혁신시킨다는 믿음" 네이버 광폭행보',
#  "에이프리카, AI 통합 플랫폼 '치타' 조달청 디지털서비스몰 등록",
#  '세일즈포스·마이크로소프트…전세계 AI기업 한방에 투자',
#  '현대차 연구개발본부, AI활용 대규모 경력직원 채용',
#  "포스코그룹, AI 기술 자문위원회 신설…'미래 전략' 수립 시동",
#  '포스코그룹, \'AI 기술 자문위원회\' 신설…"신사업·인재 발굴"',
#  "괴산군도 합류 … AI 영재고 유치전 `후끈'",
#  "KB증권, 인공지능 기술 적용한 'AI상담 콜봇'",
#  '서천교육청, 미래 시대를 위한 AI 교육 교원 연수 운영',
#  'aT, 농산물 가격 예측 AI 경진대회 개최',
#  '시(詩) 감정선까지 짚어낸 AI...‘무한도전’',
#  '의료기 유통 에이치엔드림, AI영상분석 우경정보기술과 협약',
#  '호남대, 광주발달장애인훈련센터 AI교육과정 자문',
#  '덴마크에 AI정당 등장···2023년 의석 확보 목표',
#  '[Pangyo Tech] 리빌더AI, 가상공간 구축 위해 메가플랜과 맞손... 다량의 실사...',
#  "'모네인 듯, 모네 아닌' AI 그림…예술적 가치 있을까? [아트마켓 사용설명서...",
#  '진천교육청-진천군-카이스트, K-스마트교육 2.0 로봇 AI 영재캠프 개최',
#  '울산대 맞춤형 AI 인력양성과정 수료식 개최',
#  '기보, 신입직원 75명 뽑는다…AI역량검사·블라인드 채용',
#  '[AI·VR·AR, 미래를 연다](9)써니팩토리',
#  "[김주하 AI 앵커와 쉬운 우리말로] '스키드 마크'를 우리말로 하면?",
#  '라이언로켓 X 티그컴퍼니, AI 접목한 새로운 K컬처 선봬',
#  '[포착] 한밤중 극단적 선택 직전, AI가 극적 구조했다',
#  '지질자원연, 제2회 지질자원데이터 활용 AI 경진대회',
#  '키움증권, AI가 고객 투자성향 분석해 자동으로 자산 배분',
#  '[이환주의 아트살롱]AI와 예술 1화: AI가 노벨문학상을 받는다면?',
#  '[삼성화재배 AI와 함께하는 바둑 해설] 수에는 가격이 없다',
#  'DL이앤씨, AI·360도 카메라 기반 현장관리 솔루션 도입',
#  '고위험 수입식품, AI가 차단한다',
#  "GS네오텍, AI 기반 보안 서비스 '사이트 디펜더' 출시",
#  '"딥페이크, 사회·국가적 혼란 초래 우려…AI로 AI 악용 막아야"',
#  '[게시판] KB증권, AI 상담 콜봇 서비스 오픈',
#  'AI 스타트업 ‘마크비전’ 260억 시리즈A 유치 성공 [주간 VC 동향]',
#  '제이엘케이 AI 치매 분석 솔루션, 태국 허가 획득',
#  '포스코 AI기술 자문위원회…산학전문가 20여명 첫 회의',
#  '[데일리 IT 단신] KT-NIPA, ICT 벤처 DX컨설팅·AI인재양성 지원 外',
#  "[특징주]드림어스컴퍼니, 아마존 2조에 아이로봇 인수..AI 로봇청소기 '에이클...",
#  '한양대 ERICA, CEO를 위한 AI 교육과정 신설',
#  'KAIST "반도체·AI 생태계 선도…논문 수 세계 상위권"',
#  'KT-세존, AI·DX기술 기반 방역 산업 분야 협력',
#  'KT-강동경희대병원, AI로봇 활용 병원업무 디지털전환 협약',
#  'KT, EBS와 AI 인재 육성…SW·AI 학습환경 제공',
#  '[특징주]링크제니시스, 정부 AI 산업 원천기술 확보 추진..국내최초 AI 시스템...',
#  "'인공지능(AI) 활용 간담회' 개최",
#  '이영복 제네시스랩 대표 "사람이 갖는 편견…공정한 AI면접에는 없습니다" [시...',
#  'AI 돌봄 인형…독거 노인 든든한 벗',
#  '강기정 광주시장 "여당이 AI반도체 단지 등 현안 힘써달라"',
#  'KB증권, AI 상담 콜봇 서비스 오픈外키움증권 [쿡경제]',
#  '시 쓰고 그림 그리고… 예술영역 넘보는 AI',
#  '가상의 쌍둥이로 내 병 미리 찾아낸다... KT, AI 헬스케어 시스템 개발 착수',
#  '금융에 스며드는 AI…활성화 정책도',
#  "[IR52 장영실상] 삼성전자, '로봇청소기 비스포크 제트봇 AI'",
#  '화성시 새솔동 등 AI 자원회수기기 9곳 시범 운영',
#  "삼성전자·SK하이닉스, AI 반도체로 '초격차 경영 속도'",
#  '빅데이터ㆍAI 활용 고위험 수입식품 선별한다',
#  "'인공지능(AI) 활용 간담회'에서 발언하는 김소영 금융위 부위원장",
#  "아이스크림에듀, '서리풀 샘 AI 스마트 스쿨링' 우수 학습 멘티에 장학금 수여",
#  '괴산군도 AI영재고 유치전 가세…군의회, 건의문 채택',
#  "에듀윌, 공무원 합격진단 'AI-Pass'…예측 서비스 운영",
#  '위메프, 애플 출신 AI전문가 기술책임자로 영입',
#  "롯데정보통신, '보안 AI 모델'로 지능형 위협 차단",
#  '딥브레인AI, 하나은행 앱에 AI은행원 공급',
#  '금융위, 금융분야 AI기술 활성화 나선다',
#  'KOTRA, 중견기업 ESG 위기감지…AI로 관련뉴스 분석 후 제공키로',
#  '빅데이터·AI 기반 위험도로예측 시범서비스 구축',
#  '포스코그룹, AI 기술 자문위원회 신설…신기술·전략방향 조언',
#  '삼성전자, “국내 대학·대학원생 중 AI 최고수는?”',
#  'KT, EBS와 AI 교육 협력…"디지털 100만 인재 양성 기여"',
#  '삼성전자, AI 인력・기술 난제 공모전으로 해결',
#  '영진전문대 AI융합기계계열 학생들, ICROS 2022 학술대회 우수논문상 수상',
#  '현대차, 전동화 등 연구개발 경력 인재 대규모 채용…AI 활용 인터뷰 도입',
#  '괴산군의회, AI 영재고 유치 건의문 채택',
#  "KB증권, 인공지능 기술 적용 'AI 상담 콜봇' 서비스 시행",
#  "삼성전자, 대학·대학원생 대상 '2022 삼성 AI 챌린지' 개최",
#  '위험상황, 폰으로…도로교통공단, ‘AI 기술 활용’ 교통사고 예방 나서',
#  "삼성전자, 제2회 '삼성 AI 챌린지' 개최",
#  '현대자동차, AI로 대규모 R&D 경력 인재 확보 나선다',
#  'KB證, ‘AI 상담 콜봇’ 서비스 오픈',
#  '인공지능 우수 인력 발굴…삼성전자 ‘AI 챌린지’',
#  '호남대,\xa0광주발달장애인훈련센터\xa0AI교육과정 자문',
#  '포스코그룹, AI 기술 자문위원회 신설한다',
#  '포스코그룹, AI 기술 자문위 신설…미래 전략 수립',
#  "KB증권, 'AI 상담 콜봇' 서비스 오픈",
#  "금융 분야 AI기술 키운다…'데이터 라이브러리' 구축(종합)",
#  'KT, EBS와 손잡고 ‘AI 꿈나무’ 육성',
#  "삼성전자, 대학원생 대상 'AI 챌린지'... 신소재 연구·컴퓨터 비전 공모",
#  '포스코그룹, AI 기술 자문위원회 신설',
#  '호남대, 광주발달장애인훈련센터 AI교육 자문',
#  '"초등생도 \'코딩\' 즐기도록"…KT, EBS와 \'SW·AI\' 인재 키운다',
#  "삼성전자, '2022 삼성 AI 챌린지' 개최",
#  '포스코그룹, AI 기술 자문위원회 신설…기술 공유·토론 진행',
#  '현대차, R&D 인력 채용…AI가 면접 본다',
#  '경북교육청, 누구나 가능한 SW-AI교육 기반 마련 확대',
#  "현대차, R&D 경력 인재 세자릿수 채용…'AI 인터뷰 도입'",
#  '맞춤형 AI 인력 양성과정 77명 수료',
#  '"AI반도체 수요 폭발"…삼성전자, 우수인력 발굴',
#  '"100만 디지털 인재 양성"...KT, EBS와 AI·SW 교육 협력',
#  '서울시-KAIST, 기업 AI 인력양성 프로그램 지원',
#  'KT·NIPA, AI·DX 분야 인재양성 MOU 체결',
#  "KB증권 'AI 상담 콜봇' 서비스 시행…24시간 어디서나 상담 가능",
#  "삼성전자, '2022 삼성 AI 챌린지'...인공지능 기반 '신소재 연구'와 '컴퓨터 ...",
#  'KT, EBS와 ‘소프트웨어·AI 미래인재’ 키운다',
#  '금융 AI 개발용 공동 데이터 라이브러리 출범',
#  '인공지능 솔루션 전문기업 리빌더AI, 메가플랜과 가상공간 활용 최적 솔루션 ...',
#  'KB증권, ‘AI 상담 콜봇’ 서비스 오픈',
#  '"인공지능으로 반·디 연구" 삼성전자, \'2022 삼성 AI 챌린지\' 개최',
#  "포스코그룹 'AI 기술 자문위원회' 신설",
#  "금융권 AI 도입 확대되나…금융위 '데이터 라이브러리' 추진",
#  '영진전문대 AI융합기계계열, 제어로봇시스템 재학생 전문대 유일 우수 논문상...',
#  'KT-NIPA, 컨설팅 및 AI·DX 인재양성 업무 협약',
#  'KT, EBS와 AI·SW 인재 양성 위한 교육 콘텐츠 제작',
#  '경북교육청, SW-AI교육 환경개선 사업 확대 실시',
#  "삼성전자, '2022 삼성 AI 챌린지' 개최....AI 우수 인력 발굴과 반도체, 디스...",
#  "거대 금융 정보 저장소 구축...'금융AI 고도화' 첫걸음",
#  '영진전문대, AI융합기계계열 학술대회서 전문대생 유일 우수논문상 수상',
#  'KT, EBS와 AI 인재 육성 협력',
#  'KB증권, AI 상담 콜봇 서비스 개시',
#  '포스코그룹, AI기술 자문위 신설…AI사업분야·인재 발굴 나선다',
#  "경북교육청, 누구나 가능한 'SW-AI교육' 기반 마련",
#  'KT, EBS와 함께 AI 인재 육성한다',
#  "KB증권, AI 음성 상담 서비스 '콜봇' 오픈",
#  '경북교육청, SW-AI교육 환경개선 사업 확대 추진',
#  "농정원, 총 상금 1억 원 규모 '스마트농업 AI 경진대회’",
#  '"신사업·인재 발굴"…포스코그룹, \'AI 기술 자문위원회\' 운영',
#  "동강대, 'AI 산타' 플랫폼 활용 토익 교육 실시",
#  "가명정보 재사용 허용 '금융 AI 데이터 라이브러리' 구축",
#  '포스코그룹, AI기술 자문위원회 신설',
#  'KT, AI로봇 기반 병원업무 DX 추진',
#  "KT, EBS와 함께 'SW·AI 인재' 키운다",
#  "KT-EBS, SW·AI 인재 육성 '한뜻'",
#  '김소영 "금융권도 AI 활성화 필요…빅데이터 확보·제도정비 나설 것"',
#  "KAIST가 'AI 반도체' 주도한다",
#  '설계대로 잘 짓고 있나…AI가 콕 찾아낸다',
#  '포스코그룹, AI기술 자문위 신설…전문가 20명으로 구성',
#  '포스코그룹, AI기술 자문위원회 신설…전문가 20여명 참여',
#  '금융위 "AI로 불필요한 규제 없애고 소비자 편익 높인다"',
#  "화성시, 'AI자원회수기기 설치' 시범운영",
#  "조선대, 화정중서 'AI‧SW 여름방학 아카데미' 진행",
#  "KT, EBS와 함께 'AI 인재' 육성한다",
#  "윤선생, AI 영어 말하기 이벤트 '말하톤 대회' 개최",
#  '포스코그룹, AI와 더 가깝게…AI기술 자문委 신설',
#  '금융AI 활성화 위해 금융·비금융 대규모 컨소시엄 꾸린다',
#  '도로교통공단, AI 기반 교통사고분석시스템 사업 착수',
#  "서울시, KAIST AI 대학원과 협력…'최고급 AI 개발자 양성 교육' 프로그램 지...",
#  "한밤 충무대교 난간 넘어간 40대 'AI 시스템'이 구조했다",
#  "금융권 AI기술 키운다...'데이터 라이브러리' 추진",
#  'KB증권, "AI가 고객에 전화 걸어 상담진행한다"',
#  "'AI 영재고 괴산군 유치 건의문' 채택",
#  "삼성전자 '2022 삼성 AI 챌린지' 개최",
#  "삼성전자, '2022 삼성 AI 챌린지' 개최...대학·대학원생 대상",
#  'KB증권, 인공지능 기술 적용 ‘AI 상담 콜봇’ 서비스 시행',
#  '[게시판] 에프앤가이드·리퍼블릭케이·연세대, AI 업무협약',
#  '[주간VC동향] 인공지능(AI) 스타트업 마크비전 260억원 규모 시리즈A 투자 유...',
#  '‘AI 돌봄 인형’ 독거 노인 든든한 벗',
#  '삼진제약, 사이클리카와 AI 신약개발 공동연구 계약 체결',
#  '韓国の大学・大学院生を対象に「2022サムスンAIチャレンジ」開催',
#  'KT, EBS와 AI 인재 육성 위해 MOU 체결\xa0\xa0',
#  "KB증권, 'AI 상담 콜봇' 서비스 선봬",
#  '"美, AI칩 설계·제조 핵심 소프트웨어 中수출금지 추진"',
#  "AI가 시를 쓴다고?...카카오브레인이 개발한 '시인 AI' 첫 작품 나온다",
#  '‘금융 데이터 도서관’ 만든다… 금융위, ‘금융 AI 혁신’ 박차',
#  '화성시, AI\xa0자원회수기기로 재활용률 높인다',
#  '삼진제약, 신약개발 속도…AI 개발 플랫폼과 협업',
#  'KT, NIPA와 ICT 벤처 육성 및 AI·디지털전환 인재 양성 공동 추진',
#  '"치매예방"…SK케미칼, 36개 기관에 AI기반 인지개선 프로그램 보급',
#  '금융권, 빅테크 진출 위해 AI 활용 활성화 나선다',
#  'KT, EBS와 공교육 내\xa0SW·AI\xa0학습환경 개선 나서',
#  "SK㈜ C&C 'AI 뇌출혈 영상의료 솔루션', 울릉도 환자 돕는다",
#  "리퍼블릭케이·에프앤가이드·연세대, 'AI로 금융시장 연구' 협약",
#  '리빌더AI, 가상공간 구축위해 메가플랜과 MOU 체결',
#  "SK케미칼 '치매예방 AI서비스' 노인센터에 지원",
#  '`금융 AI 데이터 라이브러리` 구축된다…"가명정보 재사용 허용"',
#  'KT, EBS와 SW·AI 학습환경 제공 위한 MOU 체결',
#  'KB증권, AI 상담 콜봇 서비스 오픈',
#  '인공지능으로 미래가치 높인다…포스코그룹, AI 기술 자문위원회 신설',
#  "KB증권, 시간·장소\xa0제약없이 'AI 상담' 받는다",
#  "DL이앤씨, AI·360도 카메라 기반 현장관리 솔루션 '디비전' 도입",
#  "SK C&C, 울릉군보건의료원에 'AI 뇌출혈 영상 의료 솔루션' 공급",
#  'KT, EBS와 AI 인재 키운다…100만 디지털 인재 양성 기여',
#  "자율주행 시스템용 AI 스타트업 '퍼셉티브 오토마타' 좌초",
#  "시드투자…의료 AI 로봇 '코넥티브'·푸드헬스 '마음영양'",
#  '경북교육청, 누구나 가능한 SW-AI교육 기반 마련',
#  '괴산군의회 "AI 영재고 유치 생존 문제"…건의문 채택',
#  "포스코그룹, AI 기술 자문위원회 신설… '학계위원회' 킥오프 미팅",
#  'AI 신약개발, ‘빨리빨리’ 안되는 이유 있다…“정확도⋅상업성에 초점 맞춰...',
#  "KB증권, 고객 편의 증대 위한 'AI 상담 콜봇' 서비스 오픈",
#  'KT, S/W·AI 인재 육성 위해 EBS와 맞손',
#  '포스코, AI기술 자문위원회 신설… 트렌드 공유·미래사업 조언',
#  'KAIST, AI 반도체 생태계 선도...관련 세계 학회 종횡무진',
#  'SK㈜ C&C, 울릉군보건의료원에 AI 뇌출혈 판독 솔루션 공급',
#  '"충무대교 배회하면 수상해"…통영시 AI로 자살시도자 구조',
#  'AI가 설명도 한다고?',
#  '울산대, 맞춤형 AI 인력양성과정 수료식',
#  '[AI 주간 브리핑] 신기방기 AI모델들, 인기몰이 중 \xa0 \xa0\xa0',
#  "AI·우주 분야 등 전문가 한 곳에?···대전시, '월드포럼' 개최",
#  '충북 4개 시·군 AI영재고 유치전 후끈…의회도 가세',
#  '포스코그룹, AI기술 자문위원회 신설로 "체계 구축"',
#  '김소영 부위원장 "빅데이터·AI 활용 지원…금융규제 혁신"',
#  '금융위 부위원장 “금융권 빅데이터·AI 활용 위해 규제 혁신”',
#  '포스코그룹, 전문가 20여명 참여한 AI 기술 자문위원회 신설',
#  '파수, 비식별 솔루션에 AI 기술 탑재…“분류 정확도 강화”',
#  'SK케미칼, 치매 해결 위한 AI기반 인지개선 프로그램 보급 시작',
#  '현대차 연구개발본부, 대규모 경력R&D 인재 모집!... AI 활용 화상 인터뷰 적...',
#  '괴산군의회 "괴산에 \'AI 영재고\' 유치해야" 결의문 채택',
#  '포스코그룹, AI 기술 자문위원회 신설...AI분야 학계, 산업계 전문가 20명으로...',
#  '스타트업 손잡은 교육업계…AI 기술 도입 에듀테크 강화',
#  '[농정춘추] 단순농작업 혁신 위한 AI 로봇 개발과 보급 필요성',
#  '이글루, KISA 사이버보안 AI 데이터셋 구축 사업 수주',
#  "삼성전자, AI 인재 발굴·연구 위한 경연장 '삼성 AI 챌린지' 개최",
#  "'가명정보 재사용' AI 데이터 라이브러리 구축",
#  '금융당국, AI데이터 라이브러리 구축 추진',
#  "카카오 AI, '시'도 쓴다",
#  "AI 적극 활용하는 포스코그룹... 스마트 제철소 이어 'AI 기술 자문위' 신설해...",
#  "DL이앤씨, 국내 최초 AI·360도 카메라 기반 현장관리 솔루션 '디비전' 도입",
#  '금융위 "빅데이터·AI 활용 지원…금융규제 혁신"',
#  '전북교육청, AI기반 학생맞춤형 수업 전체 학교로 확산',
#  '떨어지는 글쓰기 능력…AI가 작문 훈련 돕는다',
#  "세종충남대병원, 대화형 메신저 'AI 챗봇' 서비스 오픈",
#  '[Tech in Trend] 개인정보 침해 우려 줄이는 AI 알고리즘, 연합학습',
#  "인기 애니 '귀멸의 칼날' 속 캐릭터들을 'AI'로 현실세계에 소환하자 보인 실...",
#  'KB證, AI 상담 콜봇 서비스 오픈',
#  '삼성전자, \'2022 삼성 AI 챌린지\' 개최..."AI 우수 인력 발굴, 반도체, 디스플...',
#  '한줄? 두줄? 애매한 임테기…AI는 안다 99.9% 확률로',
#  '삼진제약, 캐나다 사이클리카와 AI 신약개발 공동연구 계약',
#  '포스코그룹, AI 분야 전문가 20명으로 ‘AI 기술 자문위원회’ 신설',
#  "딥브레인AI, 하나은행 하나원큐에 'AI뱅커' 공급",
#  'DL이앤씨, AI 360도 카메라 기반 ‘디비전’ 도입',
#  '건강하고 안전한 생활 공간을 위해 … KT, ㈜세존과 AI/DX기술 기반 방역 산업...',
#  '3D 모델링 AI 솔루션 전문기업 리빌더AI, 메가플랜과 MOU 체결',
#  '\xa0‘AI 뇌출혈 영상 의료 솔루션’으로 울릉도 응급환자 돕는다',
#  'KT, EBS와 함께 AI 인재육성 나선다',
#  'DL이앤씨, 국내 첫 AI·360도 카메라 기반 현장관리 솔루션 도입',
#  '"AI반도체 집적단지 조성 등 힘 모으자"',
#  "금융위, 가명정보 재사용하는 'AI 데이터 라이브러리' 구축",
#  '인포텍코퍼레이션, 세액공제 AI솔루션 출시',
#  '"언제든 신속 상담 가능"...KB증권, ‘AI 상담 콜봇’ 서비스 오픈',
#  '포스코, AI 기술 자문위 신설 … 학계·산업계 두 분야로 운영',
#  "SK케미칼, AI 인지개선 '사운드마인드' 노인보호센터 보급",
#  '포스코그룹, AI 기술 자문위원회 첫 회의',
#  '식약처, AI로 위험 수입식품 잡는다',
#  '에프앤가이드·리퍼블릭케이·연세대, AI 금융투자 연구 나선다',
#  "더핑크퐁컴퍼니-AI 네트워크, '핑크퐁 아기상어' NFT 전시",
#  "에듀윌, 인공지능 합격비서 'AI-Pass' 추진…AI 합격진단 예측 서비스 선오픈",
#  "KB증권, 'AI 상담 콜봇' 서비스 개시",
#  '이제 AI컴퓨터비전과 360도 카메라로 건설현장 관리한다',
#  '‘의사만큼 똑똑한’ 뇌출혈 전문 AI 의사, 이번엔 울릉도로 향한다',
#  'GS네오텍, AI 기반 보안솔루션 서비스 ‘사이트디펜더’ 출시',
#  "'치매' ESG 나선 SK케미칼… AI 인지개선 프로그램 보급",
#  "[단독] n번방 사건 뒤 'AI 탐지' 도입했지만…이름값 '글쎄'",
#  "시(詩) 쓰는 카카오 AI '시아', 첫번째 시집 '시를 쓰는 이유' 출간",
#  '괴산군의회 "AI 영재고 유치는 지역 생존 문제"…건의문 채택',
#  '[포토] KT, EBS와 SW·AI 학습환경 제공 MOU',
#  '한밤중 대교 위 왔다갔다…극단적 선택 직전 AI가 구조했다',
#  '방문요양 스타트업 케어링, 네이버와 손잡고 AI 돌봄 서비스 박차',
#  "KB증권, 'AI 상담 콜봇' 서비스 오픈…연내 적용범위 확대 [증권오늘]",
#  '포스코그룹, AI 기술 자문위 신설',
#  '조선대, ‘AI·SW 여름방학 아카데미’ 성료',
#  '중기부, 194억 투입 AI로봇 등 154개 기업 지원',
#  'DGIST 창업기업 ㈜유니바, AI학습용 데이터 구축 지원사업 선정',
#  '포스코그룹, AI 기술자문위원회 신설',
#  '삼진제약, 캐나다 AI 기업과 신약개발 공동연구',
#  "금융위, AI 활용 활성화한다…'금융 AI 데이터 라이브러리' 구축",
#  "롯데정보통신, '시큐파이 SOC'에 보안 AI 모델 적용",
#  '화성시, AI자원회수기 새솔동 9군데 설치 운영',
#  "KT, EBS와 '맞손'…소프트웨어(SW)·인공지능(AI)\xa0학습환경 제공",
#  '금융위 "금융권 공유 AI 데이터 라이브러리 구축 지원"',
#  '에듀윌, 공무원 수험생 대상 AI 합격진단 서비스 오픈',
#  'KT·EBS, 디지털 인재 양성 \'맞손\'···"AI 학습환경 제공"',
#  "SK(주) C&C, 울릉군보건의료원에 'AI 뇌출혈 영상 의료 솔루션' 공급",
#  '[동아광장/이성주]책임감 있는 AI',
#  '\'금융 AI 데이터 라이브러리\' 구축···"가명정보 재사용 허용"',
#  '경북교육청, SW-AI교육 환경개선 사업 확대',
#  '포스코그룹, AI 기술 자문위 신설···각계 전문가 20명 구성',
#  'KT 대구경북본부, 라마다 문경새재에 AI호텔 서비스 제공',
#  '화성시 , 재활용 AI자원회수기 설치',
#  'KB증권, ‘AI 상담 콜봇’ 서비스 오픈... “신속한 상담 가능”',
#  'SK케미칼, 36개 기관에 AI 기반 인지개선프로그램 보급',
#  'KT, EBS와 소프트웨어·AI 인재 육성한다',
#  '금융위,\xa0금융분야 AI 활성화 나선다…"가명정보 재사용 허용"',
#  "에듀윌, 인공지능 합격비서 'AI-Pass'로 에듀테크 입지 강화",
#  'AI로 위조상품 꽉 잡는 마크비전, 260억원 투자 유치',
#  'SK㈜ C&C, 3시간 골든타임 잡는 ‘AI 뇌출혈 솔루션’ 울릉도에 공급',
#  '딥노이드, AI 기반 흉부 엑스레이 진단 논문 국제학술지 게재',
#  'SK㈜ C&C의 CT분석 AI가 울릉도 응급진료 돕는다',
#  'AI가 쓴 시집 나온다',
#  "리빌더AI-메가플랜, 가상공간 구축위해 모델링 전문 기업 '맞손'",
#  'AI가 내 대출 심사, 어떻게 믿지?',
#  '금융위 "금융권 빅데이터 AI 활성화 위해 규제 혁신"',
#  "이글루코퍼레이션, KISA '보안 AI 데이터셋' 구축 사업 수주",
#  'AI영재고 유치전 괴산군도 가세…군의회 건의문 채택',
#  "멋쟁이사자처럼, 데이터 분석가 양성 'AI 스쿨' 29일까지 모집",
#  'AI인재가 없는 이유 "코딩 몇 줄로 답 내는 게 아니라 기본원리 아는 인재 필...',
#  "DL이앤씨, AI·360도 카메라 기반 현장관리기법 '디비전' 도입",
#  "KB증권, 'AI 상담 콜봇' 서비스 시행",
#  'AI 은행원이 대출 심사까지…"금융빅데이터·AI활용 막는 규제 혁신"',
#  'GS네오텍, AI 기반의 보안솔루션 서비스 ‘사이트디펜더’ 출시',
#  'KAIST “반도체·AI 생태계 선도…논문 수 세계 상위권”',
#  '금융 AI 활성화 추진…데이터 라이브러리 만든다',
#  "'농산물 가격 예측 AI 경진대회’ 개최",
#  'SK케미칼 "고령층에 AI 치매예방 프로그램 보급합니다"',
#  '포스코그룹, AI 기술 자문위원회 신설..."진화하는 AI신기술·전략 방향 조언...',
#  'KT, AI 식이·인슐린 솔루션 디지털 트윈으로 당뇨 관리',
#  "2022년\xa0말,\xa0AI\xa0보안성\xa0검증체계\xa0위해\xa0'AI\xa0보안\xa0가이드라인'\xa0마련",
#  '10년째 2400억 비트코인 찾는 영국男…"AI·로봇 사용해 수색"',
#  "SK C&C, 골든타임 잡는 'AI 기반 뇌출혈 솔루션' 울릉도 공급",
#  'KT-강동경희대병원, AI 로봇 의료서비스 개발 협약 맺어',
#  '1만3000여편 읽으며 작법 익혀…시 쓰는 카카오 AI',
#  'AI 학습속도 4.5배↑…스마트폰 과부하 막는다',
#  '의료 AI 로봇기업 ‘코넥티브’, 시드 투자 유치',
#  'KB국민銀, AI기술 적용 기업여신 자동심사 시스템 구축',
#  '한밤중 대교 위 서성여…극단적 선택 직전 AI가 구조',
#  "'큰 글씨에 AI 자막'… 저축은행, 금융 취약층 맞춤 디지털 서비스",
#  "aT, '농산물 가격 예측모형 개발' AI 경진대회 연다",
#  '포스코그룹, AI 기술 자문위원회 신설…AI분야 학계 등 20명 구성',
#  '금융위, 금융분야 AI 활성화 나선다…"규제 적극 해소"',
#  "카카오브레인, '시 쓰는 AI' 내놨다…시집도 출간",
#  '시, 그림, 작곡까지 ‘뚝딱’…“AI, 넌 못하는 게 뭐니?”',
#  'SK C&C, 울릉군보건의료원에 AI 뇌출혈 판독 솔루션 공급',
#  "KB증권 'AI 상담 콜봇' 서비스…담보부족 등 자동 안내",
#  '포스코, AI기술 자문위원회 신설...첫 회의 개최',
#  '루이비통도 고객…AI로 위조상품 막는 마크비전, 260억 투자 유치',
#  '"AI가 유전도 뚫는다…전환기 에너지기업은 변신중" [실리콘밸리 인사이드]',
#  '딥노이드, AI 솔루션 활용한 폐질환 탐지 유용성 입증',
#  "[#IT라운지] 통신 4사 '업무협약'·SK C&C 'AI의료솔루션' 제공",
#  '스마트폰 위 ‘AI 연합학습 속도’ 4.5배 늘리는 기법 개발',
#  '루닛, 임상시험서 AI 치료 효과 확인에 주가 급등',
#  '포스코그룹, AI사업분야ㆍ인재 발굴 나선다',
#  "팜캐드, '바이오플러스·인터펙스'서 AI 약물개발 성과 등 발표",
#  "SK C&C 'AI 뇌출혈 영상 진단'…울릉도 응급환자 돕는다",
#  "한국농수산식품유통공사, '농산물 가격 예측 AI 경진대회' 개최",
#  '롯데정보통신, 보안 AI로 지능형 위협 차단',
#  '기보, 신입 공채…표절 여부 AI로 거른다',
#  "투디지트, AI 기반 뉴스 추천·분석 정보 제공 서비스 '뉴스샐러드' 개발",
#  '정부, 가명정보 재사용 허용 ‘금융 AI 데이터 라이브러리’ 구축한다',
#  '통영시, AI 딥러닝 기술로 ‘극단적 선택’ 막았다',
#  'AI가 개발하는 신약, 어디까지 왔나…"수요 맞춰 다양한 방식 분화"',
#  'KT, EBS와 함께 AI 인재 육성..."소프트웨어·인공지능 학습환경 제공을 위한...',
#  '오산시, AI로 CCTV 관제…범죄 예방 효과 기대',
#  '포스코그룹, AI 기술 자문위원회 신설…AI분야 산·학 전문가 20명 구성',
#  '삼진제약, 캐나다 사이클리카와 AI 신약개발 공동연구 계약 체결',
#  '금융권 "금융 AI 활성화, 소비자 편익 제고 기대"',
#  '허송연 아나, 은행원 됐다?…"AI휴먼 모델 계약후 AI뱅커로 활약"',
#  '화성시, AI 자원회수기기 9개소 시범운영',
#  '세종충남대병원, AI 챗봇 서비스 오픈',
#  '금융권 AI 빅데이터 적극 활용 돕는다',
#  "식약처, AI 활용한 '위험예측 기반 검사·관리 시스템' 구축 추진",
#  'SK㈜ C&C, ‘AI 뇌출혈 영상 의료 솔루션’으로 울릉도 응급환자 돕는다',
#  'KB증권, ‘AI 상담 콜봇’ 서비스 개시···담보부족·해외주식 배당옵션 등...',
#  '금융위, 디지털 금융혁신…빅데이터-AI 활용 활성화한다',
#  '‘AI 반도체’ 기술패권 전쟁시대…KAIST ‘초격차기술’ 확보 나선다',
#  '반도체·AI·빅데이터 등 석박사 증원 쉬워져···개정안 국무회의 통과',
#  "메타AI, 최신 AI 챗봇 '블렌더봇3' 소개",
#  "에프앤가이드·리퍼블릭케이·연세대, 'AI 활용한 금융 시장 연구' MOU 체결",
#  '조선대 지역사회 중학생 AI·SW교실 임무 완수',
#  '김소영 부위원장 "금융규제 혁신해 빅데이터·AI 활성화해야"',
#  "포스코그룹, 'AI기술 자문위원회' 신설...인공지능 분야 학계, 산업계 전문가...",
#  "KB증권 'AI 상담 콜봇' 서비스 오픈",
#  '롯데정보통신, 보안 AI 모델로 지능형 위협 차단',
#  'KT, EBS와 함께 AI 인재 육성 협력',
#  "DL이앤씨, AI·360도 카메라 활용 현장관리 솔루션 '디비전' 도입",
#  '‘예술’ 영역 넘보는 인공지능…시 쓰고 그림 그리는 초거대AI',
#  "멋쟁이사자처럼, 데이터 분석가 양성 과정 'AI 스쿨' 모집",
#  "영진전문대 'AI융합기계계열 학술대회 논문상' 수상",
#  "딥브레인AI, 하나은행 모바일 앱에 'AI 휴먼' 공급",
#  '김소영, "디지털 금융규제 혁신…빅데이터·AI 활용 지원"',
#  'SK하이닉스, AI·빅데이터 연산에 최적화한 CXL 메모리 첫 샘플 개발',
#  "KB증권, 'AI 상담 콜봇' 서비스 시작...24시간 상담 가능",
#  "헷갈리는 '임테기' 결과 AI가 알려준다…NHN에듀, 서비스 출시",
#  "조선대 김영식 교수, 서울대 및 대구경북대 연구팀과 '프라이버시 보장 AI 기...",
#  'SK케미칼 등 3사, AI 치매예방 프로그램 보급···"사회적 가치 창출"',
#  '“300회 이상 실증, AI와 위성, 암호통신까지…UAM 경쟁사보다 우위”',
#  'SK케미칼, AI기반 인지개선 프로그램 노인보호센터 보급',
#  "AI 기반 무릎관절 수술 '코넥티브', 카카오벤처스 시드투자 유치",
#  'SK케미칼, AI 인지개선 프로그램 보급…치매 예방 앞장',
#  '스마트폰 위 AI 연합학습 속도 4.5배 높여 과부하 막는다',
#  '“AI가 이런 것까지?”‥KB증권, ‘AI 상담 콜봇’ 서비스 선봬',
#  '[인터뷰] 김제민 연출 "시 쓰는 AI 작가 \'시아\'는 질문 품은 공동 창작자"',
#  'SK㈜ C&C ‘AI 영상 의료 솔루션’ 울릉도에 공급',
#  "카카오브레인, 시쓰는 AI '시아' 시집 출간",
#  '이글루코퍼레이션, KISA 사이버보안 AI 데이터셋 사업 수주',
#  '“삼성·LG, 고객 목소리 들어야…” 글로벌 AI 고객경험 분석 CEO가 던진 말...',
#  '통영 충무대교 난간 넘던 40대 AI가 구해',
#  '제이엘케이, AI 기반 뇌 노화 분석 솔루션 태국 허가 획득',
#  '카카오 AI, 시인으로 데뷔한다…"시를 쓰는 이유" 8일 출간',
#  '삼진제약, 캐나다 `사이클리카`와 AI 신약개발 공동연구 계약 체결',
#  'SK㈜ C&C, AI 뇌출혈 검사 솔루션 울릉도 공급',
#  'AI로 공공SW사업 제안요청서 작성 불편 해결',
#  '경북교육청, 누구나 가능한 SW-AI 교육 기반 마련',
#  '의료 AI 로봇 기업 코넥티브, 카카오벤처스 시드 투자 유치',
#  'SK㈜ C&C, 울릉군보건의료원에 AI 뇌출혈 영상 의료 솔루션 공급',
#  '스마트뱅킹에 AI 휴먼이?',
#  '딥브레인AI, 하나은행 모바일 앱에 AI 뱅커 공급',
#  'KB증권 " \'AI상담 콜봇\' 서비스 시행...고객 편익 증대"',
#  '금융분야 AI 경쟁력 키운다…관련 제도·규제 혁신',
#  '조달청 AI기반 SW사업 발주지원시스템 도입…제안요청서 자동생성',
#  "AI 물류 스타트업 '바이너리브릿지' 44억 규모 프리A 투자 유치",
#  '"해외 우수 인재 모신다" 현대차, AI·자율주행 박사 국내 초청 채용',
#  '롯데정보통신, 보안 AI로 고도화된 사이버위협 대응',
#  "DL이앤씨, AI‧360도 카메라 기반 현장관리 솔루션 '디비전' 도입",
#  '화성시 AI 자원회수기기로 재활용률 높인다',
#  "KT 인공지능 교육서비스 '코디니', EBS 교육플랫폼 '이솦'에 탑재...AI·SW\xa0...",
#  '금융위, 금융분야 AI 데이터 라이브러리 구축',
#  '위험한 수입식품, AI로 판별한다',
#  'SK케미칼·SK바이오사이언스·SK플라즈마, AI로 치매 해결 시도',
#  '에듀윌, 인공지능 합격비서 ‘AI 패스’ 만든다',
#  '"시를 쓴다는 건, 세상에서 가장 짧은 말을 하는 것"..AI가 쓴 서시',
#  'SK케미칼, 치매 예방 활동 펼친다…노인센터에 AI 기반 인지개선프로그램 보급',
#  '‘쿨투라cultura 8월호’ K-콘텐츠의 AI 활용 전망을 탐색하다',
#  '조달청, AI기반 공공SW사업 발주지원시스템 개통',
#  "딥브레인AI, 하나은행 모바일 앱에 'AI 뱅커' 공급",
#  'SK㈜ C&C, AI 뇌출혈 영상기술로 울릉도 환자 돕는다',
#  "DL이앤씨, 국내 최초 AI·360도 카메라 현장관리 솔루션 '디비전' 도입",
#  '화성시, AI 자원회수기기로 재활용률 높인다',
#  '국민은행, AI 기술 적용 기업여신 자동심사 시스템 구축',
#  '삼진제약, 캐나다 사이클리카와 AI 신약개발 공동연구',
#  '카카오브레인, 초거대 AI 언어 모델 ‘KoGPT’ 활용 시집 출간',
#  "하나은행, 모바일 앱 내 'AI뱅커' 도입",
#  '딥노이드, "AI솔루션 폐질환 위치 탐지 입증… 국제학술지 게재"',
#  '메디웨일 "망막 검사로 심혈관질환 예측하는 AI 의료기기 허가"',
#  '트윔, 에너지 산업 분야 50억원 규모 AI 검사 프로젝트 수주',
#  "SK㈜ C&C, 울릉도보건의료원에 'AI 뇌출혈 영상 의료 솔루션' 공급",
#  '삼진제약, AI 신약개발 플랫폼사와 공동연구 계약',
#  '"국방과학기술의 첨단화"…정부, AI·로봇·UAM 활용 국방 R&D 강화',
#  '"美, 中에 AI 반도체 설계·제조 핵심 소프트웨어 수출 금지 추진"',
#  '포스코그룹, AI 기술 전문가 모아 자문위원회 신설',
#  "[초점] 메타 경영진, 새로 발표한 최첨단 AI 때문에 '난감'",
#  'AI 기반 인지개선 프로그램… 노인보호센터 통해 보급',
#  "스마트폰 위 AI '연합학습' 속도 4.5배 달성...KAIST, 새로운 가속 기법 개발",
#  '"AI신약개발, 속도보다 정확도…상업화 위한 맞춤형·차별화 필요"',
#  'DL이앤씨, AI기반 360도 카메라 건설현장 도입..공기 단축 효과',
#  '김소영 금융위 부위원장 "AI 기술 고도화 필수적"',
#  '금융위, 가명 금융정보 재사용 허용...금융 AI 데이터 라이브러리 구축',
#  '"AI로 골든타임 지킨다"…SK C&C, 울릉도에 \'AI 뇌출혈 판독 솔루션\' 공급',
#  "파수, 개인정보 비식별 솔루션 'ADID'에 AI 기술 탑재",
#  '삼진제약, 캐나다 AI 업체와 신약 개발 나선다',
#  'KT-강동경희대병원, AI 로봇 활용 병원 업무 디지털 전환 협력',
#  "의료 AI 로봇기업 '코넥티브', 시드 투자 유치",
#  "파수, 비식별 솔루션 '애널리틱디아이디'에 AI 기술 탑재",
#  '"여성 언더웨어도 이젠 AI시대"...AI맞춤형 속옷추천앱 ‘퍼펙트핏’ 눈길',
#  '"우린 늘 1등" 카이스트, 반도체·AI 연구 성과 발표',
#  '"발주도 입찰도 어려운 공공SW사업, AI기술이 도와드려요"',
#  'SK케미칼, AI 인지개선프로그램 보급 통해 치매 예방 나선다',
#  '스마트폰 AI 연합학습 속도, 4.5배 빨라진다',
#  '카카오 AI, 그림 이어 시도 쓴다',
#  "[굿모닝충북] 한 끼 밥도 못 챙기면서 'AI영재고' 타령 빈축",
#  '“충무대교 위 수상한 움직임 포착” 통영시 AI, 투신 시도자 구했다',
#  "'6천억 시장' 음식물처리기…똑똑해야 팔린다 'AI 무장'",
#  'KAIST, AI 반도체 생태계 이끈다',
#  'KT, 채용연계형 AI 석사과정 신입생 모집',
#  '장성군,인공지능(AI)말동무 인형 지원사업 추진',
#  'SK㈜ C&C, AI 뇌출혈 영상 의료 솔루션 공급 확대',
#  'DL이앤씨, AI·360도 카메라 활용해 현장관리 효율 극대화',
#  '2400억 비트코인 찾으려 9년째 쓰레기장 맴도는 남성…"AI·로봇으로 수색"',
#  "\xad AI 모델 '연합학습' 속도 빨라진다",
#  '괴산군의회 "AI영재고, 괴산 유치해야"',
#  'DGIST 학부생 창업기업, AI 학습용 데이터 구축 지원사업 선정',
#  '美 애플 AI개발 이진호 박사 위메프, 최고기술책임자 영입',
#  'SK C&C, AI로 울릉도 응급환자 돕는다',
#  '"반도체·AI 생태계 선도"',
#  '포항공대, AI 경영자 양성을 위한 최고경영자과정 신설',
#  '삼진제약-사이클리카 ‘AI 신약개발 공동연구’ 계약',
#  '충남도, AI학습용 ‘종패 생산 데이터’ 구축',
#  '기보, 2022년도 신입직원 75명 채용... AI 빅데이터 기반 검사 실시',
#  "이글루코퍼레이션, 'KISA 사이버보안 AI 데이터셋' 사업 수주",
#  'KB국민은행, AI활용 다각화 나선다',
#  "DL이앤씨, AI·360도카메라 기반 현장관리기법 '디비전' 도입",
#  '금융위, AI 활용 디지털 금융혁신 돕는다..‘AI 데이터 라이브러리’ 구축',
#  '괴산도 AI영재고 ‘유치전’ 가세…군의회, 건의문 채택',
#  '카이스트 “반도체·AI 생태계 선도…논문 수 세계 상위권”',
#  '통영 충무대교 난간 넘은 40대 `AI`가 구조',
#  'AI기반 학생맞춤형 수업 전체 학교로 확대 모색',
#  '괴산군의회, AI 영재고 유치 건의문',
#  'KT AI 호텔, 라마다 문경새재 호텔에 들어선다',
#  "에듀윌, 인공지능 비서 'AI-Pass' 공개",
#  "[재택플러스] '무인'점포 범죄‥'AI'기술 도입",
#  '英, 운전중 핸드폰 사용 단속하는 AI 감시 차량 운영',
#  'SK㈜ C&C, 울릉군보건의료원에 AI 뇌출혈 검사 솔루션 공급',
#  '포스코그룹, AI 전문가 목소리 듣는다',
#  'DL이앤씨, AI·360도 카메라 기반 현장관리 솔루션 ‘디비전’ 도입',
#  'CJ올리브네트웍스, AI 인재 양성 박차',
#  '코트라, 중견기업 ESG 이슈 모니터링 서비스…“AI로 분석해요”',
#  '경상국립대 AI융합인재교육연구단, 지자체 네트워킹 및 협력강화 워크숍',
#  '팜캐드, AI 신약개발 플랫폼 성과 공개',
#  '형형색색 두둥실…미국서 열기구 축제｜AI가 Pick한 세상',
#  '금융 AI 데이터 라이브러리 구축…금융위 "금융규제 혁신"',
#  '보은군의회, AI영재고 유치 촉구',
#  'AI·360도 카메라 기반 현장관리 솔루션...DL이앤씨, 이스라엘社 손잡고 전격...',
#  '블로그 | 클라우드 기반 AI/ML이 온프레미스로 돌아오는 이유',
#  '"나랑 게임 한판 할래?"...친구 아닌 AI가 하는 말이었다',
#  '경북교육청, SW-AI교육 환경개선 사업 시행',
#  '금융위, “금융권 AI 활성화 적극 지원”',
#  '파수, 비식별 솔루션 ‘애널리틱디아이디’에 AI 기술 탑재',
#  '개인정보 유출 없다···스마트폰 AI기술 4.5배 ↑\xa0',
#  '포스코, AI 기술 자문위원회 신설…신기술·미래 전략 조언',
#  "괴산군의회 'AI 영재고 괴산군 유치 건의문' 채택",
#  '삼성, AI·ML에 최적화된 차세대 메모리 솔루션 대거 공개',
#  "인공지능 합격비서가 공무원 수험생에게 합격 진단해주는 에듀윌 'AI-Pass'",
#  "KAIST, 반도체와 AI 핵심 기술력으로 '인공지능 반도체 '생태계 선도한다",
#  '고려대 법학전문대학원, 데이터·AI 전문 과정 개설',
#  '누구나 고흐처럼 그릴 수 있다… AI만 있다면',
#  'SK C&C, 울릉군보건의료원에 AI기반 영상 의료 솔루션 ‘메디컬 인사이트 플러...',
#  'LG전자·美 사운드하운드, 차량용 AI 음성인식 공동 개발',
#  'DL이앤씨, 국내 최초 AI·360도 카메라 기반 현장관리 솔루션 ‘디비전’ 도입',
#  'AI 활용해 고위험 수입식품 스마트하게 찾는다',
#  '"AI 코딩 교육 인프라 확대"...KT-EBS, SW·AI 인재 양성 위한 업무협약',
#  '화성시, AI자원회수기기 설치 시범운영',
#  '미디어그룹사람과숲, ‘AI 데이터셋’ 부문 3년 연속 ‘ICT대상’ 수상',
#  'DL이앤씨, AI 기반 현장관리 솔루션 ‘디비전’ 도입',
#  '"AI로 임신테스트기 결과 확인하세요"…NHN에듀 \'AI핑봇 임신테스트\' 출시',
#  '강기정 광주시장 “여당이 AI반도체 단지 등 현안 힘써달라”',
#  'AI속기사, 이젠 경찰조사때 대신 받아쓴다',
#  '의료인공지능 솔루션 기업 뷰노, 데이터 기반 의료AI 사업 박차',
#  'KAIST, 스마트폰 위 AI 연합학습 속도 4.5배 획기적 향상 기법 ‘개발’',
#  '[NOW] 詩 쓰는 AI 작가, 대학로 무대 진출',
#  '에듀윌, 인공지능 합격비서 ‘AI-Pass’ 서비스 오픈',
#  "카카오브레인 AI모델 시아, 첫 시집 '시를 쓰는 이유' 출간",
#  "이스트소프트-YBM, 외국어 교육 특화 'AI 휴먼' 만든다",
#  'KB국민은행, AI 기업여신 자동심사 시스템 구축',
#  '금융위, AI 활성화 위해 망분리 규제 개선ㆍ데이터 라이브러리 구축 나선다',
#  '금융당국, 금융권 AI 도입 박차…“금융규제 혁신 필수”',
#  '"AI, 7살 수준 자의식" 주장했다 해고…현실은?',
#  'HPE, AI 추론 전용 서버 출시',
#  "하나은행, 모바일 앱 하나원큐에 'AI 뱅커' 도입",
#  'KTOA, KIF 신규 자펀드 결성 추진...AI·6G 분야 투자',
#  "[AI-META 시대 '미래전략'] <25>공정거래",
#  "SK㈜ C&C, 'AI 뇌출혈 영상 의료 솔루션'으로 울릉도 응급환자 돕는다",
#  'KB국민은행, 기업여신 자동심사 AI 구축',
#  '"상상력을 펼쳐라"...경북교육청, SW-AI교육 기반 마련 나서',
#  '“모두가 쓸 수 있는 AI 기술을 만들고 싶다”',
#  'AI 인재 찾아 어디든 간다… 대학교·지하철역서 채용 캠페인',
#  '"중대재해처벌법 해법 찾기"...철강사, 안전 경영 위한 AI 기술 고도화',
#  '경상국립대학교 AI융합인재교육연구단, 지자체 네트워킹 및 협력강화 워크숍 ...',
#  '한양대 ERICA, CEO AI 교육과정 신설',
#  '루닛, 임상시험서 AI 치료효과 확인에 주가 급등',
#  '[단독] 실체없는 AI 영재고, 충북도내 기초정부간 갈등만 증폭',
#  '[#증권톡톡] 한국투자증권, 해외주식형 ELS 2종 모집·KB증권, AI 상담 콜봇 ...',
#  'DL이앤씨, AI기반 컴퓨터‧360도 카메라로 건설현장 관리',
#  '금융 모바일 앱에도 AI 휴먼이··· 딥브레인AI, 하나은행에 ‘AI 뱅커’ 공...',
#  '제이엘케이 AI 치매 분석 솔루션 태국 허가',
#  "조달청, AI 기반 공공SW사업 발주지원시스템 'e-제안요청 도움' 구축",
#  "AI 인공관절 로봇 전문 코넥티브 '시드 투자' 완료",
#  'KT, 2023학년도 봄학기 채용연계형 AI 석사과정 신입생 모집',
#  "농정원, '2022 스마트농업 AI 경진대회' 개최",
#  '리퍼블릭케이·에프앤가이드·연세대학교 AI기술 활용 위해 MOU체결',
#  '성범죄 피해 조서 쓰는 AI, 2급지 경찰서까지 확대',
#  '전주비전대 평생교육원, AI융합교육·데이터라벨러 수강생 모집',
#  '"재활용률을 높이자"… 화성시, 새솔동에 AI 자원 회수기기 설치',
#  '보은군의회 "교육·정주여건 위해 AI영재고 유치해야"',
#  '금융위 “빅데이터·AI활용 규제 혁신” 금융사 가명정보 재사용도 허용한다',
#  'AI가 극단적 선택 40대 구해…학습 통해 행동 포착',
#  'ポスコグループ、「AI技術諮問委員会」新設…新事業·人材発掘',
#  'AI활용 스마트폰으로 술 등 진위 여부 가린다',
#  "[AI-META 시대 '미래전략'] <24>평생교육 '새판짜기'",
#  'AI 물류 스타트업 ‘바이너리브릿지’, 44억원 투자 유치',
#  '미래에셋증권, AI활용한 디지털PB센터 출범',
#  '충남도, AI 학습용 ‘종패 생산 데이터’ 구축',
#  'A4 1장을 순식간에 1줄 요약… 초거대 AI ‘엑사원’이 세상을 바꾼다',
#  "AI가 나 대신 '대출심사' 해준다는데,,,과연?",
#  '금융당국 "금융권, 빅데이터·AI 효과적 활용토록 규제 혁신할 것"',
#  'DL이앤씨, 360도 카메라로 건설 현장 찍고 AI로 분석',
#  '수리硏, 산업수학에 ‘AI’ 접목시킨다',
#  '화성시, AI 자원회수기기 9개소 설치',
#  '국민은행, 안심전환대출 AI 상담 서비스 지원…"수요 급증 대비"',
#  '"시 쓰는 카카오 AI"…카카오브레인 AI \'시아\' 시집 출간',
#  "KB국민은행, AI 적용 '기업여신 자동심사 시스템' 구축",
#  "'모빌리티,\xa0로봇,\xa0AI\xa0넘어서\xa0우주로'\xa0제2회\xa0MARS\xa0월드포럼\xa0개최",
#  '충남도, AI 학습용 종패 생산 데이터 구축',
#  'KT, 산학협력 고도화…AI인재 연간 30명 키운다',
#  '전남 장성군, 인공지능(AI) 말동무 인형 지원사업 추진',
#  '딥노이드, AI로 폐질환 위치까지 탐지한다',
#  "빅데이터· AI 활용한 '위험 수입식품' 관리 체계 구축 추진 - 식약처-",
#  '국민은행, AI기술 적용 기업대출 자동심사 시스템 구축',
#  'KT, 채용연계형 전일제 AI 석사과정 신입생 모집',
#  "조선대, 지역사회 연계 '중학생 AI·SW 교실’ 성황리 마무리",
#  '딥노이드, AI 기반 흉부 엑스레이 진단 논문 네이처 파트너저널 게재',
#  'AI·SW 온라인 코딩입문훈련 교육과정 운영',
#  'SK C&C, ‘AI 뇌출혈 영상 의료 솔루션’으로 울릉도 응급환자 돕는다',
#  '시 한편 쓰는 데 1초…초거대 AI가 쓴 시집 나온다',
#  'AI 챗봇 심심이, 연구자 위해 초거대 대화 데이터 공개',
#  'KAIST, AI 연합학습 속도 4.5배 획기적 향상…스마트폰 과부하 문제 해결 기대',
#  'TTA, AI 제품·서비스 신뢰성 확보 컨설팅 제공',
#  '美, ‘주요고객’ 中에 AI칩 설계·제조 핵심 소프트웨어 수출금지 추진',
#  '충남도, 스마트 어업 실현...AI 학습용 수산종자 생산 데이터 구축',
#  'aT, 농산물 가격 예측 AI 경진대회',
#  '인권위, 국가인권정책계획에 ‘AI 인권보호 강화’ 권고 담았다',
#  '[단독 인터뷰] \'AI 대부\' 제프리 힌턴 "Mr. Cho 같은 인재 유치하려면 기업도...',
#  'KB국민은행, AI 기술을 적용한 기업여신 자동심사 시스템 구축',
#  'DL이앤씨, 국내 최초 AI·360도 카메라 기반 현장관리 솔루션 도입',
#  '금융위 "금융분야 AI기술 고도화 필수"...\'금융 AI 데이터 라이브러리\'\xa0구축',
#  "투디지트, AI 뉴스 분석 주식정보 서비스 '뉴스샐러드'로 글로벌 기업 도약 꿈...",
#  '국표원, AI 응용 가전제품 안전관리 지침 개발 착수',
#  '‘이루다 사태 방지’…TTA, ‘AI 신뢰성 확보 컨설팅’ 제공',
#  '표준협회, AI·SW 온라인 코딩입문훈련 교육과정 운영',
#  '전북교육청, AI기반 교수·학습지원을 위한 미래교육 공감토크',
#  "이글루코퍼레이션, KISA '사이버보안 AI 데이터셋 구축 사업' 수주",
#  '울릉도 뇌출혈환자 "골든타임 지킨다"…SK㈜ C&C, \'AI 뇌출혈 판독 솔루션\' 군...',
#  "화성시, 새솔동에 'AI자원회수기기' 설치하고 시범운영",
#  'AI 시대 겨냥 CXL 기반 차세대 메모리 확장 플랫폼 개발',
#  '지질연, 제2회 지질자원데이터 활용 및 AI 경진대회 개최',
#  "인티그리트, 차세대 AI 소셜로봇 '디코닉' 출시",
#  "'충북 AI 영재고' 유치, 괴산도 참여…도내 7곳 뜨거운 경쟁",
#  "충남도, AI 학습용 '종패 생산 데이터' 구축",
#  "SKT, 화신과 '인더스트리얼AI' 사업 확대 협력",
#  '이종호 과기부 장관 “반도체·5G 기술 우위…바이오·AI 부족”',
#  '"KAIST, 반도체·AI 분야 논문 수 세계 상위권"',
#  'SKT, AI 비서 \'에이닷\'…"TV와 게임도 품었다"',
#  "하나은행, 모바일앱에 'AI뱅커' 도입",
#  '카카오브레인, 초거대 AI 보폭 넓힌다…의료영상 분야 진출',
#  '에프앤가이드·리퍼블릭케이·연세대, ‘AI 자산 관리’ 연구 개발 위해 맞손',
#  "'멋쟁이사자처럼', 'AI 스쿨' 8월29일까지 모집",
#  "AI·머신러닝 응답속도 최대 20배 '업'...삼성, 차세대 메모리 솔루션 대거 공...",
#  '"AI, 7살 수준 자의식" 주장했다 해고…실제 어느 정도?',
#  '"AI 뱅커입니다" 은행 모바일 앱에 디지털 휴먼 최초 등장',
#  '식약처, AI 활용 고위험 수입식품 검사·관리 나선다',
#  'SK㈜C&C,울릉도에 ‘AI뇌출혈 영상 의료 솔루션’ 공급',
#  '딥노이드, AI로 폐질환 및 위치까지 탐지하는 논문 네이처 파트너저널에 게재',
#  '한밤중 충무대교 난간 넘어간 40대 AI가 구조',
#  'KB국민은행, ‘안심전환대출’ 상담에 AI 음성상담 지원',
#  "딥브레인AI, '월클' 손흥민 AI 휴먼으로 구현",
#  "DL이앤씨, 국내 최초 AI 현장관리 솔루션 '디비전' 도입",
#  "(현장+)AI 기반 신약 개발…데이터 활용 여부가 '관건'",
#  '인공지능(AI)이 쓴 시(詩), 사람들 마음 울릴까?',
#  '건양고 AI 및 디스플레이 응용 융합 메이커 교육 개최',
#  '이스트소프트, 외국어 교육 특화된 AI 휴먼 만든다…YBM과 맞손',
#  "의료 AI 로봇기업 '코넥티브', 카카오벤처스 시드 투자 유치",
#  '농산물 가격 예측 AI 경진대회 개최',
#  "AI 물류 스타트업 '바이너리브릿지', 44억원 투자 유치",
#  "AI ARS '상담콜', AI 보이스 적용 '고객 콜백 예약 기능' 오픈",
#  '진천중, 생거진천 인공지능(AI) 마을학교 운영',
#  'KT, 2023 봄학기 채용연계형 AI 석사 신입생 모집',
#  'KT, 강동경희대병원과 AI 로봇 서비스 개발',
#  "'2022 농산물 가격 예측 AI 경진대회' 개최",
#  "KAIST, 스마트폰 위 인공지능(AI) 연합학습 속도 '4.5배 향상'",
#  '대화를 통해 더 똑똑해지는 인공지능 챗봇...메타 AI, 거의 모든 주제에 말할...',
#  '그림 그리는 AI ‘DALL·E’, 저작권 문제 없을까?',
#  '[특징주] 루닛, AI 치료효과 확인에 5% 급등',
#  '카페24, AI로 만든 쇼핑몰 상세페이지 500만건 넘어',
#  "'해리포터' 책으로만 읽은 AI가 그린 캐릭터들 실제 외모 (사진 10장)",
#  "울산대 '맞춤형 AI 인력양성과정 수료식 및 시상식' 개최",
#  'KT, AI 로봇으로 병원 디지털 전환 나선다',
#  '이글루코퍼레이션, KISA 사이버보안 AI 데이터셋 구축 사업 수주',
#  '"우리 공장에도 AI 도입하자"…LGU+, 구독형 스마트팩토리 상품 출시',
#  'AI technology-financial services',
#  "[주간 IT] 사용자 스마트폰 데이터 기반 'AI 서비스' 날개 단다",
#  'SK C&C, 울릉군보건의료원에 AI 뇌출혈 영상 의료 솔루션 공급',
#  '출시 한 달 된 AI코딩비서 "개발자 수준 높인다"',
#  "DL이앤씨, AI·360도 카메라 현장 도입 '디지털 혁신' 박차",
#  'SK케미칼, 치매 예방 위해 AI 기반 인지개선프로그램 보급 나서',
#  'DL이앤씨, AI로 공정별 하자 바로바로 잡아낸다',
#  "진짜보다 나은 '가짜' 데이터로 AI에 연료 공급",
#  'SKT, 산업 AI로 뿌리기업 지원',
#  '미국, AI칩 설계·제조 핵심 소프트웨어 중국 수출금지 추진',
#  '보은군의회 "지역균형 발전 차원 보은에 AI영재고 건립해야"',
#  'KISTI, 쿠웨이트 고등학생 대상 DATA·AI 캠프 운영',
#  '순천시, AI 반려로봇 돌봄 서비스',
#  '모아데이타, AI 기반 B2C 자회사 세이지앤컴퍼니 신설',
#  "SK㈜ C&C, 'AI 뇌출혈 영상 의료 솔루션'으로 울릉도 응급환자 지원",
#  '하나은행, 은행권 최초 모바일 앱 하나원큐 내 ‘AI뱅커’ 도입',
#  "하나은행 앱에선 'AI 뱅커'가 금융시장 브리핑",
#  '강기정 광주시장 "AI반도체 단지 현안 힘 보태달라"',
#  '보은군의회, AI영재고 유치 촉구 결의안 채택',
#  '‘눈’으로 심혈관질환 예측하는 AI 의료기기 등장',
#  '삼진제약, AI 신약개발 나선다',
#  'AI 활용해 고위험 수입식품 선별',
#  '청년·신중년에 AI 원스톱 취업 지원',
#  '조달청, 공공 SW사업 발주에 AI 기술 도입…오늘부터 본격 서비스',
#  "파수, 데이터 비식별화 솔루션 '애널리틱디아이디'에 AI 기술 탑재",
#  "세종충남대병원, 대화형 메신저 'AI 챗봇'서비스 오픈",
#  '순천향대천안병원, AI·IoT 활용 정신질환자 응급상황 예측시스템 개발 추진',
#  '[단독] 조용병 회장 야심작 ‘신한 AI’ 상장 추진…지주 자회사 최초',
#  "삼진제약, 캐나다 '사이클리카'와 AI 신약개발 공동연구 나선다",
#  "셀바스AI, 'AI 음성인식 기반 성폭력 피해 조서 작성 시스템' 확대 적용",
#  '[D리포트] "AI, 사람 같은 자아 있다" 주장했다가 해고…현실은?',
#  '혁신성장 정책금융, AI 분야 공급액 5년새 45배 증가',
#  '건양고, AI 및 디스플레이 응용 융합 메이커 교육 개최',
#  '카카오엔터프라이즈, 세계 AI 얼굴인식 기술대회서 잇따라 1위',
#  '카뱅, 에프앤가이드와 금융콘텐츠 읽고 쓰는 AI 모델 만든다',
#  '전주비전대 평생교육원, AI융합교육 자격취득 과정생 등 모집',
#  "충남, AI 학습용 '종패 생산 데이터' 구축한다",
#  'KB국민은행, AI 기술 적용한 기업여신 자동심사 시스템 구축',
#  "와이즈에이아이, AI 개인비서 앱 'AI-ME' 상표 등록 완료",
#  "[AI-META 시대 '미래전략'] <23>게임스토리텔링",
#  '딥브레인AI, 하나은행 모바일 앱에 ‘AI 뱅커’ 공급',
#  "'임테기 흐릿한 줄로 수차례 반복'…이젠 AI가 판독해준다",
#  '[인터뷰] “KT는 음성 전문가…목소리로 자폐⋅폐렴 진단 AI 만들 것”',
#  '룰루랩, 하노이의대와 피부질환 AI 분석 솔루션 공동연구 협약',
#  'SKT, 화신과 AI 용접품질 관리기술 협업…"인더스트리얼AI 확대"',
#  'DL이앤씨, AI·360도 카메라로 현장 하자 줄인다',
#  '이글루코퍼레이션, KISA 사이버 보안 AI 데이터셋 구축 사업 수주',
#  '광양제철소, AI 기반 하역 크레인 안전거리 자동측정 시스템 구축',
#  '조선대, AI‧SW 여름방학 아카데미 진행',
#  '"헷갈리는 \'임테기\' 결과, AI가 판독"…NHN에듀, \'AI핑봇 임신테스트\' 출시',
#  '광양제철소, \'AI 기반\' 하역크레인 안전거리 자동측정 시스템 구축.."즉각 감...',
#  "하나은행, 은행권 최초 모바일 앱 하나원큐 내 'AI뱅커' 도입",
#  '금융위원회 "빅데이터·AI 활용 지원…규제 혁신"',
#  '인천재능대,\xa0AI\xa0ONE-STOP\xa0프로그램\xa0체험\xa0교육\xa0운영',
#  '고병원성 AI·ASF 미발생 EU지역 축산물 수입 가능…수입조건 변경',
#  "딥노이드 연구팀, 2년여간 'AI기반 흉부 X-ray진단' 논문 네이처 파트너저널(...",
#  "[fn마켓워치]카카오벤처스·슈미트, AI 인공관절 로봇 수술 '코넥티브'에 투자",
#  '에듀윌, AI로 합격 예측한다…"연내 AI-Pass 완성"',
#  'SK케미칼, AI 기반 인지개선 프로그램 보급…치매 해결 나서',
#  '더핑크퐁컴퍼니-AI 네트워크, ‘핑크퐁 아기상어’ NFT 전시 개최',
#  "광주인력개발원, AI활용 SW개발 경진대회 '성료'",
#  '미, AI칩 설계·제조 핵심 소프트웨어 중국수출 막는다',
#  '딥노이드 AI 의료 솔루션, 폐질환 및 위치까지 탐지하는 임상적 유용성 입증',
#  'KB국민은행, AI 기술 적용 기업여신 자동심사 시스템 구축',
#  'DL이앤씨 AI·360도 카메라 현장관리 솔루션 도입',
#  "aT, '농산물 가격 예측 AI 경진대회' 개최",
#  "금융권 'AI 혁신' 시동 걸었지만… 활성화까진 '산 넘어 산'",
#  "KT, EBS와 AI 인재 육성 '맞손'… 소프트웨어·인공지능 학습 제공 MOU 체결 ...",
#  '조달청, AI 기반 공공SW 사업 발주지원시스템 개통',
#  "AI ARS 상담콜, 인공지능 보이스 적용 '고객 콜백 예약 기능' 선봬",
#  '"사람의 뇌처럼 인지하는 AI 탐구 중"…제프리 힌턴 교수 \'뇌\' 향한 혁신은 평...',
#  '울릉군 의료 서비스 향상...SK C&C, AI 뇌출혈 판독 솔루션 공급',
#  'TTA, AI 제품·서비스 신뢰성 무료 컨설팅 기업 공모',
#  '금융 AI 도서관 출범...데이터 필요할 때 꺼내쓴다',
#  '미래에셋증권-네이버클라우드, AI·클라우드로 금융서비스',
#  "하나은행, 환율·금융시장 전망해주는 'AI뱅커' 도입",
#  '식약처, AI 활용해 고위험 수입식품 걸러낸다',
#  "삼진제약, 'AI 신약개발 공동연구' 계약 체결",
#  'KAIST, 국내 AI 반도체 선도...내년에 반도체시스템공학과 설립',
#  'KT·강동경희대병원, AI 로봇 활용해 병원 업무 디지털 전환 추진',
#  'AI 물류 스타트업 ‘바이너리브릿지’, 44억 원 규모 프리A 투자 유치',
#  '천안교육지원청, 2022 천안AI꿈키움터 여름방학캠프',
#  "디지털 금융혁신 목표...금융위, '빅데이터-AI 활용 활성화 방안' 제시",
#  "채용 정보서 AI 테크로...'HR 서비스 2.0' 변신 경쟁 후끈",
#  '`AI뱅커`가 시장동향 알려주는 하나은행앱',
#  "DL이앤씨, AI 현장관리 솔루션 '디비전' 도입",
#  "카카오브레인, 초거대 AI 언어 모델 활용 '시집' 출간",
#  '"AI가 보험 심사" 생보사들 디지털 혁신 바람',
#  '이든앤앨리스마케팅, AI 전문기업 데이콘과 데이터 기반 마케팅 플랫폼 개발 ...',
#  'KAIST, 스스로 학습·진화하는 흉부 엑스선 AI진단기술 개발',
#  '하나은행 "모바일 앱 하나원큐에 \'AI뱅커\' 도입"',
#  "DL이앤씨, 현장관리 솔루션 도입...'국내 최초' AI·360도 카메라 활용",
#  'KT-강동경희대학교병원, AI 로봇 활용 병원 업무 디지털 전환 협력',
#  '삼진제약, 加 사이클리카와 AI 신약개발 공동연구 계약 체결',
#  "AI, 작곡하고 그림 그리더니...이번엔 시집 냈다[Geeks' Briefing]",
#  '지자연, 지질자원데이터·AI 경진대회 개최',
#  '수리연, IAAE 국제인공지능&윤리협회, 산업수학 기반 AI 사업 협력',
#  '<오후여담>AI시대 新직업',
#  "의료 AI 로봇 '코넥티브', 시드 투자 유치...카카오·슈미트 참여",
#  "AI ARS '상담콜', 인공지능 적용 '고객 콜백 예약 기능' 오픈",
#  '삼진제약, 캐나다 바이오사와 AI 공동연구',
#  '김소영 금융위 부위원장 "금융분야 AI 활성화 정책 적극 지원"',
#  '"결혼도 스마트하게"…하동군, \'AI 맞썸다방\' 눈길',
#  'AI가 축구대회를 알아서 중계한다고? AI스포츠중계 시스템은 무엇?',
#  'AI와 병원정보시스템 결합…비플러스랩-이지케어텍 맞손',
#  '카카오브레인, 시 쓰는 AI 모델 `시아` 시집 출간',
#  '통영시, CCTV에 AI 딥러닝 기법 도입',
#  'SK㈜ C&C, \'AI 뇌출혈 판독 솔루션\' 울릉도에 공급…"골든타임 지킨다"',
#  "KB증권, 'AI 상담 콜봇' 서비스 실시",
#  "AI가 쓴 시로 만든 시극 '파포스'…8월 대학로예술극장",
#  "KB국민은행, '기업 성장성 분석' AI 심사시스템 구축",
#  '"AI로 자폐증 진단한다"… 정부 예산 100억 투입하는 이유',
#  '건설산업 혁신 IT 기술로 진화…AI·360도 카메라 기반 솔루션 도입',
#  '기후변화·AI 전문가 대거 참석…공동번영 위해 머리 맞댄다',
#  '하나은행, 은행권 최초 앱에 AI뱅커 도입...환율·펀드 서비스',
#  '암 찾아 치료하는 ‘방사선 미사일’ 등 핵의학 발전…"AI 접목 신약 개발 도...',
#  '“어르신, AI 스피커 이 바구니에 담아 보관하세요”',
#  '천안교육지원청, 2022 천안AI꿈키움터 여름방학캠프 운영',
#  '"덜어내고 덜어내 남는 말이 詩" AI시인의 등장',
#  'KT 대경본부, AI 호텔 서비스 도입…라마다 문경새재 호텔과 업무협약',
#  'DL이앤씨, AI·360도 카메라 현장관리 솔루션 도입',
#  "[중기소식]상담콜, AI 보이스 적용 '고객 콜백 예약' 등",
#  '진천중 AI 마을학교 운영',
#  '[사고]‘2022 AI코리아 대상’ 공모합니다',
#  'AI영재고 유치에 괴산도 가세',
#  "'내가 보고 싶은 선수만'…와이에스티, '추계 중등축구대회' AI 중계 적용",
#  "캠프서 배우는 'AI 교육', 초‧중‧고 200명 참여",
#  "AI 학습용 '종패 생산 데이터' 구축한다",
#  '롯데정보통신, 보안 AI 모델로 지능형 위협 차단한다',
#  '보은군 AI 영재고 유치전 가세…지자체 간 불꽃경쟁 예고',
#  '[특징주] 딥노이드, AI로 폐 질환 위치까지 감지 소식에 급등',
#  'DL이앤씨, 디지털 혁신의 힘..AI·360도 카메라 기반 현장관리 솔루션 도입',
#  'SK케미칼 등 SK 3사, 성남·청주 36개 기관에 AI 인지개선프로그램 보급',
#  '지식의 전당에 걸맞은 웅장한 선율…AI음악가 작품입니다',
#  "도시공유플랫폼, 창업박람회서 AI 무인 편의점 '아이스Go' 전시",
#  "KB국민은행, AI 기술 적용 '기업여신 자동심사 시스템' 구축",
#  '삼진제약-加 사이클리카, AI 신약개발 공동연구',
#  '김주하 AI 앵커와 함께하는 이 시각 주요뉴스 - 8월 5일 낮 12시',
#  'SK케미칼 등 3사, AI 기반 인지기능개선 프로그램으로 치매 예방 나서',
#  'LG전자, 사운드하운드와 차량용 AI 음성인식 솔루션 개발',
#  "전북교육청 'AI기반 맞춤형 수업 확산' 모색",
#  "전북교육청, 'AI기반 학생맞춤형 수업' 전체 학교로 확산한다",
#  '하나은행, 모바일 앱 하나원큐에 ‘AI 뱅커’ 도입… “금융정보 브리핑 서비...',
#  'KT AI로봇 활용해 병원 디지털전환 지원, 강동경희대병원과 업무협약 체결',
#  "모바일서 금융시장·환율 전망 브리핑…하나銀 'AI뱅커' 도입",
#  '인재 양성에 열 올리는 북한…"VR부터 AI 교수법까지 개발"',
#  "SKT, 용접 품질 관리도 AI로…'인더스트리얼 AI' 사업 확대",
#  "'사람인가, AI인가'…CNN, 韓 가상 인플루언서 열풍 조명",
#  '카카오브레인, 의료영상 분야로 초거대 AI 연구 확장',
#  "카카오브레인 AI 아티스트 칼로, '갤럭시 북 아트 프로젝트'에 활용",
#  '"AI기반 시장변화 감지"...KB국민카드 \'소셜미디어\' 분석 플랫폼 구축',
#  'KT-KAIST·포스텍·한양대, 채용연계형 AI 석사과정 모집',
#  '마이더스AI, 663억 규모 유상증자 결정',
#  "삼진제약, 캐나다 '사이클리카'와 AI 신약개발 협력",
#  '포스코그룹, AI 기술 자문위원회 신설…"미래 전략 수립에 큰 역할 기대"',
#  "[AI-META 시대 '미래전략']<21>지역 발전",
#  '미래에셋증권·네이버클라우드, AI·클라우드 기반 서비스 협력',
#  '[ET라씨로] 루닛, 비인두암 환자 대상 AI 치료효과 확인에 주가 강세',
#  'AI 번역 엑스엘에이트(XL8), WINGS(윙스) 선정..."구어체까지 완벽 소화"',
#  'AI 챗봇 심심이, 초거대 대화 데이터 연구자들에게 공개',
#  "NHN에듀, 'AI핑봇 임신테스트'서비스 출시",
#  "KB국민카드 임직원들, AI 활용해 '소셜 데이터' 분석한다",
#  '룰루랩, 하노이의대와 베트남 AI 의료 생태계 구축한다',
#  '미래에셋證·네이버클라우드, AI 기반 고객서비스 확대에 맞손',
#  'DL이앤씨, AI·360도 카메라로 시공 품질 체크한다',
#  '전주교대 SW·AI 교육 역량 강화 연수 실시',
#  '[제45기 SG배 한국일보 명인전] AI와의 시너지 효과',
#  'KT, 2023년 봄학기 채용연계형 AI 석사과정 신입생 모집',
#  "[AI-META 시대 '미래전략'] <22>인공지능 미래 발전과 대응",
#  '日 NYK 이데미츠, AI 연료저감 시스템으로 동남아 석탄발전시장 공략',
#  "영상 속 '깊이 정보'… AI 알고리즘으로 정확히 알아낸다",
#  "삼진제약x사이클리카 'AI 신약개발 공동연구' 계약",
#  '현대차, AI. AAM. 자율주행. 로보틱스 분야 우수인재 모신다. 북미. 유럽대학...',
#  'SK케미칼, AI 기반 인지 개선 프로그램 보급으로 치매 예방에 앞장',
#  'TTA,\xa0AI 제품‧서비스 신뢰성 확보 컨설팅 제공',
#  '“금융권 기술 수준 감안, AI 금융 정책방향 ‘활성화’에 초점 맞춰야”',
#  "'인공지능 AI 로봇이 관리하는 호텔은 어떨까?' .... KT AI 호텔, 라마다 문경...",
#  "장성, 고위험 독거노인 위한 '인공지능(AI) 말동무 인형' 지원",
#  "SK텔레콤, AI 서비스 '에이닷'에 TV·게임 추가",
#  "스스로 데이터 공부해 진단능력 끌어올리는 '흉부 엑스선 AI' 나왔다",
#  'KTOA, KIF 신규 자펀드 결성 추진..."AI·6G·메타버스 투자"',
#  '초거대 AI가 쓴 시집 나온다',
#  '하나은행, 모바일 앱 내 AI뱅커 도입…"은행권 최초"',
#  "대전AI교육지원체험센터, '인공지능 교육\xa0학생캠프' 운영",
#  '에이수스, 엔비디아 젯슨 플랫폼 기반 지능형 엣지 AI 시스템 발표',
#  '삼진제약, 사이클리카와 AI 신약개발 공동연구 협약',
#  '인간을 흔드는 AI, 바로 보기',
#  '가톨릭중앙의료원·카카오브레인, 의료영상 AI 개발 업무협약',
#  '폭포서 흙탕물이 콸콸…최악 홍수 미얀마｜AI가 Pick한 세상',
#  "하나은행, 'AI뱅커' 도입",
#  '삼진제약, 캐나다 사이클리카와 AI 신약개발 공동 연구',
#  '삼성전자 "AI 아티스트와 함께 갤럭시 북 꾸며봐요"',
#  '기업여신도 AI가 머신러닝 기반 심사',
#  '고병원성 AI·아프리카돼지열병 미발생 EU 지역 축산물 수입 가능',
#  '[ET뉴스픽!]日 세관, AI로 부정수출 감시',
#  '"비대면으로 가입하고 AI가 심사"…생명보험업계 디지털 혁신 바람',
#  "DL이앤씨,\xa0국내 최초 'AI·360도 카메라' 기반 현장관리 솔루션 선봬",
#  'AI 국제표준화 한국이 주도한다',
#  "오씸코리아, AI 스트레스 관리시스템 탑재 안마의자 '유러브3' 선보여",
#  'KT, EBS와 함께 AI 인재 육성',
#  "카카오브레인, 시 쓰는 AI 모델 '시아' 개발…시집도 출간",
#  "'금융 AI기술 지원' 금융위, '데이터댐 구축' 나선다",
#  '스마트폰 위 AI 연합학습 속도 4.5배 향상 기법 개발',
#  "더핑크퐁컴퍼니-AI 네트워크, '핑크퐁 아기상어' NFT 전시 개최",
#  '룰루랩, 하노이 의대와 피부데이터 기반 AI 의료 생태계 육성',
#  '서울대, 구글·메타·스탠퍼드 대학 등 해외 AI 연구자 초청',
#  '와이즈에이아이, AI 비서 앱 ‘에이미’ 상표 등록 완료',
#  '핑크다이어리, AI핑봇 임신테스트 서비스 출시',
#  "KT, 'AI 방역로봇' 광고 유튜브 조회수 1200만회 돌파",
#  'KT 대경본부 AI 기반 솔루션 호텔 라마다 문경새재에 적용',
#  '카카오브레인 AI 기반 모델 시아, 시집 출간한다',
#  "'AI 기계학습' 국제 표준화, ETRI 선봉 나선다",
#  '의료 AI 로봇기업 코넥티브, 시드 투자 유치',
#  'KT, 2023학년도 봄학기 채용연계형 AI석사과정 신입생 모집',
#  '매년 뇌경색 환자 2% ‘심근경색’…“AI로 심장병 찾아낸다”',
#  'KB국민은행, AI 기술로 기업여신 자동심사',
#  '삼진제약, 캐나다 ‘사이클리카’社와 AI 신약개발 공동연구 착수',
#  "인공지능 융합 강의 'AI+X'…국내 최고의 강좌를 개설하다",
#  '카카오브레인 "AI가 시를 쓰는 이유"',
#  '경북교육청, 누구나 가능한 SW-AI교육 기반 마련…학교 현장 70.2억 지원',
#  '광양제철소, "AI 기반 하역 크레인 안전거리 자동측정 시스템 구축"',
#  '"AI가 자동심사해 보험금 즉시 지급"…생보사, 디지털 혁신 \'박차\'',
#  "조선대 '중학생 AI·SW 교실' 성황",
#  "'루미가 돕는다' 순천시, AI 반려로봇 어르신 돌봄 시작",
#  "[팍스테크니카 인재에 달렸다] 영업맨도 AI 전문가 '환골탈태'…전공 상관없이...",
#  'KT-강동경희대학교병원, AI 로봇 활용-병원 업무 디지털 전환 협력',
#  '“하나 모바일 AI 뱅커가 금융 브리핑 해드려요”',
#  '손 잡은 이지케어텍·비플러스랩…"AI 의료솔루션 신규 서비스 모색"',
#  '에이수스(ASUS), 엔비디아 젯슨 플랫폼 기반 지능형 엣지 AI 시스템 발표',
#  '지질자원연, 지질자원데이터 활용·AI 경진대회 개최',
#  "[더뉴스] 시 쓰고, 연예계까지 접수...'AI' 얼마나 진화했나?",
#  "롯데정보통신, '보안 AI 모델' 지능형 위협 차단",
#  '표준협회, AI·SW 실무 기술인력 양성한다',
#  'NHN에듀 “한줄? 두줄? 헷갈리는 ‘임테기’ 결과 AI로 판단하세요”',
#  '김주하 AI가 전하는 8월 5일 뉴스7 예고',
#  '인천재능대, AI ONE-STOP 프로그램 체험 교육 운영',
#  "시(詩) 쓰는 AI '시아', 첫번째 시집 '시를 쓰는 이유' 출간",
#  'KT, 강동경희대병원과 AI로봇 활용 병원 업무 디지털 전환 MOU',
#  "하나은행, 모바일 앱에 'AI 뱅커' 도입",
#  "순천시, AI 반려로봇 '말동무 해드리는 인형' 보급 사업",
#  '생체 신호 분야 주목하는 의료 AI 기업들…그 배경은?',
#  '[특징주] 루닛, 비인두암 환자 병용요법서 AI 치료효과 확인에 강세',
#  "AI 네트워크-더핑크퐁컴퍼니, '언커먼 갤러리'서 핑크퐁 아기상어 NFT 첫 전시",
#  '보안기업 이글루코퍼레이션, AI 특허 획득…머신러닝 강화한다',
#  '카페24 "AI로 만든 쇼핑몰 상세페이지 500만건 넘어"',
#  "[SR전자] 삼성전자 '삼성 AI 챌린지' 개최…디스플레이 연구 난제 해결",
#  '초중등 교사 AI·SW 교육 역량 키운다',
#  'DL이앤씨, 업계 최초 AI·360도 카메라 활용 현장관리 솔루션 도입',
#  'SKT, 산업용 AI 사업 확대…“국내 제조업 경쟁력 강화”',
#  '통영시 ‘AI 자살예방시스템’으로 40대 구조',
#  "산업AI 원프레딕트, '세계 50대 첨단 제조 스타트업'에 이름 올렸다",
#  '교육시장에 AI 기술 도입 사례 확산',
#  '룰루랩-하노이의대, 피부데이터 기반 AI 의료생태계 키운다',
#  'CJ올리브네트웍스, AI·SW 재능기부 대학생 모집',
#  '경기도, 고병원성 AI 92% 줄어…"야생조수 차단 시범사업 덕"',
#  '재활용률↑...화성시, AI 자원회수기기 운영',
#  "AI 학습용 '종패 생산 데이터' 구축",
#  '[카드] 셀바스 AI, 성폭력 피해 조서 작성 시스템 확대 적용',
#  "이글루, '능동형 보안관제' AI 데이터셋 구축 사업 수주",
#  '尹 AI·디지털 의료 평가기간 단축...의료 빅데이터 법제화 주문',
#  '카카오뱅크 "금융 콘텐츠 읽고 쓰는 AI 모델 개발"',
#  "[기업] SKT, 자동차 부품업체와 '용접 AI' 기술 계약 체결",
#  "'논문 수 세계 최상위권' 반도체·AI서 위용 펼치는 KAIST",
#  'SKT AI 서비스 ‘에이닷’, TV·게임 신규 서비스 업데이트',
#  '하나은행, 모바일 앱 하나원큐 내 ‘AI 뱅커’ 도입',
#  '세종대 김수연 교수, AI 학습용 데이터 구축 지원사업 선정',
#  "하나은행,\xa0모바일 앱 하나원큐 내 'AI뱅커' 도입",
#  'DL이앤씨, 국내 첫 AI·360º 카메라 현장관리 도입... "디지털 기술 선도"',
#  'NHN에듀 ‘핑크다이어리’, 헷갈리는 임신 여부 ‘AI’로 판독',
#  '제이엘케이, AI 치매 분석 솔루션 ‘에이트로스캔’ 태국 허가 획득',
#  "AI로봇 활용 병원업무 디지털전환...KT·강동경희대병원, '맞손'",
#  "밸류링크유, AI기반 물류 서비스 '바이너리브릿지'와 이커머스 물류 혁신 및 ...",
#  'SKT, 車부품 제조사와 손잡고 산업용 AI 확대 나선다',
#  '울진 추계중등축구대회, AI 중계한다… 어떤 효과 있을까?',
#  'SKT, 용접 품질 관리도 AI로',
#  '하나은행, 하나원큐 ‘AI뱅커’ 선봬',
#  "하나은행, 딥러닝 기반 'AI뱅커' 하나원큐에 도입 [은행오늘]",
#  "'CXL 초격차' 속도내는 삼성·SK…AI 등 포트폴리오 확대(종합)",
#  '"새로운 세상을 여는 모두의 인공지능(AI)교육 학생캠프" 운영',
#  'KAIST, 민간과 손잡고 SAR 위성 정보 활용 AI연구 나서',
#  '전북교육청 미래교육 토크서 서거석 교육감, AI수업 시연',
#  '돌고래와 인간의 의사소통, AI로 시도한다',
#  'KT, 2023년 봄학기 채용연계형 AI 석사과정 모집',
#  'LGU+, 근로복지공단 민원업무 AI로 개선',
#  "[주간VC동향] 인공지능(AI) 의료 스타트업 '에어스메디컬' 253억원 규모 시리...",
#  '168m 상공에 대롱대롱…번지점프 사고｜AI가 Pick한 세상',
#  "딥노이드 'AI 기반 폐질환 탐지' 논문, 네이처 파트너 저널 게재",
#  '구글 딥마인드 AI, 거의 모든 단백질 구조를 예측한다',
#  '삼진제약-사이클리카, AI 신약개발 공동연구 계약 체결',
#  "DL이앤씨, 국내 최초 건설현장에서 AI 활용... 현장관리 솔루션 '디비전' 도입",
#  'AI 신약개발업계 정체기 돌입..."시장 확장보다 성과 주력할때"',
#  "하나은행, 은행권 최초 모바일 앱 내 'AI뱅커' 도입",
#  '신한AI, 신한금융 자회사 최초 IPO 도전?',
#  '서울인공지능고, 중3학생 대상 AI·빅데이터 캠프 개최…29일까지 신청',
#  'DL이앤씨, AI·360도 카메라로 시공하자 줄인다',
#  "하나은행, 모바일 앱 하나원큐에 'AI뱅커' 도입",
#  '카페24, AI 제작 쇼핑몰 상세페이지 제작 500만건 돌파',
#  "장성군, 독거노인 '인공지능(AI) 말동무 인형' 지원",
#  "SKT, '인더스트리얼 AI' 사업 확대",
#  "AI가 시도 쓰네…카카오브레인, 초거대 AI 'KoGPT' 활용 시집 출간",
#  '오픈소스 AI 쓸 수 없는 軍…독자 개발 모색 위한 세미나 개최',
#  '[사설]고도화 시급한 금융AI 컨소시엄',
#  '보은군 AI영재고 유치전 가세…추진위원회 구성',
#  '인트플로우, 축산동물 AI 학습 데이터 구축사업 수주',
#  '카카오브레인, 의료영상 분야로 초거대 AI 모델 연구 확장 나서',
#  '천안시 아우내도서관 초·중생 대상 AI/SW 교육 캠프 운영',
#  '김주하 AI 앵커와 함께하는 이 시각 주요뉴스 - 8월 4일 낮 12시',
#  'KB국민은행, 안심전환대출 상담에 AI 도입',
#  "오씸코리아, AI 스트레스 관리시스템 탑재한 안마의자 '유러브3' 출시",
#  "대전AI교육지원체험센터, 초‧중‧고 '인공지능(AI)교육 학생캠프' 운영",
#  'KT, 2023학년도 채용연계형 AI석사과정 신입생 모집',
#  '메디웨일, 망막 기반 심혈관질환 예측 AI 의료기기 품목 허가',
#  "AI ARS 상담콜, '고객 콜백 예약 기능' 선봬...인공지능 보이스 적용",
#  '강동경희대병원, KT와 의료기관 AI로봇서비스모델 공동개발',
#  "하나은행, 은행권 최초 'AI뱅커' 도입",
#  '삼진제약, 캐나다 기업과 AI 신약개발 공동연구 추진',
#  '괴산군의회, AI영재고 유치 건의문 채택',
#  '베토벤, 고흐 환생도 가능..‘스탠포드 AI 인덱스’ 미-중 투톱, 한국은?[여의...',
#  "카카오뱅크, 에프앤가이드와 금융 AI 고도화 '맞손'",
#  "리퍼블릭케이·에프앤가이드·연세대, 'AI 시장진단 연구' MOU 체결",
#  '한국AI속기사협회, AI데이터전문속기 프리랜서 오프라인 교육 실시',
#  'KB국민은행, ‘AI 기업여신 자동심사 시스템’ 구축',
#  "SK텔레콤, '인터스트리얼 AI' 사업 확대 나선다",
#  'SKT, ‘인더스트리얼 AI’ 사업 확대 나선다',
#  '軍도 수학에 러브콜 "독자 AI(인공지능) 알고리즘 만들겠다"',
#  "가톨릭대-마인드허브, '뇌신경 환자 언어재활 AI 연구' 협약",
#  ...]

# %% [markdown]
# ## 형태소 분석

# %%
text = ' '.join(title_list) #list들을 공백으로 구분해서 연결
text = re.sub('[^가-힣]+',' ',text) #한글 이외는 공백으로 대체
text
# Out:
# ' 서울성모병원 당뇨 관리 돕는 기술 개발 삼성전자 인재 키워 반도체 디스플레이 연구한다 삼성전자 챌린지 농정원 스마트농업 경진대회 개최 총상금 억원 코트라 활용 중견기업 모니터링 지원 벤처에 컨설팅 인재 양성 지원 영진전문대 융합기계계열 로봇관련 학술대회 논문상 수상 일주일내 범죄 발생 예측 정확도 도입 득될까 공감하는 로 사람다운 로봇 세상 만든다 와 대화 이동통신 모니터링 고독사 예방 팔걷은 지자체들 영남중 대구고 동아리 주최 경진대회 수상 현대차 경력 세자릿수 채용 인터뷰 도입 서울시 기업 내부서 고급 개발자 인력 양성하도록 지원 지금 들어가고 월까지는 팔아라 가 예언하는 나스닥 남성희 전문대교협회장 전문대 반도체 전공에 년제 허용해야 시대 미래전략 교육 대전환 시 쓰는 인간에게 던지는 화두는 조선대 프라이버시 보장 기술 공동 개발 동형암호 실용화 기반 마련 도로교통공단 빅데이터 기반 위험도로예측 시범서비스 구축 조선대 화정중서 여름방학 아카데미 진행 와 영어 말하기 대결 윤선생 말하톤 대회 개최 카카오가 찜한 아이돌 뉴스 생방송에서 일냈다 가상인간 열풍 땅개 서 무장 호랑이 로 전투력 초격차로 적 초토화 스토리 과기정통부 초일류 전략 내놓는다 활용 제고에 방점 와 인재 육성 맞손 풍선 속 다이아몬드 찾기 중국 쇼핑몰 아수라장 가 한 세상 광주시의회 전문가 초청 인공지능 발전방향 공부 똑똑한 은행원 나온다 금융위 가명정보 데이터로 허용 동강대 기반 맞춤형 토익 프로그램 실시 가 이젠 시도 쓰고 작곡도 한다 저작권은 어떻게 될까 김포공항 반입금지 물품 초만에 잡는다 서울시 고급 개발자 양성 프로그램 지원 로 병원 혁신시킨다는 믿음 네이버 광폭행보 에이프리카 통합 플랫폼 치타 조달청 디지털서비스몰 등록 세일즈포스 마이크로소프트 전세계 기업 한방에 투자 현대차 연구개발본부 활용 대규모 경력직원 채용 포스코그룹 기술 자문위원회 신설 미래 전략 수립 시동 포스코그룹 기술 자문위원회 신설 신사업 인재 발굴 괴산군도 합류 영재고 유치전 후끈 증권 인공지능 기술 적용한 상담 콜봇 서천교육청 미래 시대를 위한 교육 교원 연수 운영 농산물 가격 예측 경진대회 개최 시 감정선까지 짚어낸 무한도전 의료기 유통 에이치엔드림 영상분석 우경정보기술과 협약 호남대 광주발달장애인훈련센터 교육과정 자문 덴마크에 정당 등장 년 의석 확보 목표 리빌더 가상공간 구축 위해 메가플랜과 맞손 다량의 실사 모네인 듯 모네 아닌 그림 예술적 가치 있을까 아트마켓 사용설명서 진천교육청 진천군 카이스트 스마트교육 로봇 영재캠프 개최 울산대 맞춤형 인력양성과정 수료식 개최 기보 신입직원 명 뽑는다 역량검사 블라인드 채용 미래를 연다 써니팩토리 김주하 앵커와 쉬운 우리말로 스키드 마크 를 우리말로 하면 라이언로켓 티그컴퍼니 접목한 새로운 컬처 선봬 포착 한밤중 극단적 선택 직전 가 극적 구조했다 지질자원연 제 회 지질자원데이터 활용 경진대회 키움증권 가 고객 투자성향 분석해 자동으로 자산 배분 이환주의 아트살롱 와 예술 화 가 노벨문학상을 받는다면 삼성화재배 와 함께하는 바둑 해설 수에는 가격이 없다 이앤씨 도 카메라 기반 현장관리 솔루션 도입 고위험 수입식품 가 차단한다 네오텍 기반 보안 서비스 사이트 디펜더 출시 딥페이크 사회 국가적 혼란 초래 우려 로 악용 막아야 게시판 증권 상담 콜봇 서비스 오픈 스타트업 마크비전 억 시리즈 유치 성공 주간 동향 제이엘케이 치매 분석 솔루션 태국 허가 획득 포스코 기술 자문위원회 산학전문가 여명 첫 회의 데일리 단신 벤처 컨설팅 인재양성 지원 특징주 드림어스컴퍼니 아마존 조에 아이로봇 인수 로봇청소기 에이클 한양대 를 위한 교육과정 신설 반도체 생태계 선도 논문 수 세계 상위권 세존 기술 기반 방역 산업 분야 협력 강동경희대병원 로봇 활용 병원업무 디지털전환 협약 와 인재 육성 학습환경 제공 특징주 링크제니시스 정부 산업 원천기술 확보 추진 국내최초 시스템 인공지능 활용 간담회 개최 이영복 제네시스랩 대표 사람이 갖는 편견 공정한 면접에는 없습니다 시 돌봄 인형 독거 노인 든든한 벗 강기정 광주시장 여당이 반도체 단지 등 현안 힘써달라 증권 상담 콜봇 서비스 오픈 키움증권 쿡경제 시 쓰고 그림 그리고 예술영역 넘보는 가상의 쌍둥이로 내 병 미리 찾아낸다 헬스케어 시스템 개발 착수 금융에 스며드는 활성화 정책도 장영실상 삼성전자 로봇청소기 비스포크 제트봇 화성시 새솔동 등 자원회수기기 곳 시범 운영 삼성전자 하이닉스 반도체로 초격차 경영 속도 빅데이터 활용 고위험 수입식품 선별한다 인공지능 활용 간담회 에서 발언하는 김소영 금융위 부위원장 아이스크림에듀 서리풀 샘 스마트 스쿨링 우수 학습 멘티에 장학금 수여 괴산군도 영재고 유치전 가세 군의회 건의문 채택 에듀윌 공무원 합격진단 예측 서비스 운영 위메프 애플 출신 전문가 기술책임자로 영입 롯데정보통신 보안 모델 로 지능형 위협 차단 딥브레인 하나은행 앱에 은행원 공급 금융위 금융분야 기술 활성화 나선다 중견기업 위기감지 로 관련뉴스 분석 후 제공키로 빅데이터 기반 위험도로예측 시범서비스 구축 포스코그룹 기술 자문위원회 신설 신기술 전략방향 조언 삼성전자 국내 대학 대학원생 중 최고수는 와 교육 협력 디지털 만 인재 양성 기여 삼성전자 인력 기술 난제 공모전으로 해결 영진전문대 융합기계계열 학생들 학술대회 우수논문상 수상 현대차 전동화 등 연구개발 경력 인재 대규모 채용 활용 인터뷰 도입 괴산군의회 영재고 유치 건의문 채택 증권 인공지능 기술 적용 상담 콜봇 서비스 시행 삼성전자 대학 대학원생 대상 삼성 챌린지 개최 위험상황 폰으로 도로교통공단 기술 활용 교통사고 예방 나서 삼성전자 제 회 삼성 챌린지 개최 현대자동차 로 대규모 경력 인재 확보 나선다 상담 콜봇 서비스 오픈 인공지능 우수 인력 발굴 삼성전자 챌린지 호남대 광주발달장애인훈련센터 교육과정 자문 포스코그룹 기술 자문위원회 신설한다 포스코그룹 기술 자문위 신설 미래 전략 수립 증권 상담 콜봇 서비스 오픈 금융 분야 기술 키운다 데이터 라이브러리 구축 종합 와 손잡고 꿈나무 육성 삼성전자 대학원생 대상 챌린지 신소재 연구 컴퓨터 비전 공모 포스코그룹 기술 자문위원회 신설 호남대 광주발달장애인훈련센터 교육 자문 초등생도 코딩 즐기도록 와 인재 키운다 삼성전자 삼성 챌린지 개최 포스코그룹 기술 자문위원회 신설 기술 공유 토론 진행 현대차 인력 채용 가 면접 본다 경북교육청 누구나 가능한 교육 기반 마련 확대 현대차 경력 인재 세자릿수 채용 인터뷰 도입 맞춤형 인력 양성과정 명 수료 반도체 수요 폭발 삼성전자 우수인력 발굴 만 디지털 인재 양성 와 교육 협력 서울시 기업 인력양성 프로그램 지원 분야 인재양성 체결 증권 상담 콜봇 서비스 시행 시간 어디서나 상담 가능 삼성전자 삼성 챌린지 인공지능 기반 신소재 연구 와 컴퓨터 와 소프트웨어 미래인재 키운다 금융 개발용 공동 데이터 라이브러리 출범 인공지능 솔루션 전문기업 리빌더 메가플랜과 가상공간 활용 최적 솔루션 증권 상담 콜봇 서비스 오픈 인공지능으로 반 디 연구 삼성전자 삼성 챌린지 개최 포스코그룹 기술 자문위원회 신설 금융권 도입 확대되나 금융위 데이터 라이브러리 추진 영진전문대 융합기계계열 제어로봇시스템 재학생 전문대 유일 우수 논문상 컨설팅 및 인재양성 업무 협약 와 인재 양성 위한 교육 콘텐츠 제작 경북교육청 교육 환경개선 사업 확대 실시 삼성전자 삼성 챌린지 개최 우수 인력 발굴과 반도체 디스 거대 금융 정보 저장소 구축 금융 고도화 첫걸음 영진전문대 융합기계계열 학술대회서 전문대생 유일 우수논문상 수상 와 인재 육성 협력 증권 상담 콜봇 서비스 개시 포스코그룹 기술 자문위 신설 사업분야 인재 발굴 나선다 경북교육청 누구나 가능한 교육 기반 마련 와 함께 인재 육성한다 증권 음성 상담 서비스 콜봇 오픈 경북교육청 교육 환경개선 사업 확대 추진 농정원 총 상금 억 원 규모 스마트농업 경진대회 신사업 인재 발굴 포스코그룹 기술 자문위원회 운영 동강대 산타 플랫폼 활용 토익 교육 실시 가명정보 재사용 허용 금융 데이터 라이브러리 구축 포스코그룹 기술 자문위원회 신설 로봇 기반 병원업무 추진 와 함께 인재 키운다 인재 육성 한뜻 김소영 금융권도 활성화 필요 빅데이터 확보 제 ...

# %%
#konlpy(콘엘피) = 형태소 분석
from konlpy.tag import Okt
from collections import Counter
okt = Okt() #객체형성

morph = okt.pos(text) #형태소로 변환 #word= 단어 / tag=품사
morph

noun_list =[]
stop_word = []
for word, tag in morph: #word= 단어 / tag=품사
    if(tag=='Noun') & (len(word)>1): #noun이고 단어가 1글자 이상인것(1글자는 보통 조사이기때문)
        if word not in stop_word:
            noun_list.append(word)

count = Counter(noun_list) #단어별 숫자세주기

# 2022
data =dict(count.most_common()) #빈도수 정리 내림차
series = pd.Series(data)
df=pd.DataFrame(series, columns=['cnt'])
# student_20 =df.loc['청소년'].cnt

df.head()
# Out:
#      cnt
# 개발   332
# 서비스  253
# 기반   252
# 기술   233
# 사업   217

# %% [markdown]
# ## wordcloud

# %%
data.pop('트럼프')

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sns

wordcloud = WordCloud(font_path='../visualization/dataset/malgun.ttf', background_color='white',
                     colormap='flare',width=1500,height=1000).generate_from_frequencies(data)
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 1499.5, 999.5, -0.5)

# %% [markdown]
# ## 트렌드 분석 및 인사이트
