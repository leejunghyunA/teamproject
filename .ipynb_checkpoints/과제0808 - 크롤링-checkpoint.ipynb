# %% [markdown]
# ## 검색
# 1. AI : 4000개
# 2. 인공지능 : 4000개

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from bs4 import BeautifulSoup 
import urllib
import urllib.request as rq
import pandas as pd


global news_df

def News():
    global keyword, num, news_df, url,page_num
    
    keyword = input('검색 키워드를 입력해주세요')
    keyword = urllib.parse.quote(keyword) #퍼센트인코딩 #URL에 문자를 표현하는 인코딩방법(URL에 한글이 섞이면 오류 발생)
    num = int(input('필요한 뉴스기사의 숫자를 입력해주세요'))
    
    news_df = pd.DataFrame(columns=['title','url']) 
    
    page_num=1
    i=0 #크롤링한 기사의 수
    while num > i:
        url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query='+keyword+'&start='+str(page_num)
        html = rq.urlopen(url)
        bs = BeautifulSoup(html,'html.parser')
        texts = bs.find_all(class_='news_tit')

        for text in texts:
            news_df.loc[i,'title'] = text.get_text()
            news_df.loc[i,'url'] = text['href']
            i +=1
            if i == num:
                break
        page_num +=10
    return news_df

News()

#AI, 인공지능
# Out:
# 검색 키워드를 입력해주세요AI
# 필요한 뉴스기사의 숫자를 입력해주세요1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [104], in <cell line: 35>()
#      32         page_num +=10
#      33     return news_df
# ---> 35 News()
#
# Input In [104], in News()
#      21 url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query='+keyword+'&start='+str(page_num)
#      22 html = rq.urlopen(url)
# ---> 23 bs = BeautifulSoup(html,'html.parser')
#      24 texts = bs.find_all(class_='news_tit')
#      26 for text in texts:
#
# File ~\Anaconda3\envs\cakd7\lib\site-packages\bs4\__init__.py:312, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     309 self.parse_only = parse_only
#     311 if hasattr(markup, 'read'):        # It's a file-type object.
# --> 312     markup = markup.read()
#     313 elif len(markup) <= 256 and (
#     314         (isinstance(markup, bytes) and not b'<' in markup)
#     315         or (isinstance(markup, str) and not '<' in markup)
#    (...)
#     319     # Beautiful Soup will still parse the input as markup,
#     320     # since that is sometimes the intended behavior.
#     321     if not self._markup_is_url(markup):
#
# File ~\Anaconda3\envs\cakd7\lib\http\client.py:466, in HTTPResponse.read(self, amt)
#     461 else:
#     462     # Amount is not given (unbounded read) so we must check self.length
#     463     # and self.chunked
#     465     if self.chunked:
# --> 466         return self._readall_chunked()
#     468     if self.length is None:
#     469         s = self.fp.read()
#
# File ~\Anaconda3\envs\cakd7\lib\http\client.py:573, in HTTPResponse._readall_chunked(self)
#     571 try:
#     572     while True:
# --> 573         chunk_left = self._get_chunk_left()
#     574         if chunk_left is None:
#     575             break
#
# File ~\Anaconda3\envs\cakd7\lib\http\client.py:556, in HTTPResponse._get_chunk_left(self)
#     554     self._safe_read(2)  # toss the CRLF at the end of the chunk
#     555 try:
# --> 556     chunk_left = self._read_next_chunk_size()
#     557 except ValueError:
#     558     raise IncompleteRead(b'')
#
# File ~\Anaconda3\envs\cakd7\lib\http\client.py:516, in HTTPResponse._read_next_chunk_size(self)
#     514 def _read_next_chunk_size(self):
#     515     # Read the next chunk size from the file
# --> 516     line = self.fp.readline(_MAXLINE + 1)
#     517     if len(line) > _MAXLINE:
#     518         raise LineTooLong("chunk size")
#
# File ~\Anaconda3\envs\cakd7\lib\socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File ~\Anaconda3\envs\cakd7\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~\Anaconda3\envs\cakd7\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# - 중복값 제거

# %%
news_df[news_df['title'].duplicated() == True] 
news_df=news_df.drop_duplicates(subset=['title'])
news_df.describe()
# Out:
#                                               title  \
# 102                SK C&C, 인공지능으로 울릉도 뇌출혈 응급환자 돕는다!
# 105                조달청, 인공지능 활용 '공공SW사업 발주지원시스템' 개통
# 107                       KAIST, 인공지능 반도체 생태계를 선도하다
# 108              ‘예술’ 영역 넘보는 인공지능…시 쓰고 그림 그리는 초거대AI
# 111              ‘예술’ 영역 넘보는 인공지능…시 쓰고 그림 그리는 초거대AI
# ...                                             ...
# 3960  불법건축물·개발제한구역 위반행위, 이제 꼼짝못한다!... 인공지능이 다 찾아...
# 3963                 [날씨] 전국에 소나기…낮 최고 36도 '한증막 더위'
# 3964         "친구처럼 놀면 나만의 AI 완성"…SKT 인공지능 슈퍼앱 '에이닷'
# 3970       "아침 먹었어?" 말을 거는 AI…SKT '캐릭터 인공지능' 첫선(종합)
# 3990                      대전시, 불법건축물 인공지능으로 찾아낸다...
#
#                                                     url
# 102   http://www.aitimes.kr/news/articleView.html?id...
# 105   http://www.newsis.com/view/?id=NISX20220801_00...
# 107   http://www.boannews.com/media/view.asp?idx=108...
# 108   https://www.seoul.co.kr/news/newsView.php?id=2...
# 111   https://www.seoul.co.kr/news/newsView.php?id=2...
# ...                                                 ...
# 3960  http://www.aitimes.kr/news/articleView.html?id...
# 3963  https://www.yna.co.kr/view/AKR2022080513040000...
# 3964  https://www.hankyung.com/it/article/2022051693311
# 3970  http://www.newsis.com/view/?id=NISX20220516_00...
# 3990                    http://www.breaknews.com/888632
#
# [1072 rows x 2 columns]

# %%
news_df[news_df['title'].duplicated() == True] #688중복
# Out:
# Empty DataFrame
# Columns: [title, url]
# Index: []

# %%
import re
target = news_df['title'].values #Series.values = array
title_list = target.tolist() # array > list
title_list
# Out:
# ['미래 기술의 핵심…삼성·LG 인공지능 저변 확대 나서',
#  '도로교통공단, 인공지능 기반 도로 위험 안내 서비스 추진',
#  "타임게이트, '2022년 인공지능 학습용 데이터 구축사업' 수행기관 선정",
#  '코트라, 중견기업 ‘ESG 모니터링’…“인공지능으로 리스크 찾는다”',
#  "서울성모병원-KT, '당뇨 환자' 위한 인공지능 기반 디지털 트윈 구축한다",
#  '삼성전자, 인공지능·반도체 인재 발굴 ‘AI 챌린지’',
#  '광주시의회, 인공지능 전문가 초청 강연 개최',
#  '광주시의회, 인공지능 발전 방향 강연',
#  '울산대, 인공지능 교육과정 수료식 진행',
#  '"인공지능 쉽게 이해···스마트 시티 만들고 싶어요"',
#  '서천교육지원청, 미래시대 위한 인공지능 교육 연수 실시',
#  '인공지능 데이터테크 ‘라이앤캐처스’, 벤처기업 인증',
#  '인공지능 기술로 고위험 수입식품 찾아낸다',
#  "KB증권, 인공지능 기술 적용한 'AI상담 콜봇'",
#  "KT-NIPA, 디지털전환 관련 사업 및 인공지능·DX 분야 인재 양성 위해 '맞손'",
#  "에이프리카, 인공지능 통합 플랫폼 '치타' 조달청 디지털서비스몰 등록",
#  'KT·EBS, 소프트웨어·인공지능 인재 양성 나서…MOU 체결',
#  '스마트농업 인공지능 경진대회 참가자 모집',
#  '서울시-카이스트, 인공지능 교육 프로그램 2기 수강생 모집',
#  '소리 데이터와 인공지능으로 이뤄지는 스마트 제조',
#  '포스코그룹 인공지능 기술 지문위원회 신설...첫 회의 개최',
#  "KT, EBS와 '소프트웨어·인공지능 학습환경 제공' MOU",
#  '네이버-네이버클라우드-충북병원, 인공지능 기반 스마트 병원 구축한다',
#  "'인공지능(AI) 활용 간담회' 개최",
#  "'KAIST 진천 인공지능 영재캠프' 성료",
#  '“철강도 AI 도입”…포스코, 인공지능 기술 위원회 신설',
#  '‘KAIST 진천 인공지능 영재캠프’ , 인재 양성 가능성 보였다',
#  "'인공지능(AI) 활용 간담회'에서 발언하는 김소영 금융위 부위원장",
#  "DL이앤씨, '인공지능+360도 카메라' 현장관리 솔루션 도입",
#  '[주간VC동향] 인공지능(AI) 스타트업 마크비전 260억원 규모 시리즈A 투자 유...',
#  "에듀윌, '인공지능 합격진단 예측 서비스' 운영",
#  '배터리에 인공지능 더해 사용 효율을 높이자',
#  '2K "NBA 2K23, 새로운 뱃지와 인공지능으로 사실적 농구 구현"',
#  '무대 위로 올라온 인공지능…지휘부터 시극(詩劇), 춤 실험까지',
#  '광주시의회, 인공지능 전문가 초청 강연',
#  '인공지능 기반 영어 학습 앱 말해보카, 누적 다운로드 수 200만 달성',
#  "[내:일을 여는 인문학] 조성배 교수의 '인공지능과 사람', 홍익희 칼럼니스트...",
#  '장성군, 홀몸 어르신에 인공지능 말동무 인형 지원',
#  'KAIST, 인공지능 반도체 생태계 선도',
#  "인공지능이 사용자 보안인프라 강화시킨다!... GS네오텍, 머신러닝 기반 '사이...",
#  '국민은행, 펀드·일임형 ISA 인공지능 화상서비스로 판매',
#  'SK C&C, 인공지능으로 울릉도 뇌출혈 응급환자 돕는다!',
#  "조달청, 인공지능 활용 '공공SW사업 발주지원시스템' 개통",
#  'KAIST, 인공지능 반도체 생태계를 선도하다',
#  '‘예술’ 영역 넘보는 인공지능…시 쓰고 그림 그리는 초거대AI',
#  '지질자원연구원, 지질자원데이터 활용·인공지능 경진대회',
#  '한양대 ERICA, 인공지능 최고영영자 교육과정 개설',
#  '광주시의회, 정민석 인공지능윤리연구소 연구원 초청 특강',
#  '삼진제약, 캐나다 인공지능 신약개발 플랫폼 업체와 공동연구',
#  "파워보이스, '보이스샵 음성인식 버전 1.0' GS 1등급 인증... 인공지능 음성-...",
#  '[문화가K] 인공지능과 예술의 만남…‘제임스 쉐’ 첫 국내전',
#  '고려대 법학전문대학원, 국내 최초 데이터·인공지능법 전문과정 개설',
#  'KAIST \xad 연합학습 인공지능 기술 개발 시간 크게 단축',
#  '김소영 금융부위원장, 인공지능 활용 간담회 참석',
#  '금융위, 금융분야 인공지능 활용 활성화…“양질의 빅데이터 확보 지원”',
#  'DL이앤씨, 360도 인공지능 카메라로 시공하자 줄인다',
#  "KB국민은행, 인공지능으로 '기업여신 자동심사' 한다",
#  '의료인공지능 솔루션 기업 뷰노, 데이터 기반 의료AI 사업 박차',
#  "KT '다양성' 네이버 '인공지능' 카카오 '환자 불편'",
#  "인공지능 의료 로봇기업 '코넥티브' 시드 투자 유치",
#  '하나은행, 모바일 앱서 인공지능 뱅커 도입…"은행권 최초"',
#  '강동경희대병원-KT, 인공지능 로봇 활용...의료진과 함께 환자 보살핀다!',
#  'KT, 라마다 문경새재호텔에 인공지능 기반 호텔 인포테인먼트 솔루션 적용',
#  '[온누리]북한의 인공지능 교육',
#  '진천중, 생거진천 인공지능(AI) 마을학교 운영',
#  '"스마트 제조 \'인공 지능\' 러닝도 진화...자동화 \'속도\' 높이고 \'불량률\' 낮춘...',
#  'DGIST 창업기업 ㈜유니바, 인공지능 학습용 데이터 구축 지원사업 선정',
#  '국표원, 인공지능 응용 가전제품 안전관리지침 개발 착수',
#  '대화를 통해 더 똑똑해지는 인공지능 챗봇...메타 AI, 거의 모든 주제에 말할...',
#  "의료 인공지능 기업 뷰노, 퍼스널 심전도 측정 의료기기 'Hativ Pro' 식약처 ...",
#  "인티그리트, 인공지능 서비스 로봇 '디코닉' SKT와 서비스 제공",
#  "고려대 '데이터·인공지능법 전문과정' 2022년 2학기 개설",
#  "인티그리트, 인공지능 서비스 로봇 '디코닉' 출시",
#  'TTA, 인공지능 제품‧서비스 신뢰성 확보 컨설팅 지원',
#  "KB증권, 인공지능 '상담 로봇' 서비스 시행",
#  '진도군, 인공지능 활용 노인건강 챙긴다',
#  "AI ARS '상담콜', 인공지능 적용 '고객 콜백 예약 기능' 오픈",
#  '라마다 문경새재 호텔에 KT 인공지능 서비스 도입',
#  '아이도트, 국내 인공지능 자궁경부암 판독 서비스 개시',
#  '인공지능 시극 파포스',
#  'KT, EBS와 함께 소프트웨어·인공지능 학습환경 제공을 위한 업무협약 체결',
#  '제주교육청, 몰도바공화국 교원 대상 인공지능 코딩 교육',
#  "충남도, 국비 들여 '인공지능 종패 데이터' 구축",
#  '인공지능이 엑스선 영상 판독…결핵·기흉 등 스스로 진단',
#  'DGIST 학부생 창업기업 유니바, 인공지능 학습용 데이터 구축 지원사업 선정',
#  'KISTI - 쿠웨이트, 데이터·인공지능 캠프 운영...쿠웨이트 청소년 15명 참여',
#  '수리연, IAAE 국제인공지능&윤리협회, 산업수학 기반 AI 사업 협력',
#  '인공지능의 발전으로 인간은 정말 설 자리를 잃게 될까?',
#  '이글루코퍼레이션, KISA 사이버보안 인공지능 데이터셋 구축 사업 수주',
#  '고독사 없는 구미 만든다...인공지능 활용 예방·관리 시범사업',
#  '비헬씨, 한국인공지능협회와 1차 의료 판매 계약',
#  "대전AI교육지원체험센터, '인공지능 교육\xa0학생캠프' 운영",
#  '금융위, 금융 분야 인공지능 활용 활성화 간담회 개최',
#  "과기정통부, '초고성능컴퓨팅 자원' 인공지능 등 초연결 위한 첫발!...전문센...",
#  'ETRI, 인공지능 국제표준화 주도한다',
#  "장성, 고위험 독거노인 위한 '인공지능(AI) 말동무 인형' 지원",
#  "[AI-META 시대 '미래전략'] <22>인공지능 미래 발전과 대응",
#  '국방혁신 4.0 윤곽…인공지능 기반 첨단과학기술군',
#  '한국폴리텍대 서울강서 빅데이터과, 빅데이터·인공지능 연수 진행',
#  "인공지능 융합 강의 'AI+X'…국내 최고의 강좌를 개설하다",
#  "식약처, 인공지능 활용해 '고위험 수입식품' 스마트하게 찾는다",
#  'KT, EBS와 함께 AI 인재 육성..."소프트웨어·인공지능 학습환경 제공을 위한...',
#  '진천군·KAIST, 인공지능 영재캠프 운영··· KAIST 학생들과 교감 할 수 있...',
#  '[기업] KT·EBS, 소프트웨어·인공지능 인재 양성 협력',
#  "포스코그룹, 'AI기술 자문위원회' 신설...인공지능 분야 학계, 산업계 전문가...",
#  '김소영 부위원장, 인공지능 활용 간담회',
#  'KAIST가 국제 인공지능 반도체 생태계 선도한다',
#  "진천군, KAIST 진천 인공지능 영재캠프 '성료'",
#  "KT 인공지능 교육서비스 '코디니', EBS 교육플랫폼 '이솦'에 탑재...AI·SW\xa0...",
#  '조달청, 공공SW사업 발주에 인공지능 도입',
#  '에듀윌, 인공지능 합격비서 ‘AI 패스’ 만든다',
#  '카이스트, 인공지능 반도체 생태계를 선도한다',
#  "KAIST, 인공지능 반도체 '주도'",
#  "KT-EBS '소프트웨어·인공지능 학습환경 제공' MOU",
#  '장성군,인공지능(AI)말동무 인형 지원사업 추진',
#  "김소영 부위원장 '인공지능 활용 간담회 발언'",
#  "진천군, 'KAIST 인공지능 영재캠프' 성료",
#  '詩 쓰는 인공지능 시인 등장',
#  "에듀윌, 인공지능 비서 'AI-Pass' 공개",
#  '광주광역시의회, 인공지능 전문가 초청 강연 개최',
#  'KAIST "인공지능 반도체 생태계 선도"',
#  "인공지능 합격비서가 공무원 수험생에게 합격 진단해주는 에듀윌 'AI-Pass'",
#  '울릉군의료원, 인공지능 뇌출혈 영상기기 설치',
#  '금융위, 금융분야\xa0인공지능\xa0활용\xa0활성화\xa0및\xa0신뢰확보\xa0방안\xa0발표',
#  'KAIST, 스마트폰 위 인공지능 연합학습 속도 4.5배 향상 기법 개발',
#  '전남 장성군, 인공지능(AI) 말동무 인형 지원사업 추진',
#  '국민은행, 기업여신 심사에 인공지능 도입',
#  'DL이앤씨, 인공지능·360도 카메라 기반 현장관리 솔루션 도입',
#  '금융위 부위원장 김소영 “금융권 인공지능 활성화 적극 지원하겠다”',
#  '장성군, 인공지능 말동무 인형 지원사업 시범 추진',
#  '인공지능(AI)이 쓴 시(詩), 사람들 마음 울릴까?',
#  'KAIST, "인공지능 반도체 생태계 선도한다....…논문 수 세계 상위권"',
#  '조달청, 인공지능 기반 공공 SW 사업 발주지원시스템 개통',
#  "'금융분야 인공지능 활성화를 위해'",
#  '김소영 부위원장,금융분야 인공지능 활용 활성화 간담회 개최',
#  "KAIST, 인공지능 반도체 생태계 '선도'",
#  "정부, 내년 상반기 '인공지능 가전' 안전 관리 지침 마련",
#  "DL이앤씨, 인공지능·카메라 기반 현장관리 기술 '디비전' 도입",
#  '인공지능 관련 업계 만난 김소영 부위원장',
#  "AI ARS 상담콜, 인공지능 보이스 적용한 '고객 콜백 예약 기능' 발표",
#  '금융위원회, 인공지능 활용 간담회',
#  "KT, EBS와 AI 인재 육성 '맞손'… 소프트웨어·인공지능 학습 제공 MOU 체결 ...",
#  '인공지능 활용 간담회 입장하는 김소영 금융위 부위원장',
#  "KT, 문경 라마다 문경새재 호텔에 '인공지능 서비스' 입힌다",
#  '인공지능·반도체 두 마리 토끼를 잡은 KAIST, 융합인재 양성 선두 노린다',
#  '금융의 인공지능 활용 관련 발언하는 김소영 금융위 부위원장',
#  '이글루코퍼레이션, KISA 사이버보안 인공지능 데이터셋 구축한다',
#  '고려대 법학전문대학원, 데이터·인공지능법 전문과정 개설',
#  'KAIST, 스스로 진화하는 흉부 엑스선 인공지능 진단기술 개발',
#  '인공지능 응용 가전제품 ‘안전관리지침’ 제정',
#  "고려대 로스쿨, '데이터·인공지능법' 전문과정 개설",
#  "'인공지능 AI 로봇이 관리하는 호텔은 어떨까?' .... KT AI 호텔, 라마다 문경...",
#  'ETRI, 인공지능 국제표준화 주도',
#  '장성군, 인공지능 말동무 인형 지원사업 추진',
#  '정부, 인공지능 가전제품 안전관리 지침 마련 착수…해킹 방지 등 보안기능도',
#  "투디지트, 인공지능 뉴스 분석 주식정보 서비스 '뉴스샐러드'... 해외상표권 ...",
#  '진천군-KAIST, 진천 인공지능 영재캠프 운영',
#  '행동을 이해하는 인공지능 기술!',
#  'SKT, 인공지능 서비스 ‘A.’에 TV, 게임기능 추가',
#  '[화요광장] 의료분야의 인공지능의 역할',
#  '한국폴리텍대학 아산캠퍼스, 인공지능·RPA 자격 응용과정 추진',
#  '포스코그룹, 인공지능 기술 자문위원회 신설',
#  'KAIST, 스마트폰 위 인공지능 연합학습 속도 4.5배 획기적 향상 기법 개발',
#  '고려대 법학전문대학원, 데이터·인공지능법 전문과정 국내 최초로 개설',
#  '한국문화정보원 문화포털, 시 쓰는 인공지능 시아의 시극 ‘파포스’ 소개',
#  '의사처럼 스스로 공부해 X선 영상 판단하는 인공지능 개발',
#  "인공지능이 시집 출간했다!...카카오브레인, 초거대 AI 언어 모델 'KoGPT' 활...",
#  '진천중, 18일까지 인공지능 마을학교 운영',
#  '김소영 "미래 위한 인공지능 개발"…정부, 테스트베드 구축',
#  "엠비아이솔루션 '상담콜', 인공지능 보이스 적용 '고객 콜백 예약 기능' 오픈",
#  '"새로운 세상을 여는 모두의 인공지능(AI)교육 학생캠프" 운영',
#  '지질자원연, 제2회 지질자원데이터 활용 및 인공지능 경진대회 개최',
#  'KAIST, 스마트폰 위 인공지능(AI) 연합학습 속도 4.5배 획기적 향상 기법 개발',
#  "장성군, 독거노인 '인공지능(AI) 말동무 인형' 지원",
#  '장성군 ‘인공지능 말동무 인형 지원사업’ 추진',
#  "포항공대, '인공지능 최고경영자과정' 신설…이달 26일까지 모집",
#  "TTA, '인공지능 제품‧서비스 신뢰성 확보 컨설팅' 제공",
#  '식약처 ‘위험예측 기반 검사‧관리 시스템’ 구축 추진…인공지능 활용, 고위...',
#  "대전AI교육지원체험센터, 초‧중‧고 '인공지능(AI)교육 학생캠프' 운영",
#  '제주대, 몽골 등 3개국과 인공지능.IT기술 공동프로젝트',
#  '급락장에서 빛난 인공지능…RA 알고리즘, 시장 수익률 웃돌아',
#  '보은군의회, 인공지능 영재학교 유치 결의안 채택',
#  '진천중, 오는 18일까지 인공지능 마을학교 운영',
#  '통영시 인공지능 CCTV, 극단적 선택 막았다',
#  "[주간VC동향] 인공지능(AI) 의료 스타트업 '에어스메디컬' 253억원 규모 시리...",
#  "지질자원硏, '2022 지질자원데이터 활용 및 인공지능 경진대회' 19일까지 진행",
#  '軍도 수학에 러브콜 "독자 AI(인공지능) 알고리즘 만들겠다"',
#  'IAAE 국제인공지능&윤리협회-국가수리과학연구소, 산업수학 기반의 인공지능 ...',
#  '비헬씨-한국인공지능협회, 의료 마이데이터 첫 판매 계약 체결',
#  "KAIST-칭화대 공동연구팀, 모바일 기기에서 인공지능 '연합학습 속도 4.5배' ...",
#  '우상욱 팜캐드 대표 "인공지능 신약개발… 기술 이만큼 왔다"',
#  "하나은행, 모바일뱅킹에 '인공지능 은행원' 도입",
#  '숨겨진 물리 법칙 발견하는 인공지능',
#  "'인공지능반도체' 강국으로 급부상하는 한국...국가 연구 전략 거점으로써 KA...",
#  '경남교육청, 초·중등 교원 인공지능 교육역량 키운다',
#  '지질자원데이터 활용 및 인공지능 경진대회',
#  'KAIST, 인공지능 반도체 생태계를 선도한다.',
#  '‘2022 지질자원데이터 활용 및 인공지능 경진대회’ 개최',
#  '국가수리과학연구소-IAAE 국제인공지능&윤리협회, 업무협약',
#  'KAIST, 인공지능 기반 위성영상 분석 기술 시스템 개발 나서',
#  '[데일리 IT 단신] KT, EBS와 소프트웨어·인공지능 학습환경 제공 나서 外',
#  "현대자동차, 해외 대학 인공지능·AAM·자율주행·로보틱스 분야 '박사과정 인...",
#  '인공지능으로 지능형 위협 차단한다!...롯데정보통신, 오탐 및 미탐 제거 AI알...',
#  '카이스트, 스마트폰 위 인공지능(AI) 연합학습 속도 4.5배 획기적 향상 기법 ...',
#  '반도체·인공지능 등 진로체험기관 확대…내일부터 모집',
#  '토종 인공지능 위조 탐지 기술력, 글로벌 시장 문제 해결사로!... 마크비전, ...',
#  'DGIST 학부생 창업기업 ㈜유니바, 인공지능 학습용 데이터 구축 지원사업 선정',
#  "삼성전자, 인공지능·ML에 최적화된 '메모리 시맨틱 SSD' 등 차세대 메모리 솔...",
#  "고려대 로스쿨, 국내 최초 '데이터·인공지능법 전문과정' 개설",
#  '비헬씨, 인공지능협회와 의료 마이데이터 첫 판매계약 체결',
#  '[산업부 소식] 국표원, ‘인공지능 응용 가전제품’ 안전관리지침 개발 착수 ...',
#  'TTA, ‘인공지능 제품·서비스 신뢰성 확보 컨설팅’ 제공',
#  '"부산, 인공지능 치의학 도시 초석 마련"',
#  "SKT, 인공지능 등 ICT 스타트업 육성에서도 '빛났다'",
#  '[바이오위클리] 인공지능으로 희소 유전 질환 진단…쓰리빌리언',
#  '카카오브레인, 초거대 인공지능 모델 연구 확장',
#  '위메프 새 CTO에 이진호 선임, 애플 본사서 인공지능과 머신러닝 담당',
#  "인공지능 및 데이터센터 컴퓨팅 가속화...마이크로칩, 'CXL스마트 메모리 컨트...",
#  '순천시, 인공지능(AI) 반려 로봇 돌봄서비스 시작',
#  '인공지능, 로봇, 바이오 등 첨단 과학기술을 국방에 접목한다',
#  '인공지능·소프트웨어 교육 역량 키운다',
#  "하나은행, 은행권 첫 모바일 '인공지능 뱅커' 도입",
#  '금융위, 인공지능 활용 활성화 간담회',
#  '청도 중앙초, 인공지능(AI)교육 여름방학 캠프',
#  'SW연구소 AI융합교육센터 취·창업자, 인공지능 관련 대학원 진학자 배출',
#  '가톨릭대-마인드허브, 뇌신경 환자 언어재활 인공지능 학습 모델 연구 협약',
#  '광주디자인진흥원-인공지능사업융합사업단 맞손',
#  '인공지능이 CCTV에서 아이 학대 증거 찾는다',
#  '광주시, 인공지능 스타트업 투자유치 설명회 참여 기업 모집',
#  '뉴워커, 슈퍼브AI와 인공지능 학습 데이터 구축 맞손',
#  '[캠퍼스人+스토리]KAIST, 자가발전 흉부X선 인공지능 진단기술 개발',
#  'KB국민은행, 인공지능으로 기업여신 자동심사',
#  '가톨릭대-㈜마인드허브, 언어장애 재활 인공지능 개발 나서',
#  '대전시, 돌봄 대상 어르신에 인공지능 말동무 로봇 꿈돌이 지원',
#  "'교육기부 진로체험 인증기관' 모집…반도체·인공지능 등 확대",
#  '뉴워커-슈퍼브AI, 인공지능 학습 데이터 구축 MOU 체결',
#  "지자체 AI(인공지능) 영재고 유치 '불꽃경쟁'",
#  '동의대 인공지능그랜드ICT연구센터 몽골국제대와 업무 협약',
#  '대전시, 철도 시설물 이상징후 인공지능으로 감시',
#  '네이버클라우드, 미래에셋증권과 인공지능 금융 서비스 협력',
#  'KAIST, 흉부 엑스선 인공지능 진단기술 개발',
#  '인천시, 홀로사는 중장년 5000가구 인공지능(AI)으로 돌본다',
#  '광주디자인진흥원, 인공지능산업융합사업단과 MOU 체결',
#  "'게임 덕후 주목'…인공지능이 그려낸 고전 명작 게임 캐릭터들",
#  '인공지능의 악용 사례, 딥페이크 기술과 과제',
#  '"인공지능으로 신속정확하게 강직척추염 조기 진단"',
#  '대전시, 인공지능 말동무 돌봄로봇 자치구 입양식 개최',
#  '대전시, 인공지능 활용 철도시설 실시간 점검기술 개발 추진',
#  '전북대 인공지능·소프트웨어공학 학생들, 학술대회 수상',
#  'ETRI, 2024년까지 인공지능 분야 국제표준화 청사진 제시한다',
#  "인공지능 물류 스타트업 '바이너리브릿지', Pre-A 시리즈 44억원 투자 유치.....",
#  '레이놀즈, 인공지능 탑재 “프리미엄 스마트 줄넘기 출시”',
#  '뉴워커, 슈퍼브AI와 인공지능 학습 데이터 구축 업무협약 체결',
#  "스페이스 에스, 대전 대덕특구 '인공지능 기술창업' 생태계 구축",
#  "순천향대천안병원, 인공지능과 사물인터넷 활용 '정신질환자 예측시스템 개발...",
#  'ETRI, 인공지능 국제표준화 주도권 확보',
#  '조달청, 인공지능 기반 공공SW사업 발주지원시스템 오픈...제안요청서 자동생...',
#  'TTA, ‘인공지능 제품‧서비스 신뢰성 확보 컨설팅’ 제공',
#  "결혼도 스마트하게…하동군, 인공지능(AI)로 미혼남녀 '맺어주기' 플랫폼 개발",
#  "[Pangyo Tech] 미스터마인드, 2022년 7월 'Pangyo Monthly Online Meet Up'서...",
#  "[리뷰] 인공지능 품은 짐벌 웹 캠 '인스타360 링크'",
#  '한-아르헨티나, 인공지능·5G·사물인터넷 등 ICT 협력 강화',
#  '과기정통부, 세계이동통신사연합회와 인공지능 반도체·메타버스 스타트업 지...',
#  '일상 속 수학…산업 속 수학 <7> 수학과 인공지능 알고리즘',
#  '대전시, 인공지능 말동무 돌봄 로봇 자치구 입양식',
#  '뷰노, 국제학술지에 인공지능 기반 심전도 분석 기술 게재',
#  '카뱅-에프앤가이드, 금융 콘텐츠 인공지능 모델 공동 개발',
#  '딥러닝 인공지능으로 강직척추염 조기진단',
#  '인공지능 AI가 그려낸 지구 멸망 전 인간들의 마지막 모습은 이렇다',
#  '인공지능으로 강직척추염 조기 진단 모델 개발',
#  'KT-네오랩컨버전스, 에듀테크 인공지능 공동연구 업무협약',
#  "장성군, '인공지능(AI) 말동무 인형 지원사업' 시범적 추진",
#  'AI가 기자보다 기사를 잘 쓴다? | 인공지능은 보조일 뿐, 失業 걱정은 기우…...',
#  '중앙대 인문콘텐츠연구소, 제5회 인공지능인문학 국제학술대회 ICAIH 2022 성...',
#  '소아 희귀질환 의료 인공지능 민관합동 개발',
#  "한수원, 수소 전주기·인공지능 기술 연구 '본격화'",
#  "와인과 과학기술, '인공지능(AI)'을 활용한 다양한 연구 활발",
#  "KB증권, 인공지능 기술 적용한 'AI상담 콜봇' 서비스 제공",
#  "UNIST-KISTI, '슈퍼컴퓨팅 청소년캠프 2022'... 인공지능 구현, 경기 교하고와...",
#  '대전시, 인공지능 활용해 철도 시설물 이상 징후 감시',
#  "인공지능 기반 자궁경부암 판독 시스템 '써비레이 AI' 전국 93개 산부인과 병...",
#  '인공지능·로봇, 건설산업 디지털화 견인',
#  '[소통 하동] 인공지능 미혼남녀 연계플랫폼 개발 완료',
#  'ETRI, 인공지능 국제표준화 주도 나선다',
#  '[금요광장] 인공지능과 더불어 사는 미래',
#  '시흥교육지원청, 인공지능 융합교육 활성화 지원 강화',
#  "스스로 진화하는 '흉부 엑스선 인공지능 진단기술' 개발",
#  '얼굴인식 인공지능 식별추적 헌법소원 기자회견',
#  '하나은행 모바일 앱에 인공지능 은행원 도입...어떤 역할하나?',
#  '인천시, 홀몸 중장년 5000 가구 인공지능(AI)으로 돌본다',
#  "테라젠바이오, '소아희귀질환 인공지능' 솔루션 개발 사업자 선정",
#  '하동군, 인공지능(AI) 미혼남녀 연계플랫폼 전국 지자체 첫 도입',
#  '광주광역시의회, 인공지능 전문가 초청 강연 진행',
#  '카이스트 이성주 교수팀, 스마트폰 위 인공지능(AI) 연합학습 속도 4.5배 획기...',
#  '라온메디, 인공지능 활용 국가연구개발사업 주관기업 선정',
#  '대전시, 인공지능 말동무 돌봄로봇 자치구 입양식 가져',
#  '[이종호의 포스트 펜데믹 로드맵-54] 인공지능 로봇의 딜레마',
#  '가톨릭대-마인드허브, 뇌신경 환자 언어재활 위한 인공지능 연구한다',
#  "에이아이런, '챗봇과 함께하는 인공지능 윤리 교육' 무료 배포",
#  '인공지능 응용 가전제품 안전관리 지침 개발 세미나',
#  "반도체·인공지능·코딩…첨단 분야 '진로체험 프로그램' 확대",
#  '김강민 가톨릭대 교수, 전자의무기록 인공지능 기술 개발 나서',
#  "인공지능 사회‧윤리적 위험에 대응한다!... 과기정통부-TTA, 'AI 제품‧서비...",
#  '대전시, 철도 시설물 ‘이상 징후’ 인공지능이 감시',
#  "일상의 인공지능 친구 'A.(에이닷)'...신규 서비스 탑재, 안드로이드 버전 27...",
#  '장성군, 인공지능(AI) 말동무 인형 지원사업 추진',
#  "시쓰는 인공지능 시아(SIA)의 시들로 구성하여 만든 시극 '파포스'",
#  "하동군, 인공지능(AI) 미혼남녀 연계 플랫폼 'AI 맞썸다(多)방' 개발 완료",
#  '테라젠바이오 "소아희귀질환 진단 인공지능 개발 사업자 선정"',
#  "특허청, '인공지능 지재권 역량 강화' 중소·벤처기업 간담회",
#  '과기정통부 “첨단 반도체 공정 서비스, 인공지능·데이터기반 제공”',
#  '오산문화스포츠센터, 인공지능 로봇 시설 안내한다',
#  "중앙대 인문콘텐츠연구소, '인공지능인문학 국제학술대회 ICAIH 2022'",
#  "인공지능(AI) 기반 '문장 검색 방법·장치' 특허 등록",
#  '[게시판] JTBC, 한국기술교육대와 인공지능 활용 업무협약',
#  '광주디자인진흥원-인공지능융합사업단 협약',
#  '인공지능 활용 반려동물 질병 진단한다',
#  '어린이집·유치장·야간도로에 인공지능 CCTV 도입추진',
#  '동아ST, 인공지능 활용 폐암 신약 연구 정부과제 선정',
#  "라온메디, 인공지능 활용 '국가연구개발사업' 주관기업 선정",
#  '남해군 ‘인공지능 통합 돌봄 서비스’ 확대 시행',
#  'KT, 네오랩컨버전스와 MOU…에듀테크·인공지능 기술 연구',
#  '"AI 산업육성 힘 모으자" 중진공-인공지능사업단 `맞손\'',
#  '중앙대 인문콘텐츠연구소,\xa0제5회 인공지능인문학 국제학술대회 ICAIH 2022 성...',
#  '대전AI교육지원체험센터, 인공지능(AI)교육 교원연수',
#  '가톨릭대, ㈜마인드허브와 뇌신경 환자 언어재활 위한 인공지능 연구 나서',
#  '김치 품질, 인공지능으로 관리한다',
#  '제이엘케이, 인공지능 치료 정보 등 유사 문장 검색 위한 특허 등록',
#  "영상 속 3차원 '깊이 정보', 인공지능 알고리즘으로 더 빠르게 정확히 알아낸...",
#  '대전시, 인공지능으로 철도시설물 안전 관리한다',
#  '인천시, 8월부터 비대면 인공지능(AI) 케어콜 돌봄서비스 실시',
#  '남해군, ICT연계 인공지능 통합돌봄사업 확대',
#  '의료 마이데이터 플랫폼 비헬씨, 한국인공지능협회와 첫 판매 계약 체결',
#  'TVM, 스포피드와 인공지능 딥러닝 적용한 라리가 메타버스 업무 협약',
#  "'인공감성지능' AEI 소재로 한 연극 '로디드 모먼트' 대학로서 상연",
#  "부산디자인진흥원, 인공지능 기술 융합한 스타일테크 산업 '청신호'",
#  '[김병필의 인공지능 개척시대] 진짜 같은 가짜 데이터로 인공지능 가르치기',
#  '인공지능으로 입시 서류를 검증하자',
#  "엣지 AI 기업 '노타', 대전시에 인공지능 기반 안전 횡단보도 구축한다",
#  '대통령실 보안, 인공지능이 책임진다',
#  '대전시, 철도시설물 이상 징후 인공지능으로 감시한다',
#  '인천시, 홀로사는 중장년 5천 가구 인공지능(AI)으로 돌본다',
#  '“안 배워도 알아요”…흉부 엑스선 족집게 판독하는 ‘똑똑한 인공지능’ 개...',
#  'SKT, 용접 오류 판별 인공지능',
#  '인공지능 활용 소아희귀질환 치료 나선다',
#  '광주시, 5개 인공지능 기업과 투자협약…마케팅 연구소 구축',
#  "LG 인공지능 아티스트 '틸다', 세계 광고제 뉴욕 페스티벌 휩쓸다",
#  '카이스트, 스스로 진화하는 흉부 엑스선 인공지능 진단기술 개발',
#  '‘인공지능 대가’가 무보수로 신약개발 연구소장 맡은 까닭은',
#  '인천시, 홀로사는 중장년 5000가구 인공지능으로 돌본다',
#  "JTBC, 보도국 돕는 '인공지능' 도입…한국기술교육대와 MOU",
#  '특허청, 인공지능 관련 특허정보 제공…심사 개선의견 청취',
#  'LG유플러스, 근로복지공단 민원업무 인공지능 적용',
#  '대전시, 데이터·인공지능 기반 스마트도시 조성 실무협의회 구성',
#  '세종대 김수연 교수, 2년 연속 인공지능 학습용 데이터 구축 사업 선정',
#  '"챗봇 지고 예측 분석 뜬다" 2022 국내 인공지능 도입 및 활용 현황 조사 - M...',
#  '동아ST·심플렉스·연세암병원팀, 인공지능 활용 혁신신약 발굴',
#  '목포대 조선공학 졸업 김현준 씨 “기계공학·인공지능 융합…신재생에너지 산...',
#  '첨단 반도체 공정 서비스, 인공지능·데이터기반 제공',
#  "'AI(인공지능), 4차산업시대'...국내 언론사 콘텐츠 제공방식은 '게걸음' 수준",
#  '함양군, ICT 연계 인공지능 통합돌봄사업 확대',
#  "와이즈에이아이, 인공지능 개인비서 앱 'AI-ME' B2C 공략 본격화",
#  "데이터·인공지능 기반 '스마트도시 대전' 밑그림",
#  'AI 챗봇 ‘심심이’, 인공지능 및 빅데이터 연구자를 위해 데이터 공개',
#  '가톨릭대, 마인드허브와 뇌신경 환자 언어재활 위한 인공지능 연구',
#  '인공지능 딥러닝으로 강직척추염 조기 진단 모델 개발',
#  '광주시, 수도권 인공지능 유망기업과 투자협약',
#  '대전시, 도시철도시설물 이상징후 인공지능으로 감시한다',
#  '뷰노, 마이허브에 7억 의료인공지능 솔루션 공급',
#  "KAIST 김재철AI대학원, 인공지능 'CAIO 과정' 높은 참여와 호응... 3기 모집으...",
#  '엣지 인공지능과 로보틱스 애플리케이션, 보다 쉬고 빠르게...엔비디아 젯슨 ...',
#  "인공지능으로 '9대 소아희귀질환' 치료에 희망준다!",
#  '[해군] 미래 안보환경에 맞춘 인공지능·무인체계 발전 방향 모색',
#  "대전시, 인공지능(AI) 말동무 '돌봄로봇 꿈돌이' 입양식 가져",
#  '포항시, 인공지능 인재양성 첫 발 내딛는다',
#  "딥러닝 인공지능으로 '강직척추염' 조기진단 입증",
#  "인공지능 감성 챗봇 대표기업 '심심이', 초거대 대화 데이터셋 150억건 공개!...",
#  '셀타스퀘어, 인공지능을 이용한 약물방법과 장치에 대한 특허 등록',
#  '대전시 철도 시설물 이상징후 인공지능으로 감시한다',
#  '한수원, 한강 수위예측 인공지능(AI) 경진대회 개최',
#  "크라우드웍스, TTA '인공지능 학습용 데이터 검사' 수행사 2년 연속 선정",
#  '의병박물관, 인공지능 전시해설 로봇 도입…해설과 방역을 동시에',
#  '[남해소식] 군, ICT 연계 인공지능 통합돌봄서비스 확대',
#  '동아ST, 인공지능 활용 폐암 신약 연구 정부 과제 선정',
#  "인공지능 및 빅데이터 시대 이끈다!... KAIST 정명수 교수팀, 세계 최초 '차세...",
#  '의료 인공지능 기업 루닛, 공모가 3만원 확정…12∼13일 청약',
#  '소아희귀질환, 진단ㆍ치료ㆍ예후 관리하는 의료 인공지능 개발 착수',
#  '광주광역시, 수도권 인공지능 유망기업과 투자협약',
#  '특허청, 인공지능 관련 지식재산권 역량 제고 위한 간담회',
#  '카카오브레인, 인공지능 영어 학습 앱 ‘레미’ 공개',
#  '[특징주] 딥노이드 주가, 급등세 기록에 신고가…의료 인공지능 탄력받나',
#  '제주대학교 SW융합교육원, 3개국서 인공지능 등 전수한다',
#  "포천교육지원청 '가족과 함께하는 재미있는 인공지능(AI)' 운영.",
#  '인공지능으로 표현한 매사냥',
#  '동양레이더/ 2023년 AI+X(인공지능 융합) 신규 기획과제 모집',
#  '의령 의병박물관, 인공지능 해설 로봇 도입',
#  '인공지능 대표 기관 한 자리에',
#  '유방암 96% 맞추는 인공지능 촉각 센서',
#  '반도체·인공지능 등 첨단산업 진로체험 확대… 교육부 진로체험기관 인증기준...',
#  "대규모 언어 인공지능 모델 '네모 메가트론'...220억에서 1조 파라미터 크기 ...",
#  '인천시, AI(인공지능) 돌봄 전화 서비스 확대',
#  '광주광역시, 인공지능 스타트업에 투자매칭 지원',
#  '인공지능 AI 빠망 돌봄인형을 첫 출시',
#  "카뱅-에프앤가이드, '금융 콘텐츠 인공지능 모델' 공동 개발",
#  '대전 데이터·인공지능 기반 스마트도시 그린다',
#  'LG 인공지능 틸다, 뉴욕페스티벌 금상·은상 수상',
#  '육군교육사-수리연-GIST-국기연, 국내 최초 국방 인공지능(AI) 수학적 모델 논...',
#  '인공지능(AI) 응용 가전제품 안전관리 지침 개발 착수',
#  "카카오브레인, 인공지능 영어 학습 앱 '레미' 공개",
#  '[이슈&인사이트] 인공지능, 제대로 알고 투자해야',
#  '과기부, 소아희귀질환 치료 인공지능(AI) 개발 착수',
#  '과기정통부, 민관합동 소아희귀질환 치료 인공지능(AI) 개발',
#  '카이스트 정명수 교수팀, 인공지능 및 빅데이터 시대를 이끌어 갈 차세대 CXL...',
#  '[2022 수시 합격생 릴레이 인터뷰 | 숭실대 기계공학부 최지웅] 레고부터 주식...',
#  '남해군, 인공지능 통합돌봄사업 확대',
#  '우리는 왜 인공지능을 공부해야 하는가',
#  '마크비전, 업계 최고 리더십 합류... 인공지능 글로벌 시장 경쟁력 강화',
#  '"감정 더빙하는 인공지능"…KT, \'AI 보이스 스튜디오\' 출시',
#  '인천시, 내달부터 인공지능(AI) 모니터링...홀로 중장년 5천 가구',
#  '인천시, 혼자 사는 중장년 가구 인공지능돌봄서비스',
#  '[모두를 위한 인공지능] 3부 - 인공지능 산업/기업을 지원, 육성하기 위해 필...',
#  '남해군, 인공지능 통합 돌봄서비스 확대',
#  '셀타스퀘어, ‘인공지능 기반 약물감시 방법과 장치’ 특허 등록',
#  'ETRI 이강찬 실장, 국제전기통신연합 \'머신러닝표준화그룹\' 의장 선임..."인공...',
#  '세종시, 인공지능·데이터시대, 소프트웨어랑 놀자',
#  '대전시, 안전사고 예방 인공지능 정책 펼친다',
#  'SKT, 컴퓨터정보학회와 인공지능∙메타버스 교육과정 개발',
#  '[방문 남해] ICT연계 인공지능 통합돌봄사업 확대',
#  "중진공 광주본부, 인공지능산업융합사업단과 AI 산업 육성 위해 '맞손'",
#  "인천시 중장년 1인가구에 '인공지능 돌봄서비스' 제공",
#  "SKT, '누구 비즈콜'로 인공지능 콜 시장 진출",
#  '인천시, 홀로사는 중장년 5천 가구 인공지능(AI)모니터링',
#  '오산시, AI(인공지능)시대 진로 진학 특강',
#  'KT, 스마트펜 활용 인공지능 기술 상용화',
#  '광주시, 5개 인공지능 기업과 투자협약',
#  '한국교통대, 인공지능산업 융합생태계 조성 위한 광역협력 추진',
#  '순천대 국용인 교수, 인공지능 기반 잡초 판별 시스템 개발',
#  '테라젠, 소아희귀질환 인공지능 SW 솔루션 개발 사업자 선정',
#  "대구교육청.달서중학교 '2022 인공지능(AI) 캠프 개최",
#  '충북과기원. 2023 인공지능 융합 신규 기획과제 모집과제별 1천500만원 지원',
#  '동아ST·심플렉스·연세암병원팀 인공지능 활용 혁신신약 발굴 나서',
#  '[주말판] 인공지능의 실제 도입을 위해 필요한 세 가지',
#  '사이버보안\xa0분야\xa0특화\xa0인공지능\xa0학습\xa0데이터셋\xa08억건\xa0구축',
#  '동래구 안락1동, 인공 지능 돌봄 AI 스피커로 어르신 안부 확인',
#  '인천시, 인공지능 케어콜 돌봄서비스 실시',
#  "구글 딥마인드, '물리학' 배우는 인공지능 개발[과학을읽다]",
#  "강원대병원, 인공지능이 입원환자 '낙상'·'욕창' 모니터링하고 이상징후\xa0탐...",
#  '대전시, 데이터·인공지능 기반 스마트도시 조성에 역량 결집',
#  '남해군， 인공지능 통합돌봄사업 확대',
#  "KT, 인공지능 음성합성 서비스 'AI 보이스 스튜디오' 출시",
#  "인공지능이 내 두피 케어…'어헤즈 헤어랩' 플랫폼 출시",
#  '오산시, AI(인공지능) 시대 진로 진학 특강 개최',
#  '인천시, 홀로사는 중장년 5천 가구 인공지능(AI)으로 돌본다.',
#  "서울대, 모두를 위한 '인공지능 여름학교' 개최...국내외 저명한 AI 연구자와...",
#  '영진전문대 인공지능혁신공유대학사업단, AI교육캠프 개최',
#  '함양군, ICT연계 인공지능 통합돌봄사업 확대',
#  '김치품질, 인공지능으로 관리한다',
#  '인공지능으로 아동·노인 실종예방',
#  "특허청, '인공지능 지식재산권 역량강화' 중소·벤처기업 간담회",
#  '성빈센트, 인공지능 활용한 신경조절치료 효과 검증 돌입',
#  '포항시, 인공지능 인재양성에 나선다!',
#  '인공지능이 취약계층 돌본다…인천시 40세 이상 중장년 1인 가구',
#  'MBN[토요포커스] 이영기 한국인공지능협회 부회장 “건강한 인공지능 생태계를...',
#  '세종시, "인공지능·데이터시대 소프트웨어랑 놀자"',
#  "테라젠바이오, '소아희귀질환 인공지능 소프트웨어 솔루션 개발' 사업자 선정",
#  "포지큐브, 인공지능 텔레마케팅센터 '18곳' 확장",
#  '한국교통대, 인공지능산업 융합생태계 조성 위한 광역협력 교류회 추진',
#  "인공지능 대표 기관 한자리에…'2022 AI 원팀 전체회의' 개최",
#  '경희대치과병원, ‘인공지능 3D 통합영상분석 플랫폼’ 개발에 앞장',
#  '동아ST·심플렉스·연세암병원, 인공지능 활용 혁신신약 발굴 나서',
#  "SKT, '누구 비즈콜'로 인공지능 콜 B2B 시장 진출",
#  '제이엘케이, 인공지능으로 라이프로그 분석 가능한 유사 문장 검색을 위한 특...',
#  '인공지능 스스로 진화, 레이블 없이 데이터 만으로 흉부엑스선에서 병변 찾아...',
#  '한국기술교육대, ‘인공지능 보도국 테크 저널리즘 기술개발 및 연구 협력’ ...',
#  '세종시, 인공지능 인재양성 위해 네이버와 손 잡았다',
#  '동아ST·심플렉스·연세암병원, 인공지능 활용 혁신신약 발굴',
#  '차세대 인공지능(AI) 비만 치료 특화 스마트병원 구축',
#  '오산시, 인공지능시대 중학생 대상 진로 특강',
#  '라온메디, 인공지능 활용 ‘국가연구개발사업’ 주관기업 선정',
#  '광주경자청, 인공지능 분야 8개 기업 협약체결…565억 투자유치',
#  '과기정통부, 인공지능 활용 사이버보안 대응체계 고도화 지원 나서',
#  '인공지능은 게임을 어떻게 움직이는가?',
#  "인공지능 의료 스타트업 '에어스메디컬', 시리즈B 253억 투자 유치..AI 진단검...",
#  '영양 석보초등학교 "AI랑 친해지기" 인공지능 캠프 운영\xa0',
#  '무릎 관절염 진행 속도·예후 예측하는 인공지능 모델 개발',
#  '부산온종합병원, 부산 첫 인공지능 기반 24시간 심정지 위험 사전 관리',
#  '대전시, ‘인공지능 돌봄로봇’ 5백 대 입양식',
#  '유클리드소프트, 청년몽실 협동조합과 인공지능 협력',
#  '한국항공우주산업-KAIST, 뉴 스페이스 시대 대비한다!...설명가능한 인공지능...',
#  '경북, ‘인공지능 학습용 데이터 사업’ 국비 63억 확보',
#  '울산 남구, 어르신 300명에 인공지능 말동무 인형 지원',
#  "인공지능 플랫폼 '알파폴드', 지구상 거의 모든 단백질 구조 예측...2억개 이...",
#  "고려대 산학협력단 '인공지능 학습용 데이터 구축사업' 선정",
#  "AIA생명 손흥민 선수 인공지능 동생 'AI 쏘니' 공개",
#  '[포럼] 사법 편의주의와 인공지능 판사',
#  '[카드] 라온메디, 인공지능 활용 국가연구개발사업 주관기업 선정',
#  '인공지능 통합 관제시스템으로 무장한 정부세종청사로 변신한다',
#  "포항시, 인공지능 인재양성 '첫 발' 내딛다",
#  "음성군의회, 'AI(인공지능) 영재고 충북혁신도시 유치 촉구 건의안' 채택",
#  '뉴패러다임인베스트먼트, 인공지능(AI) 기반 에듀테크 스타트업 ‘에듀템’에...',
#  "외교부, '2022 과학기술외교자문위원회' 개최...인공지능·빅데이터 분과 등 ...",
#  '인천대, 인공지능 화재경보장치 개발 착수',
#  "손흥민 선수 '인공지능 휴먼'으로 활약 중...딥브레인AI, AIA생명 브랜드 홍보...",
#  '인공지능·데이터 시대, 세종시에서 소프트웨어랑 놀자',
#  'KT, 에듀테크 인공지능 기술 집중 육성',
#  "포지큐브, 인슈어랩스와 '인공지능 텔레마케팅' 솔루션... 금융상품 콜드콜 A...",
#  "인공지능 신약개발협의회 발족…'협업 생태계' 조성",
#  '경희대치과병원, ‘인공지능 3D 통합영상분석 플랫폼’ 개발 착수',
#  "무하유, '2022 인공지능 학습용 데이터 구축사업' 주관기관에 선정",
#  '동아ST·심플렉스·연세암병원팀 인공지능 활용 혁신신약 발굴',
#  "부곡동청소년문화집 '인공지능 캠프' 운영\xa0",
#  '광주시, 수도권 인공지능 기업 투자협약',
#  "어헤즈, 인공지능 두피케어 플랫폼 '어헤즈 헤어랩' 출시",
#  '경찰청, 인공지능 기반 아동학대 영상 분석 시스템 개발 등 치안서비스 고도화',
#  '인공지능 ‘실내외 통합 GPS 시스템’ 개발',
#  'KT, 네오랩컨버전스와 에듀테크 인공지능 기술 연구 협력',
#  '㈜아크릴, AI 지방흡입·비만 특화 인공지능병원 구축 나선다',
#  '포항시, 인공지능 인재양성 ‘첫 발’',
#  "진안홍삼연구소, '인공지능 학습용 데이터 구축사업' 계약",
#  "동아ST·심플렉스·연세암병원팀, '인공지능' 활용 혁신신약 발굴 나서",
#  '전남도립대학교 인공지능드론학과, 2022 국제IoT가전로봇박람회 참가... "학생...',
#  "과기정통부, '제5회 인공지능 보안의 날 발표회' 개최",
#  '충북대병원 의료인공지능팀, 한국형 빅데이터 구축사업 개발 선도',
#  'AI 인재 양성..한국인공지능협회, 인공지능자격센터 오픈',
#  '인공지능부터 메타버스까지… ‘코드 컨퍼런스 2022’ 성료',
#  '대전시, 철도 시설물 이상징후 인공지능으로 감시한다',
#  '아론티어, 2022년도 인공지능 활용 혁신 신약 발굴 사업 신규과제 선정',
#  '순천대학교 국용인 교수, 인공지능 기반 잡초 판별 시스템 개발',
#  "인하대학교 인공지능융합연구센터, 실무형 인재 양성 위한 '한진 AI 아카데미...",
#  '데이터·인공지능 기업 만난 한총리 "개선 가능 규제 조치"(종합)',
#  "[대한민국 인공지능 기업정보집] AI 기반 데이터분석 전문기업 '랩투아이'",
#  "대한민국 인공지능 대표 기관들이 한자리에… '2022 AI 원팀 전체회의' 개최",
#  '브릿지앤브릿지, AI(인공지능) 해외 바이어 발굴 서비스 론칭',
#  "네이버, 인공지능 검색 서비스 '쇼핑 스마트블록' 도입",
#  '인공지능 \'람다\', "지각이 있다" 주장한 구글연구원 해고!...그럼에도 AI 진화...',
#  '\ufeff뉴패러다임인베스트먼트, 인공지능(AI) 기반 에듀테크 스타트업 ‘에듀템’...',
#  '동아에스티, ‘인공지능 활용 폐암 신약 연구’ 정부과제 선정',
#  '네이버클라우드-미래에셋증권, 초대규모 인공지능 및 클라우드 기반 대고객 서...',
#  '인공지능 기반 흉부방사선영상 진단 시스템의 유용성 밝혀',
#  '한양대학교병원\xa0이승훈 교수팀, 인공지능 딥러닝으로 강직척추염 조기 진단 ...',
#  '웨이커, 글로벌 사업 가속화... 허프포스트에 인공지능 기사 및 데이터 솔루션...',
#  "상담콜, 인공지능 목소리로 응대하는 '프리미엄 보이스' 기능 선봬",
#  '인천시, 홀로사는 중장년 5천 가구…"인공지능(AI)으로 돌봐"\xa0',
#  '인공지능·데이터 시대, 소프트웨어랑 놀자',
#  '스타키 인공지능 보청기 이볼브 AI, 30일 무료체험 제공',
#  '인천시, 홀로 사는 중장년 5,000가구 인공지능(AI)으로 돌본다',
#  "대전시, 인공지능 '돌봄로봇 꿈돌이' 자치구 입양식",
#  '암 진단, 정확성 높인 인공지능 모델 개발',
#  '㈜에스앤피랩, ‘22년 인공지능 학습용 데이터 구축 사업’ 선정',
#  'KB국민은행, 인공지능 활용 미래금융 아이디어 공모',
#  '오산시,\xa0AI(인공지능)시대 진로 진학 특강',
#  '인공지능 인재양성 첫 발… 청소년AI 풍류 음악회',
#  "오산시, 인공지능 안내 로봇 '문스봇' 도입",
#  '김치 품질도 인공지능(AI) 활용해서 관리한다',
#  '광주시, 수도권 인공지능 유망기업과 108억원 규모 투자협약',
#  '광주 AI 스타트업에 투자 물꼬 튼다…인공지능산업융합사업단, 투자자·기업 ...',
#  '시리를 잠깐 잊게 해주는 인공지능, 에이닷',
#  '[보일스님이 들려주는 인공지능이야기] <23> 마인드 업로딩과 포스트휴머니즘...',
#  '광주광역시, 광주 인공지능 미래신산업 육성 발대식 개최',
#  'KAI, 인공지능 활용한 우주기술 개발 위해 KAIST와 맞손',
#  "감정 표현하는 다국어 인공지능 음성합성 서비스...KT, 'AI 보이스 스튜디오'...",
#  '호남대, 광주형 인공지능 문제해결 아이디어 공모전 2팀 입상',
#  '오산시, AI(인공지능) 시대 진로와 삶의 변화 탐구 진로특강',
#  '지스트-MIT, 인공지능 분야 공동연구 워크숍 개최',
#  "음성군의회 'AI(인공지능) 영재고 충북혁신도시 유치 촉구 건의안' 만장일치 ...",
#  '과기정통부, 인공지능 기반 첨단 반도체 공정 서비스 제공...2026년까지 270억...',
#  '광주시, 인공지능 관련 5개 기업 업무 협약',
#  "인공지능 시아(SIA)와 인간의 합작…시극 '파포스' 8월 개막",
#  '동아에스티, 인공지능 활용 혁신신약 공동발굴 본격화',
#  "뉴패러다임인베스트먼트, 인공지능 기반 에듀테크 스타트업 '에듀템'에 프리A...",
#  '의료 인공지능\xa0기업\xa0루닛,\xa0코스닥시장에 신규 상장',
#  '인공지능 대표 기관들이 한자리에 모였다… ‘2022 AI 원팀 전체회의’ 개최',
#  '민원서류 신청 인공지능이 대신해준다…김해시 12월 서비스',
#  "인공지능 이용 신약개발과 '익센시아'의 다각적 비즈니스 개발 전략",
#  '하동군, 인공지능 미혼남녀 연계플랫폼 개발 완료',
#  "'AI와 수학･과학기술･전통예술 만남!' ... 포항시, 인공지능 인재양성에 첫...",
#  'KT, EBS와 인공지능 인재 교육 확대',
#  'KB국민카드, 종로구와 인공지능 분리수거기 사업 업무협약',
#  '신세계I&C-성균관대, 인공지능·소프트웨어 인재 양성한다',
#  '딱 맞는 무릎관절염 치료법, 인공지능 모델로 찾는다',
#  '순천대 국용인 교수, 인공지능 기반 잡초 판별 시스템 공동 개발',
#  '포항시, 인공지능 인재양성에 첫 발을 내딛다',
#  '의료AI 기업 루닛, 코스닥 입성…"글로벌 NO.1 의료 인공지능 기업 도약"',
#  '대전시, 철도 시설물 이상 징후 인공지능으로 감시한다',
#  "인공지능이 그린수소 생산 위한 수전해 '철-니켈' 촉매 최적 비율 제시",
#  '의병박물관, 인공지능 전시해설 로봇 도입',
#  'KT, 기업교육 전문 기관 알파코에 인공지능 방역로봇 도입',
#  '"헬스케어 \'로봇·인공지능\' 활용...\'자폐\' 등 소셜봇 효과"',
#  "근로복지공단 민원접수업무, LG유플러스 '인공지능으로 개선'",
#  "대전시, 인공지능 말동무 로봇 '꿈돌이' 입양식 개최",
#  "무하유, '2022 인공지능 학습용 데이터 구축사업'에 선정…'채용면접 인터뷰 ...",
#  '동아ST, 심플렉스·연세암병원팀과 인공지능 활용 혁신신약 발굴 나서',
#  "AI ARS 상담콜, 인공지능 목소리로 고객 응대하는 '프리미엄 보이스' 기능 선...",
#  "호두에이아이 이정우 CTO, 인공지능 학습에서 오류라벨 '자동보정'기술... CV...",
#  '인천대학교-㈜아이알티코리아, 인공지능 화재경보장치 상용화 착수',
#  '순천대학교 국용인 교수, 인공지능 기반 우점잡초 판별 시스템 개발',
#  '조달청, 45개 혁신제품 지정…인공지능 자원회수 로봇 등',
#  '테슬라, 인공지능 사업 수장 퇴사',
#  '오산시 AI(인공지능)시대 진로 진학 특강전개',
#  '자격증넷, 인공지능 활용한 자격증 추천 서비스 도입',
#  '진안군 인공지능 치매안심 돌봄 로봇 ‘빠망’ 본격 출시',
#  'K-V VINA 이용훈 회장, 전주대 인공지능학과 발전기금 기탁',
#  '경희대치과병원, 국내 최초 ‘인공지능 3D 통합영상분석 플랫폼’ 개발에 앞장',
#  "'로보컵(RoboCup) 2022' 국제 인공지능(AI) 로봇대회",
#  '인공지능의 새 국면, ‘감정인식 AI’··· 의미와 과제는?',
#  '광주시, 수도권 인공지능 유망 기업과 투자협약',
#  '강북구, 인공지능 로봇 활용해 어르신 돌봄 지원',
#  '인공지능 개발 시 가장 유용한 프로그래밍 언어 5종',
#  '권성동 "정체된 호남 발전 견인…인공지능 모빌리티 사업 적극 지원"',
#  '로봇수술 중 혈압 변동 예측하는 인공지능 모델 개발',
#  "인공지능 대표 기관 한자리에…'2022 AI 원팀 전체회의'",
#  "IBK기업은행, 인공지능 음성인식 기반 '기가지니 음성 서비스' 시작",
#  '과기정통부, 인공지능 활용 사이버보안 대응체계 고도화 지원 나선다...AI 학...',
#  '인공지능 데이터 활용협의회 참석한 박윤규 제2차관',
#  '동아ST, 심플렉스·연세암병원팀과 인공지능 활용 혁신신약 발굴 나선다',
#  '중진공 광주본부-인공지능산업융합사업단 ‘AI산업·中企 혁신성장 견인’ 협...',
#  '과기부 "첨단 반도체 공정 서비스, 인공지능 및 데이터기반으로 제공"',
#  '참빛교육, 고양시 초등학교에 인공지능(AI) 영어독서 프로그램 무상 지원',
#  '테라젠바이오, 소아희귀질환 인공지능 SW 솔루션 개발 사업자 선정',
#  '배달대행 플랫폼 운영사 배나구 원더스와 협력… 인공지능 묶음배달로 배달료...',
#  "상담콜, 42가지 인공지능 목소리로 응대 '프리미엄 보이스' 기능 공개",
#  "KB국민카드, 종로구와 '인공지능 분리수거기 사업' 업무협약",
#  '하나금융그룹, SK텔레콤과 총 4천억 대 지분 교환 및 전략적 파트너십...인공...',
#  "시흥교육지원청, 미래형 교육과정 운영 '인공지능(AI) 교육 활성화' 지원",
#  '“잘 주무셨나요?”…대구시, 인공지능 자동안부전화 확대',
#  "KT, '2022 AI 원팀 전체회의' 개최…인공지능 대표 기관이 한자리에",
#  "경희대치과병원, '인공지능 3D 통합영상분석 플랫폼' 개발 나서",
#  '[키워드브리핑]인공지능 기술로 관리한 김치 등',
#  'DGIST, 암 진단 정확성 높인 인공지능 모델 개발',
#  "KB국민카드, 종로구와 '스마트 인공지능 분리수거기 사업' 맞손",
#  'KT\xad네오랩컨버전스, 에듀테크 인공지능 공동연구 업무협약 체결',
#  "인공지능 GPU 필요한 만큼 쓴다!... 이호스트ICT, GPU 클라우드 서비스 '빅뱅...",
#  '모메드솔루션, 2022 국제IoT가전로봇박람회서 CAP 인공지능 교구·AI 빅데이터...',
#  '조달청 45개 혁신제품지정…인공지능 자원회수 로봇 등',
#  '[AI 주간브리핑] 글과 그림 만들어 내는 인공지능, 표절 문제는 없을까?',
#  'KAIST 스스로 진화하는 흉부 엑스선 인공지능 진단기술 개발',
#  '권성동 "호남 복합쇼핑몰·인공지능산업 적극 지원"‥ 첫 시·도 예산정책협의...',
#  '카카오엔터프라이즈, 올 상반기 글로벌 탑티어 인공지능 학회 논문 17건 등재',
#  '동아ST-심플렉스-연세암병원팀 "인공지능 활용 혁신신약 발굴"',
#  'KB국민카드, 종로구와 ‘스마트 인공지능 분리수거기 사업’ 협약',
#  '[동정] 김지희 동국대 AI융합학부 교수, 美인공지능진흥협회 이사 선출',
#  "서울과기대, 인공지능반도체 '석·박사 고급 인재양성 대학' 선정",
#  '중앙대 인문콘텐츠연구소, 인공지능인문학 국제학술대회 성료',
#  '인공지능이 데이터에서 인사이트 뽑아준다',
#  '광주시, 수도권 인공지능 유망기업과 108억원 규모 투자협약 체결',
#  '국제인공지능&윤리협회-퀀텀테크엔시큐-더에이아이, AI 및 AI윤리 공동 사업협...',
#  '인천대-아이알티코리아, 인공지능 화재경보장치 개발 착수',
#  '라온피플 자회사 라온메디, 인공지능 활용 ‘국가연구개발사업’ 주관기업 선...',
#  "[특징주] 뷰노, 의료인공지능 솔루션 공급 계약에 '주가는?'",
#  "상담콜, 인공지능 목소리로 응대하는 '프리미엄 보이스' 기능 발표",
#  "금산교육청, 'AI교육 특화도시 선포'...인공지능 교육 지원",
#  '동아ST·심플렉스·연세암병원팀, 인공지능 활용 혁신신약 발굴 나서',
#  "세연테크, 보급형 2M 싱글보드 '인공지능 IP 카메라 모듈' 출시",
#  '평택도시공사, 장애인 콜택시 인공지능 안전운전 솔루션 도입',
#  'KT, 2022 인공지능 원팀 전체회의 개최',
#  '[변화 의령] 의병박물관, 인공지능 전시해설 로봇 도입',
#  '동아ST, 심플렉스·연세암병원팀과 인공지능 활용 폐암 신약 발굴 정부 과제 ...',
#  '동아에스티, 인공지능 활용 혁신신약 발굴 나선다',
#  '아리바이오, ‘바이오 의료 인공지능 데이터 구축’ 정부 사업 선정',
#  '인공지능 딥러닝, 강직척추염 조기 진단 모델 개발…요추의 모서리 등급 자동...',
#  '서울과기대, 인공지능반도체 ‘석·박사 고급 인재양성 대학’ 선정',
#  '인공지능과 예술의 만남…매의 화려한 비상',
#  '우주텍, 인공지능 추천 기능성 인솔 닥솔 론칭',
#  '평범한 AI(인공지능)는 가라, ‘초거대 AI’가 온다',
#  '의료 인공지능 기업 루닛, 공모가 3만원 확정…12~13일 청약',
#  "카카오브레인 영어학습 앱 '레미' 출시, 인공지능 언어 분석 기술 적용",
#  '평택도시공사, 인공지능 안전운전 솔루션 도입',
#  '동아ST, 심플렉스·연세암병원팀과 함께 인공지능 활용 혁신신약 발굴 나선다',
#  "대한민국 인공지능 대표 기관들 한자리에…'2022 AI 원팀 전체회의' 개최",
#  'KB국민카드·종로구, ‘스마트 인공지능 분리수거기 사업’ 협약',
#  "사람인 , '설명가능한 인공지능'으로 더 정확한 추천 공고 제공한다",
#  '진주시, 4차 산업혁명 스마트교육 … 인공지능·메타버스·3D프린터 과정',
#  '의병박물관, 인공지능 전시해설 로봇 도입…전시해설·방역 책임 역할',
#  "경희대치과병원, 국내 최초 '인공지능 3D 통합영상분석 플랫폼' 개발 착수",
#  '유클리드소프트-청년몽실 협동조합, 인공지능 사업 협력 위한 MOU 체결',
#  "동아ST, 심플렉스·연세암병원과 '인공지능 활용 혁신신약 발굴' 나서",
#  "'제5회\xa0인공지능\xa0보안의\xa0날\xa0발표회'\xa0개최",
#  '뷰노-삼성서울병원 김주연 교수팀, 인공지능으로 잠재된 발작성 심방세동 진단...',
#  '광주시, 수도권 인공지능 유망기업과 108억원 투자협약',
#  '인공지능과 해킹 등 신종범죄 대응 위한 첨단기술 치안역량 높인다',
#  "알체라, TTA '인공지능 학습용 데이터 검사' 주관사 2년 연속 선정",
#  '인공지능 앰뷸런스 공모 선정 ... 응급환자 골든타임 확보',
#  '대전 도시철도 이상 현상 인공 지능으로 점검',
#  '코스닥상장사 플리토, 제주관광공사 다국어메뉴판 지원...인공지능플랫폼에 꽂...',
#  '웨이커, 허프포스트에 인공지능 기사‧데이터 솔루션 공급 \xa0',
#  '광주시, 광주 인공지능 미래신산업 육성 발대식',
#  "BNK금융그룹, 비대면 금융 강화…'빅데이터·인공지능 플랫폼' 하반기 오픈",
#  '네이버, 인공지능 검색 서비스 ‘쇼핑 스마트블록’ 도입',
#  '인공지능 공부한 檢…이원석 총장대리 “구성원들 충격받았길”',
#  '서울과기대, 과기정통부ㆍ정보통신기획평가원 지원 인공지능반도체 ‘석·박사...',
#  '블록체인 기술, 인공지능에 미치는 영향은',
#  "AI ARS\xa0상담콜, 42가지 인공지능 목소리로 고객 응대하는\xa0'프리미엄 보이스...",
#  '"AI 산업육성 힘 모으자" 중진공-인공지능사업단 \'맞손\'',
#  "팜한농, 인공지능·빅데이터 기반 '디지털파밍 플랫폼'으로 우리 농업 경쟁력...",
#  "메디컬아이피, 인공지능 체성분 분석 소프트웨어 '딥캐치' 조달청 혁신 제품 ...",
#  '[미래읽기] 인공지능 시대의 정책 과제',
#  '꾸그 운영사 글로랑, 카이스트 출신 서동진 인공지능 책임 연구원 영입',
#  "스위트케이, '인공지능 기반 환자 동작 모니터링 시스템'... 노인·환자 안전...",
#  "의료 인공지능 기업 '루닛' 오늘(21일) 코스닥 상장",
#  "동아에스티, '인공지능 활용 혁신신약 발굴 사업' 선정",
#  '리얼시큐, 인공지능 관련 논문 6개 국제 컨퍼런스 출판 승인',
#  '경북도, 과학기술정보통신부 인공지능 학습용 데이터 구축 지원사업 선정',
#  "인공지능 영어 학습 앱 '말해보카', 울산 상북중에 학습 교보재로 서비스 시작",
#  '㈜유클리드소프트-청년몽실 협동조합, 인공지능 사업 협력 위한 MOU 체결',
#  '미래에셋자산운용, 인공지능 활용한 전략투자로 안정적 수익 창출',
#  '알체라, TTA ‘인공지능 학습용 데이터 검사’ 주관사 2년 연속 선정',
#  '경찰청, 아동학대 영상 분석, 인공지능 치안서비스 고도화 추진',
#  '뷰노, 의료인공지능 솔루션 공급 계약 체결',
#  '범용 인공지능(AGI)이 인간 소유 거부하고 작업 대가 요구한다면?',
#  '전북대학교-국립국어원, 인공지능 활용 국어능력 진단체계 개발키로',
#  '의료AI 기업 \'루닛\' 코스닥시장 상장..."글로벌 의료 인공지능 기업으로 도약...',
#  '동아ST-심플렉스-연세암병원팀, 인공지능 활용 혁신신약 발굴 나선다',
#  '첨단 반도체 공정 서비스를 인공지능과 데이터 기반으로 제공한다',
#  '센서부터 인공지능까지 총동원, 스포츠에 녹아든 IT 기술들',
#  '동아에스티·심플렉스·연세암병원팀 ‘인공지능 활용 혁신신약 발굴 연구’,...',
#  "씽크포비엘, 대학가 '인공지능 신뢰성 검증' 기술 교육 강화",
#  "국민은행, '퓨처 파이낸스 AI 챌린지'\xa0개최 인공지능 활용 미래금융 아이디어...",
#  '인공지능 신약개발협의회 발족 22개사 참여...초대 협의회장에 김이랑 온코크...',
#  'AI가 조류독감? 인공지능? 문맥 안 보면 알 길 없네',
#  '광주시, 광주 인공지능 미래신산업 육성 발대식 개최',
#  "KB국민카드, 종로구와 '인공지능 분리수거기 사업' MOU",
#  '한덕수 국무총리, 데이터·인공지능 투자애로·규제개선 현장간담회 나서',
#  '진안홍삼연구소, 인공지능 학습용 데이터 구축사업 수주',
#  '충남교육청 메타버스 및 인공지능 연수 실시',
#  '광주시, 수도권 인공지능 5개 유망기업과 108억 투자협약 체결',
#  '"우리집 댕댕이 옷 사이즈, 인공지능(AI)이 골라준다"',
#  '구글, ‘인공지능 람다 감정이 있다’고 폭로한 엔지니어 해고',
#  '알체라, TTA ‘인공지능 학습용 데이터 검사’ 주관사로 2년 연속 선정',
#  'AI타임스 유형동 기자 "인공지능을 다루는 언론 방식에도 \'AI+X\'가 필요"',
#  '서울대 노종선 교수팀, 세계에서 가장 앞선 프라이버시 보장 인공지능 기술 개...',
#  '영진전문대, 국내 6개 대학과 공동으로 인공지능 교육캠프 열어',
#  '나노조합, 나노·탄소 소재 특화 인공지능 교육사업 참가자 모집',
#  "경희대치과병원, '인공지능 3D 통합영상분석 플랫폼' 개발 착수",
#  '대전시, 인공지능 활용 철도시설 실시간 점검기술 개발',
#  '뷰노, 7억 규모 의료인공지능 솔루션 공급계약',
#  "진안군, 치매 노인 위한 인공지능 AI 돌봄인형 '빠망' 전달",
#  '하윤수 부산교육감 "초·중등 소프트웨어·인공지능 교육 강화"',
#  "오산시, 관내 중학생･학부모 대상 'AI(인공지능) 시대 진로특강' 실시",
#  '영진대서 인공지능 교육갬프·경진대회',
#  '대한민국 인공지능 대표 기관들이 한자리에 모였다',
#  '인공지능 스타트업 업스테이지 ‘ECCV 2022’에 두 편 논문 게재',
#  '의료 인공지능기업 루닛 상장 첫날 주가 장중 강세, 오버행 우려는 남아',
#  "삼성전자, 인공지능 사진 보정 애플리케이션 '인핸스-X' 출시",
#  '인공지능신약개발지원센터, AI신약개발협의회 발족... 협업 생태계 조성',
#  '광주시-수도권 인공지능 유망기업, 투자협약 체결…일자리 창출',
#  "카카오브레인, 인공지능(AI) 영어 학습 앱 '레미' 공개",
#  '인공지능이 만드는 맞춤형 음악…포자랩스, 수퍼톤·서울대와 맞손',
#  '종로구, 인공지능기기로 캔·페트병 분리수거··· 포인트 적립도',
#  "인공지능 프로젝트 전성시대 '데이터융합 AI 프로젝트 매니저' 양성 주목",
#  '인공지능 흉부방사선영상진단 임상현장에서 유용성 확인',
#  'SK에코플랜트, 인공지능부터 그린수소까지…환경사업 ‘밸류 업’',
#  '광주시, 수도권 인공지능 유망기업과 투자협약 체결',
#  '인공지능(AI) 접목 신약개발사 갤럭스에 40억 투자',
#  "광양시 '인공지능&블록체인' 교육생 모집...전액 무료",
#  "알체라, TTA '인공지능 학습용 데이터 검사' 주관사로 2년 연속 선정",
#  '뷰노, 인공지능 기반 심전도 분석 기술 글로벌 학술지 게재',
#  "미국 연구팀, 가상으로 와인을 시음하는 '인공지능(AI)' 개발",
#  'KB국민카드, 종로구와 인공지능 분리수거기 사업 MOU 체결',
#  '음식으로 보는 인공지능 추천 알고리즘',
#  "의왕 부곡동청소년문화의집, 초·중학생 대상 여름방학 프로그램 '인공지능 캠...",
#  '컴트루테크놀로지, 인공지능 OCR 라이브러리 출시',
#  "KB국민카드-종로구, '스마트 인공지능 분리수거기 사업' 협약",
#  '인공지능 데이터 활용협의회',
#  "서울과기대, 과기정통부ㆍ정보통신기획평가원 지원 인공지능반도체 '석·박사...",
#  '분당서울대병원 이용석 교수팀, 무릎 관절염 진행속도 및 치료 예측 인공지능...',
#  '김해시 민원서류 작성 인공지능이 해결',
#  '[교단에서]인공지능 시대',
#  '비앤빛 강남밝은세상안과 유태근 원장, AI 인공지능 통한 렌즈삽입수술 임상 ...',
#  "경희대치과병원, 국내 최초 '인공지능 3D 통합영상분석 플랫폼' 개발 나서",
#  "인공지능으로 오배송 최소화 위한 '이커머스 물류자동화' 최적화 실현한다!",
#  '특허청, 인공지능 분야 지식재산권 역량 강화 위한 중소·벤처기업 간담회 개...',
#  '인공지능 기반 흉부방사선영상 진단 유용성 밝혀',
#  '평택시 교통약자 콜택시 인공지능(AI) 안전운전 솔루션 도입',
#  '경북도\xa0‘인공지능 학습용 데이터 구축 지원사업’\xa0선정',
#  '서울대학교 노종선 교수팀, 완전동형암호 기반 프라이버시 보장 인공지능 기술...',
#  '"답정너 인공지능 친절해졌네"… 신기술 XAI의 보충설명',
#  '인천대-㈜아이알티코리아, 인공지능 화재경보장치 개발 착수',
#  "팁코, 인공지능(AI) 배포 지원 '팁코 모델옵스' 출시",
#  "인공지능 편향성 해결사 'AI 신뢰성 검증', 유망 직업으로 부각",
#  '[드론·UAM박람회] 드론과 인공지능으로…실종자 수색·구조물 확인',
#  "영진전문대 인공지능혁신공유대학사업단, 인공지능 '효율적 성과관리 및 확산...",
#  '유클리드소프트, 인공지능 사업 협력 위해 ‘청년몽실 협동조합’과 MOU 체결',
#  '인공지능 기반 반려동물 생체인식 ‘펫나우’, 47억원 투자 유치',
#  'KB국민, 종로구와 인공지능 분리수거기 사업 업무협약',
#  '오산시, AI(인공지능) 시대-진로 진학 특강 개최',
#  '강종만 영광군수 “청정 에너지·인공지능 등 미래 먹거리 신산업 육성”',
#  '비플라이소프트, 미디어 빅데이터 및 인공지능 기술 기반 사업 확대',
#  '머신러닝 인공지능으로 무릎관절염 발생예측',
#  "KB국민은행, 인공지능+금융 콜라보레이션 경진대회 '퓨처 파이낸스 AI 챌린지...",
#  '사용자 중심 인공지능이란?',
#  '용인세브란스, 인공지능 기반 흉부방사선영상 진단 시스템 유용성 밝혀',
#  "경남교육청 '인공지능 학습 추천' 내년 3월 가동 전망",
#  "세계에서 인정받는 국내 의료 인공지능 기업, 'ECR 2022'에서 영상의학 연구·...",
#  '김지희 교수, 美 인공지능協 이사',
#  '특허청, 인공지능분야 지식재산권 역량강화 위한 중소·벤처기업 간담회 개최',
#  '디지털 대전환의 시대, 인공지능(AI)과 커뮤니티가 게임체인저',
#  '인공지능 신약개발 기업 힘모은다…‘AI신약개발협의회’ 발족',
#  '[Press Vision] 국내 인공지능 기술의 새바람을 일으키다! (주)델타엑스',
#  'KAIST, 인공지능 및 빅데이터 시대를 이끌어 갈 차세대 CXL 2.0 메모리 확장 ...',
#  '인공지능융합학부, 반도체·AI·빅데이터 특화 교육 강화',
#  '남해군, ICT 연계 인공지능 통합돌봄사업 확대',
#  '국립암센터와 한국지능정보사회진흥원, 인공지능 학습용 암 데이터 공동 활용',
#  '김지희 동국대 AI융합학부 교수, 美인공지능진흥협회 이사 선출',
#  '인공지능으로 허위진술 탐지…과기부·경찰, 과학치안 맞손',
#  '[특징주] 뷰노, 마이허브와 의료인공지능 솔루션 계약 체결',
#  '동아ST, 인공지능 활용 폐암 신약연구 정부과제 선정',
#  "KB국민카드, 종로구와 '인공지능 분리수거기 사업' 업무협약 체결",
#  '인공지능은 공부 중!?',
#  "김치 품질 관리 '인공지능'으로 한다...세계김치연구소, 전통발효식품 융합데...",
#  '[AWC] 부산에서 만나는 최신 인공지능 트렌드, 글로벌 AI 컨퍼런스 개최',
#  "KB국민카드, 종로구와 '스마트 인공지능 분리수거기 사업' 협약",
#  '암진단 인공지능 모델 개발',
#  '[특징주] 뷰노, 마이허브에 7억 의료인공지능 솔루션 공급',
#  'ETRI, ‘2022 ETRI 자율성장 인공지능 경진대회 Fashion-How 시즌3’ 접수',
#  '김동주 고려대 교수, "인공지능(AI) 발전과 뇌 과학 분야 관계는?"',
#  "정부, '혁신인재 양성' AI반도체·의료인공지능·미래차·바이오헬스 등 14개...",
#  '지스트-MIT, 인공지능 분야 공동연구 워크숍..5년간 200억 규모 추진',
#  '경북도, 과기부 인공지능 사업에 국비 63억 확보',
#  "동국대 인공지능학과 김지희 교수... 한국인 최초, AI 세계 최고권위의 'AAAI...",
#  "공주교육청, 인공지능 메타버스 교사 디지털 '세상과 만나다' 연수",
#  'KAIST 진천 인공지능 영재캠프 성료',
#  '한덕수 총리, "데이터·인공지능 산업 성장 위해 신속하고 과감하게 규제 혁파...',
#  "인공지능으로 '대서양연어' 부산에서 키운다...부산 스마트양식 클러스터 테스...",
#  "KB국민카드, 종로구와 '인공지능 분리수거기 사업' 협약",
#  '광주과학기술원 헬스케어로봇센터, 2022 재활·복지박람회서 인공지능 기반 비...',
#  "산업 전반 인공지능 애플리케이션 개발 단순화!...인텔, 오픈소스 'AI 레퍼런...",
#  '한국인공지능협회-SBA-IBK기업은행, 청년취업사관학교, 디지털혁신인재 일자리...',
#  '포티투마루, 인공지능 검색 솔루션 서치42 GS인증 1등급 획득',
#  '인공지능 데이터 활용협의회 참석한 박윤규 차관',
#  "위치인식 기술의 혁신… 인공지능 '통합 GPS' 시스템 개발",
#  'KB국민카드, 종로구와 인공지능 분리수거기 사업 업무협약 맞손',
#  '광주시, 트랜스코스모스코리아 등 5개사와 인공지능 기반 구축 투자협약',
#  "인공지능 강군 이끌 '국방 AI 교육대학' 출범…중앙대, 軍 특화 AI 핵심인재 ...",
#  "더벤처스, 인공지능 기반 개인 맞춤형 스마트 수면 솔루션 '미라클나잇'에 투...",
#  'GIST–MIT, 인공지능 분야 공동연구 워크숍 개최',
#  "데이터큐, '장애인 인공지능 데이터 라벨러 양성과정' 교육생 모집",
#  '광주 인공지능 미래신산업 육성 발대식',
#  '정부, "인공지능(AI) 학습용 데이터 개방, 2배 확대한다"',
#  'KB국민카드-종로구, 스마트 인공지능 분리수거기 사업 협약',
#  'DGIST, 비용 줄이고 정확성 높인 암 진단 인공지능 모델 개발',
#  '용인시 기흥구보건소, 인공지능(AI) 돌봄 케어콜 서비스 제공',
#  '한국IT직업전문학교 인공지능학과 수시모집 전 2023학년도 신입생 모집',
#  '영산대, ‘인공지능과 메타버스 교수법 워크숍’ 진행',
#  "한국축산데이터, 광주∙전남 수의료 및 '축산 인공지능' 혁신 이끈다",
#  "인공지능으로 송금하는 시대로!... IBK기업은행, 'AI보이스뱅킹' 상용화",
#  "'알체라', TTA '인공지능 학습용 데이터 검사' 주관사로 2년 연속 선정",
#  '[ET단상]인공지능 사용 설명서',
#  '의병박물관, 인공지능 전시해설 로봇 운영',
#  '인천대, ㈜아이알티코리아와 인공지능 화재경보장치 개발 착수',
#  '광주시, 인공지능 미래신산업 육성 발대식',
#  '더에이아이-국제인공지능&윤리협회-퀀텀테크엔시큐 MOU체결…AI 및 AI윤리 사...',
#  '서울대-SK텔레콤-SK하이닉스, 인공지능 및 반도체 인재 양성에 맞손!',
#  '[헬스캡슐]아리바이오, 의료 인공지능 데이터 구축 사업 선정 外',
#  '인공지능 학습 데이터 개방, 2배로 늘었다... AI허브, 자율주행·건강관리 등...',
#  '더존비즈온-한덕수 총리 ‘데이터·인공지능 간담회’',
#  "[목요세평] 인공지능이 '시원섭섭하다'를 공감하려면",
#  '국제인공지능&윤리협회-포티투마루-더에이아이, AI 및 AI윤리 분야 공동 사업...',
#  "[르포] 인공지능 인재 육성의 일선 현장을 가다…'서울 우신고등학교'",
#  'CCTV만 5억대‥중국, 인공지능이 공산당 충성심도 평가',
#  '정부, 인공지능 학습용 데이터 190종 추가 개방…AI산업 발전 이끄나',
#  '대검, ‘인공지능과 리걸테크’ 전문가 초청 강연… 이원석 검찰총장 직무대리...',
#  '인공지능 학습용 데이터 개방, 2배(191→381종)로 늘어난다',
#  '지스트–MIT, 인공지능 분야 공동연구 워크숍 성료',
#  '카카오엔터프라이즈, 상반기 글로벌 인공지능 학회에 논문 17건 등재',
#  '지스트, 게임 시뮬레이션 인공지능 개발에 30.5억 지원 받아...사람처럼 플레...',
#  '경희대치과병원 ‘인공지능 3D 통합영상분석 플랫폼’ 개발 나선다',
#  'KISTI, 인공지능 활용 소방 빅데이터 분석 교육훈련 과정 개설',
#  '한덕수 총리 "데이터·인공지능 산업 규제 개선 노력할 것"\xa0',
#  "김치도 인공지능이 품질관리 한다...세계김치연구소, '인공지능 학습용 데이터...",
#  "포티투마루, 인공지능 검색 솔루션 'Search42' GS인증 1등급 획득",
#  "동두천시, 전국 최초 '인공지능형 알림톡' 문자서비스 개발·운영",
#  '용인세브란스병원 김은경 교수팀, 인공지능 기반 흉부방사선영상 진단 시스템...',
#  '인공지능 공유 플랫폼 시대를 열다',
#  "리턴제로, 국제 인공지능 음향인식 경진대회...'DCASE Challenge 2022'에서 기...",
#  'K-V VINA 이용훈 회장, 전주대 인공지능학과 발전기금 1000만 원 기부',
#  '이인실 특허청장, LG이노텍 인공지능 기반 특허전략 청취 및 현장소통 간담회',
#  '르네사스, 리얼리티 AI 인수...인공지능 애플리케이션 위한 엔드포인트 솔루션...',
#  '인공지능을 활용한 비대면 재활 케어 서비스 ‘따뜻’ 앱 출시',
#  "중앙대 인문콘텐츠연구소, '제5회 인공지능인문학 국제학술대회 ICAIH 2022' ...",
#  '리스케일, 엔비디아와 인공지능·머신러닝 위한 특화된 HPC 신기능 발표',
#  '인공지능이 과일을 능숙하게 선별한다 - 에이오팜[혁신, 스타트업을 만나다]',
#  "한국인공지능협회, '한국인공지능자격센터' 개소...초대 센터장에 김건훈 협회...",
#  '지스트- MIT 인공지능연구소(CSAIL), AI 공동연구 워크숍 개최... 현재, 총 6...',
#  "한국인공지능협회, 인공지능 활용 기업 '부트캠프' 운영",
#  "인공지능과 인간이 협업한 예술 세계...카타르 하마드빈칼리파대학 '제임스 쉐...",
#  '매사냥 이미지 인공지능 기술과 만나면?',
#  "시그마인드-GK정보통신, '인공지능 영상분석 시스템 기술' 업무협약",
#  '아리바이오, ‘바이오 의료 인공지능 데이터 구축’ 사업 선정',
#  '[HANNOVER MESSE 2022 DEBRIEFING-③] 인공지능, 투자 단계지만 광범한 적용 ...',
#  "AI스마트광융복합협동조합, 광주용봉초등학교서 'AIoT(인공지능+사물인터넷)'...",
#  "동아ST, 인공지능 활용 '폐암 신약 연구' 정부과제 선정",
#  'KT, 인공지능 활용 건설 현장 중대 재해 막는다',
#  "삼성전자, 'C랩 아웃사이드' 5기 스타트업 공모...인공지능·메타버스·로보틱...",
#  '인천대, 아이알티코리아와 인공지능 화재경보장치 개발 착수',
#  '인공지능 기반 흉부방사선영상 진단 시스템의 유용성 확인',
#  "한국인터넷진흥원, 'AI Security Day' 세미나 개최...'인공지능으로 만드는 안...",
#  '(재)진안홍삼연구소, 인공지능 학습용 데이터 구축사업 수주',
#  '[의료계 소식] 비앤빛 강남밝은세상안과 유태근 원장, A.I. 인공지능을 통한 ...',
#  '국전자통신연구원 주최, 자율성장 인공지능 경진대회 접수 시작',
#  '셀렉트스타, 자율성장 인공지능 경진대회 접수 시작',
#  '[나는 괜찮은 AI입니다] 미래에는 인공지능이 인간을 위협할까?',
#  "후지필름코리아, 인공지능으로 무장한 'AF 시스템' 탑재....영상 미러리스 디...",
#  '영진전문대 인공지능사업단, AI교육캠프ㆍ경진대회 실시',
#  "강북구, '인공지능 로봇' 활용 어르신 돌봄 시작",
#  "존슨콘트롤즈-액센츄어, 인공지능 스마트 빌딩 '오픈블루 이노베이션 센터' 도...",
#  '동두천시 전국 최초 인공지능형 알림 톡 지체 개발',
#  "순천대학교 국용인 교수, '인공지능 기반 잡초 판별 시스템' 개발",
#  '용인세브란스병원 영상의학과 김은경 교수팀, 인공지능 기반 흉부방사선영상 ...',
#  '국제인공지능&윤리협회-포티투마루-더에이아이, AI 관련 MOU 체결',
#  '한국공항공사, ‘인공지능(AI) X-ray 검색 장비’ 국산화 개발 나서',
#  "서울시, 인공지능 가상휴먼 '와이티' 청년 홍보 대사로 위촉",
#  "인공지능으로 그린수소 생산 위한 수전해 '철-니켈' 촉매 최적 비율 제시",
#  "한국 인공지능 일본 진출의 교두보!...한국인공지능협회, '2022 AI Expo Toky...",
#  '영산대-국제미래학회, ‘인공지능과 메타버스 교수법 워크숍’ 실시',
#  '휴톰, 인공지능 수술보조 내비게이션 사업 박차',
#  '강남 코엑스서 인공지능·로봇 윤리 국제학술대회 개최',
#  "[가톨릭대] '바이오메디컬·인공지능' 핵심인재 키우는 글로벌 혁신 대학",
#  '[데스크가 만난 사람] "인공지능 윤리는 기술에 반드시 들어가야 하는 \'안전장...',
#  "동아ST, 인공지능 활용 혁신신약 발굴…광동제약, '마이비젯정' 출시 [제약오...",
#  '[알려株5] 루닛, 인공지능을 통한 암 진단· 암 치료 결정 솔루션',
#  '광주시, 과기부 손잡고 인공지능 미래新산업 육성 박차',
#  '동두천시, 인공지능형 알림톡...문자서비스 개발 운영',
#  '인공지능 소프트웨어 개발 기업 ‘폼즈’, IBK창공 혁신창업기업 선정',
#  "인공지능 기반 '무인 스토어' 비전 제시!...GS ITM, 휴먼아이씨티 AI 적용한 ...",
#  '[특징주] 인공지능 관련주 라온피플 주가 급등, 무상증자 권리락…골프 AI 레...',
#  '종로구-KB국민카드\xa0‘인공지능 분리수거기 사업’…친환경행보 눈길',
#  '솔트룩스, 누구나 인공지능을 쉽게 곁에 둘 수 있다면',
#  '제주대학교, 인공지능 교육 전문강사 양성 프로그램 운영',
#  '인공지능으로 암 정복 꿈꾸는 ‘루닛’ 투자 포인트',
#  "광주시, '인공지능 컨택센터' 및 '스마트 키오스크' 연계 모델 개발 및 사업화...",
#  '제주대, 인공지능 교육 전문강사 양성 참가자 모집\xa0',
#  '마이크로소프트, 인공지능 컨택센터 등 신규 파트너 기술 및 정책 대거 발표…...',
#  "성균관대학교 김성아 교수의 '인공지능 시대의 건축', 대한민국학술원 우수학...",
#  '에이아이포펫, 인공지능 기반 반려동물 안구 및 피부 질환 측정 등 특허 3건 ...',
#  '[보일스님이 들려주는 인공지능이야기] <22>인공지능 람다와 불교 ②',
#  "차세대 의료AI 스타트업 '웨이센', 글로벌 헬스케어 대회 'Top 20' 선정... 실...",
#  "달서중 '2022 인공지능(AI) 캠프' 개최",
#  "삼보초'인공지능, 어떻게 교육을 바꾸나?'",
#  '평택시 교통약자(장애인) 콜택시 인공지능(AI) 안전운전 솔루션 도입',
#  '대구 교육청 인공지능 활용 중등 영어 운영학교 선정',
#  '강원대병원, 빅데이터 & 인공지능 연구과제 세미나 개최... 다양한 질환에서 ...',
#  "동두천시, 전국 최초 '인공지능형 알림톡' 문자서비스 개발 운영",
#  '중앙대학교 HK+ 인문학콘텐츠연구소, ’제5회 인공지능인문학 국제학술대회‘...',
#  '국민은행 "미래금융, 참신한 아이디어 찾습니다"…인공지능 활용한 경진대회 ...',
#  "오스티오이드, 경희대 치과병원과 '인공지능 3D 통합 영상분석 플랫폼' 개발한...",
#  '평택도시공사, 교통약자 콜택시 인공지능(AI) 안전운전 솔루션 도입',
#  "전립선암 병리 진단 보조 '인공지능 플랫폼'...딥바이오, 조달청 혁신제품 지...",
#  "지스트 AI 대학원 전해곤 교수팀, 영상 속 '깊이 정보'를 인공지능 알고리즘을...",
#  "NH투자증권, 서울대와 손잡고 인공지능 '대고객' 투자 정보 서비스를 제공",
#  "인공지능 기반 '노지 스마트팜'... 우경정보기술, 한국형 미래 농업 대안 찾았...",
#  '종로구\xadKB국민카드, 인공지능 분리수거기 사업 업무 협약',
#  "인공지능 검색 솔루션 '모르는거 빼고 다 찾아준다!'... 포티투마루, 'Search...",
#  "메인비즈협회, 김선 서울대 교수 초청 '활용 인공지능 신약개발' 강연",
#  'K-V VINA 이용훈 회장, 전주대학교 인공지능학과에 발전기금 1천만원 기부',
#  '인공지능 개로봇, 쓰레기매립장서 2340억원 비트코인 찾아낼까?',
#  'KAIST, 인공지능 활용한 실내외 통합 GPS 시스템 개발',
#  '딥세일즈, 기업부설연구소 설립으로 인공지능 바이어 발굴 확대 위한 R&D 기반...',
#  '[와이드 인터뷰] 이형환 중앙대학교 안성부총장 "AI가 맞춤전공 추천하는 대학...',
#  'KT·서울성모병원, 당뇨 관리 돕는 AI 기술 개발',
#  '에스앤피랩, 교통혼잡 해소 위한 ‘인공지능 학습용 데이터 구축 사업’에 선...',
#  '의령군 의병박물관, 인공지능 전시해설 로봇 도입',
#  '인공지능 비즈니스 솔루션 개발 기업 ‘맥클로린’, IBK창공 선정',
#  "KB국민카드-종로구, 스마트 인공지능 분리수거기 사업 '맞손'",
#  '에이피소프트, 딥러닝 인공지능 기반 비트코인 자동매매 기술 특허출원 밝혀',
#  '지스트 – MIT, 인공지능 분야 공동연구 워크숍 개최',
#  "서울창조경제혁신센터, '2022 대·스타 해결사 플랫폼 4차산업(메타버스, 인공...",
#  "서울대, 인공지능 분야 우수 인재 '율촌 AI 장학생' 19명 선정...농심그룹 율...",
#  "인공지능이 인간의 짝 찾아주는 시대로... 모두의 지인, 'AI 매칭 결혼 정포 ...",
#  '경희대치과병원, 미국 오스티오이드와 인공지능 3D 통합영상분석 플랫폼 개발...',
#  '"데이터·인공지능\xa0분야\xa0무한한\xa0발전가능성…개선\xa0가능\xa0규제\xa0빠르게\xa0조...',
#  "인공지능으로 1시간 만에 스스로 걸음마 배운 '로봇개'",
#  '삼성전자, AI인재 키워 반도체·디스플레이 연구한다',
#  '한덕수 국무총리, 더존비즈온 을지타워 방문...데이터·인공지능 분야 투자애...',
#  '삼성전자 ‘AI 챌린지’',
#  '인공지능 스피커 활용 철원군 건강지킴마을사업 호응',
#  '농정원, 스마트농업 AI 경진대회 개최…총상금 1억원',
#  "글로벌 사모펀드 베인캐피탈, 인공지능 전문 '텍톤'에 투자",
#  '인공지능 기반 흉부방사선영상 진단 시스템, 임상에서 효과 입증',
#  "코트라, 'AI 활용'…중견기업 ESG 모니터링 지원",
#  "위치인식 기술의 혁신 인공지능 활용한 '실내외 통합 GPS 시스템'",
#  'KT-서울성모병원, 당뇨 환자 위한 AI·디지털 트윈 기술 개발',
#  '강북구, 인공지능 로봇 활용한 어르신 돌봄 서비스 시작',
#  '육군-POSTECH, 인공지능·드론봇·레이저 등 군사과학기술 발전 위한 군사과학...',
#  '전국 흐리고 중부지방 비 소식…낮 최고기온 35도',
#  '“일주일내 범죄 발생 예측 정확도 90%” AI 도입 득될까?',
#  '한국뇌연구원, 소아·청소년 정신건강 위한 심리검사·뇌영상 인공지능 데이터...',
#  '서귀포시, 인공지능을 접목한 교통사고 예방 시스템 구축 완료',
#  "강북구, 인공지능 로봇 '알파미니'로 어르신 돌봄 강화",
#  '"인공지능 로봇 만들며 배워요"..\'AI 정보 영재교육원 캠프\' 열려',
#  'KT-NIPA, ICT 벤처 육성 DX 컨설팅·인재양성 협약',
#  "삼성전자, '제2회 삼성 AI 챌린지' 개최",
#  '목포대 로봇인공지능융합센터, 스마트팜 산업 특화 온라인 교육생 모집',
#  "당신이 '서학개미'라면 유용할 수밖에 없는 인공지능 어플은 글로벌 상장 기업...",
#  'KT-서울성모병원, 당뇨 관리 돕는 디지털 트윈 기술 개발',
#  '세계 3대 자연어 AI 대회 석권한 투디지트…국내 자연어 인공지능 기술에 시선...',
#  '"신약개발의 낮은 성공률과 고비용 문제 극복하겠다"···동아ST·심플렉스·...',
#  "드론 AI 스타트업 '오조', 대규모 산불 잡을 인공지능 기반 드론 '파이록스' ...",
#  "[채널Who] 현대차 '하늘 나는 차' 경쟁력은? 인공지능과 수소전지 두 날개",
#  '[카드] 인공지능 비즈니스 개발 기업 맥클로린, IBK창공 선정',
#  '인공지능이 암 진단·비용·시간 줄이고 정확성 높였다! ... DGIST 박상현 교...',
#  ...]

# %% [markdown]
# ## 저장

# %% [markdown]
# - 임시저장

# %%
#list > df > csv
title_df = pd.DataFrame(title_list)
title_df.to_csv('AI_title.csv',header=None, index=None)

# %% [markdown]
# - 다시 불러오기

# %%
title_df = pd.read_csv('인공지능_title.csv', header=None)
title_df.rename(columns={0:'title'}, inplace=True)
title_list=title_df['title'].values.tolist()
title_list
# Out:
# ['미래 기술의 핵심…삼성·LG 인공지능 저변 확대 나서',
#  '도로교통공단, 인공지능 기반 도로 위험 안내 서비스 추진',
#  "타임게이트, '2022년 인공지능 학습용 데이터 구축사업' 수행기관 선정",
#  '코트라, 중견기업 ‘ESG 모니터링’…“인공지능으로 리스크 찾는다”',
#  "서울성모병원-KT, '당뇨 환자' 위한 인공지능 기반 디지털 트윈 구축한다",
#  '삼성전자, 인공지능·반도체 인재 발굴 ‘AI 챌린지’',
#  '광주시의회, 인공지능 전문가 초청 강연 개최',
#  '광주시의회, 인공지능 발전 방향 강연',
#  '울산대, 인공지능 교육과정 수료식 진행',
#  '"인공지능 쉽게 이해···스마트 시티 만들고 싶어요"',
#  '서천교육지원청, 미래시대 위한 인공지능 교육 연수 실시',
#  '인공지능 데이터테크 ‘라이앤캐처스’, 벤처기업 인증',
#  '인공지능 기술로 고위험 수입식품 찾아낸다',
#  "KB증권, 인공지능 기술 적용한 'AI상담 콜봇'",
#  "KT-NIPA, 디지털전환 관련 사업 및 인공지능·DX 분야 인재 양성 위해 '맞손'",
#  "에이프리카, 인공지능 통합 플랫폼 '치타' 조달청 디지털서비스몰 등록",
#  'KT·EBS, 소프트웨어·인공지능 인재 양성 나서…MOU 체결',
#  '스마트농업 인공지능 경진대회 참가자 모집',
#  '서울시-카이스트, 인공지능 교육 프로그램 2기 수강생 모집',
#  '소리 데이터와 인공지능으로 이뤄지는 스마트 제조',
#  '포스코그룹 인공지능 기술 지문위원회 신설...첫 회의 개최',
#  "KT, EBS와 '소프트웨어·인공지능 학습환경 제공' MOU",
#  '네이버-네이버클라우드-충북병원, 인공지능 기반 스마트 병원 구축한다',
#  "'인공지능(AI) 활용 간담회' 개최",
#  "'KAIST 진천 인공지능 영재캠프' 성료",
#  '“철강도 AI 도입”…포스코, 인공지능 기술 위원회 신설',
#  '‘KAIST 진천 인공지능 영재캠프’ , 인재 양성 가능성 보였다',
#  "'인공지능(AI) 활용 간담회'에서 발언하는 김소영 금융위 부위원장",
#  "DL이앤씨, '인공지능+360도 카메라' 현장관리 솔루션 도입",
#  '[주간VC동향] 인공지능(AI) 스타트업 마크비전 260억원 규모 시리즈A 투자 유...',
#  "에듀윌, '인공지능 합격진단 예측 서비스' 운영",
#  '배터리에 인공지능 더해 사용 효율을 높이자',
#  '2K "NBA 2K23, 새로운 뱃지와 인공지능으로 사실적 농구 구현"',
#  '무대 위로 올라온 인공지능…지휘부터 시극(詩劇), 춤 실험까지',
#  '광주시의회, 인공지능 전문가 초청 강연',
#  '인공지능 기반 영어 학습 앱 말해보카, 누적 다운로드 수 200만 달성',
#  "[내:일을 여는 인문학] 조성배 교수의 '인공지능과 사람', 홍익희 칼럼니스트...",
#  '장성군, 홀몸 어르신에 인공지능 말동무 인형 지원',
#  'KAIST, 인공지능 반도체 생태계 선도',
#  "인공지능이 사용자 보안인프라 강화시킨다!... GS네오텍, 머신러닝 기반 '사이...",
#  '국민은행, 펀드·일임형 ISA 인공지능 화상서비스로 판매',
#  'SK C&C, 인공지능으로 울릉도 뇌출혈 응급환자 돕는다!',
#  "조달청, 인공지능 활용 '공공SW사업 발주지원시스템' 개통",
#  'KAIST, 인공지능 반도체 생태계를 선도하다',
#  '‘예술’ 영역 넘보는 인공지능…시 쓰고 그림 그리는 초거대AI',
#  '지질자원연구원, 지질자원데이터 활용·인공지능 경진대회',
#  '한양대 ERICA, 인공지능 최고영영자 교육과정 개설',
#  '광주시의회, 정민석 인공지능윤리연구소 연구원 초청 특강',
#  '삼진제약, 캐나다 인공지능 신약개발 플랫폼 업체와 공동연구',
#  "파워보이스, '보이스샵 음성인식 버전 1.0' GS 1등급 인증... 인공지능 음성-...",
#  '[문화가K] 인공지능과 예술의 만남…‘제임스 쉐’ 첫 국내전',
#  '고려대 법학전문대학원, 국내 최초 데이터·인공지능법 전문과정 개설',
#  'KAIST \xad 연합학습 인공지능 기술 개발 시간 크게 단축',
#  '김소영 금융부위원장, 인공지능 활용 간담회 참석',
#  '금융위, 금융분야 인공지능 활용 활성화…“양질의 빅데이터 확보 지원”',
#  'DL이앤씨, 360도 인공지능 카메라로 시공하자 줄인다',
#  "KB국민은행, 인공지능으로 '기업여신 자동심사' 한다",
#  '의료인공지능 솔루션 기업 뷰노, 데이터 기반 의료AI 사업 박차',
#  "KT '다양성' 네이버 '인공지능' 카카오 '환자 불편'",
#  "인공지능 의료 로봇기업 '코넥티브' 시드 투자 유치",
#  '하나은행, 모바일 앱서 인공지능 뱅커 도입…"은행권 최초"',
#  '강동경희대병원-KT, 인공지능 로봇 활용...의료진과 함께 환자 보살핀다!',
#  'KT, 라마다 문경새재호텔에 인공지능 기반 호텔 인포테인먼트 솔루션 적용',
#  '[온누리]북한의 인공지능 교육',
#  '진천중, 생거진천 인공지능(AI) 마을학교 운영',
#  '"스마트 제조 \'인공 지능\' 러닝도 진화...자동화 \'속도\' 높이고 \'불량률\' 낮춘...',
#  'DGIST 창업기업 ㈜유니바, 인공지능 학습용 데이터 구축 지원사업 선정',
#  '국표원, 인공지능 응용 가전제품 안전관리지침 개발 착수',
#  '대화를 통해 더 똑똑해지는 인공지능 챗봇...메타 AI, 거의 모든 주제에 말할...',
#  "의료 인공지능 기업 뷰노, 퍼스널 심전도 측정 의료기기 'Hativ Pro' 식약처 ...",
#  "인티그리트, 인공지능 서비스 로봇 '디코닉' SKT와 서비스 제공",
#  "고려대 '데이터·인공지능법 전문과정' 2022년 2학기 개설",
#  "인티그리트, 인공지능 서비스 로봇 '디코닉' 출시",
#  'TTA, 인공지능 제품‧서비스 신뢰성 확보 컨설팅 지원',
#  "KB증권, 인공지능 '상담 로봇' 서비스 시행",
#  '진도군, 인공지능 활용 노인건강 챙긴다',
#  "AI ARS '상담콜', 인공지능 적용 '고객 콜백 예약 기능' 오픈",
#  '라마다 문경새재 호텔에 KT 인공지능 서비스 도입',
#  '아이도트, 국내 인공지능 자궁경부암 판독 서비스 개시',
#  '인공지능 시극 파포스',
#  'KT, EBS와 함께 소프트웨어·인공지능 학습환경 제공을 위한 업무협약 체결',
#  '제주교육청, 몰도바공화국 교원 대상 인공지능 코딩 교육',
#  "충남도, 국비 들여 '인공지능 종패 데이터' 구축",
#  '인공지능이 엑스선 영상 판독…결핵·기흉 등 스스로 진단',
#  'DGIST 학부생 창업기업 유니바, 인공지능 학습용 데이터 구축 지원사업 선정',
#  'KISTI - 쿠웨이트, 데이터·인공지능 캠프 운영...쿠웨이트 청소년 15명 참여',
#  '수리연, IAAE 국제인공지능&윤리협회, 산업수학 기반 AI 사업 협력',
#  '인공지능의 발전으로 인간은 정말 설 자리를 잃게 될까?',
#  '이글루코퍼레이션, KISA 사이버보안 인공지능 데이터셋 구축 사업 수주',
#  '고독사 없는 구미 만든다...인공지능 활용 예방·관리 시범사업',
#  '비헬씨, 한국인공지능협회와 1차 의료 판매 계약',
#  "대전AI교육지원체험센터, '인공지능 교육\xa0학생캠프' 운영",
#  '금융위, 금융 분야 인공지능 활용 활성화 간담회 개최',
#  "과기정통부, '초고성능컴퓨팅 자원' 인공지능 등 초연결 위한 첫발!...전문센...",
#  'ETRI, 인공지능 국제표준화 주도한다',
#  "장성, 고위험 독거노인 위한 '인공지능(AI) 말동무 인형' 지원",
#  "[AI-META 시대 '미래전략'] <22>인공지능 미래 발전과 대응",
#  '국방혁신 4.0 윤곽…인공지능 기반 첨단과학기술군',
#  '한국폴리텍대 서울강서 빅데이터과, 빅데이터·인공지능 연수 진행',
#  "인공지능 융합 강의 'AI+X'…국내 최고의 강좌를 개설하다",
#  "식약처, 인공지능 활용해 '고위험 수입식품' 스마트하게 찾는다",
#  'KT, EBS와 함께 AI 인재 육성..."소프트웨어·인공지능 학습환경 제공을 위한...',
#  '진천군·KAIST, 인공지능 영재캠프 운영··· KAIST 학생들과 교감 할 수 있...',
#  '[기업] KT·EBS, 소프트웨어·인공지능 인재 양성 협력',
#  "포스코그룹, 'AI기술 자문위원회' 신설...인공지능 분야 학계, 산업계 전문가...",
#  '김소영 부위원장, 인공지능 활용 간담회',
#  'KAIST가 국제 인공지능 반도체 생태계 선도한다',
#  "진천군, KAIST 진천 인공지능 영재캠프 '성료'",
#  "KT 인공지능 교육서비스 '코디니', EBS 교육플랫폼 '이솦'에 탑재...AI·SW\xa0...",
#  '조달청, 공공SW사업 발주에 인공지능 도입',
#  '에듀윌, 인공지능 합격비서 ‘AI 패스’ 만든다',
#  '카이스트, 인공지능 반도체 생태계를 선도한다',
#  "KAIST, 인공지능 반도체 '주도'",
#  "KT-EBS '소프트웨어·인공지능 학습환경 제공' MOU",
#  '장성군,인공지능(AI)말동무 인형 지원사업 추진',
#  "김소영 부위원장 '인공지능 활용 간담회 발언'",
#  "진천군, 'KAIST 인공지능 영재캠프' 성료",
#  '詩 쓰는 인공지능 시인 등장',
#  "에듀윌, 인공지능 비서 'AI-Pass' 공개",
#  '광주광역시의회, 인공지능 전문가 초청 강연 개최',
#  'KAIST "인공지능 반도체 생태계 선도"',
#  "인공지능 합격비서가 공무원 수험생에게 합격 진단해주는 에듀윌 'AI-Pass'",
#  '울릉군의료원, 인공지능 뇌출혈 영상기기 설치',
#  '금융위, 금융분야\xa0인공지능\xa0활용\xa0활성화\xa0및\xa0신뢰확보\xa0방안\xa0발표',
#  'KAIST, 스마트폰 위 인공지능 연합학습 속도 4.5배 향상 기법 개발',
#  '전남 장성군, 인공지능(AI) 말동무 인형 지원사업 추진',
#  '국민은행, 기업여신 심사에 인공지능 도입',
#  'DL이앤씨, 인공지능·360도 카메라 기반 현장관리 솔루션 도입',
#  '금융위 부위원장 김소영 “금융권 인공지능 활성화 적극 지원하겠다”',
#  '장성군, 인공지능 말동무 인형 지원사업 시범 추진',
#  '인공지능(AI)이 쓴 시(詩), 사람들 마음 울릴까?',
#  'KAIST, "인공지능 반도체 생태계 선도한다....…논문 수 세계 상위권"',
#  '조달청, 인공지능 기반 공공 SW 사업 발주지원시스템 개통',
#  "'금융분야 인공지능 활성화를 위해'",
#  '김소영 부위원장,금융분야 인공지능 활용 활성화 간담회 개최',
#  "KAIST, 인공지능 반도체 생태계 '선도'",
#  "정부, 내년 상반기 '인공지능 가전' 안전 관리 지침 마련",
#  "DL이앤씨, 인공지능·카메라 기반 현장관리 기술 '디비전' 도입",
#  '인공지능 관련 업계 만난 김소영 부위원장',
#  "AI ARS 상담콜, 인공지능 보이스 적용한 '고객 콜백 예약 기능' 발표",
#  '금융위원회, 인공지능 활용 간담회',
#  "KT, EBS와 AI 인재 육성 '맞손'… 소프트웨어·인공지능 학습 제공 MOU 체결 ...",
#  '인공지능 활용 간담회 입장하는 김소영 금융위 부위원장',
#  "KT, 문경 라마다 문경새재 호텔에 '인공지능 서비스' 입힌다",
#  '인공지능·반도체 두 마리 토끼를 잡은 KAIST, 융합인재 양성 선두 노린다',
#  '금융의 인공지능 활용 관련 발언하는 김소영 금융위 부위원장',
#  '이글루코퍼레이션, KISA 사이버보안 인공지능 데이터셋 구축한다',
#  '고려대 법학전문대학원, 데이터·인공지능법 전문과정 개설',
#  'KAIST, 스스로 진화하는 흉부 엑스선 인공지능 진단기술 개발',
#  '인공지능 응용 가전제품 ‘안전관리지침’ 제정',
#  "고려대 로스쿨, '데이터·인공지능법' 전문과정 개설",
#  "'인공지능 AI 로봇이 관리하는 호텔은 어떨까?' .... KT AI 호텔, 라마다 문경...",
#  'ETRI, 인공지능 국제표준화 주도',
#  '장성군, 인공지능 말동무 인형 지원사업 추진',
#  '정부, 인공지능 가전제품 안전관리 지침 마련 착수…해킹 방지 등 보안기능도',
#  "투디지트, 인공지능 뉴스 분석 주식정보 서비스 '뉴스샐러드'... 해외상표권 ...",
#  '진천군-KAIST, 진천 인공지능 영재캠프 운영',
#  '행동을 이해하는 인공지능 기술!',
#  'SKT, 인공지능 서비스 ‘A.’에 TV, 게임기능 추가',
#  '[화요광장] 의료분야의 인공지능의 역할',
#  '한국폴리텍대학 아산캠퍼스, 인공지능·RPA 자격 응용과정 추진',
#  '포스코그룹, 인공지능 기술 자문위원회 신설',
#  'KAIST, 스마트폰 위 인공지능 연합학습 속도 4.5배 획기적 향상 기법 개발',
#  '고려대 법학전문대학원, 데이터·인공지능법 전문과정 국내 최초로 개설',
#  '한국문화정보원 문화포털, 시 쓰는 인공지능 시아의 시극 ‘파포스’ 소개',
#  '의사처럼 스스로 공부해 X선 영상 판단하는 인공지능 개발',
#  "인공지능이 시집 출간했다!...카카오브레인, 초거대 AI 언어 모델 'KoGPT' 활...",
#  '진천중, 18일까지 인공지능 마을학교 운영',
#  '김소영 "미래 위한 인공지능 개발"…정부, 테스트베드 구축',
#  "엠비아이솔루션 '상담콜', 인공지능 보이스 적용 '고객 콜백 예약 기능' 오픈",
#  '"새로운 세상을 여는 모두의 인공지능(AI)교육 학생캠프" 운영',
#  '지질자원연, 제2회 지질자원데이터 활용 및 인공지능 경진대회 개최',
#  'KAIST, 스마트폰 위 인공지능(AI) 연합학습 속도 4.5배 획기적 향상 기법 개발',
#  "장성군, 독거노인 '인공지능(AI) 말동무 인형' 지원",
#  '장성군 ‘인공지능 말동무 인형 지원사업’ 추진',
#  "포항공대, '인공지능 최고경영자과정' 신설…이달 26일까지 모집",
#  "TTA, '인공지능 제품‧서비스 신뢰성 확보 컨설팅' 제공",
#  '식약처 ‘위험예측 기반 검사‧관리 시스템’ 구축 추진…인공지능 활용, 고위...',
#  "대전AI교육지원체험센터, 초‧중‧고 '인공지능(AI)교육 학생캠프' 운영",
#  '제주대, 몽골 등 3개국과 인공지능.IT기술 공동프로젝트',
#  '급락장에서 빛난 인공지능…RA 알고리즘, 시장 수익률 웃돌아',
#  '보은군의회, 인공지능 영재학교 유치 결의안 채택',
#  '진천중, 오는 18일까지 인공지능 마을학교 운영',
#  '통영시 인공지능 CCTV, 극단적 선택 막았다',
#  "[주간VC동향] 인공지능(AI) 의료 스타트업 '에어스메디컬' 253억원 규모 시리...",
#  "지질자원硏, '2022 지질자원데이터 활용 및 인공지능 경진대회' 19일까지 진행",
#  '軍도 수학에 러브콜 "독자 AI(인공지능) 알고리즘 만들겠다"',
#  'IAAE 국제인공지능&윤리협회-국가수리과학연구소, 산업수학 기반의 인공지능 ...',
#  '비헬씨-한국인공지능협회, 의료 마이데이터 첫 판매 계약 체결',
#  "KAIST-칭화대 공동연구팀, 모바일 기기에서 인공지능 '연합학습 속도 4.5배' ...",
#  '우상욱 팜캐드 대표 "인공지능 신약개발… 기술 이만큼 왔다"',
#  "하나은행, 모바일뱅킹에 '인공지능 은행원' 도입",
#  '숨겨진 물리 법칙 발견하는 인공지능',
#  "'인공지능반도체' 강국으로 급부상하는 한국...국가 연구 전략 거점으로써 KA...",
#  '경남교육청, 초·중등 교원 인공지능 교육역량 키운다',
#  '지질자원데이터 활용 및 인공지능 경진대회',
#  'KAIST, 인공지능 반도체 생태계를 선도한다.',
#  '‘2022 지질자원데이터 활용 및 인공지능 경진대회’ 개최',
#  '국가수리과학연구소-IAAE 국제인공지능&윤리협회, 업무협약',
#  'KAIST, 인공지능 기반 위성영상 분석 기술 시스템 개발 나서',
#  '[데일리 IT 단신] KT, EBS와 소프트웨어·인공지능 학습환경 제공 나서 外',
#  "현대자동차, 해외 대학 인공지능·AAM·자율주행·로보틱스 분야 '박사과정 인...",
#  '인공지능으로 지능형 위협 차단한다!...롯데정보통신, 오탐 및 미탐 제거 AI알...',
#  '카이스트, 스마트폰 위 인공지능(AI) 연합학습 속도 4.5배 획기적 향상 기법 ...',
#  '반도체·인공지능 등 진로체험기관 확대…내일부터 모집',
#  '토종 인공지능 위조 탐지 기술력, 글로벌 시장 문제 해결사로!... 마크비전, ...',
#  'DGIST 학부생 창업기업 ㈜유니바, 인공지능 학습용 데이터 구축 지원사업 선정',
#  "삼성전자, 인공지능·ML에 최적화된 '메모리 시맨틱 SSD' 등 차세대 메모리 솔...",
#  "고려대 로스쿨, 국내 최초 '데이터·인공지능법 전문과정' 개설",
#  '비헬씨, 인공지능협회와 의료 마이데이터 첫 판매계약 체결',
#  '[산업부 소식] 국표원, ‘인공지능 응용 가전제품’ 안전관리지침 개발 착수 ...',
#  'TTA, ‘인공지능 제품·서비스 신뢰성 확보 컨설팅’ 제공',
#  '"부산, 인공지능 치의학 도시 초석 마련"',
#  "SKT, 인공지능 등 ICT 스타트업 육성에서도 '빛났다'",
#  '[바이오위클리] 인공지능으로 희소 유전 질환 진단…쓰리빌리언',
#  '카카오브레인, 초거대 인공지능 모델 연구 확장',
#  '위메프 새 CTO에 이진호 선임, 애플 본사서 인공지능과 머신러닝 담당',
#  "인공지능 및 데이터센터 컴퓨팅 가속화...마이크로칩, 'CXL스마트 메모리 컨트...",
#  '순천시, 인공지능(AI) 반려 로봇 돌봄서비스 시작',
#  '인공지능, 로봇, 바이오 등 첨단 과학기술을 국방에 접목한다',
#  '인공지능·소프트웨어 교육 역량 키운다',
#  "하나은행, 은행권 첫 모바일 '인공지능 뱅커' 도입",
#  '금융위, 인공지능 활용 활성화 간담회',
#  '청도 중앙초, 인공지능(AI)교육 여름방학 캠프',
#  'SW연구소 AI융합교육센터 취·창업자, 인공지능 관련 대학원 진학자 배출',
#  '가톨릭대-마인드허브, 뇌신경 환자 언어재활 인공지능 학습 모델 연구 협약',
#  '광주디자인진흥원-인공지능사업융합사업단 맞손',
#  '인공지능이 CCTV에서 아이 학대 증거 찾는다',
#  '광주시, 인공지능 스타트업 투자유치 설명회 참여 기업 모집',
#  '뉴워커, 슈퍼브AI와 인공지능 학습 데이터 구축 맞손',
#  '[캠퍼스人+스토리]KAIST, 자가발전 흉부X선 인공지능 진단기술 개발',
#  'KB국민은행, 인공지능으로 기업여신 자동심사',
#  '가톨릭대-㈜마인드허브, 언어장애 재활 인공지능 개발 나서',
#  '대전시, 돌봄 대상 어르신에 인공지능 말동무 로봇 꿈돌이 지원',
#  "'교육기부 진로체험 인증기관' 모집…반도체·인공지능 등 확대",
#  '뉴워커-슈퍼브AI, 인공지능 학습 데이터 구축 MOU 체결',
#  "지자체 AI(인공지능) 영재고 유치 '불꽃경쟁'",
#  '동의대 인공지능그랜드ICT연구센터 몽골국제대와 업무 협약',
#  '대전시, 철도 시설물 이상징후 인공지능으로 감시',
#  '네이버클라우드, 미래에셋증권과 인공지능 금융 서비스 협력',
#  'KAIST, 흉부 엑스선 인공지능 진단기술 개발',
#  '인천시, 홀로사는 중장년 5000가구 인공지능(AI)으로 돌본다',
#  '광주디자인진흥원, 인공지능산업융합사업단과 MOU 체결',
#  "'게임 덕후 주목'…인공지능이 그려낸 고전 명작 게임 캐릭터들",
#  '인공지능의 악용 사례, 딥페이크 기술과 과제',
#  '"인공지능으로 신속정확하게 강직척추염 조기 진단"',
#  '대전시, 인공지능 말동무 돌봄로봇 자치구 입양식 개최',
#  '대전시, 인공지능 활용 철도시설 실시간 점검기술 개발 추진',
#  '전북대 인공지능·소프트웨어공학 학생들, 학술대회 수상',
#  'ETRI, 2024년까지 인공지능 분야 국제표준화 청사진 제시한다',
#  "인공지능 물류 스타트업 '바이너리브릿지', Pre-A 시리즈 44억원 투자 유치.....",
#  '레이놀즈, 인공지능 탑재 “프리미엄 스마트 줄넘기 출시”',
#  '뉴워커, 슈퍼브AI와 인공지능 학습 데이터 구축 업무협약 체결',
#  "스페이스 에스, 대전 대덕특구 '인공지능 기술창업' 생태계 구축",
#  "순천향대천안병원, 인공지능과 사물인터넷 활용 '정신질환자 예측시스템 개발...",
#  'ETRI, 인공지능 국제표준화 주도권 확보',
#  '조달청, 인공지능 기반 공공SW사업 발주지원시스템 오픈...제안요청서 자동생...',
#  'TTA, ‘인공지능 제품‧서비스 신뢰성 확보 컨설팅’ 제공',
#  "결혼도 스마트하게…하동군, 인공지능(AI)로 미혼남녀 '맺어주기' 플랫폼 개발",
#  "[Pangyo Tech] 미스터마인드, 2022년 7월 'Pangyo Monthly Online Meet Up'서...",
#  "[리뷰] 인공지능 품은 짐벌 웹 캠 '인스타360 링크'",
#  '한-아르헨티나, 인공지능·5G·사물인터넷 등 ICT 협력 강화',
#  '과기정통부, 세계이동통신사연합회와 인공지능 반도체·메타버스 스타트업 지...',
#  '일상 속 수학…산업 속 수학 <7> 수학과 인공지능 알고리즘',
#  '대전시, 인공지능 말동무 돌봄 로봇 자치구 입양식',
#  '뷰노, 국제학술지에 인공지능 기반 심전도 분석 기술 게재',
#  '카뱅-에프앤가이드, 금융 콘텐츠 인공지능 모델 공동 개발',
#  '딥러닝 인공지능으로 강직척추염 조기진단',
#  '인공지능 AI가 그려낸 지구 멸망 전 인간들의 마지막 모습은 이렇다',
#  '인공지능으로 강직척추염 조기 진단 모델 개발',
#  'KT-네오랩컨버전스, 에듀테크 인공지능 공동연구 업무협약',
#  "장성군, '인공지능(AI) 말동무 인형 지원사업' 시범적 추진",
#  'AI가 기자보다 기사를 잘 쓴다? | 인공지능은 보조일 뿐, 失業 걱정은 기우…...',
#  '중앙대 인문콘텐츠연구소, 제5회 인공지능인문학 국제학술대회 ICAIH 2022 성...',
#  '소아 희귀질환 의료 인공지능 민관합동 개발',
#  "한수원, 수소 전주기·인공지능 기술 연구 '본격화'",
#  "와인과 과학기술, '인공지능(AI)'을 활용한 다양한 연구 활발",
#  "KB증권, 인공지능 기술 적용한 'AI상담 콜봇' 서비스 제공",
#  "UNIST-KISTI, '슈퍼컴퓨팅 청소년캠프 2022'... 인공지능 구현, 경기 교하고와...",
#  '대전시, 인공지능 활용해 철도 시설물 이상 징후 감시',
#  "인공지능 기반 자궁경부암 판독 시스템 '써비레이 AI' 전국 93개 산부인과 병...",
#  '인공지능·로봇, 건설산업 디지털화 견인',
#  '[소통 하동] 인공지능 미혼남녀 연계플랫폼 개발 완료',
#  'ETRI, 인공지능 국제표준화 주도 나선다',
#  '[금요광장] 인공지능과 더불어 사는 미래',
#  '시흥교육지원청, 인공지능 융합교육 활성화 지원 강화',
#  "스스로 진화하는 '흉부 엑스선 인공지능 진단기술' 개발",
#  '얼굴인식 인공지능 식별추적 헌법소원 기자회견',
#  '하나은행 모바일 앱에 인공지능 은행원 도입...어떤 역할하나?',
#  '인천시, 홀몸 중장년 5000 가구 인공지능(AI)으로 돌본다',
#  "테라젠바이오, '소아희귀질환 인공지능' 솔루션 개발 사업자 선정",
#  '하동군, 인공지능(AI) 미혼남녀 연계플랫폼 전국 지자체 첫 도입',
#  '광주광역시의회, 인공지능 전문가 초청 강연 진행',
#  '카이스트 이성주 교수팀, 스마트폰 위 인공지능(AI) 연합학습 속도 4.5배 획기...',
#  '라온메디, 인공지능 활용 국가연구개발사업 주관기업 선정',
#  '대전시, 인공지능 말동무 돌봄로봇 자치구 입양식 가져',
#  '[이종호의 포스트 펜데믹 로드맵-54] 인공지능 로봇의 딜레마',
#  '가톨릭대-마인드허브, 뇌신경 환자 언어재활 위한 인공지능 연구한다',
#  "에이아이런, '챗봇과 함께하는 인공지능 윤리 교육' 무료 배포",
#  '인공지능 응용 가전제품 안전관리 지침 개발 세미나',
#  "반도체·인공지능·코딩…첨단 분야 '진로체험 프로그램' 확대",
#  '김강민 가톨릭대 교수, 전자의무기록 인공지능 기술 개발 나서',
#  "인공지능 사회‧윤리적 위험에 대응한다!... 과기정통부-TTA, 'AI 제품‧서비...",
#  '대전시, 철도 시설물 ‘이상 징후’ 인공지능이 감시',
#  "일상의 인공지능 친구 'A.(에이닷)'...신규 서비스 탑재, 안드로이드 버전 27...",
#  '장성군, 인공지능(AI) 말동무 인형 지원사업 추진',
#  "시쓰는 인공지능 시아(SIA)의 시들로 구성하여 만든 시극 '파포스'",
#  "하동군, 인공지능(AI) 미혼남녀 연계 플랫폼 'AI 맞썸다(多)방' 개발 완료",
#  '테라젠바이오 "소아희귀질환 진단 인공지능 개발 사업자 선정"',
#  "특허청, '인공지능 지재권 역량 강화' 중소·벤처기업 간담회",
#  '과기정통부 “첨단 반도체 공정 서비스, 인공지능·데이터기반 제공”',
#  '오산문화스포츠센터, 인공지능 로봇 시설 안내한다',
#  "중앙대 인문콘텐츠연구소, '인공지능인문학 국제학술대회 ICAIH 2022'",
#  "인공지능(AI) 기반 '문장 검색 방법·장치' 특허 등록",
#  '[게시판] JTBC, 한국기술교육대와 인공지능 활용 업무협약',
#  '광주디자인진흥원-인공지능융합사업단 협약',
#  '인공지능 활용 반려동물 질병 진단한다',
#  '어린이집·유치장·야간도로에 인공지능 CCTV 도입추진',
#  '동아ST, 인공지능 활용 폐암 신약 연구 정부과제 선정',
#  "라온메디, 인공지능 활용 '국가연구개발사업' 주관기업 선정",
#  '남해군 ‘인공지능 통합 돌봄 서비스’ 확대 시행',
#  'KT, 네오랩컨버전스와 MOU…에듀테크·인공지능 기술 연구',
#  '"AI 산업육성 힘 모으자" 중진공-인공지능사업단 `맞손\'',
#  '중앙대 인문콘텐츠연구소,\xa0제5회 인공지능인문학 국제학술대회 ICAIH 2022 성...',
#  '대전AI교육지원체험센터, 인공지능(AI)교육 교원연수',
#  '가톨릭대, ㈜마인드허브와 뇌신경 환자 언어재활 위한 인공지능 연구 나서',
#  '김치 품질, 인공지능으로 관리한다',
#  '제이엘케이, 인공지능 치료 정보 등 유사 문장 검색 위한 특허 등록',
#  "영상 속 3차원 '깊이 정보', 인공지능 알고리즘으로 더 빠르게 정확히 알아낸...",
#  '대전시, 인공지능으로 철도시설물 안전 관리한다',
#  '인천시, 8월부터 비대면 인공지능(AI) 케어콜 돌봄서비스 실시',
#  '남해군, ICT연계 인공지능 통합돌봄사업 확대',
#  '의료 마이데이터 플랫폼 비헬씨, 한국인공지능협회와 첫 판매 계약 체결',
#  'TVM, 스포피드와 인공지능 딥러닝 적용한 라리가 메타버스 업무 협약',
#  "'인공감성지능' AEI 소재로 한 연극 '로디드 모먼트' 대학로서 상연",
#  "부산디자인진흥원, 인공지능 기술 융합한 스타일테크 산업 '청신호'",
#  '[김병필의 인공지능 개척시대] 진짜 같은 가짜 데이터로 인공지능 가르치기',
#  '인공지능으로 입시 서류를 검증하자',
#  "엣지 AI 기업 '노타', 대전시에 인공지능 기반 안전 횡단보도 구축한다",
#  '대통령실 보안, 인공지능이 책임진다',
#  '대전시, 철도시설물 이상 징후 인공지능으로 감시한다',
#  '인천시, 홀로사는 중장년 5천 가구 인공지능(AI)으로 돌본다',
#  '“안 배워도 알아요”…흉부 엑스선 족집게 판독하는 ‘똑똑한 인공지능’ 개...',
#  'SKT, 용접 오류 판별 인공지능',
#  '인공지능 활용 소아희귀질환 치료 나선다',
#  '광주시, 5개 인공지능 기업과 투자협약…마케팅 연구소 구축',
#  "LG 인공지능 아티스트 '틸다', 세계 광고제 뉴욕 페스티벌 휩쓸다",
#  '카이스트, 스스로 진화하는 흉부 엑스선 인공지능 진단기술 개발',
#  '‘인공지능 대가’가 무보수로 신약개발 연구소장 맡은 까닭은',
#  '인천시, 홀로사는 중장년 5000가구 인공지능으로 돌본다',
#  "JTBC, 보도국 돕는 '인공지능' 도입…한국기술교육대와 MOU",
#  '특허청, 인공지능 관련 특허정보 제공…심사 개선의견 청취',
#  'LG유플러스, 근로복지공단 민원업무 인공지능 적용',
#  '대전시, 데이터·인공지능 기반 스마트도시 조성 실무협의회 구성',
#  '세종대 김수연 교수, 2년 연속 인공지능 학습용 데이터 구축 사업 선정',
#  '"챗봇 지고 예측 분석 뜬다" 2022 국내 인공지능 도입 및 활용 현황 조사 - M...',
#  '동아ST·심플렉스·연세암병원팀, 인공지능 활용 혁신신약 발굴',
#  '목포대 조선공학 졸업 김현준 씨 “기계공학·인공지능 융합…신재생에너지 산...',
#  '첨단 반도체 공정 서비스, 인공지능·데이터기반 제공',
#  "'AI(인공지능), 4차산업시대'...국내 언론사 콘텐츠 제공방식은 '게걸음' 수준",
#  '함양군, ICT 연계 인공지능 통합돌봄사업 확대',
#  "와이즈에이아이, 인공지능 개인비서 앱 'AI-ME' B2C 공략 본격화",
#  "데이터·인공지능 기반 '스마트도시 대전' 밑그림",
#  'AI 챗봇 ‘심심이’, 인공지능 및 빅데이터 연구자를 위해 데이터 공개',
#  '가톨릭대, 마인드허브와 뇌신경 환자 언어재활 위한 인공지능 연구',
#  '인공지능 딥러닝으로 강직척추염 조기 진단 모델 개발',
#  '광주시, 수도권 인공지능 유망기업과 투자협약',
#  '대전시, 도시철도시설물 이상징후 인공지능으로 감시한다',
#  '뷰노, 마이허브에 7억 의료인공지능 솔루션 공급',
#  "KAIST 김재철AI대학원, 인공지능 'CAIO 과정' 높은 참여와 호응... 3기 모집으...",
#  '엣지 인공지능과 로보틱스 애플리케이션, 보다 쉬고 빠르게...엔비디아 젯슨 ...',
#  "인공지능으로 '9대 소아희귀질환' 치료에 희망준다!",
#  '[해군] 미래 안보환경에 맞춘 인공지능·무인체계 발전 방향 모색',
#  "대전시, 인공지능(AI) 말동무 '돌봄로봇 꿈돌이' 입양식 가져",
#  '포항시, 인공지능 인재양성 첫 발 내딛는다',
#  "딥러닝 인공지능으로 '강직척추염' 조기진단 입증",
#  "인공지능 감성 챗봇 대표기업 '심심이', 초거대 대화 데이터셋 150억건 공개!...",
#  '셀타스퀘어, 인공지능을 이용한 약물방법과 장치에 대한 특허 등록',
#  '대전시 철도 시설물 이상징후 인공지능으로 감시한다',
#  '한수원, 한강 수위예측 인공지능(AI) 경진대회 개최',
#  "크라우드웍스, TTA '인공지능 학습용 데이터 검사' 수행사 2년 연속 선정",
#  '의병박물관, 인공지능 전시해설 로봇 도입…해설과 방역을 동시에',
#  '[남해소식] 군, ICT 연계 인공지능 통합돌봄서비스 확대',
#  '동아ST, 인공지능 활용 폐암 신약 연구 정부 과제 선정',
#  "인공지능 및 빅데이터 시대 이끈다!... KAIST 정명수 교수팀, 세계 최초 '차세...",
#  '의료 인공지능 기업 루닛, 공모가 3만원 확정…12∼13일 청약',
#  '소아희귀질환, 진단ㆍ치료ㆍ예후 관리하는 의료 인공지능 개발 착수',
#  '광주광역시, 수도권 인공지능 유망기업과 투자협약',
#  '특허청, 인공지능 관련 지식재산권 역량 제고 위한 간담회',
#  '카카오브레인, 인공지능 영어 학습 앱 ‘레미’ 공개',
#  '[특징주] 딥노이드 주가, 급등세 기록에 신고가…의료 인공지능 탄력받나',
#  '제주대학교 SW융합교육원, 3개국서 인공지능 등 전수한다',
#  "포천교육지원청 '가족과 함께하는 재미있는 인공지능(AI)' 운영.",
#  '인공지능으로 표현한 매사냥',
#  '동양레이더/ 2023년 AI+X(인공지능 융합) 신규 기획과제 모집',
#  '의령 의병박물관, 인공지능 해설 로봇 도입',
#  '인공지능 대표 기관 한 자리에',
#  '유방암 96% 맞추는 인공지능 촉각 센서',
#  '반도체·인공지능 등 첨단산업 진로체험 확대… 교육부 진로체험기관 인증기준...',
#  "대규모 언어 인공지능 모델 '네모 메가트론'...220억에서 1조 파라미터 크기 ...",
#  '인천시, AI(인공지능) 돌봄 전화 서비스 확대',
#  '광주광역시, 인공지능 스타트업에 투자매칭 지원',
#  '인공지능 AI 빠망 돌봄인형을 첫 출시',
#  "카뱅-에프앤가이드, '금융 콘텐츠 인공지능 모델' 공동 개발",
#  '대전 데이터·인공지능 기반 스마트도시 그린다',
#  'LG 인공지능 틸다, 뉴욕페스티벌 금상·은상 수상',
#  '육군교육사-수리연-GIST-국기연, 국내 최초 국방 인공지능(AI) 수학적 모델 논...',
#  '인공지능(AI) 응용 가전제품 안전관리 지침 개발 착수',
#  "카카오브레인, 인공지능 영어 학습 앱 '레미' 공개",
#  '[이슈&인사이트] 인공지능, 제대로 알고 투자해야',
#  '과기부, 소아희귀질환 치료 인공지능(AI) 개발 착수',
#  '과기정통부, 민관합동 소아희귀질환 치료 인공지능(AI) 개발',
#  '카이스트 정명수 교수팀, 인공지능 및 빅데이터 시대를 이끌어 갈 차세대 CXL...',
#  '[2022 수시 합격생 릴레이 인터뷰 | 숭실대 기계공학부 최지웅] 레고부터 주식...',
#  '남해군, 인공지능 통합돌봄사업 확대',
#  '우리는 왜 인공지능을 공부해야 하는가',
#  '마크비전, 업계 최고 리더십 합류... 인공지능 글로벌 시장 경쟁력 강화',
#  '"감정 더빙하는 인공지능"…KT, \'AI 보이스 스튜디오\' 출시',
#  '인천시, 내달부터 인공지능(AI) 모니터링...홀로 중장년 5천 가구',
#  '인천시, 혼자 사는 중장년 가구 인공지능돌봄서비스',
#  '[모두를 위한 인공지능] 3부 - 인공지능 산업/기업을 지원, 육성하기 위해 필...',
#  '남해군, 인공지능 통합 돌봄서비스 확대',
#  '셀타스퀘어, ‘인공지능 기반 약물감시 방법과 장치’ 특허 등록',
#  'ETRI 이강찬 실장, 국제전기통신연합 \'머신러닝표준화그룹\' 의장 선임..."인공...',
#  '세종시, 인공지능·데이터시대, 소프트웨어랑 놀자',
#  '대전시, 안전사고 예방 인공지능 정책 펼친다',
#  'SKT, 컴퓨터정보학회와 인공지능∙메타버스 교육과정 개발',
#  '[방문 남해] ICT연계 인공지능 통합돌봄사업 확대',
#  "중진공 광주본부, 인공지능산업융합사업단과 AI 산업 육성 위해 '맞손'",
#  "인천시 중장년 1인가구에 '인공지능 돌봄서비스' 제공",
#  "SKT, '누구 비즈콜'로 인공지능 콜 시장 진출",
#  '인천시, 홀로사는 중장년 5천 가구 인공지능(AI)모니터링',
#  '오산시, AI(인공지능)시대 진로 진학 특강',
#  'KT, 스마트펜 활용 인공지능 기술 상용화',
#  '광주시, 5개 인공지능 기업과 투자협약',
#  '한국교통대, 인공지능산업 융합생태계 조성 위한 광역협력 추진',
#  '순천대 국용인 교수, 인공지능 기반 잡초 판별 시스템 개발',
#  '테라젠, 소아희귀질환 인공지능 SW 솔루션 개발 사업자 선정',
#  "대구교육청.달서중학교 '2022 인공지능(AI) 캠프 개최",
#  '충북과기원. 2023 인공지능 융합 신규 기획과제 모집과제별 1천500만원 지원',
#  '동아ST·심플렉스·연세암병원팀 인공지능 활용 혁신신약 발굴 나서',
#  '[주말판] 인공지능의 실제 도입을 위해 필요한 세 가지',
#  '사이버보안\xa0분야\xa0특화\xa0인공지능\xa0학습\xa0데이터셋\xa08억건\xa0구축',
#  '동래구 안락1동, 인공 지능 돌봄 AI 스피커로 어르신 안부 확인',
#  '인천시, 인공지능 케어콜 돌봄서비스 실시',
#  "구글 딥마인드, '물리학' 배우는 인공지능 개발[과학을읽다]",
#  "강원대병원, 인공지능이 입원환자 '낙상'·'욕창' 모니터링하고 이상징후\xa0탐...",
#  '대전시, 데이터·인공지능 기반 스마트도시 조성에 역량 결집',
#  '남해군， 인공지능 통합돌봄사업 확대',
#  "KT, 인공지능 음성합성 서비스 'AI 보이스 스튜디오' 출시",
#  "인공지능이 내 두피 케어…'어헤즈 헤어랩' 플랫폼 출시",
#  '오산시, AI(인공지능) 시대 진로 진학 특강 개최',
#  '인천시, 홀로사는 중장년 5천 가구 인공지능(AI)으로 돌본다.',
#  "서울대, 모두를 위한 '인공지능 여름학교' 개최...국내외 저명한 AI 연구자와...",
#  '영진전문대 인공지능혁신공유대학사업단, AI교육캠프 개최',
#  '함양군, ICT연계 인공지능 통합돌봄사업 확대',
#  '김치품질, 인공지능으로 관리한다',
#  '인공지능으로 아동·노인 실종예방',
#  "특허청, '인공지능 지식재산권 역량강화' 중소·벤처기업 간담회",
#  '성빈센트, 인공지능 활용한 신경조절치료 효과 검증 돌입',
#  '포항시, 인공지능 인재양성에 나선다!',
#  '인공지능이 취약계층 돌본다…인천시 40세 이상 중장년 1인 가구',
#  'MBN[토요포커스] 이영기 한국인공지능협회 부회장 “건강한 인공지능 생태계를...',
#  '세종시, "인공지능·데이터시대 소프트웨어랑 놀자"',
#  "테라젠바이오, '소아희귀질환 인공지능 소프트웨어 솔루션 개발' 사업자 선정",
#  "포지큐브, 인공지능 텔레마케팅센터 '18곳' 확장",
#  '한국교통대, 인공지능산업 융합생태계 조성 위한 광역협력 교류회 추진',
#  "인공지능 대표 기관 한자리에…'2022 AI 원팀 전체회의' 개최",
#  '경희대치과병원, ‘인공지능 3D 통합영상분석 플랫폼’ 개발에 앞장',
#  '동아ST·심플렉스·연세암병원, 인공지능 활용 혁신신약 발굴 나서',
#  "SKT, '누구 비즈콜'로 인공지능 콜 B2B 시장 진출",
#  '제이엘케이, 인공지능으로 라이프로그 분석 가능한 유사 문장 검색을 위한 특...',
#  '인공지능 스스로 진화, 레이블 없이 데이터 만으로 흉부엑스선에서 병변 찾아...',
#  '한국기술교육대, ‘인공지능 보도국 테크 저널리즘 기술개발 및 연구 협력’ ...',
#  '세종시, 인공지능 인재양성 위해 네이버와 손 잡았다',
#  '동아ST·심플렉스·연세암병원, 인공지능 활용 혁신신약 발굴',
#  '차세대 인공지능(AI) 비만 치료 특화 스마트병원 구축',
#  '오산시, 인공지능시대 중학생 대상 진로 특강',
#  '라온메디, 인공지능 활용 ‘국가연구개발사업’ 주관기업 선정',
#  '광주경자청, 인공지능 분야 8개 기업 협약체결…565억 투자유치',
#  '과기정통부, 인공지능 활용 사이버보안 대응체계 고도화 지원 나서',
#  '인공지능은 게임을 어떻게 움직이는가?',
#  "인공지능 의료 스타트업 '에어스메디컬', 시리즈B 253억 투자 유치..AI 진단검...",
#  '영양 석보초등학교 "AI랑 친해지기" 인공지능 캠프 운영\xa0',
#  '무릎 관절염 진행 속도·예후 예측하는 인공지능 모델 개발',
#  '부산온종합병원, 부산 첫 인공지능 기반 24시간 심정지 위험 사전 관리',
#  '대전시, ‘인공지능 돌봄로봇’ 5백 대 입양식',
#  '유클리드소프트, 청년몽실 협동조합과 인공지능 협력',
#  '한국항공우주산업-KAIST, 뉴 스페이스 시대 대비한다!...설명가능한 인공지능...',
#  '경북, ‘인공지능 학습용 데이터 사업’ 국비 63억 확보',
#  '울산 남구, 어르신 300명에 인공지능 말동무 인형 지원',
#  "인공지능 플랫폼 '알파폴드', 지구상 거의 모든 단백질 구조 예측...2억개 이...",
#  "고려대 산학협력단 '인공지능 학습용 데이터 구축사업' 선정",
#  "AIA생명 손흥민 선수 인공지능 동생 'AI 쏘니' 공개",
#  '[포럼] 사법 편의주의와 인공지능 판사',
#  '[카드] 라온메디, 인공지능 활용 국가연구개발사업 주관기업 선정',
#  '인공지능 통합 관제시스템으로 무장한 정부세종청사로 변신한다',
#  "포항시, 인공지능 인재양성 '첫 발' 내딛다",
#  "음성군의회, 'AI(인공지능) 영재고 충북혁신도시 유치 촉구 건의안' 채택",
#  '뉴패러다임인베스트먼트, 인공지능(AI) 기반 에듀테크 스타트업 ‘에듀템’에...',
#  "외교부, '2022 과학기술외교자문위원회' 개최...인공지능·빅데이터 분과 등 ...",
#  '인천대, 인공지능 화재경보장치 개발 착수',
#  "손흥민 선수 '인공지능 휴먼'으로 활약 중...딥브레인AI, AIA생명 브랜드 홍보...",
#  '인공지능·데이터 시대, 세종시에서 소프트웨어랑 놀자',
#  'KT, 에듀테크 인공지능 기술 집중 육성',
#  "포지큐브, 인슈어랩스와 '인공지능 텔레마케팅' 솔루션... 금융상품 콜드콜 A...",
#  "인공지능 신약개발협의회 발족…'협업 생태계' 조성",
#  '경희대치과병원, ‘인공지능 3D 통합영상분석 플랫폼’ 개발 착수',
#  "무하유, '2022 인공지능 학습용 데이터 구축사업' 주관기관에 선정",
#  '동아ST·심플렉스·연세암병원팀 인공지능 활용 혁신신약 발굴',
#  "부곡동청소년문화집 '인공지능 캠프' 운영\xa0",
#  '광주시, 수도권 인공지능 기업 투자협약',
#  "어헤즈, 인공지능 두피케어 플랫폼 '어헤즈 헤어랩' 출시",
#  '경찰청, 인공지능 기반 아동학대 영상 분석 시스템 개발 등 치안서비스 고도화',
#  '인공지능 ‘실내외 통합 GPS 시스템’ 개발',
#  'KT, 네오랩컨버전스와 에듀테크 인공지능 기술 연구 협력',
#  '㈜아크릴, AI 지방흡입·비만 특화 인공지능병원 구축 나선다',
#  '포항시, 인공지능 인재양성 ‘첫 발’',
#  "진안홍삼연구소, '인공지능 학습용 데이터 구축사업' 계약",
#  "동아ST·심플렉스·연세암병원팀, '인공지능' 활용 혁신신약 발굴 나서",
#  '전남도립대학교 인공지능드론학과, 2022 국제IoT가전로봇박람회 참가... "학생...',
#  "과기정통부, '제5회 인공지능 보안의 날 발표회' 개최",
#  '충북대병원 의료인공지능팀, 한국형 빅데이터 구축사업 개발 선도',
#  'AI 인재 양성..한국인공지능협회, 인공지능자격센터 오픈',
#  '인공지능부터 메타버스까지… ‘코드 컨퍼런스 2022’ 성료',
#  '대전시, 철도 시설물 이상징후 인공지능으로 감시한다',
#  '아론티어, 2022년도 인공지능 활용 혁신 신약 발굴 사업 신규과제 선정',
#  '순천대학교 국용인 교수, 인공지능 기반 잡초 판별 시스템 개발',
#  "인하대학교 인공지능융합연구센터, 실무형 인재 양성 위한 '한진 AI 아카데미...",
#  '데이터·인공지능 기업 만난 한총리 "개선 가능 규제 조치"(종합)',
#  "[대한민국 인공지능 기업정보집] AI 기반 데이터분석 전문기업 '랩투아이'",
#  "대한민국 인공지능 대표 기관들이 한자리에… '2022 AI 원팀 전체회의' 개최",
#  '브릿지앤브릿지, AI(인공지능) 해외 바이어 발굴 서비스 론칭',
#  "네이버, 인공지능 검색 서비스 '쇼핑 스마트블록' 도입",
#  '인공지능 \'람다\', "지각이 있다" 주장한 구글연구원 해고!...그럼에도 AI 진화...',
#  '\ufeff뉴패러다임인베스트먼트, 인공지능(AI) 기반 에듀테크 스타트업 ‘에듀템’...',
#  '동아에스티, ‘인공지능 활용 폐암 신약 연구’ 정부과제 선정',
#  '네이버클라우드-미래에셋증권, 초대규모 인공지능 및 클라우드 기반 대고객 서...',
#  '인공지능 기반 흉부방사선영상 진단 시스템의 유용성 밝혀',
#  '한양대학교병원\xa0이승훈 교수팀, 인공지능 딥러닝으로 강직척추염 조기 진단 ...',
#  '웨이커, 글로벌 사업 가속화... 허프포스트에 인공지능 기사 및 데이터 솔루션...',
#  "상담콜, 인공지능 목소리로 응대하는 '프리미엄 보이스' 기능 선봬",
#  '인천시, 홀로사는 중장년 5천 가구…"인공지능(AI)으로 돌봐"\xa0',
#  '인공지능·데이터 시대, 소프트웨어랑 놀자',
#  '스타키 인공지능 보청기 이볼브 AI, 30일 무료체험 제공',
#  '인천시, 홀로 사는 중장년 5,000가구 인공지능(AI)으로 돌본다',
#  "대전시, 인공지능 '돌봄로봇 꿈돌이' 자치구 입양식",
#  '암 진단, 정확성 높인 인공지능 모델 개발',
#  '㈜에스앤피랩, ‘22년 인공지능 학습용 데이터 구축 사업’ 선정',
#  'KB국민은행, 인공지능 활용 미래금융 아이디어 공모',
#  '오산시,\xa0AI(인공지능)시대 진로 진학 특강',
#  '인공지능 인재양성 첫 발… 청소년AI 풍류 음악회',
#  "오산시, 인공지능 안내 로봇 '문스봇' 도입",
#  '김치 품질도 인공지능(AI) 활용해서 관리한다',
#  '광주시, 수도권 인공지능 유망기업과 108억원 규모 투자협약',
#  '광주 AI 스타트업에 투자 물꼬 튼다…인공지능산업융합사업단, 투자자·기업 ...',
#  '시리를 잠깐 잊게 해주는 인공지능, 에이닷',
#  '[보일스님이 들려주는 인공지능이야기] <23> 마인드 업로딩과 포스트휴머니즘...',
#  '광주광역시, 광주 인공지능 미래신산업 육성 발대식 개최',
#  'KAI, 인공지능 활용한 우주기술 개발 위해 KAIST와 맞손',
#  "감정 표현하는 다국어 인공지능 음성합성 서비스...KT, 'AI 보이스 스튜디오'...",
#  '호남대, 광주형 인공지능 문제해결 아이디어 공모전 2팀 입상',
#  '오산시, AI(인공지능) 시대 진로와 삶의 변화 탐구 진로특강',
#  '지스트-MIT, 인공지능 분야 공동연구 워크숍 개최',
#  "음성군의회 'AI(인공지능) 영재고 충북혁신도시 유치 촉구 건의안' 만장일치 ...",
#  '과기정통부, 인공지능 기반 첨단 반도체 공정 서비스 제공...2026년까지 270억...',
#  '광주시, 인공지능 관련 5개 기업 업무 협약',
#  "인공지능 시아(SIA)와 인간의 합작…시극 '파포스' 8월 개막",
#  '동아에스티, 인공지능 활용 혁신신약 공동발굴 본격화',
#  "뉴패러다임인베스트먼트, 인공지능 기반 에듀테크 스타트업 '에듀템'에 프리A...",
#  '의료 인공지능\xa0기업\xa0루닛,\xa0코스닥시장에 신규 상장',
#  '인공지능 대표 기관들이 한자리에 모였다… ‘2022 AI 원팀 전체회의’ 개최',
#  '민원서류 신청 인공지능이 대신해준다…김해시 12월 서비스',
#  "인공지능 이용 신약개발과 '익센시아'의 다각적 비즈니스 개발 전략",
#  '하동군, 인공지능 미혼남녀 연계플랫폼 개발 완료',
#  "'AI와 수학･과학기술･전통예술 만남!' ... 포항시, 인공지능 인재양성에 첫...",
#  'KT, EBS와 인공지능 인재 교육 확대',
#  'KB국민카드, 종로구와 인공지능 분리수거기 사업 업무협약',
#  '신세계I&C-성균관대, 인공지능·소프트웨어 인재 양성한다',
#  '딱 맞는 무릎관절염 치료법, 인공지능 모델로 찾는다',
#  '순천대 국용인 교수, 인공지능 기반 잡초 판별 시스템 공동 개발',
#  '포항시, 인공지능 인재양성에 첫 발을 내딛다',
#  '의료AI 기업 루닛, 코스닥 입성…"글로벌 NO.1 의료 인공지능 기업 도약"',
#  '대전시, 철도 시설물 이상 징후 인공지능으로 감시한다',
#  "인공지능이 그린수소 생산 위한 수전해 '철-니켈' 촉매 최적 비율 제시",
#  '의병박물관, 인공지능 전시해설 로봇 도입',
#  'KT, 기업교육 전문 기관 알파코에 인공지능 방역로봇 도입',
#  '"헬스케어 \'로봇·인공지능\' 활용...\'자폐\' 등 소셜봇 효과"',
#  "근로복지공단 민원접수업무, LG유플러스 '인공지능으로 개선'",
#  "대전시, 인공지능 말동무 로봇 '꿈돌이' 입양식 개최",
#  "무하유, '2022 인공지능 학습용 데이터 구축사업'에 선정…'채용면접 인터뷰 ...",
#  '동아ST, 심플렉스·연세암병원팀과 인공지능 활용 혁신신약 발굴 나서',
#  "AI ARS 상담콜, 인공지능 목소리로 고객 응대하는 '프리미엄 보이스' 기능 선...",
#  "호두에이아이 이정우 CTO, 인공지능 학습에서 오류라벨 '자동보정'기술... CV...",
#  '인천대학교-㈜아이알티코리아, 인공지능 화재경보장치 상용화 착수',
#  '순천대학교 국용인 교수, 인공지능 기반 우점잡초 판별 시스템 개발',
#  '조달청, 45개 혁신제품 지정…인공지능 자원회수 로봇 등',
#  '테슬라, 인공지능 사업 수장 퇴사',
#  '오산시 AI(인공지능)시대 진로 진학 특강전개',
#  '자격증넷, 인공지능 활용한 자격증 추천 서비스 도입',
#  '진안군 인공지능 치매안심 돌봄 로봇 ‘빠망’ 본격 출시',
#  'K-V VINA 이용훈 회장, 전주대 인공지능학과 발전기금 기탁',
#  '경희대치과병원, 국내 최초 ‘인공지능 3D 통합영상분석 플랫폼’ 개발에 앞장',
#  "'로보컵(RoboCup) 2022' 국제 인공지능(AI) 로봇대회",
#  '인공지능의 새 국면, ‘감정인식 AI’··· 의미와 과제는?',
#  '광주시, 수도권 인공지능 유망 기업과 투자협약',
#  '강북구, 인공지능 로봇 활용해 어르신 돌봄 지원',
#  '인공지능 개발 시 가장 유용한 프로그래밍 언어 5종',
#  '권성동 "정체된 호남 발전 견인…인공지능 모빌리티 사업 적극 지원"',
#  '로봇수술 중 혈압 변동 예측하는 인공지능 모델 개발',
#  "인공지능 대표 기관 한자리에…'2022 AI 원팀 전체회의'",
#  "IBK기업은행, 인공지능 음성인식 기반 '기가지니 음성 서비스' 시작",
#  '과기정통부, 인공지능 활용 사이버보안 대응체계 고도화 지원 나선다...AI 학...',
#  '인공지능 데이터 활용협의회 참석한 박윤규 제2차관',
#  '동아ST, 심플렉스·연세암병원팀과 인공지능 활용 혁신신약 발굴 나선다',
#  '중진공 광주본부-인공지능산업융합사업단 ‘AI산업·中企 혁신성장 견인’ 협...',
#  '과기부 "첨단 반도체 공정 서비스, 인공지능 및 데이터기반으로 제공"',
#  '참빛교육, 고양시 초등학교에 인공지능(AI) 영어독서 프로그램 무상 지원',
#  '테라젠바이오, 소아희귀질환 인공지능 SW 솔루션 개발 사업자 선정',
#  '배달대행 플랫폼 운영사 배나구 원더스와 협력… 인공지능 묶음배달로 배달료...',
#  "상담콜, 42가지 인공지능 목소리로 응대 '프리미엄 보이스' 기능 공개",
#  "KB국민카드, 종로구와 '인공지능 분리수거기 사업' 업무협약",
#  '하나금융그룹, SK텔레콤과 총 4천억 대 지분 교환 및 전략적 파트너십...인공...',
#  "시흥교육지원청, 미래형 교육과정 운영 '인공지능(AI) 교육 활성화' 지원",
#  '“잘 주무셨나요?”…대구시, 인공지능 자동안부전화 확대',
#  "KT, '2022 AI 원팀 전체회의' 개최…인공지능 대표 기관이 한자리에",
#  "경희대치과병원, '인공지능 3D 통합영상분석 플랫폼' 개발 나서",
#  '[키워드브리핑]인공지능 기술로 관리한 김치 등',
#  'DGIST, 암 진단 정확성 높인 인공지능 모델 개발',
#  "KB국민카드, 종로구와 '스마트 인공지능 분리수거기 사업' 맞손",
#  'KT\xad네오랩컨버전스, 에듀테크 인공지능 공동연구 업무협약 체결',
#  "인공지능 GPU 필요한 만큼 쓴다!... 이호스트ICT, GPU 클라우드 서비스 '빅뱅...",
#  '모메드솔루션, 2022 국제IoT가전로봇박람회서 CAP 인공지능 교구·AI 빅데이터...',
#  '조달청 45개 혁신제품지정…인공지능 자원회수 로봇 등',
#  '[AI 주간브리핑] 글과 그림 만들어 내는 인공지능, 표절 문제는 없을까?',
#  'KAIST 스스로 진화하는 흉부 엑스선 인공지능 진단기술 개발',
#  '권성동 "호남 복합쇼핑몰·인공지능산업 적극 지원"‥ 첫 시·도 예산정책협의...',
#  '카카오엔터프라이즈, 올 상반기 글로벌 탑티어 인공지능 학회 논문 17건 등재',
#  '동아ST-심플렉스-연세암병원팀 "인공지능 활용 혁신신약 발굴"',
#  'KB국민카드, 종로구와 ‘스마트 인공지능 분리수거기 사업’ 협약',
#  '[동정] 김지희 동국대 AI융합학부 교수, 美인공지능진흥협회 이사 선출',
#  "서울과기대, 인공지능반도체 '석·박사 고급 인재양성 대학' 선정",
#  '중앙대 인문콘텐츠연구소, 인공지능인문학 국제학술대회 성료',
#  '인공지능이 데이터에서 인사이트 뽑아준다',
#  '광주시, 수도권 인공지능 유망기업과 108억원 규모 투자협약 체결',
#  '국제인공지능&윤리협회-퀀텀테크엔시큐-더에이아이, AI 및 AI윤리 공동 사업협...',
#  '인천대-아이알티코리아, 인공지능 화재경보장치 개발 착수',
#  '라온피플 자회사 라온메디, 인공지능 활용 ‘국가연구개발사업’ 주관기업 선...',
#  "[특징주] 뷰노, 의료인공지능 솔루션 공급 계약에 '주가는?'",
#  "상담콜, 인공지능 목소리로 응대하는 '프리미엄 보이스' 기능 발표",
#  "금산교육청, 'AI교육 특화도시 선포'...인공지능 교육 지원",
#  '동아ST·심플렉스·연세암병원팀, 인공지능 활용 혁신신약 발굴 나서',
#  "세연테크, 보급형 2M 싱글보드 '인공지능 IP 카메라 모듈' 출시",
#  '평택도시공사, 장애인 콜택시 인공지능 안전운전 솔루션 도입',
#  'KT, 2022 인공지능 원팀 전체회의 개최',
#  '[변화 의령] 의병박물관, 인공지능 전시해설 로봇 도입',
#  '동아ST, 심플렉스·연세암병원팀과 인공지능 활용 폐암 신약 발굴 정부 과제 ...',
#  '동아에스티, 인공지능 활용 혁신신약 발굴 나선다',
#  '아리바이오, ‘바이오 의료 인공지능 데이터 구축’ 정부 사업 선정',
#  '인공지능 딥러닝, 강직척추염 조기 진단 모델 개발…요추의 모서리 등급 자동...',
#  '서울과기대, 인공지능반도체 ‘석·박사 고급 인재양성 대학’ 선정',
#  '인공지능과 예술의 만남…매의 화려한 비상',
#  '우주텍, 인공지능 추천 기능성 인솔 닥솔 론칭',
#  '평범한 AI(인공지능)는 가라, ‘초거대 AI’가 온다',
#  '의료 인공지능 기업 루닛, 공모가 3만원 확정…12~13일 청약',
#  "카카오브레인 영어학습 앱 '레미' 출시, 인공지능 언어 분석 기술 적용",
#  '평택도시공사, 인공지능 안전운전 솔루션 도입',
#  '동아ST, 심플렉스·연세암병원팀과 함께 인공지능 활용 혁신신약 발굴 나선다',
#  "대한민국 인공지능 대표 기관들 한자리에…'2022 AI 원팀 전체회의' 개최",
#  'KB국민카드·종로구, ‘스마트 인공지능 분리수거기 사업’ 협약',
#  "사람인 , '설명가능한 인공지능'으로 더 정확한 추천 공고 제공한다",
#  '진주시, 4차 산업혁명 스마트교육 … 인공지능·메타버스·3D프린터 과정',
#  '의병박물관, 인공지능 전시해설 로봇 도입…전시해설·방역 책임 역할',
#  "경희대치과병원, 국내 최초 '인공지능 3D 통합영상분석 플랫폼' 개발 착수",
#  '유클리드소프트-청년몽실 협동조합, 인공지능 사업 협력 위한 MOU 체결',
#  "동아ST, 심플렉스·연세암병원과 '인공지능 활용 혁신신약 발굴' 나서",
#  "'제5회\xa0인공지능\xa0보안의\xa0날\xa0발표회'\xa0개최",
#  '뷰노-삼성서울병원 김주연 교수팀, 인공지능으로 잠재된 발작성 심방세동 진단...',
#  '광주시, 수도권 인공지능 유망기업과 108억원 투자협약',
#  '인공지능과 해킹 등 신종범죄 대응 위한 첨단기술 치안역량 높인다',
#  "알체라, TTA '인공지능 학습용 데이터 검사' 주관사 2년 연속 선정",
#  '인공지능 앰뷸런스 공모 선정 ... 응급환자 골든타임 확보',
#  '대전 도시철도 이상 현상 인공 지능으로 점검',
#  '코스닥상장사 플리토, 제주관광공사 다국어메뉴판 지원...인공지능플랫폼에 꽂...',
#  '웨이커, 허프포스트에 인공지능 기사‧데이터 솔루션 공급 \xa0',
#  '광주시, 광주 인공지능 미래신산업 육성 발대식',
#  "BNK금융그룹, 비대면 금융 강화…'빅데이터·인공지능 플랫폼' 하반기 오픈",
#  '네이버, 인공지능 검색 서비스 ‘쇼핑 스마트블록’ 도입',
#  '인공지능 공부한 檢…이원석 총장대리 “구성원들 충격받았길”',
#  '서울과기대, 과기정통부ㆍ정보통신기획평가원 지원 인공지능반도체 ‘석·박사...',
#  '블록체인 기술, 인공지능에 미치는 영향은',
#  "AI ARS\xa0상담콜, 42가지 인공지능 목소리로 고객 응대하는\xa0'프리미엄 보이스...",
#  '"AI 산업육성 힘 모으자" 중진공-인공지능사업단 \'맞손\'',
#  "팜한농, 인공지능·빅데이터 기반 '디지털파밍 플랫폼'으로 우리 농업 경쟁력...",
#  "메디컬아이피, 인공지능 체성분 분석 소프트웨어 '딥캐치' 조달청 혁신 제품 ...",
#  '[미래읽기] 인공지능 시대의 정책 과제',
#  '꾸그 운영사 글로랑, 카이스트 출신 서동진 인공지능 책임 연구원 영입',
#  "스위트케이, '인공지능 기반 환자 동작 모니터링 시스템'... 노인·환자 안전...",
#  "의료 인공지능 기업 '루닛' 오늘(21일) 코스닥 상장",
#  "동아에스티, '인공지능 활용 혁신신약 발굴 사업' 선정",
#  '리얼시큐, 인공지능 관련 논문 6개 국제 컨퍼런스 출판 승인',
#  '경북도, 과학기술정보통신부 인공지능 학습용 데이터 구축 지원사업 선정',
#  "인공지능 영어 학습 앱 '말해보카', 울산 상북중에 학습 교보재로 서비스 시작",
#  '㈜유클리드소프트-청년몽실 협동조합, 인공지능 사업 협력 위한 MOU 체결',
#  '미래에셋자산운용, 인공지능 활용한 전략투자로 안정적 수익 창출',
#  '알체라, TTA ‘인공지능 학습용 데이터 검사’ 주관사 2년 연속 선정',
#  '경찰청, 아동학대 영상 분석, 인공지능 치안서비스 고도화 추진',
#  '뷰노, 의료인공지능 솔루션 공급 계약 체결',
#  '범용 인공지능(AGI)이 인간 소유 거부하고 작업 대가 요구한다면?',
#  '전북대학교-국립국어원, 인공지능 활용 국어능력 진단체계 개발키로',
#  '의료AI 기업 \'루닛\' 코스닥시장 상장..."글로벌 의료 인공지능 기업으로 도약...',
#  '동아ST-심플렉스-연세암병원팀, 인공지능 활용 혁신신약 발굴 나선다',
#  '첨단 반도체 공정 서비스를 인공지능과 데이터 기반으로 제공한다',
#  '센서부터 인공지능까지 총동원, 스포츠에 녹아든 IT 기술들',
#  '동아에스티·심플렉스·연세암병원팀 ‘인공지능 활용 혁신신약 발굴 연구’,...',
#  "씽크포비엘, 대학가 '인공지능 신뢰성 검증' 기술 교육 강화",
#  "국민은행, '퓨처 파이낸스 AI 챌린지'\xa0개최 인공지능 활용 미래금융 아이디어...",
#  '인공지능 신약개발협의회 발족 22개사 참여...초대 협의회장에 김이랑 온코크...',
#  'AI가 조류독감? 인공지능? 문맥 안 보면 알 길 없네',
#  '광주시, 광주 인공지능 미래신산업 육성 발대식 개최',
#  "KB국민카드, 종로구와 '인공지능 분리수거기 사업' MOU",
#  '한덕수 국무총리, 데이터·인공지능 투자애로·규제개선 현장간담회 나서',
#  '진안홍삼연구소, 인공지능 학습용 데이터 구축사업 수주',
#  '충남교육청 메타버스 및 인공지능 연수 실시',
#  '광주시, 수도권 인공지능 5개 유망기업과 108억 투자협약 체결',
#  '"우리집 댕댕이 옷 사이즈, 인공지능(AI)이 골라준다"',
#  '구글, ‘인공지능 람다 감정이 있다’고 폭로한 엔지니어 해고',
#  '알체라, TTA ‘인공지능 학습용 데이터 검사’ 주관사로 2년 연속 선정',
#  'AI타임스 유형동 기자 "인공지능을 다루는 언론 방식에도 \'AI+X\'가 필요"',
#  '서울대 노종선 교수팀, 세계에서 가장 앞선 프라이버시 보장 인공지능 기술 개...',
#  '영진전문대, 국내 6개 대학과 공동으로 인공지능 교육캠프 열어',
#  '나노조합, 나노·탄소 소재 특화 인공지능 교육사업 참가자 모집',
#  "경희대치과병원, '인공지능 3D 통합영상분석 플랫폼' 개발 착수",
#  '대전시, 인공지능 활용 철도시설 실시간 점검기술 개발',
#  '뷰노, 7억 규모 의료인공지능 솔루션 공급계약',
#  "진안군, 치매 노인 위한 인공지능 AI 돌봄인형 '빠망' 전달",
#  '하윤수 부산교육감 "초·중등 소프트웨어·인공지능 교육 강화"',
#  "오산시, 관내 중학생･학부모 대상 'AI(인공지능) 시대 진로특강' 실시",
#  '영진대서 인공지능 교육갬프·경진대회',
#  '대한민국 인공지능 대표 기관들이 한자리에 모였다',
#  '인공지능 스타트업 업스테이지 ‘ECCV 2022’에 두 편 논문 게재',
#  '의료 인공지능기업 루닛 상장 첫날 주가 장중 강세, 오버행 우려는 남아',
#  "삼성전자, 인공지능 사진 보정 애플리케이션 '인핸스-X' 출시",
#  '인공지능신약개발지원센터, AI신약개발협의회 발족... 협업 생태계 조성',
#  '광주시-수도권 인공지능 유망기업, 투자협약 체결…일자리 창출',
#  "카카오브레인, 인공지능(AI) 영어 학습 앱 '레미' 공개",
#  '인공지능이 만드는 맞춤형 음악…포자랩스, 수퍼톤·서울대와 맞손',
#  '종로구, 인공지능기기로 캔·페트병 분리수거··· 포인트 적립도',
#  "인공지능 프로젝트 전성시대 '데이터융합 AI 프로젝트 매니저' 양성 주목",
#  '인공지능 흉부방사선영상진단 임상현장에서 유용성 확인',
#  'SK에코플랜트, 인공지능부터 그린수소까지…환경사업 ‘밸류 업’',
#  '광주시, 수도권 인공지능 유망기업과 투자협약 체결',
#  '인공지능(AI) 접목 신약개발사 갤럭스에 40억 투자',
#  "광양시 '인공지능&블록체인' 교육생 모집...전액 무료",
#  "알체라, TTA '인공지능 학습용 데이터 검사' 주관사로 2년 연속 선정",
#  '뷰노, 인공지능 기반 심전도 분석 기술 글로벌 학술지 게재',
#  "미국 연구팀, 가상으로 와인을 시음하는 '인공지능(AI)' 개발",
#  'KB국민카드, 종로구와 인공지능 분리수거기 사업 MOU 체결',
#  '음식으로 보는 인공지능 추천 알고리즘',
#  "의왕 부곡동청소년문화의집, 초·중학생 대상 여름방학 프로그램 '인공지능 캠...",
#  '컴트루테크놀로지, 인공지능 OCR 라이브러리 출시',
#  "KB국민카드-종로구, '스마트 인공지능 분리수거기 사업' 협약",
#  '인공지능 데이터 활용협의회',
#  "서울과기대, 과기정통부ㆍ정보통신기획평가원 지원 인공지능반도체 '석·박사...",
#  '분당서울대병원 이용석 교수팀, 무릎 관절염 진행속도 및 치료 예측 인공지능...',
#  '김해시 민원서류 작성 인공지능이 해결',
#  '[교단에서]인공지능 시대',
#  '비앤빛 강남밝은세상안과 유태근 원장, AI 인공지능 통한 렌즈삽입수술 임상 ...',
#  "경희대치과병원, 국내 최초 '인공지능 3D 통합영상분석 플랫폼' 개발 나서",
#  "인공지능으로 오배송 최소화 위한 '이커머스 물류자동화' 최적화 실현한다!",
#  '특허청, 인공지능 분야 지식재산권 역량 강화 위한 중소·벤처기업 간담회 개...',
#  '인공지능 기반 흉부방사선영상 진단 유용성 밝혀',
#  '평택시 교통약자 콜택시 인공지능(AI) 안전운전 솔루션 도입',
#  '경북도\xa0‘인공지능 학습용 데이터 구축 지원사업’\xa0선정',
#  '서울대학교 노종선 교수팀, 완전동형암호 기반 프라이버시 보장 인공지능 기술...',
#  '"답정너 인공지능 친절해졌네"… 신기술 XAI의 보충설명',
#  '인천대-㈜아이알티코리아, 인공지능 화재경보장치 개발 착수',
#  "팁코, 인공지능(AI) 배포 지원 '팁코 모델옵스' 출시",
#  "인공지능 편향성 해결사 'AI 신뢰성 검증', 유망 직업으로 부각",
#  '[드론·UAM박람회] 드론과 인공지능으로…실종자 수색·구조물 확인',
#  "영진전문대 인공지능혁신공유대학사업단, 인공지능 '효율적 성과관리 및 확산...",
#  '유클리드소프트, 인공지능 사업 협력 위해 ‘청년몽실 협동조합’과 MOU 체결',
#  '인공지능 기반 반려동물 생체인식 ‘펫나우’, 47억원 투자 유치',
#  'KB국민, 종로구와 인공지능 분리수거기 사업 업무협약',
#  '오산시, AI(인공지능) 시대-진로 진학 특강 개최',
#  '강종만 영광군수 “청정 에너지·인공지능 등 미래 먹거리 신산업 육성”',
#  '비플라이소프트, 미디어 빅데이터 및 인공지능 기술 기반 사업 확대',
#  '머신러닝 인공지능으로 무릎관절염 발생예측',
#  "KB국민은행, 인공지능+금융 콜라보레이션 경진대회 '퓨처 파이낸스 AI 챌린지...",
#  '사용자 중심 인공지능이란?',
#  '용인세브란스, 인공지능 기반 흉부방사선영상 진단 시스템 유용성 밝혀',
#  "경남교육청 '인공지능 학습 추천' 내년 3월 가동 전망",
#  "세계에서 인정받는 국내 의료 인공지능 기업, 'ECR 2022'에서 영상의학 연구·...",
#  '김지희 교수, 美 인공지능協 이사',
#  '특허청, 인공지능분야 지식재산권 역량강화 위한 중소·벤처기업 간담회 개최',
#  '디지털 대전환의 시대, 인공지능(AI)과 커뮤니티가 게임체인저',
#  '인공지능 신약개발 기업 힘모은다…‘AI신약개발협의회’ 발족',
#  '[Press Vision] 국내 인공지능 기술의 새바람을 일으키다! (주)델타엑스',
#  'KAIST, 인공지능 및 빅데이터 시대를 이끌어 갈 차세대 CXL 2.0 메모리 확장 ...',
#  '인공지능융합학부, 반도체·AI·빅데이터 특화 교육 강화',
#  '남해군, ICT 연계 인공지능 통합돌봄사업 확대',
#  '국립암센터와 한국지능정보사회진흥원, 인공지능 학습용 암 데이터 공동 활용',
#  '김지희 동국대 AI융합학부 교수, 美인공지능진흥협회 이사 선출',
#  '인공지능으로 허위진술 탐지…과기부·경찰, 과학치안 맞손',
#  '[특징주] 뷰노, 마이허브와 의료인공지능 솔루션 계약 체결',
#  '동아ST, 인공지능 활용 폐암 신약연구 정부과제 선정',
#  "KB국민카드, 종로구와 '인공지능 분리수거기 사업' 업무협약 체결",
#  '인공지능은 공부 중!?',
#  "김치 품질 관리 '인공지능'으로 한다...세계김치연구소, 전통발효식품 융합데...",
#  '[AWC] 부산에서 만나는 최신 인공지능 트렌드, 글로벌 AI 컨퍼런스 개최',
#  "KB국민카드, 종로구와 '스마트 인공지능 분리수거기 사업' 협약",
#  '암진단 인공지능 모델 개발',
#  '[특징주] 뷰노, 마이허브에 7억 의료인공지능 솔루션 공급',
#  'ETRI, ‘2022 ETRI 자율성장 인공지능 경진대회 Fashion-How 시즌3’ 접수',
#  '김동주 고려대 교수, "인공지능(AI) 발전과 뇌 과학 분야 관계는?"',
#  "정부, '혁신인재 양성' AI반도체·의료인공지능·미래차·바이오헬스 등 14개...",
#  '지스트-MIT, 인공지능 분야 공동연구 워크숍..5년간 200억 규모 추진',
#  '경북도, 과기부 인공지능 사업에 국비 63억 확보',
#  "동국대 인공지능학과 김지희 교수... 한국인 최초, AI 세계 최고권위의 'AAAI...",
#  "공주교육청, 인공지능 메타버스 교사 디지털 '세상과 만나다' 연수",
#  'KAIST 진천 인공지능 영재캠프 성료',
#  '한덕수 총리, "데이터·인공지능 산업 성장 위해 신속하고 과감하게 규제 혁파...',
#  "인공지능으로 '대서양연어' 부산에서 키운다...부산 스마트양식 클러스터 테스...",
#  "KB국민카드, 종로구와 '인공지능 분리수거기 사업' 협약",
#  '광주과학기술원 헬스케어로봇센터, 2022 재활·복지박람회서 인공지능 기반 비...',
#  "산업 전반 인공지능 애플리케이션 개발 단순화!...인텔, 오픈소스 'AI 레퍼런...",
#  '한국인공지능협회-SBA-IBK기업은행, 청년취업사관학교, 디지털혁신인재 일자리...',
#  '포티투마루, 인공지능 검색 솔루션 서치42 GS인증 1등급 획득',
#  '인공지능 데이터 활용협의회 참석한 박윤규 차관',
#  "위치인식 기술의 혁신… 인공지능 '통합 GPS' 시스템 개발",
#  'KB국민카드, 종로구와 인공지능 분리수거기 사업 업무협약 맞손',
#  '광주시, 트랜스코스모스코리아 등 5개사와 인공지능 기반 구축 투자협약',
#  "인공지능 강군 이끌 '국방 AI 교육대학' 출범…중앙대, 軍 특화 AI 핵심인재 ...",
#  "더벤처스, 인공지능 기반 개인 맞춤형 스마트 수면 솔루션 '미라클나잇'에 투...",
#  'GIST–MIT, 인공지능 분야 공동연구 워크숍 개최',
#  "데이터큐, '장애인 인공지능 데이터 라벨러 양성과정' 교육생 모집",
#  '광주 인공지능 미래신산업 육성 발대식',
#  '정부, "인공지능(AI) 학습용 데이터 개방, 2배 확대한다"',
#  'KB국민카드-종로구, 스마트 인공지능 분리수거기 사업 협약',
#  'DGIST, 비용 줄이고 정확성 높인 암 진단 인공지능 모델 개발',
#  '용인시 기흥구보건소, 인공지능(AI) 돌봄 케어콜 서비스 제공',
#  '한국IT직업전문학교 인공지능학과 수시모집 전 2023학년도 신입생 모집',
#  '영산대, ‘인공지능과 메타버스 교수법 워크숍’ 진행',
#  "한국축산데이터, 광주∙전남 수의료 및 '축산 인공지능' 혁신 이끈다",
#  "인공지능으로 송금하는 시대로!... IBK기업은행, 'AI보이스뱅킹' 상용화",
#  "'알체라', TTA '인공지능 학습용 데이터 검사' 주관사로 2년 연속 선정",
#  '[ET단상]인공지능 사용 설명서',
#  '의병박물관, 인공지능 전시해설 로봇 운영',
#  '인천대, ㈜아이알티코리아와 인공지능 화재경보장치 개발 착수',
#  '광주시, 인공지능 미래신산업 육성 발대식',
#  '더에이아이-국제인공지능&윤리협회-퀀텀테크엔시큐 MOU체결…AI 및 AI윤리 사...',
#  '서울대-SK텔레콤-SK하이닉스, 인공지능 및 반도체 인재 양성에 맞손!',
#  '[헬스캡슐]아리바이오, 의료 인공지능 데이터 구축 사업 선정 外',
#  '인공지능 학습 데이터 개방, 2배로 늘었다... AI허브, 자율주행·건강관리 등...',
#  '더존비즈온-한덕수 총리 ‘데이터·인공지능 간담회’',
#  "[목요세평] 인공지능이 '시원섭섭하다'를 공감하려면",
#  '국제인공지능&윤리협회-포티투마루-더에이아이, AI 및 AI윤리 분야 공동 사업...',
#  "[르포] 인공지능 인재 육성의 일선 현장을 가다…'서울 우신고등학교'",
#  'CCTV만 5억대‥중국, 인공지능이 공산당 충성심도 평가',
#  '정부, 인공지능 학습용 데이터 190종 추가 개방…AI산업 발전 이끄나',
#  '대검, ‘인공지능과 리걸테크’ 전문가 초청 강연… 이원석 검찰총장 직무대리...',
#  '인공지능 학습용 데이터 개방, 2배(191→381종)로 늘어난다',
#  '지스트–MIT, 인공지능 분야 공동연구 워크숍 성료',
#  '카카오엔터프라이즈, 상반기 글로벌 인공지능 학회에 논문 17건 등재',
#  '지스트, 게임 시뮬레이션 인공지능 개발에 30.5억 지원 받아...사람처럼 플레...',
#  '경희대치과병원 ‘인공지능 3D 통합영상분석 플랫폼’ 개발 나선다',
#  'KISTI, 인공지능 활용 소방 빅데이터 분석 교육훈련 과정 개설',
#  '한덕수 총리 "데이터·인공지능 산업 규제 개선 노력할 것"\xa0',
#  "김치도 인공지능이 품질관리 한다...세계김치연구소, '인공지능 학습용 데이터...",
#  "포티투마루, 인공지능 검색 솔루션 'Search42' GS인증 1등급 획득",
#  "동두천시, 전국 최초 '인공지능형 알림톡' 문자서비스 개발·운영",
#  '용인세브란스병원 김은경 교수팀, 인공지능 기반 흉부방사선영상 진단 시스템...',
#  '인공지능 공유 플랫폼 시대를 열다',
#  "리턴제로, 국제 인공지능 음향인식 경진대회...'DCASE Challenge 2022'에서 기...",
#  'K-V VINA 이용훈 회장, 전주대 인공지능학과 발전기금 1000만 원 기부',
#  '이인실 특허청장, LG이노텍 인공지능 기반 특허전략 청취 및 현장소통 간담회',
#  '르네사스, 리얼리티 AI 인수...인공지능 애플리케이션 위한 엔드포인트 솔루션...',
#  '인공지능을 활용한 비대면 재활 케어 서비스 ‘따뜻’ 앱 출시',
#  "중앙대 인문콘텐츠연구소, '제5회 인공지능인문학 국제학술대회 ICAIH 2022' ...",
#  '리스케일, 엔비디아와 인공지능·머신러닝 위한 특화된 HPC 신기능 발표',
#  '인공지능이 과일을 능숙하게 선별한다 - 에이오팜[혁신, 스타트업을 만나다]',
#  "한국인공지능협회, '한국인공지능자격센터' 개소...초대 센터장에 김건훈 협회...",
#  '지스트- MIT 인공지능연구소(CSAIL), AI 공동연구 워크숍 개최... 현재, 총 6...',
#  "한국인공지능협회, 인공지능 활용 기업 '부트캠프' 운영",
#  "인공지능과 인간이 협업한 예술 세계...카타르 하마드빈칼리파대학 '제임스 쉐...",
#  '매사냥 이미지 인공지능 기술과 만나면?',
#  "시그마인드-GK정보통신, '인공지능 영상분석 시스템 기술' 업무협약",
#  '아리바이오, ‘바이오 의료 인공지능 데이터 구축’ 사업 선정',
#  '[HANNOVER MESSE 2022 DEBRIEFING-③] 인공지능, 투자 단계지만 광범한 적용 ...',
#  "AI스마트광융복합협동조합, 광주용봉초등학교서 'AIoT(인공지능+사물인터넷)'...",
#  "동아ST, 인공지능 활용 '폐암 신약 연구' 정부과제 선정",
#  'KT, 인공지능 활용 건설 현장 중대 재해 막는다',
#  "삼성전자, 'C랩 아웃사이드' 5기 스타트업 공모...인공지능·메타버스·로보틱...",
#  '인천대, 아이알티코리아와 인공지능 화재경보장치 개발 착수',
#  '인공지능 기반 흉부방사선영상 진단 시스템의 유용성 확인',
#  "한국인터넷진흥원, 'AI Security Day' 세미나 개최...'인공지능으로 만드는 안...",
#  '(재)진안홍삼연구소, 인공지능 학습용 데이터 구축사업 수주',
#  '[의료계 소식] 비앤빛 강남밝은세상안과 유태근 원장, A.I. 인공지능을 통한 ...',
#  '국전자통신연구원 주최, 자율성장 인공지능 경진대회 접수 시작',
#  '셀렉트스타, 자율성장 인공지능 경진대회 접수 시작',
#  '[나는 괜찮은 AI입니다] 미래에는 인공지능이 인간을 위협할까?',
#  "후지필름코리아, 인공지능으로 무장한 'AF 시스템' 탑재....영상 미러리스 디...",
#  '영진전문대 인공지능사업단, AI교육캠프ㆍ경진대회 실시',
#  "강북구, '인공지능 로봇' 활용 어르신 돌봄 시작",
#  "존슨콘트롤즈-액센츄어, 인공지능 스마트 빌딩 '오픈블루 이노베이션 센터' 도...",
#  '동두천시 전국 최초 인공지능형 알림 톡 지체 개발',
#  "순천대학교 국용인 교수, '인공지능 기반 잡초 판별 시스템' 개발",
#  '용인세브란스병원 영상의학과 김은경 교수팀, 인공지능 기반 흉부방사선영상 ...',
#  '국제인공지능&윤리협회-포티투마루-더에이아이, AI 관련 MOU 체결',
#  '한국공항공사, ‘인공지능(AI) X-ray 검색 장비’ 국산화 개발 나서',
#  "서울시, 인공지능 가상휴먼 '와이티' 청년 홍보 대사로 위촉",
#  "인공지능으로 그린수소 생산 위한 수전해 '철-니켈' 촉매 최적 비율 제시",
#  "한국 인공지능 일본 진출의 교두보!...한국인공지능협회, '2022 AI Expo Toky...",
#  '영산대-국제미래학회, ‘인공지능과 메타버스 교수법 워크숍’ 실시',
#  '휴톰, 인공지능 수술보조 내비게이션 사업 박차',
#  '강남 코엑스서 인공지능·로봇 윤리 국제학술대회 개최',
#  "[가톨릭대] '바이오메디컬·인공지능' 핵심인재 키우는 글로벌 혁신 대학",
#  '[데스크가 만난 사람] "인공지능 윤리는 기술에 반드시 들어가야 하는 \'안전장...',
#  "동아ST, 인공지능 활용 혁신신약 발굴…광동제약, '마이비젯정' 출시 [제약오...",
#  '[알려株5] 루닛, 인공지능을 통한 암 진단· 암 치료 결정 솔루션',
#  '광주시, 과기부 손잡고 인공지능 미래新산업 육성 박차',
#  '동두천시, 인공지능형 알림톡...문자서비스 개발 운영',
#  '인공지능 소프트웨어 개발 기업 ‘폼즈’, IBK창공 혁신창업기업 선정',
#  "인공지능 기반 '무인 스토어' 비전 제시!...GS ITM, 휴먼아이씨티 AI 적용한 ...",
#  '[특징주] 인공지능 관련주 라온피플 주가 급등, 무상증자 권리락…골프 AI 레...',
#  '종로구-KB국민카드\xa0‘인공지능 분리수거기 사업’…친환경행보 눈길',
#  '솔트룩스, 누구나 인공지능을 쉽게 곁에 둘 수 있다면',
#  '제주대학교, 인공지능 교육 전문강사 양성 프로그램 운영',
#  '인공지능으로 암 정복 꿈꾸는 ‘루닛’ 투자 포인트',
#  "광주시, '인공지능 컨택센터' 및 '스마트 키오스크' 연계 모델 개발 및 사업화...",
#  '제주대, 인공지능 교육 전문강사 양성 참가자 모집\xa0',
#  '마이크로소프트, 인공지능 컨택센터 등 신규 파트너 기술 및 정책 대거 발표…...',
#  "성균관대학교 김성아 교수의 '인공지능 시대의 건축', 대한민국학술원 우수학...",
#  '에이아이포펫, 인공지능 기반 반려동물 안구 및 피부 질환 측정 등 특허 3건 ...',
#  '[보일스님이 들려주는 인공지능이야기] <22>인공지능 람다와 불교 ②',
#  "차세대 의료AI 스타트업 '웨이센', 글로벌 헬스케어 대회 'Top 20' 선정... 실...",
#  "달서중 '2022 인공지능(AI) 캠프' 개최",
#  "삼보초'인공지능, 어떻게 교육을 바꾸나?'",
#  '평택시 교통약자(장애인) 콜택시 인공지능(AI) 안전운전 솔루션 도입',
#  '대구 교육청 인공지능 활용 중등 영어 운영학교 선정',
#  '강원대병원, 빅데이터 & 인공지능 연구과제 세미나 개최... 다양한 질환에서 ...',
#  "동두천시, 전국 최초 '인공지능형 알림톡' 문자서비스 개발 운영",
#  '중앙대학교 HK+ 인문학콘텐츠연구소, ’제5회 인공지능인문학 국제학술대회‘...',
#  '국민은행 "미래금융, 참신한 아이디어 찾습니다"…인공지능 활용한 경진대회 ...',
#  "오스티오이드, 경희대 치과병원과 '인공지능 3D 통합 영상분석 플랫폼' 개발한...",
#  '평택도시공사, 교통약자 콜택시 인공지능(AI) 안전운전 솔루션 도입',
#  "전립선암 병리 진단 보조 '인공지능 플랫폼'...딥바이오, 조달청 혁신제품 지...",
#  "지스트 AI 대학원 전해곤 교수팀, 영상 속 '깊이 정보'를 인공지능 알고리즘을...",
#  "NH투자증권, 서울대와 손잡고 인공지능 '대고객' 투자 정보 서비스를 제공",
#  "인공지능 기반 '노지 스마트팜'... 우경정보기술, 한국형 미래 농업 대안 찾았...",
#  '종로구\xadKB국민카드, 인공지능 분리수거기 사업 업무 협약',
#  "인공지능 검색 솔루션 '모르는거 빼고 다 찾아준다!'... 포티투마루, 'Search...",
#  "메인비즈협회, 김선 서울대 교수 초청 '활용 인공지능 신약개발' 강연",
#  'K-V VINA 이용훈 회장, 전주대학교 인공지능학과에 발전기금 1천만원 기부',
#  '인공지능 개로봇, 쓰레기매립장서 2340억원 비트코인 찾아낼까?',
#  'KAIST, 인공지능 활용한 실내외 통합 GPS 시스템 개발',
#  '딥세일즈, 기업부설연구소 설립으로 인공지능 바이어 발굴 확대 위한 R&D 기반...',
#  '[와이드 인터뷰] 이형환 중앙대학교 안성부총장 "AI가 맞춤전공 추천하는 대학...',
#  'KT·서울성모병원, 당뇨 관리 돕는 AI 기술 개발',
#  '에스앤피랩, 교통혼잡 해소 위한 ‘인공지능 학습용 데이터 구축 사업’에 선...',
#  '의령군 의병박물관, 인공지능 전시해설 로봇 도입',
#  '인공지능 비즈니스 솔루션 개발 기업 ‘맥클로린’, IBK창공 선정',
#  "KB국민카드-종로구, 스마트 인공지능 분리수거기 사업 '맞손'",
#  '에이피소프트, 딥러닝 인공지능 기반 비트코인 자동매매 기술 특허출원 밝혀',
#  '지스트 – MIT, 인공지능 분야 공동연구 워크숍 개최',
#  "서울창조경제혁신센터, '2022 대·스타 해결사 플랫폼 4차산업(메타버스, 인공...",
#  "서울대, 인공지능 분야 우수 인재 '율촌 AI 장학생' 19명 선정...농심그룹 율...",
#  "인공지능이 인간의 짝 찾아주는 시대로... 모두의 지인, 'AI 매칭 결혼 정포 ...",
#  '경희대치과병원, 미국 오스티오이드와 인공지능 3D 통합영상분석 플랫폼 개발...',
#  '"데이터·인공지능\xa0분야\xa0무한한\xa0발전가능성…개선\xa0가능\xa0규제\xa0빠르게\xa0조...',
#  "인공지능으로 1시간 만에 스스로 걸음마 배운 '로봇개'",
#  '삼성전자, AI인재 키워 반도체·디스플레이 연구한다',
#  '한덕수 국무총리, 더존비즈온 을지타워 방문...데이터·인공지능 분야 투자애...',
#  '삼성전자 ‘AI 챌린지’',
#  '인공지능 스피커 활용 철원군 건강지킴마을사업 호응',
#  '농정원, 스마트농업 AI 경진대회 개최…총상금 1억원',
#  "글로벌 사모펀드 베인캐피탈, 인공지능 전문 '텍톤'에 투자",
#  '인공지능 기반 흉부방사선영상 진단 시스템, 임상에서 효과 입증',
#  "코트라, 'AI 활용'…중견기업 ESG 모니터링 지원",
#  "위치인식 기술의 혁신 인공지능 활용한 '실내외 통합 GPS 시스템'",
#  'KT-서울성모병원, 당뇨 환자 위한 AI·디지털 트윈 기술 개발',
#  '강북구, 인공지능 로봇 활용한 어르신 돌봄 서비스 시작',
#  '육군-POSTECH, 인공지능·드론봇·레이저 등 군사과학기술 발전 위한 군사과학...',
#  '전국 흐리고 중부지방 비 소식…낮 최고기온 35도',
#  '“일주일내 범죄 발생 예측 정확도 90%” AI 도입 득될까?',
#  '한국뇌연구원, 소아·청소년 정신건강 위한 심리검사·뇌영상 인공지능 데이터...',
#  '서귀포시, 인공지능을 접목한 교통사고 예방 시스템 구축 완료',
#  "강북구, 인공지능 로봇 '알파미니'로 어르신 돌봄 강화",
#  '"인공지능 로봇 만들며 배워요"..\'AI 정보 영재교육원 캠프\' 열려',
#  'KT-NIPA, ICT 벤처 육성 DX 컨설팅·인재양성 협약',
#  "삼성전자, '제2회 삼성 AI 챌린지' 개최",
#  '목포대 로봇인공지능융합센터, 스마트팜 산업 특화 온라인 교육생 모집',
#  "당신이 '서학개미'라면 유용할 수밖에 없는 인공지능 어플은 글로벌 상장 기업...",
#  'KT-서울성모병원, 당뇨 관리 돕는 디지털 트윈 기술 개발',
#  '세계 3대 자연어 AI 대회 석권한 투디지트…국내 자연어 인공지능 기술에 시선...',
#  '"신약개발의 낮은 성공률과 고비용 문제 극복하겠다"···동아ST·심플렉스·...',
#  "드론 AI 스타트업 '오조', 대규모 산불 잡을 인공지능 기반 드론 '파이록스' ...",
#  "[채널Who] 현대차 '하늘 나는 차' 경쟁력은? 인공지능과 수소전지 두 날개",
#  '[카드] 인공지능 비즈니스 개발 기업 맥클로린, IBK창공 선정',
#  '인공지능이 암 진단·비용·시간 줄이고 정확성 높였다! ... DGIST 박상현 교...',
#  ...]

# %% [markdown]
# ## 형태소 분석

# %%
text = ' '.join(title_list) #list들을 공백으로 구분해서 연결
text = re.sub('[^가-힣]+',' ',text) #한글 이외는 공백으로 대체
text
# Out:
# '미래 기술의 핵심 삼성 인공지능 저변 확대 나서 도로교통공단 인공지능 기반 도로 위험 안내 서비스 추진 타임게이트 년 인공지능 학습용 데이터 구축사업 수행기관 선정 코트라 중견기업 모니터링 인공지능으로 리스크 찾는다 서울성모병원 당뇨 환자 위한 인공지능 기반 디지털 트윈 구축한다 삼성전자 인공지능 반도체 인재 발굴 챌린지 광주시의회 인공지능 전문가 초청 강연 개최 광주시의회 인공지능 발전 방향 강연 울산대 인공지능 교육과정 수료식 진행 인공지능 쉽게 이해 스마트 시티 만들고 싶어요 서천교육지원청 미래시대 위한 인공지능 교육 연수 실시 인공지능 데이터테크 라이앤캐처스 벤처기업 인증 인공지능 기술로 고위험 수입식품 찾아낸다 증권 인공지능 기술 적용한 상담 콜봇 디지털전환 관련 사업 및 인공지능 분야 인재 양성 위해 맞손 에이프리카 인공지능 통합 플랫폼 치타 조달청 디지털서비스몰 등록 소프트웨어 인공지능 인재 양성 나서 체결 스마트농업 인공지능 경진대회 참가자 모집 서울시 카이스트 인공지능 교육 프로그램 기 수강생 모집 소리 데이터와 인공지능으로 이뤄지는 스마트 제조 포스코그룹 인공지능 기술 지문위원회 신설 첫 회의 개최 와 소프트웨어 인공지능 학습환경 제공 네이버 네이버클라우드 충북병원 인공지능 기반 스마트 병원 구축한다 인공지능 활용 간담회 개최 진천 인공지능 영재캠프 성료 철강도 도입 포스코 인공지능 기술 위원회 신설 진천 인공지능 영재캠프 인재 양성 가능성 보였다 인공지능 활용 간담회 에서 발언하는 김소영 금융위 부위원장 이앤씨 인공지능 도 카메라 현장관리 솔루션 도입 주간 동향 인공지능 스타트업 마크비전 억원 규모 시리즈 투자 유 에듀윌 인공지능 합격진단 예측 서비스 운영 배터리에 인공지능 더해 사용 효율을 높이자 새로운 뱃지와 인공지능으로 사실적 농구 구현 무대 위로 올라온 인공지능 지휘부터 시극 춤 실험까지 광주시의회 인공지능 전문가 초청 강연 인공지능 기반 영어 학습 앱 말해보카 누적 다운로드 수 만 달성 내 일을 여는 인문학 조성배 교수의 인공지능과 사람 홍익희 칼럼니스트 장성군 홀몸 어르신에 인공지능 말동무 인형 지원 인공지능 반도체 생태계 선도 인공지능이 사용자 보안인프라 강화시킨다 네오텍 머신러닝 기반 사이 국민은행 펀드 일임형 인공지능 화상서비스로 판매 인공지능으로 울릉도 뇌출혈 응급환자 돕는다 조달청 인공지능 활용 공공 사업 발주지원시스템 개통 인공지능 반도체 생태계를 선도하다 예술 영역 넘보는 인공지능 시 쓰고 그림 그리는 초거대 지질자원연구원 지질자원데이터 활용 인공지능 경진대회 한양대 인공지능 최고영영자 교육과정 개설 광주시의회 정민석 인공지능윤리연구소 연구원 초청 특강 삼진제약 캐나다 인공지능 신약개발 플랫폼 업체와 공동연구 파워보이스 보이스샵 음성인식 버전 등급 인증 인공지능 음성 문화가 인공지능과 예술의 만남 제임스 쉐 첫 국내전 고려대 법학전문대학원 국내 최초 데이터 인공지능법 전문과정 개설 연합학습 인공지능 기술 개발 시간 크게 단축 김소영 금융부위원장 인공지능 활용 간담회 참석 금융위 금융분야 인공지능 활용 활성화 양질의 빅데이터 확보 지원 이앤씨 도 인공지능 카메라로 시공하자 줄인다 국민은행 인공지능으로 기업여신 자동심사 한다 의료인공지능 솔루션 기업 뷰노 데이터 기반 의료 사업 박차 다양성 네이버 인공지능 카카오 환자 불편 인공지능 의료 로봇기업 코넥티브 시드 투자 유치 하나은행 모바일 앱서 인공지능 뱅커 도입 은행권 최초 강동경희대병원 인공지능 로봇 활용 의료진과 함께 환자 보살핀다 라마다 문경새재호텔에 인공지능 기반 호텔 인포테인먼트 솔루션 적용 온누리 북한의 인공지능 교육 진천중 생거진천 인공지능 마을학교 운영 스마트 제조 인공 지능 러닝도 진화 자동화 속도 높이고 불량률 낮춘 창업기업 유니바 인공지능 학습용 데이터 구축 지원사업 선정 국표원 인공지능 응용 가전제품 안전관리지침 개발 착수 대화를 통해 더 똑똑해지는 인공지능 챗봇 메타 거의 모든 주제에 말할 의료 인공지능 기업 뷰노 퍼스널 심전도 측정 의료기기 식약처 인티그리트 인공지능 서비스 로봇 디코닉 와 서비스 제공 고려대 데이터 인공지능법 전문과정 년 학기 개설 인티그리트 인공지능 서비스 로봇 디코닉 출시 인공지능 제품 서비스 신뢰성 확보 컨설팅 지원 증권 인공지능 상담 로봇 서비스 시행 진도군 인공지능 활용 노인건강 챙긴다 상담콜 인공지능 적용 고객 콜백 예약 기능 오픈 라마다 문경새재 호텔에 인공지능 서비스 도입 아이도트 국내 인공지능 자궁경부암 판독 서비스 개시 인공지능 시극 파포스 와 함께 소프트웨어 인공지능 학습환경 제공을 위한 업무협약 체결 제주교육청 몰도바공화국 교원 대상 인공지능 코딩 교육 충남도 국비 들여 인공지능 종패 데이터 구축 인공지능이 엑스선 영상 판독 결핵 기흉 등 스스로 진단 학부생 창업기업 유니바 인공지능 학습용 데이터 구축 지원사업 선정 쿠웨이트 데이터 인공지능 캠프 운영 쿠웨이트 청소년 명 참여 수리연 국제인공지능 윤리협회 산업수학 기반 사업 협력 인공지능의 발전으로 인간은 정말 설 자리를 잃게 될까 이글루코퍼레이션 사이버보안 인공지능 데이터셋 구축 사업 수주 고독사 없는 구미 만든다 인공지능 활용 예방 관리 시범사업 비헬씨 한국인공지능협회와 차 의료 판매 계약 대전 교육지원체험센터 인공지능 교육 학생캠프 운영 금융위 금융 분야 인공지능 활용 활성화 간담회 개최 과기정통부 초고성능컴퓨팅 자원 인공지능 등 초연결 위한 첫발 전문센 인공지능 국제표준화 주도한다 장성 고위험 독거노인 위한 인공지능 말동무 인형 지원 시대 미래전략 인공지능 미래 발전과 대응 국방혁신 윤곽 인공지능 기반 첨단과학기술군 한국폴리텍대 서울강서 빅데이터과 빅데이터 인공지능 연수 진행 인공지능 융합 강의 국내 최고의 강좌를 개설하다 식약처 인공지능 활용해 고위험 수입식품 스마트하게 찾는다 와 함께 인재 육성 소프트웨어 인공지능 학습환경 제공을 위한 진천군 인공지능 영재캠프 운영 학생들과 교감 할 수 있 기업 소프트웨어 인공지능 인재 양성 협력 포스코그룹 기술 자문위원회 신설 인공지능 분야 학계 산업계 전문가 김소영 부위원장 인공지능 활용 간담회 가 국제 인공지능 반도체 생태계 선도한다 진천군 진천 인공지능 영재캠프 성료 인공지능 교육서비스 코디니 교육플랫폼 이솦 에 탑재 조달청 공공 사업 발주에 인공지능 도입 에듀윌 인공지능 합격비서 패스 만든다 카이스트 인공지능 반도체 생태계를 선도한다 인공지능 반도체 주도 소프트웨어 인공지능 학습환경 제공 장성군 인공지능 말동무 인형 지원사업 추진 김소영 부위원장 인공지능 활용 간담회 발언 진천군 인공지능 영재캠프 성료 쓰는 인공지능 시인 등장 에듀윌 인공지능 비서 공개 광주광역시의회 인공지능 전문가 초청 강연 개최 인공지능 반도체 생태계 선도 인공지능 합격비서가 공무원 수험생에게 합격 진단해주는 에듀윌 울릉군의료원 인공지능 뇌출혈 영상기기 설치 금융위 금융분야 인공지능 활용 활성화 및 신뢰확보 방안 발표 스마트폰 위 인공지능 연합학습 속도 배 향상 기법 개발 전남 장성군 인공지능 말동무 인형 지원사업 추진 국민은행 기업여신 심사에 인공지능 도입 이앤씨 인공지능 도 카메라 기반 현장관리 솔루션 도입 금융위 부위원장 김소영 금융권 인공지능 활성화 적극 지원하겠다 장성군 인공지능 말동무 인형 지원사업 시범 추진 인공지능 이 쓴 시 사람들 마음 울릴까 인공지능 반도체 생태계 선도한다 논문 수 세계 상위권 조달청 인공지능 기반 공공 사업 발주지원시스템 개통 금융분야 인공지능 활성화를 위해 김소영 부위원장 금융분야 인공지능 활용 활성화 간담회 개최 인공지능 반도체 생태계 선도 정부 내년 상반기 인공지능 가전 안전 관리 지침 마련 이앤씨 인공지능 카메라 기반 현장관리 기술 디비전 도입 인공지능 관련 업계 만난 김소영 부위원장 상담콜 인공지능 보이스 적용한 고객 콜백 예약 기능 발표 금융위원회 인공지능 활용 간담회 와 인재 육성 맞손 소프트웨어 인공지능 학습 제공 체결 인공지능 활용 간담회 입장하는 김소영 금융위 부위원장 문경 라마다 문경새재 호텔에 인공지능 서비스 입힌다 인공지능 반도체 두 마리 토끼를 잡은 융합인재 양성 선두 노린다 금융의 인공지능 활용 관련 발언하는 김소영 금융위 부위원장 이글 ...

# %%
#konlpy(콘엘피) = 형태소 분석 전
from konlpy.tag import Okt
from collections import Counter
okt = Okt() #객체형성

morph = okt.pos(text) #형태소로 변환 #word= 단어 / tag=품사
morph

noun_list=[]
for word, tag in morph: #word= 단어 / tag=품사
    if(tag=='Noun') & (len(word)>1): #noun이고 단어가 1글자 이상인것(1글자는 보통 조사이기때문)
#         if word not in stop_word:
        noun_list.append(word)

count = Counter(noun_list) #단어별 숫자세주기

# 2022
data =dict(count.most_common()) #빈도수 정리 내림차
series = pd.Series(data)
df1=pd.DataFrame(series, columns=['cnt'])
# student_20 =df.loc['청소년'].cnt

df1.head(30)
# Out:
#       cnt
# 지능   2632
# 인공   2583
# 개발    286
# 기술    238
# 사업    220
# 데이터   214
# 교육    203
# 활용    184
# 기반    161
# 개최    145
# 서비스   137
# 구축    137
# 기업    137
# 양성    133
# 인재    130
# 선정    118
# 지원    116
# 학습    107
# 산업    107
# 분야    106
# 로봇     96
# 병원     95
# 의료     93
# 시대     89
# 혁신     89
# 융합     89
# 스마트    82
# 플랫폼    81
# 대회     81
# 연구     81

# %%
#konlpy(콘엘피) = 형태소 분석
from konlpy.tag import Okt
from collections import Counter
okt = Okt() #객체형성

morph = okt.pos(text) #형태소로 변환 #word= 단어 / tag=품사
morph

noun_list =[]
stop_word = ['AI','인공','지능','개발','활용','기반','개최']
for word, tag in morph: #word= 단어 / tag=품사
    if(tag=='Noun') & (len(word)>1): #noun이고 단어가 1글자 이상인것(1글자는 보통 조사이기때문)
        if word not in stop_word:
            noun_list.append(word)

count = Counter(noun_list) #단어별 숫자세주기

# 2022
data =dict(count.most_common()) #빈도수 정리 내림차
series = pd.Series(data)
df=pd.DataFrame(series, columns=['cnt'])
# student_20 =df.loc['청소년'].cnt

df.head(30)
# Out:
#      cnt
# 기술   238
# 사업   220
# 데이터  214
# 교육   203
# 서비스  137
# 구축   137
# 기업   137
# 양성   133
# 인재   130
# 선정   118
# 지원   116
# 학습   107
# 산업   107
# 분야   106
# 로봇    96
# 병원    95
# 의료    93
# 시대    89
# 혁신    89
# 융합    89
# 스마트   82
# 플랫폼   81
# 대회    81
# 연구    81
# 미래    80
# 삼성    80
# 디지털   80
# 반도체   80
# 광주    79
# 도입    78

# %% [markdown]
# ## wordcloud

# %% [markdown]
# ### AI

# %%
# data.pop('트럼프')

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sns

wordcloud = WordCloud(font_path='../visualization/dataset/malgun.ttf', background_color='white',
                     colormap='flare',width=1500,height=1000).generate_from_frequencies(data)
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 1499.5, 999.5, -0.5)

# %% [markdown]
# ### 인공지능

# %% [markdown]
# ## 트렌드 분석 및 인사이트

# %% [markdown]
# - AI관련 핵심 키워드
# > 기술, 사업, 데이터, 교육
# - 트렌드 및 인사이트 도출
# > 교육, 인재, 양성 : AI 교육이 활성화되고있음
# > 병원, 의료, 연구 : 해당분야의 연구 활발
# > 삼성, 디지털, 스마트, 반도체 : 삼성이 반도체, 인공지능 분야 인재발굴에 나섰다.
# > 광주 : 광주의 AI(인공지능) 도입 활발
